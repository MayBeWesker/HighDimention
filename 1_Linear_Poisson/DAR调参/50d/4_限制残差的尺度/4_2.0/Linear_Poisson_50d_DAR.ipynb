# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
# Out:
# /tmp/ipykernel_165511/82325636.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:80% !important; }</style>

# %%
import os
import shutil

import numpy as np
import time
from pyDOE import lhs
import matplotlib
import matplotlib.pyplot as plt
import scipy.io
import random

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import ExponentialLR

# %%
import argparse
class Options_PoissonHD:
    def __init__(self):
        parser = argparse.ArgumentParser()
        parser.add_argument('--cuda', default=True, help='if you use cuda')
        
        parser.add_argument('--bot_top', type=tuple, default=(-1, 1), help='a tuple of the form (bot, top)')
        parser.add_argument('--dim', default=50, help='dimension')
        parser.add_argument('--N_r', default=2400, help='num of interior points')
        parser.add_argument('--N_b', default=1200, help='num of boundary points')
        
        parser.add_argument('--backbone_layers', type=list, default=([60]*5), help='list of nn layers of backbone')
        parser.add_argument('--subnet_layers', type=list, default=([80]*4), help='list of nn layers of subnet')
        
        parser.add_argument('--backbone_lr', type=float, default=1e-3, help='initial learning rate of backbone')
        parser.add_argument('--subnet_lr', type=float, default=1e-4, help='initial learning rate of subnet')
        
        parser.add_argument('--gamma', type=float, default=0.95, help='gamma in lr_scheduler for Adam optimizer')
        parser.add_argument('--step_size', type=int, default=2000, help='step_size of lr_scheduler for Adam optimizer')
        
        parser.add_argument('--iters_stage1', type=int, default=0, help='iters for stage 1 used Adam')
        parser.add_argument('--iters_stage2', type=int, default=0, help='iters for stage 2 used Adam')
        parser.add_argument('--iters_stage3', type=int, default=40000, help='iters for stage 3 used Adam')
        parser.add_argument('--iters_stage4', type=int, default=0, help='iters for stage 4 used Adam')
        
        parser.add_argument('--lam_res', type=float, default=1, help='weight of loss_res')
        parser.add_argument('--lam_bcs', type=float, default=1, help='weight of loss_bcs')
        parser.add_argument('--K1', type=int, default=200, help='for stage3, optimize the backbone K1 times every (K1+K2) iters')
        parser.add_argument('--K2', type=int, default=200, help='for stage3, optimize the transformer K2 times every (K1+K2) iters')
        parser.add_argument('--k_scale', type=float, default=2.0, help='the scale of transformer limited residue')
        
        self.parser = parser

    def parse_default(self):
        args = self.parser.parse_args(args=[])
        args.device = torch.device('cuda' if args.cuda else 'cpu')
        
        # 增加网络输入输出层
        args.backbone_layers = [args.dim] + args.backbone_layers + [1]
        args.subnet_layers = [args.dim] + args.subnet_layers + [args.dim]
        return args
    

args = Options_PoissonHD().parse_default()
print(args.cuda)
# Out:
# True

# %%
def save_model(state, is_best=None, save_dir=None):
    last_model = os.path.join(save_dir, 'last_model.pth')
    torch.save(state, last_model)
    if is_best:
        best_model = os.path.join(save_dir, 'best_model.pth')
        shutil.copyfile(last_model, best_model)

def seed_torch(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed) # 为了禁止hash随机化，使得实验可复现
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed) # if you are using multi-GPU.
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True
    random.seed(seed)

def grad(outputs, inputs):
    """ compute the derivative of outputs associated with inputs

    Params
    ======
    outputs: (N, 1) tensor
    inputs: (N, D) tensor
    """
    return torch.autograd.grad(outputs, inputs,
                               grad_outputs=torch.ones_like(outputs),
                               create_graph=True)

# %%
seed_torch(42)

# %% [markdown]
# ## 网络模型 (Modified ResNet / ResNet / Modified MLP / MLP)

# %%
class ModifiedResNet(nn.Module):
    def __init__(self, mlp_layers):
        super(ModifiedResNet, self).__init__()
        
        self.encoder_u = nn.Sequential()
        self.encoder_u.add_module('fc_u', nn.Linear(mlp_layers[0], mlp_layers[1], bias=True))
        self.encoder_u.add_module('act_u', nn.Tanh())
        
        self.encoder_v = nn.Sequential()
        self.encoder_v.add_module('fc_v', nn.Linear(mlp_layers[0], mlp_layers[1], bias=True))
        self.encoder_v.add_module('act_v', nn.Tanh())
        
        self.model = nn.Sequential()
        
        first_layer = nn.Sequential()
        first_layer.add_module(f'fc0', nn.Linear(mlp_layers[0], mlp_layers[1], bias=True))
        first_layer.add_module(f'act0', nn.Tanh())
        self.model.add_module(f'first', first_layer)
        
        for i in range(1, len(mlp_layers)-2):
            block = nn.Sequential()
            block.add_module(f'fc{i}_0', nn.Linear(mlp_layers[i], mlp_layers[i+1], bias=True))
            block.add_module(f'act{i}_0', nn.Tanh())
            block.add_module(f'fc{i}_1', nn.Linear(mlp_layers[i], mlp_layers[i+1], bias=True))
            block.add_module(f'act{i}_1', nn.Tanh())
            self.model.add_module(f'block{i}', block)

        last_layer = nn.Sequential()
        last_layer.add_module(f'fc{len(mlp_layers)-2}', nn.Linear(mlp_layers[-2], mlp_layers[-1], bias=False))
        self.model.add_module(f'last', last_layer)
        
#         for param in self.parameters():
#             if len(param.shape) > 1:
#                 nn.init.kaiming_normal_(param)
    
    def forward(self, X):
        u = self.encoder_u(X)
        v = self.encoder_v(X)
        
        X = self.model[0](X)
        for i_block in range(1, len(self.model) - 1):
            X_ = self.model[i_block](X)
            X = X + X_
            X = X / 2.
            X = (1 - X) * u + X * v
        return self.model[-1](X)

# %%
class ResNet(nn.Module):
    def __init__(self, mlp_layers):
        super(ResNet, self).__init__()
        
        self.model = nn.Sequential()
        
        first_layer = nn.Sequential()
        first_layer.add_module(f'fc0', nn.Linear(mlp_layers[0], mlp_layers[1], bias=True))
        first_layer.add_module(f'act0', nn.Tanh())
        self.model.add_module(f'first', first_layer)
        
        for i in range(1, len(mlp_layers)-2):
            block = nn.Sequential()
            block.add_module(f'fc{i}_0', nn.Linear(mlp_layers[i], mlp_layers[i+1], bias=True))
            block.add_module(f'act{i}_0', nn.Tanh())
            block.add_module(f'fc{i}_1', nn.Linear(mlp_layers[i], mlp_layers[i+1], bias=True))
            block.add_module(f'act{i}_1', nn.Tanh())
            self.model.add_module(f'block{i}', block)

        last_layer = nn.Sequential()
        last_layer.add_module(f'fc{len(mlp_layers)-2}', nn.Linear(mlp_layers[-2], mlp_layers[-1], bias=False))
        self.model.add_module(f'last', last_layer)
        
#         for param in self.parameters():
#             if len(param.shape) > 1:
#                 nn.init.kaiming_normal_(param)
    
    def forward(self, X):
        X = self.model[0](X)
        for i_block in range(1, len(self.model) - 1):
            X_ = self.model[i_block](X)
            X = X_ + X
        return self.model[-1](X)

# %%
class ModifiedMLP(nn.Module):
    def __init__(self, mlp_layers):
        super(ModifiedMLP, self).__init__()
        
        self.encoder_u = nn.Sequential()
        self.encoder_u.add_module('fc_u', nn.Linear(mlp_layers[0], mlp_layers[1], bias=True))
        self.encoder_u.add_module('act_u', nn.Tanh())
        
        self.encoder_v = nn.Sequential()
        self.encoder_v.add_module('fc_v', nn.Linear(mlp_layers[0], mlp_layers[1], bias=True))
        self.encoder_v.add_module('act_v', nn.Tanh())
        
        self.model = nn.Sequential()
        for i in range(len(mlp_layers)-2):
            layer = nn.Sequential()
            layer.add_module(f'fc{i}', nn.Linear(mlp_layers[i], mlp_layers[i+1], bias=True))
            layer.add_module(f'act{i}', nn.Tanh())
            self.model.add_module(f'layer{i}', layer)

        last_layer = nn.Sequential()
        last_layer.add_module(f'fc{len(mlp_layers)-2}', nn.Linear(mlp_layers[-2], mlp_layers[-1], bias=False))
        self.model.add_module(f'layer{len(mlp_layers)-2}', last_layer)
        
#         for param in self.parameters():
#             if len(param.shape) > 1:
#                 nn.init.kaiming_normal_(param)
    
    def forward(self, X):
        u = self.encoder_u(X)
        v = self.encoder_v(X)
        
        for i in range(len(self.model) - 1):
            X = self.model[i](X)
            X = X / 2.
            X = (1 - X) * u + X * v
        return self.model[-1](X)

# %%
class MLP(nn.Module):
    def __init__(self, mlp_layers):
        super(MLP, self).__init__()
        
        self.model = nn.Sequential()
        for i in range(len(mlp_layers)-2):
            layer = nn.Sequential()
            layer.add_module(f'fc{i}', nn.Linear(mlp_layers[i], mlp_layers[i+1], bias=True))
            layer.add_module(f'act{i}', nn.Tanh())
            self.model.add_module(f'layer{i}', layer)

        last_layer = nn.Sequential()
        last_layer.add_module(f'fc{len(mlp_layers)-2}', nn.Linear(mlp_layers[-2], mlp_layers[-1], bias=False))
        self.model.add_module(f'layer{len(mlp_layers)-2}', last_layer)
        
#         for param in self.parameters():
#             if len(param.shape) > 1:
#                 nn.init.kaiming_normal_(param)
    
    def forward(self, X):
        return self.model(X)

# %%
backbone = ResNet(args.backbone_layers)
backbone = backbone.to(args.device)
args.backbone = backbone
print(args.backbone)
# Out:
# ResNet(
#   (model): Sequential(
#     (first): Sequential(
#       (fc0): Linear(in_features=50, out_features=60, bias=True)
#       (act0): Tanh()
#     )
#     (block1): Sequential(
#       (fc1_0): Linear(in_features=60, out_features=60, bias=True)
#       (act1_0): Tanh()
#       (fc1_1): Linear(in_features=60, out_features=60, bias=True)
#       (act1_1): Tanh()
#     )
#     (block2): Sequential(
#       (fc2_0): Linear(in_features=60, out_features=60, bias=True)
#       (act2_0): Tanh()
#       (fc2_1): Linear(in_features=60, out_features=60, bias=True)
#       (act2_1): Tanh()
#     )
#     (block3): Sequential(
#       (fc3_0): Linear(in_features=60, out_features=60, bias=True)
#       (act3_0): Tanh()
#       (fc3_1): Linear(in_features=60, out_features=60, bias=True)
#       (act3_1): Tanh()
#     )
#     (block4): Sequential(
#       (fc4_0): Linear(in_features=60, out_features=60, bias=True)
#       (act4_0): Tanh()
#       (fc4_1): Linear(in_features=60, out_features=60, bias=True)
#       (act4_1): Tanh()
#     )
#     (last): Sequential(
#       (fc5): Linear(in_features=60, out_features=1, bias=False)
#     )
#   )
# )

# %% [markdown]
# ## 对抗TransformerNet

# %%
class TransformerNet(nn.Module):
    def __init__(self, model, bot_top):
        super(TransformerNet, self).__init__()
        self.model = model
        bot, top = bot_top
        self.length = top - bot
        self.mid = (bot + top) / 2
        
    def input_transform(self, X):
        """输入变换 压缩到[-1,1]再传入arcsin"""
        return torch.arcsin((X - self.mid) / self.length * 2.) / torch.pi
    
    def output_transform(self, X):
        # to PDE's domain 非线性放缩
        return torch.sin(torch.pi * X) / 2. * self.length + self.mid
    
    def forward(self, X, residual_limit):
        X = self.input_transform(X)
        X_ = self.model(X)
        
        X_ = torch.tanh(X_) * residual_limit  # 限制变换残差的界
        
        X = self.output_transform(X + X_)
        return X
    

model = MLP(args.subnet_layers)
transformer = TransformerNet(model, args.bot_top)
transformer = transformer.to(args.device)
args.transformer = transformer
print(args.transformer)
# Out:
# TransformerNet(
#   (model): MLP(
#     (model): Sequential(
#       (layer0): Sequential(
#         (fc0): Linear(in_features=50, out_features=80, bias=True)
#         (act0): Tanh()
#       )
#       (layer1): Sequential(
#         (fc1): Linear(in_features=80, out_features=80, bias=True)
#         (act1): Tanh()
#       )
#       (layer2): Sequential(
#         (fc2): Linear(in_features=80, out_features=80, bias=True)
#         (act2): Tanh()
#       )
#       (layer3): Sequential(
#         (fc3): Linear(in_features=80, out_features=80, bias=True)
#         (act3): Tanh()
#       )
#       (layer4): Sequential(
#         (fc4): Linear(in_features=80, out_features=50, bias=False)
#       )
#     )
#   )
# )

# %% [markdown]
# ## 数据集生成

# %%
class Dataset_PoissonHD:
    def __init__(self, bot_top, dim, device, N_max=100000):
        """
        bot_top: 空间的上下界 默认是(-1,1)
        N_max: 原始的总样本点数 例如interior(N_r) 从N_max中随机采样N_r个点作为初始点
        """
        self.bot, self.top = bot_top
        self.dim = dim
        self.device = device
        self.N_max = N_max
    
    def train_data(self, N_r, N_b):
        """训练点采样"""
        X_res = self.interior(N_r).to(self.device)
        X_bcs = self.boundary(N_b).to(self.device)
        f_res = self.func_res(X_res).to(self.device)
        u_bcs = self.func_bcs(X_bcs).to(self.device)
        
        return X_res, X_bcs, f_res, u_bcs
    
    def interior(self, N_r):
        """内部点采样"""
        X_res = torch.Tensor(self.N_max, self.dim).uniform_(self.bot, self.top)
        idx = torch.randperm(self.N_max)
        idx = idx[:N_r]
        return X_res[idx]
    
    def boundary(self, N_b):
        """边界点采样"""
        X_bcs = torch.Tensor(self.N_max, self.dim).uniform_(self.bot, self.top)
        bots = self.bot * torch.ones(1, 1)
        tops = self.top * torch.ones(1, 1)
        
        n = int(self.N_max / self.dim / 2)
        num = [n * i for i in range(2 * self.dim)]
        num[0] = 0
        num.append(self.N_max)
        
        for i in range(self.dim):  # 逐个维度设为下界bot 以及上界top 得到边界点
            X_bcs[num[2 * i]:num[2 * i + 1], i] = bots.repeat(num[2 * i + 1] - num[2 * i], 1).squeeze()
            X_bcs[num[2 * i + 1]:num[2 * i + 2], i] = tops.repeat(num[2 * i + 2] - num[2 * i + 1], 1).squeeze()

        idx = torch.randperm(self.N_max)
        idx = idx[:N_b]
        return X_bcs[idx]
    
    def func_res(self, X_res):
        """控制方程右端项"""
        f = X_res.mean(axis=1, keepdims=True)
        f = (torch.sin(f) - 2) / self.dim
        return f
    
    def func_bcs(self, X_bcs):
        """边界条件右端项"""
        u_bcs = X_bcs.mean(axis=1, keepdims=True)
        u_bcs = u_bcs ** 2 + torch.sin(u_bcs)
        return u_bcs


dataset = Dataset_PoissonHD(args.bot_top, args.dim, args.device)
args.dataset = dataset
X_res, X_bcs, f_res, u_bcs = dataset.train_data(args.N_r, args.N_b)
print(X_res.shape, X_bcs.shape, f_res.shape, u_bcs.shape)
# Out:
# torch.Size([2400, 50]) torch.Size([1200, 50]) torch.Size([2400, 1]) torch.Size([1200, 1])

# %% [markdown]
# ## 训练

# %%
class Trainer_PoissonHD:
    def __init__(self, args):
        self.args = args
        self.dim = args.dim
        self.device = args.device
        
        self.N_r = args.N_r
        self.N_b = args.N_b
        self.dataset = args.dataset
        
        self.lam_res = args.lam_res
        self.lam_bcs = args.lam_bcs
        self.gamma = args.gamma
        self.backbone = args.backbone
        
        self.model_name = self.backbone.__class__.__name__
        self.model_path = self.get_model_path()
        
        self.iters_stage1 = args.iters_stage1
        self.iters_stage2 = args.iters_stage2
        self.iters_stage3 = args.iters_stage3
        self.iters_stage4 = args.iters_stage4
        
        self.K1 = args.K1
        self.K2 = args.K2

        # eps = np.finfo(np.float32).eps
        self.optimizer_Adam = optim.Adam(self.backbone.parameters(), lr=args.backbone_lr, betas=(0.9, 0.999))
        
        self.step_size = args.step_size#int( self.iters_stage4 / (np.log(1e-3) / np.log(self.gamma)) )
        self.scheduler = ExponentialLR(self.optimizer_Adam, gamma=self.gamma, verbose=True)
        
        # subnet (transformer net)
        self.transformer = args.transformer
        self.optimizer_Adam_transformer = optim.Adam(self.transformer.parameters(), lr=args.subnet_lr)    
        self.scheduler_transformer = ExponentialLR(self.optimizer_Adam_transformer, gamma=args.gamma, verbose=True)
        
        # data
        self.X_res, self.X_bcs, self.f_res, self.u_bcs = self.dataset.train_data(self.N_r, self.N_b)
        
        # Logger
        self.logger = {
            f"stage{i + 1}": {
                "loss": [],
                "loss_res": [],
                "loss_bcs": [],
                "iter": [],
            }
            for i in range(4)
        }
        self.logger_valid = {
            f"stage{i + 1}": {
                "loss": [],
                "loss_res": [],
                "loss_bcs": [],
                "iter": [],
                "error": [],  # relative l2 error
                
                "loss_transformer": [],
                "loss_res_transformer": [],
                "loss_bcs_transformer": [],
                "error_transformer": [],  # 同一批点 经过transformer变换的rl2
                
                "distant": {"mean":[], "var":[], "min":[], "max":[]},
            }
            for i in range(4)
        }
        
        self.backbone_requires_grad = None  # 用以判断是否要更新该网络
        self.transformer_requires_grad = None
        
        self.k = None
        self.k_scale = args.k_scale
        
    def get_model_path(self):
        """生成保存模型的路径"""
        if not os.path.exists('models'):
            os.mkdir('models')
        
        path = os.path.join('models', self.model_name)
        if not os.path.exists(path):
            os.mkdir(path)
        
        return path
        
    def update_train_data(self, update_k=False):
        """更新采样点"""
        self.X_res, self.X_bcs, self.f_res, self.u_bcs = self.dataset.train_data(self.N_r, self.N_b)
        
        if update_k:
            self.k = self.update_k(self.X_res, self.f_res)
        
    def update_k(self, X_res, f_res):
        """将X_res输入net_r 确定这批X_res的限制残差的系数k"""
        self.backbone.train(False)
        
        f_res_pred = self.net_r(X_res)
        k = (f_res_pred - f_res) ** 2
#         k_sort = torch.sort(k.flatten(), dim=0).values
#         k_min2 = k_sort[10]  # 不取最小值 取近似近似的
#         k_max2 = k_sort[-10]
#         k = k / (k_max2 - k_min2)
        k = k / (k.max() - k.min())
        self.backbone.train()
        return k.detach_() * self.k_scale
    
    def compute_distant_mean_var(self, X1, X2):
        d = ((X1 - X2) ** 2).sum(axis=1) ** 0.5
        return d.mean().item(), d.var().item(), d.min().item(), d.max().item()
            
    def set_backbone_requires_grad(self, bl):
        """设置backbone是否记录梯度"""
        self.backbone_requires_grad = bl
        for param in self.backbone.parameters():
            param.requires_grad = bl

    def set_transformer_requires_grad(self, bl):
        """设置transformer是否记录梯度"""
        self.transformer_requires_grad = bl
        for param in self.transformer.parameters():
            param.requires_grad = bl

    def net_u(self, X):
        return self.backbone(X)

    def net_r(self, x):
        x.requires_grad_(True)

        u = self.net_u(x)
        grad_u = grad(u, x)[0]
        u_xx = torch.zeros(u.shape).to(x.device)
        for i in range(self.dim):
            u_xx += grad(grad_u[:, [i]], x)[0][:, [i]]

        return - u_xx
    
    def net_transformer(self, X, k):
        X.requires_grad_(False)
        return self.transformer(X, k)
    
    def compute_loss(self, use_transformer=False):
        """计算loss 可选择是否使用transformer"""
        if use_transformer:
            if self.transformer_requires_grad and not self.backbone_requires_grad:
                # 只更新transformer 训练点只考虑变换后的X_res_ 用loss_res
                
                self.X_res_ = self.X_res.clone().detach()
                self.X_res_ = self.net_transformer(self.X_res_, self.k)
                # clone会新开辟一片内存 detach会从计算图剥离
                # 用X_res_.clone().detach()计算f_res
                # 可以避免X_res计算图混乱
                # 从而保证transformer的网络正常地梯度传播
                self.f_res_ = self.dataset.func_res(self.X_res_.clone().detach())  # 细节

                f_res_pred_ = self.net_r(self.X_res_)
                
                self.loss_res = torch.mean((f_res_pred_ - self.f_res_) ** 2)
                self.loss = self.lam_res * self.loss_res
                
            elif self.backbone_requires_grad and not self.transformer_requires_grad:
                # 只更新backbone 训练点考虑变换前后的X_res X_res_ X_bcs 用loss_res和loss_bcs
                
                self.X_res_ = self.X_res.clone().detach()
                self.X_res_ = self.net_transformer(self.X_res_, self.k)
                self.f_res_ = self.dataset.func_res(self.X_res_.clone().detach())  # 细节
                
                f_res_pred_ = self.net_r(self.X_res_)
                
                self.loss_res = torch.mean((f_res_pred_ - self.f_res_) ** 2)

                u_bcs_pred = self.net_u(self.X_bcs)
                self.loss_bcs = torch.mean((u_bcs_pred - self.u_bcs) ** 2)

                self.loss = self.lam_res * self.loss_res + self.lam_bcs * self.loss_bcs
            else:
                raise "error at compute_loss"
        else:
            f_res_pred = self.net_r(self.X_res)
            self.loss_res = torch.mean((f_res_pred - self.f_res) ** 2)

            u_bcs_pred = self.net_u(self.X_bcs)
            self.loss_bcs = torch.mean((u_bcs_pred - self.u_bcs) ** 2)

            self.loss = self.lam_res * self.loss_res + self.lam_bcs * self.loss_bcs


    def log_loss(self):
        """记录当前loss至logger字典"""
        self.logger[f"stage{self.current_stage}"]["loss"].append(self.loss.item())
        self.logger[f"stage{self.current_stage}"]["loss_res"].append(self.loss_res.item())
        self.logger[f"stage{self.current_stage}"]["loss_bcs"].append(self.loss_bcs.item())
        self.logger[f"stage{self.current_stage}"]["iter"].append(self.iter + 1)

    def log_info(self):
        """保存并打印训练信息"""
        info = f'Stage {self.current_stage} Iter {self.iter+1:5d} Time:{time.time()-self.start_time:.1e} # ' + \
               f'Loss:{self.loss.item():.2e}, Loss_r:{self.loss_res.item():.2e}, Loss_b:{self.loss_bcs.item():.2e} # ' + \
               f'Valid:{self.valid_loss_value:.2e}, RL2:{self.error_u:.2e}'
        with open("train_info.txt", 'a') as f:
            f.write(info + '\n')
        print(info)
        
    def compute_rl2(self, X_res):
        """计算relative l2 error"""
        u_star = X_res.mean(axis=1, keepdims=True)
        u_star = u_star**2 + torch.sin(u_star)
        u_star = u_star.detach().cpu().numpy()
        
        u_pred = self.net_u(X_res)  # 计算预测解
        u_pred = u_pred.detach().cpu().numpy()
        
        error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)  # rl2 error
        return error_u

    def valid(self):
        """验证并保存最优模型"""
        # 计算loss
        X_res, X_bcs, f_res, u_bcs = self.dataset.train_data(1000, 1000)
        k = self.update_k(X_res, f_res)
        
        self.backbone.eval()
        self.transformer.eval()
        # 不经过transformer的loss
        f_res_pred = self.net_r(X_res)
        u_bcs_pred = self.net_u(X_bcs)
        loss_res = torch.mean((f_res_pred - f_res) ** 2)
        loss_bcs = torch.mean((u_bcs_pred - u_bcs) ** 2)
        loss = self.lam_res * loss_res + self.lam_bcs * loss_bcs
        
        # 经过transformer后的内部点的loss
        X_res_ = self.net_transformer(X_res, k)
        f_res_ = self.dataset.func_res(X_res_.clone().detach())  # 计算相应X_res_的新的f_res_
        f_res_pred_transformer = self.net_r(X_res_)
        u_bcs_pred_transformer = self.net_u(X_bcs)  # 边界点也计算 对比经过和不经过transformer的两次loss 确保两次loss是基于同一批训练点
        loss_res_transformer = torch.mean((f_res_pred_transformer - f_res_) ** 2)
        loss_bcs_transformer = torch.mean((u_bcs_pred_transformer - u_bcs) ** 2)
        loss_transformer = self.lam_res * loss_res_transformer + self.lam_bcs * loss_bcs_transformer
        
        # 计算relative l2 error
        self.error_u = self.compute_rl2(X_res)
        self.error_u_transformer = self.compute_rl2(X_res_)  # 经过transformer变换的内部点 看看其rl2是否会更大 即更难学
        
        # 计算经过transformer后的变化距离信息
        d_mean, d_var, d_min, d_max = self.compute_distant_mean_var(X_res, X_res_)
        
        self.backbone.train()
        self.transformer.train()
        
        # 记录valid的loss和rl2 error信息
        self.logger_valid[f"stage{self.current_stage}"]["loss"].append(loss.item())
        self.logger_valid[f"stage{self.current_stage}"]["loss_res"].append(loss_res.item())
        self.logger_valid[f"stage{self.current_stage}"]["loss_bcs"].append(loss_bcs.item())
        self.logger_valid[f"stage{self.current_stage}"]["iter"].append(self.iter + 1)
        self.logger_valid[f"stage{self.current_stage}"]["error"].append(self.error_u)
        
        self.logger_valid[f"stage{self.current_stage}"]["loss_transformer"].append(loss_transformer.item())
        self.logger_valid[f"stage{self.current_stage}"]["loss_res_transformer"].append(loss_res_transformer.item())
        self.logger_valid[f"stage{self.current_stage}"]["loss_bcs_transformer"].append(loss_bcs_transformer.item())
        self.logger_valid[f"stage{self.current_stage}"]["error_transformer"].append(self.error_u_transformer)
        
        self.logger_valid[f"stage{self.current_stage}"]["distant"]["mean"].append(d_mean)
        self.logger_valid[f"stage{self.current_stage}"]["distant"]["var"].append(d_var)
        self.logger_valid[f"stage{self.current_stage}"]["distant"]["min"].append(d_min)
        self.logger_valid[f"stage{self.current_stage}"]["distant"]["max"].append(d_max)
        
        # 验证模型loss是否最优并选择保存
        self.valid_loss_value = loss.item()
        is_best = self.valid_loss_value < self.best_loss
        if is_best:
            self.best_loss = self.valid_loss_value
        state = {
            'stage': self.current_stage,
            'iter': self.iter,
            'state_dict': self.backbone.state_dict(),
            'state_dict_transformer': self.transformer.state_dict(),
            'best_loss': self.best_loss
        }
        save_model(state, is_best, save_dir=self.model_path)
    
    def train(self):
        """DAR 4个Stage 训练"""
        self.start_time = time.time()
        self.best_loss = 1.e10
        
        # stage1 只训练backbone
        self.iter = 0
        self.current_stage = 1  # 设置当前stage
        self.set_backbone_requires_grad(True)  # 记录backbone的梯度
        self.set_transformer_requires_grad(False)  # 不记录transformer的梯度
        for _ in range(self.iters_stage1):
            self.optimizer_Adam.zero_grad()
            self.compute_loss(use_transformer=False)
            self.loss.backward()
            self.optimizer_Adam.step()
            self.log_loss()        
            
            if (self.iter + 1) % 100 == 0:
                self.valid()
                self.log_info()
                self.update_train_data()
            if (self.iter + 1) % self.step_size == 0:
                self.scheduler.step()
            self.iter += 1
            
            
        self.k = self.update_k(self.X_res, self.f_res)
            
                
        # stage2 只训练transformer
        self.iter = 0
        self.current_stage = 2
        self.set_backbone_requires_grad(False)
        self.set_transformer_requires_grad(True)
        for _ in range(self.iters_stage2):       
            self.optimizer_Adam_transformer.zero_grad()
            self.compute_loss(use_transformer=True)
            self.loss.backward()

            for param in self.transformer.parameters():
                if param.requires_grad == True:
                    param.grad *= -1
            self.optimizer_Adam_transformer.step()

            self.log_loss()
            
            if (self.iter + 1) % 10 == 0:
                self.valid()
                self.log_info()
                self.update_train_data(update_k=True)
            if (self.iter + 1) % self.step_size == 0:
                self.scheduler_transformer.step()
            self.iter += 1

        # stage3 同时训练backbone和transformer
        self.iter = 0
        self.current_stage = 3
        self.set_backbone_requires_grad(True)
        self.set_transformer_requires_grad(True)
        for _ in range(self.iters_stage3):
            self.optimizer_Adam.zero_grad()
            self.optimizer_Adam_transformer.zero_grad()
            
            # 优化K1次backbone 再优化K2次transformer 如此往复
            if (self.iter % (self.K1 + self.K2)) < self.K1:
                # 使用transformer优化backbone
                self.set_backbone_requires_grad(True)
                self.set_transformer_requires_grad(False)
                self.compute_loss(use_transformer=True)
                self.loss.backward()
                self.optimizer_Adam.step()
            else:
                # 优化transformer
                self.set_backbone_requires_grad(False)
                self.set_transformer_requires_grad(True)
                self.compute_loss(use_transformer=True)
                self.loss.backward()

                for param in self.transformer.parameters():
                    if param.requires_grad == True:
                        param.grad *= -1
                self.optimizer_Adam_transformer.step()
            
            self.log_loss()

            if (self.iter + 1) % 100 == 0:
                self.valid()
                self.log_info()
                self.update_train_data(update_k=True)
                
            if (self.iter + 1) % self.step_size == 0:
                self.scheduler.step()
                self.scheduler_transformer.step()
            self.iter += 1
            
        # stage4 只训练backbone
        self.iter = 0
        self.current_stage = 4
        self.set_backbone_requires_grad(True)
        self.set_transformer_requires_grad(False)
        for _ in range(self.iters_stage4):
            self.optimizer_Adam.zero_grad()
            self.compute_loss(use_transformer=False)
            self.loss.backward()
            self.optimizer_Adam.step()
            self.log_loss()

            if (self.iter + 1) % 100 == 0:
                self.valid()
                self.log_info()
                self.update_train_data()

            if (self.iter + 1) % self.step_size == 0:
                self.scheduler.step()
            self.iter += 1
            
            
trainer = Trainer_PoissonHD(args)
# Out:
# Adjusting learning rate of group 0 to 1.0000e-03.
# Adjusting learning rate of group 0 to 1.0000e-04.

# %%
trainer.train()
# Out:
# Stage 3 Iter   100 Time:8.1e+00 # Loss:2.03e-04, Loss_r:1.06e-04, Loss_b:9.75e-05 # Valid:2.18e-04, RL2:1.26e-01
# Stage 3 Iter   200 Time:1.9e+01 # Loss:1.31e-04, Loss_r:6.07e-05, Loss_b:7.00e-05 # Valid:1.65e-04, RL2:1.11e-01
# Stage 3 Iter   300 Time:3.9e+01 # Loss:9.36e-04, Loss_r:9.36e-04, Loss_b:7.00e-05 # Valid:1.76e-04, RL2:1.04e-01
# Stage 3 Iter   400 Time:5.9e+01 # Loss:7.91e-04, Loss_r:7.91e-04, Loss_b:7.00e-05 # Valid:1.40e-04, RL2:1.06e-01
# Stage 3 Iter   500 Time:7.9e+01 # Loss:1.30e-04, Loss_r:4.96e-05, Loss_b:8.00e-05 # Valid:1.57e-04, RL2:1.12e-01
# Stage 3 Iter   600 Time:1.0e+02 # Loss:9.59e-05, Loss_r:3.49e-05, Loss_b:6.10e-05 # Valid:1.26e-04, RL2:1.03e-01
# Stage 3 Iter   700 Time:1.2e+02 # Loss:4.22e-05, Loss_r:4.22e-05, Loss_b:6.10e-05 # Valid:1.37e-04, RL2:1.05e-01
# Stage 3 Iter   800 Time:1.4e+02 # Loss:4.31e-05, Loss_r:4.31e-05, Loss_b:6.10e-05 # Valid:1.42e-04, RL2:1.03e-01
# Stage 3 Iter   900 Time:1.6e+02 # Loss:7.39e-05, Loss_r:2.92e-05, Loss_b:4.47e-05 # Valid:1.29e-04, RL2:1.10e-01
# Stage 3 Iter  1000 Time:1.8e+02 # Loss:6.00e-05, Loss_r:2.16e-05, Loss_b:3.84e-05 # Valid:1.27e-04, RL2:7.48e-02
# Stage 3 Iter  1100 Time:2.0e+02 # Loss:2.75e-05, Loss_r:2.75e-05, Loss_b:3.84e-05 # Valid:1.30e-04, RL2:7.77e-02
# Stage 3 Iter  1200 Time:2.2e+02 # Loss:2.18e-05, Loss_r:2.18e-05, Loss_b:3.84e-05 # Valid:1.30e-04, RL2:7.34e-02
# Stage 3 Iter  1300 Time:2.4e+02 # Loss:4.72e-05, Loss_r:2.14e-05, Loss_b:2.58e-05 # Valid:1.48e-04, RL2:6.80e-02
# Stage 3 Iter  1400 Time:2.6e+02 # Loss:3.12e-05, Loss_r:1.52e-05, Loss_b:1.60e-05 # Valid:1.66e-04, RL2:4.95e-02
# Stage 3 Iter  1500 Time:2.8e+02 # Loss:2.92e-05, Loss_r:2.92e-05, Loss_b:1.60e-05 # Valid:1.62e-04, RL2:5.61e-02
# Stage 3 Iter  1600 Time:3.0e+02 # Loss:4.10e-05, Loss_r:4.10e-05, Loss_b:1.60e-05 # Valid:1.62e-04, RL2:5.62e-02
# Stage 3 Iter  1700 Time:3.3e+02 # Loss:5.36e-05, Loss_r:1.99e-05, Loss_b:3.38e-05 # Valid:1.94e-04, RL2:8.58e-02
# Stage 3 Iter  1800 Time:3.5e+02 # Loss:2.92e-05, Loss_r:1.60e-05, Loss_b:1.32e-05 # Valid:1.70e-04, RL2:3.90e-02
# Stage 3 Iter  1900 Time:3.7e+02 # Loss:1.89e-05, Loss_r:1.89e-05, Loss_b:1.32e-05 # Valid:1.50e-04, RL2:3.93e-02
# Stage 3 Iter  2000 Time:3.9e+02 # Loss:2.05e-05, Loss_r:2.05e-05, Loss_b:1.32e-05 # Valid:1.30e-04, RL2:4.59e-02
# Adjusting learning rate of group 0 to 9.5000e-04.
# Adjusting learning rate of group 0 to 9.5000e-05.
# Stage 3 Iter  2100 Time:4.1e+02 # Loss:2.55e-05, Loss_r:1.33e-05, Loss_b:1.21e-05 # Valid:1.36e-04, RL2:5.11e-02
# Stage 3 Iter  2200 Time:4.3e+02 # Loss:1.97e-05, Loss_r:1.15e-05, Loss_b:8.19e-06 # Valid:1.14e-04, RL2:4.33e-02
# Stage 3 Iter  2300 Time:4.5e+02 # Loss:1.99e-05, Loss_r:1.99e-05, Loss_b:8.19e-06 # Valid:1.10e-04, RL2:4.34e-02
# Stage 3 Iter  2400 Time:4.7e+02 # Loss:9.94e-06, Loss_r:9.94e-06, Loss_b:8.19e-06 # Valid:1.24e-04, RL2:4.40e-02
# Stage 3 Iter  2500 Time:4.9e+02 # Loss:3.17e-05, Loss_r:9.52e-06, Loss_b:2.22e-05 # Valid:1.16e-04, RL2:4.79e-02
# Stage 3 Iter  2600 Time:5.1e+02 # Loss:1.38e-05, Loss_r:7.92e-06, Loss_b:5.84e-06 # Valid:8.38e-05, RL2:3.28e-02
# Stage 3 Iter  2700 Time:5.3e+02 # Loss:1.06e-05, Loss_r:1.06e-05, Loss_b:5.84e-06 # Valid:7.20e-05, RL2:3.06e-02
# Stage 3 Iter  2800 Time:5.5e+02 # Loss:1.74e-05, Loss_r:1.74e-05, Loss_b:5.84e-06 # Valid:7.32e-05, RL2:3.15e-02
# Stage 3 Iter  2900 Time:5.7e+02 # Loss:1.29e-05, Loss_r:7.32e-06, Loss_b:5.61e-06 # Valid:6.43e-05, RL2:3.63e-02
# Stage 3 Iter  3000 Time:5.9e+02 # Loss:1.15e-05, Loss_r:6.43e-06, Loss_b:5.11e-06 # Valid:5.84e-05, RL2:3.08e-02
# Stage 3 Iter  3100 Time:6.1e+02 # Loss:7.48e-06, Loss_r:7.48e-06, Loss_b:5.11e-06 # Valid:5.62e-05, RL2:2.51e-02
# Stage 3 Iter  3200 Time:6.3e+02 # Loss:7.62e-06, Loss_r:7.62e-06, Loss_b:5.11e-06 # Valid:6.23e-05, RL2:3.25e-02
# Stage 3 Iter  3300 Time:6.5e+02 # Loss:9.01e-06, Loss_r:4.97e-06, Loss_b:4.04e-06 # Valid:4.82e-05, RL2:2.69e-02
# Stage 3 Iter  3400 Time:6.7e+02 # Loss:7.93e-06, Loss_r:4.77e-06, Loss_b:3.17e-06 # Valid:5.48e-05, RL2:1.99e-02
# Stage 3 Iter  3500 Time:6.9e+02 # Loss:7.60e-06, Loss_r:7.60e-06, Loss_b:3.17e-06 # Valid:4.34e-05, RL2:2.56e-02
# Stage 3 Iter  3600 Time:7.1e+02 # Loss:8.13e-06, Loss_r:8.13e-06, Loss_b:3.17e-06 # Valid:4.59e-05, RL2:2.24e-02
# Stage 3 Iter  3700 Time:7.4e+02 # Loss:7.70e-06, Loss_r:4.92e-06, Loss_b:2.78e-06 # Valid:3.47e-05, RL2:2.65e-02
# Stage 3 Iter  3800 Time:7.6e+02 # Loss:5.93e-06, Loss_r:3.58e-06, Loss_b:2.36e-06 # Valid:3.45e-05, RL2:3.18e-02
# Stage 3 Iter  3900 Time:7.8e+02 # Loss:4.94e-06, Loss_r:4.94e-06, Loss_b:2.36e-06 # Valid:3.22e-05, RL2:2.26e-02
# Stage 3 Iter  4000 Time:8.0e+02 # Loss:4.88e-06, Loss_r:4.88e-06, Loss_b:2.36e-06 # Valid:3.16e-05, RL2:2.04e-02
# Adjusting learning rate of group 0 to 9.0250e-04.
# Adjusting learning rate of group 0 to 9.0250e-05.
# Stage 3 Iter  4100 Time:8.2e+02 # Loss:4.88e-06, Loss_r:2.96e-06, Loss_b:1.92e-06 # Valid:3.26e-05, RL2:1.80e-02
# Stage 3 Iter  4200 Time:8.4e+02 # Loss:7.09e-06, Loss_r:3.06e-06, Loss_b:4.04e-06 # Valid:3.68e-05, RL2:2.83e-02
# Stage 3 Iter  4300 Time:8.6e+02 # Loss:5.28e-06, Loss_r:5.28e-06, Loss_b:4.04e-06 # Valid:3.28e-05, RL2:2.95e-02
# Stage 3 Iter  4400 Time:8.8e+02 # Loss:7.56e-06, Loss_r:7.56e-06, Loss_b:4.04e-06 # Valid:2.99e-05, RL2:3.06e-02
# Stage 3 Iter  4500 Time:9.0e+02 # Loss:4.95e-06, Loss_r:3.02e-06, Loss_b:1.93e-06 # Valid:2.73e-05, RL2:1.60e-02
# Stage 3 Iter  4600 Time:9.2e+02 # Loss:4.54e-06, Loss_r:2.78e-06, Loss_b:1.76e-06 # Valid:2.44e-05, RL2:2.02e-02
# Stage 3 Iter  4700 Time:9.4e+02 # Loss:4.50e-06, Loss_r:4.50e-06, Loss_b:1.76e-06 # Valid:2.13e-05, RL2:1.92e-02
# Stage 3 Iter  4800 Time:9.6e+02 # Loss:3.66e-06, Loss_r:3.66e-06, Loss_b:1.76e-06 # Valid:2.42e-05, RL2:1.96e-02
# Stage 3 Iter  4900 Time:9.8e+02 # Loss:3.98e-06, Loss_r:2.49e-06, Loss_b:1.49e-06 # Valid:2.28e-05, RL2:1.57e-02
# Stage 3 Iter  5000 Time:1.0e+03 # Loss:4.35e-06, Loss_r:2.25e-06, Loss_b:2.10e-06 # Valid:1.80e-05, RL2:2.01e-02
# Stage 3 Iter  5100 Time:1.0e+03 # Loss:4.18e-06, Loss_r:4.18e-06, Loss_b:2.10e-06 # Valid:2.18e-05, RL2:1.56e-02
# Stage 3 Iter  5200 Time:1.0e+03 # Loss:4.53e-06, Loss_r:4.53e-06, Loss_b:2.10e-06 # Valid:1.91e-05, RL2:1.43e-02
# Stage 3 Iter  5300 Time:1.1e+03 # Loss:3.26e-06, Loss_r:1.98e-06, Loss_b:1.28e-06 # Valid:1.58e-05, RL2:1.55e-02
# Stage 3 Iter  5400 Time:1.1e+03 # Loss:2.75e-06, Loss_r:1.69e-06, Loss_b:1.05e-06 # Valid:1.85e-05, RL2:1.48e-02
# Stage 3 Iter  5500 Time:1.1e+03 # Loss:3.88e-06, Loss_r:3.88e-06, Loss_b:1.05e-06 # Valid:1.61e-05, RL2:1.28e-02
# Stage 3 Iter  5600 Time:1.1e+03 # Loss:3.17e-06, Loss_r:3.17e-06, Loss_b:1.05e-06 # Valid:1.93e-05, RL2:1.26e-02
# Stage 3 Iter  5700 Time:1.1e+03 # Loss:3.11e-06, Loss_r:1.97e-06, Loss_b:1.14e-06 # Valid:1.82e-05, RL2:1.61e-02
# Stage 3 Iter  5800 Time:1.2e+03 # Loss:2.43e-06, Loss_r:1.58e-06, Loss_b:8.47e-07 # Valid:1.31e-05, RL2:1.49e-02
# Stage 3 Iter  5900 Time:1.2e+03 # Loss:1.94e-06, Loss_r:1.94e-06, Loss_b:8.47e-07 # Valid:1.35e-05, RL2:1.47e-02
# Stage 3 Iter  6000 Time:1.2e+03 # Loss:2.02e-06, Loss_r:2.02e-06, Loss_b:8.47e-07 # Valid:1.39e-05, RL2:1.66e-02
# Adjusting learning rate of group 0 to 8.5737e-04.
# Adjusting learning rate of group 0 to 8.5737e-05.
# Stage 3 Iter  6100 Time:1.2e+03 # Loss:2.44e-06, Loss_r:1.50e-06, Loss_b:9.43e-07 # Valid:1.27e-05, RL2:1.21e-02
# Stage 3 Iter  6200 Time:1.2e+03 # Loss:2.19e-06, Loss_r:1.36e-06, Loss_b:8.37e-07 # Valid:1.23e-05, RL2:1.15e-02
# Stage 3 Iter  6300 Time:1.3e+03 # Loss:1.93e-06, Loss_r:1.93e-06, Loss_b:8.37e-07 # Valid:1.16e-05, RL2:1.34e-02
# Stage 3 Iter  6400 Time:1.3e+03 # Loss:1.51e-06, Loss_r:1.51e-06, Loss_b:8.37e-07 # Valid:1.32e-05, RL2:1.49e-02
# Stage 3 Iter  6500 Time:1.3e+03 # Loss:2.33e-06, Loss_r:1.42e-06, Loss_b:9.17e-07 # Valid:1.18e-05, RL2:1.36e-02
# Stage 3 Iter  6600 Time:1.3e+03 # Loss:1.69e-06, Loss_r:1.14e-06, Loss_b:5.55e-07 # Valid:9.91e-06, RL2:1.06e-02
# Stage 3 Iter  6700 Time:1.3e+03 # Loss:2.19e-06, Loss_r:2.19e-06, Loss_b:5.55e-07 # Valid:1.11e-05, RL2:1.28e-02
# Stage 3 Iter  6800 Time:1.4e+03 # Loss:1.47e-06, Loss_r:1.47e-06, Loss_b:5.55e-07 # Valid:1.06e-05, RL2:1.26e-02
# Stage 3 Iter  6900 Time:1.4e+03 # Loss:2.10e-06, Loss_r:1.36e-06, Loss_b:7.45e-07 # Valid:1.02e-05, RL2:1.35e-02
# Stage 3 Iter  7000 Time:1.4e+03 # Loss:1.50e-06, Loss_r:9.71e-07, Loss_b:5.27e-07 # Valid:1.07e-05, RL2:1.05e-02
# Stage 3 Iter  7100 Time:1.4e+03 # Loss:1.62e-06, Loss_r:1.62e-06, Loss_b:5.27e-07 # Valid:1.11e-05, RL2:1.03e-02
# Stage 3 Iter  7200 Time:1.5e+03 # Loss:1.96e-06, Loss_r:1.96e-06, Loss_b:5.27e-07 # Valid:1.09e-05, RL2:9.24e-03
# Stage 3 Iter  7300 Time:1.5e+03 # Loss:1.57e-06, Loss_r:1.08e-06, Loss_b:4.89e-07 # Valid:9.18e-06, RL2:1.16e-02
# Stage 3 Iter  7400 Time:1.5e+03 # Loss:1.56e-06, Loss_r:1.03e-06, Loss_b:5.35e-07 # Valid:1.15e-05, RL2:2.01e-02
# Stage 3 Iter  7500 Time:1.5e+03 # Loss:1.31e-06, Loss_r:1.31e-06, Loss_b:5.35e-07 # Valid:9.87e-06, RL2:1.07e-02
# Stage 3 Iter  7600 Time:1.5e+03 # Loss:1.29e-06, Loss_r:1.29e-06, Loss_b:5.35e-07 # Valid:1.03e-05, RL2:9.21e-03
# Stage 3 Iter  7700 Time:1.6e+03 # Loss:1.69e-06, Loss_r:1.11e-06, Loss_b:5.73e-07 # Valid:9.29e-06, RL2:1.09e-02
# Stage 3 Iter  7800 Time:1.6e+03 # Loss:1.98e-06, Loss_r:1.25e-06, Loss_b:7.29e-07 # Valid:8.61e-06, RL2:9.36e-03
# Stage 3 Iter  7900 Time:1.6e+03 # Loss:1.46e-06, Loss_r:1.46e-06, Loss_b:7.29e-07 # Valid:7.42e-06, RL2:9.92e-03
# Stage 3 Iter  8000 Time:1.6e+03 # Loss:1.32e-06, Loss_r:1.32e-06, Loss_b:7.29e-07 # Valid:1.18e-05, RL2:1.14e-02
# Adjusting learning rate of group 0 to 8.1451e-04.
# Adjusting learning rate of group 0 to 8.1451e-05.
# Stage 3 Iter  8100 Time:1.6e+03 # Loss:1.33e-06, Loss_r:8.81e-07, Loss_b:4.47e-07 # Valid:8.12e-06, RL2:1.08e-02
# Stage 3 Iter  8200 Time:1.7e+03 # Loss:1.31e-06, Loss_r:9.03e-07, Loss_b:4.10e-07 # Valid:7.12e-06, RL2:9.36e-03
# Stage 3 Iter  8300 Time:1.7e+03 # Loss:1.21e-06, Loss_r:1.21e-06, Loss_b:4.10e-07 # Valid:8.09e-06, RL2:1.01e-02
# Stage 3 Iter  8400 Time:1.7e+03 # Loss:1.06e-06, Loss_r:1.06e-06, Loss_b:4.10e-07 # Valid:7.67e-06, RL2:9.42e-03
# Stage 3 Iter  8500 Time:1.7e+03 # Loss:1.08e-06, Loss_r:7.20e-07, Loss_b:3.60e-07 # Valid:7.19e-06, RL2:9.83e-03
# Stage 3 Iter  8600 Time:1.7e+03 # Loss:1.26e-06, Loss_r:8.04e-07, Loss_b:4.60e-07 # Valid:7.63e-06, RL2:8.17e-03
# Stage 3 Iter  8700 Time:1.8e+03 # Loss:2.04e-06, Loss_r:2.04e-06, Loss_b:4.60e-07 # Valid:7.08e-06, RL2:8.29e-03
# Stage 3 Iter  8800 Time:1.8e+03 # Loss:2.06e-06, Loss_r:2.06e-06, Loss_b:4.60e-07 # Valid:7.36e-06, RL2:9.97e-03
# Stage 3 Iter  8900 Time:1.8e+03 # Loss:1.25e-06, Loss_r:8.17e-07, Loss_b:4.31e-07 # Valid:6.43e-06, RL2:8.43e-03
# Stage 3 Iter  9000 Time:1.8e+03 # Loss:7.93e-06, Loss_r:9.21e-07, Loss_b:7.01e-06 # Valid:1.43e-05, RL2:4.04e-02
# Stage 3 Iter  9100 Time:1.8e+03 # Loss:1.19e-06, Loss_r:1.19e-06, Loss_b:7.01e-06 # Valid:1.43e-05, RL2:4.17e-02
# Stage 3 Iter  9200 Time:1.9e+03 # Loss:1.67e-06, Loss_r:1.67e-06, Loss_b:7.01e-06 # Valid:1.43e-05, RL2:4.13e-02
# Stage 3 Iter  9300 Time:1.9e+03 # Loss:1.25e-06, Loss_r:8.46e-07, Loss_b:4.07e-07 # Valid:4.64e-06, RL2:8.54e-03
# Stage 3 Iter  9400 Time:1.9e+03 # Loss:8.89e-07, Loss_r:6.24e-07, Loss_b:2.65e-07 # Valid:4.92e-06, RL2:7.75e-03
# Stage 3 Iter  9500 Time:1.9e+03 # Loss:2.36e-06, Loss_r:2.36e-06, Loss_b:2.65e-07 # Valid:4.53e-06, RL2:8.50e-03
# Stage 3 Iter  9600 Time:1.9e+03 # Loss:3.49e-06, Loss_r:3.49e-06, Loss_b:2.65e-07 # Valid:5.08e-06, RL2:7.85e-03
# Stage 3 Iter  9700 Time:2.0e+03 # Loss:9.38e-07, Loss_r:6.66e-07, Loss_b:2.73e-07 # Valid:4.20e-06, RL2:7.30e-03
# Stage 3 Iter  9800 Time:2.0e+03 # Loss:1.53e-06, Loss_r:8.75e-07, Loss_b:6.57e-07 # Valid:5.33e-06, RL2:9.16e-03
# Stage 3 Iter  9900 Time:2.0e+03 # Loss:1.01e-06, Loss_r:1.01e-06, Loss_b:6.57e-07 # Valid:4.99e-06, RL2:1.17e-02
# Stage 3 Iter 10000 Time:2.0e+03 # Loss:1.33e-06, Loss_r:1.33e-06, Loss_b:6.57e-07 # Valid:4.91e-06, RL2:1.02e-02
# Adjusting learning rate of group 0 to 7.7378e-04.
# Adjusting learning rate of group 0 to 7.7378e-05.
# Stage 3 Iter 10100 Time:2.0e+03 # Loss:1.16e-06, Loss_r:7.43e-07, Loss_b:4.14e-07 # Valid:4.72e-06, RL2:8.46e-03
# Stage 3 Iter 10200 Time:2.1e+03 # Loss:9.97e-07, Loss_r:6.66e-07, Loss_b:3.31e-07 # Valid:5.16e-06, RL2:8.97e-03
# Stage 3 Iter 10300 Time:2.1e+03 # Loss:1.33e-06, Loss_r:1.33e-06, Loss_b:3.31e-07 # Valid:4.27e-06, RL2:8.04e-03
# Stage 3 Iter 10400 Time:2.1e+03 # Loss:1.07e-06, Loss_r:1.07e-06, Loss_b:3.31e-07 # Valid:5.38e-06, RL2:1.09e-02
# Stage 3 Iter 10500 Time:2.1e+03 # Loss:9.35e-07, Loss_r:6.50e-07, Loss_b:2.85e-07 # Valid:4.47e-06, RL2:8.98e-03
# Stage 3 Iter 10600 Time:2.1e+03 # Loss:8.88e-07, Loss_r:6.08e-07, Loss_b:2.81e-07 # Valid:4.39e-06, RL2:8.33e-03
# Stage 3 Iter 10700 Time:2.2e+03 # Loss:8.16e-07, Loss_r:8.16e-07, Loss_b:2.81e-07 # Valid:4.09e-06, RL2:1.09e-02
# Stage 3 Iter 10800 Time:2.2e+03 # Loss:9.19e-07, Loss_r:9.19e-07, Loss_b:2.81e-07 # Valid:4.18e-06, RL2:7.03e-03
# Stage 3 Iter 10900 Time:2.2e+03 # Loss:8.97e-07, Loss_r:6.10e-07, Loss_b:2.86e-07 # Valid:5.49e-06, RL2:6.72e-03
# Stage 3 Iter 11000 Time:2.2e+03 # Loss:7.79e-07, Loss_r:5.28e-07, Loss_b:2.51e-07 # Valid:5.76e-06, RL2:6.14e-03
# Stage 3 Iter 11100 Time:2.3e+03 # Loss:8.21e-07, Loss_r:8.21e-07, Loss_b:2.51e-07 # Valid:5.42e-06, RL2:7.55e-03
# Stage 3 Iter 11200 Time:2.3e+03 # Loss:1.27e-06, Loss_r:1.27e-06, Loss_b:2.51e-07 # Valid:5.02e-06, RL2:6.57e-03
# Stage 3 Iter 11300 Time:2.3e+03 # Loss:7.17e-07, Loss_r:4.95e-07, Loss_b:2.22e-07 # Valid:4.80e-06, RL2:6.32e-03
# Stage 3 Iter 11400 Time:2.3e+03 # Loss:8.16e-07, Loss_r:5.60e-07, Loss_b:2.56e-07 # Valid:3.84e-06, RL2:9.00e-03
# Stage 3 Iter 11500 Time:2.3e+03 # Loss:9.72e-07, Loss_r:9.72e-07, Loss_b:2.56e-07 # Valid:4.97e-06, RL2:7.19e-03
# Stage 3 Iter 11600 Time:2.4e+03 # Loss:8.33e-07, Loss_r:8.33e-07, Loss_b:2.56e-07 # Valid:4.80e-06, RL2:6.97e-03
# Stage 3 Iter 11700 Time:2.4e+03 # Loss:7.96e-07, Loss_r:5.48e-07, Loss_b:2.49e-07 # Valid:3.97e-06, RL2:6.71e-03
# Stage 3 Iter 11800 Time:2.4e+03 # Loss:1.10e-06, Loss_r:6.14e-07, Loss_b:4.83e-07 # Valid:4.78e-06, RL2:8.23e-03
# Stage 3 Iter 11900 Time:2.4e+03 # Loss:1.07e-06, Loss_r:1.07e-06, Loss_b:4.83e-07 # Valid:4.03e-06, RL2:7.91e-03
# Stage 3 Iter 12000 Time:2.4e+03 # Loss:9.80e-07, Loss_r:9.80e-07, Loss_b:4.83e-07 # Valid:4.28e-06, RL2:1.17e-02
# Adjusting learning rate of group 0 to 7.3509e-04.
# Adjusting learning rate of group 0 to 7.3509e-05.
# Stage 3 Iter 12100 Time:2.5e+03 # Loss:8.37e-07, Loss_r:5.89e-07, Loss_b:2.48e-07 # Valid:3.11e-06, RL2:7.50e-03
# Stage 3 Iter 12200 Time:2.5e+03 # Loss:1.21e-06, Loss_r:5.19e-07, Loss_b:6.91e-07 # Valid:4.28e-06, RL2:9.20e-03
# Stage 3 Iter 12300 Time:2.5e+03 # Loss:7.91e-07, Loss_r:7.91e-07, Loss_b:6.91e-07 # Valid:4.28e-06, RL2:8.41e-03
# Stage 3 Iter 12400 Time:2.5e+03 # Loss:1.44e-06, Loss_r:1.44e-06, Loss_b:6.91e-07 # Valid:4.26e-06, RL2:7.48e-03
# Stage 3 Iter 12500 Time:2.5e+03 # Loss:6.52e-07, Loss_r:4.50e-07, Loss_b:2.03e-07 # Valid:3.93e-06, RL2:7.06e-03
# Stage 3 Iter 12600 Time:2.6e+03 # Loss:6.55e-07, Loss_r:4.01e-07, Loss_b:2.54e-07 # Valid:4.71e-06, RL2:6.95e-03
# Stage 3 Iter 12700 Time:2.6e+03 # Loss:5.25e-07, Loss_r:5.25e-07, Loss_b:2.54e-07 # Valid:4.16e-06, RL2:6.68e-03
# Stage 3 Iter 12800 Time:2.6e+03 # Loss:6.09e-07, Loss_r:6.09e-07, Loss_b:2.54e-07 # Valid:5.45e-06, RL2:6.95e-03
# Stage 3 Iter 12900 Time:2.6e+03 # Loss:5.19e-07, Loss_r:3.54e-07, Loss_b:1.65e-07 # Valid:4.97e-06, RL2:6.16e-03
# Stage 3 Iter 13000 Time:2.6e+03 # Loss:4.73e-06, Loss_r:1.25e-06, Loss_b:3.48e-06 # Valid:8.33e-06, RL2:2.63e-02
# Stage 3 Iter 13100 Time:2.7e+03 # Loss:1.62e-06, Loss_r:1.62e-06, Loss_b:3.48e-06 # Valid:8.17e-06, RL2:2.58e-02
# Stage 3 Iter 13200 Time:2.7e+03 # Loss:2.21e-06, Loss_r:2.21e-06, Loss_b:3.48e-06 # Valid:8.10e-06, RL2:2.45e-02
# Stage 3 Iter 13300 Time:2.7e+03 # Loss:5.15e-07, Loss_r:3.48e-07, Loss_b:1.68e-07 # Valid:3.11e-06, RL2:7.26e-03
# Stage 3 Iter 13400 Time:2.7e+03 # Loss:5.61e-07, Loss_r:3.50e-07, Loss_b:2.11e-07 # Valid:2.95e-06, RL2:6.23e-03
# Stage 3 Iter 13500 Time:2.7e+03 # Loss:5.15e-07, Loss_r:5.15e-07, Loss_b:2.11e-07 # Valid:2.93e-06, RL2:6.09e-03
# Stage 3 Iter 13600 Time:2.8e+03 # Loss:8.37e-07, Loss_r:8.37e-07, Loss_b:2.11e-07 # Valid:3.10e-06, RL2:6.36e-03
# Stage 3 Iter 13700 Time:2.8e+03 # Loss:1.14e-06, Loss_r:3.79e-07, Loss_b:7.56e-07 # Valid:2.00e-06, RL2:9.73e-03
# Stage 3 Iter 13800 Time:2.8e+03 # Loss:4.86e-07, Loss_r:3.27e-07, Loss_b:1.58e-07 # Valid:1.91e-06, RL2:5.30e-03
# Stage 3 Iter 13900 Time:2.8e+03 # Loss:9.30e-07, Loss_r:9.30e-07, Loss_b:1.58e-07 # Valid:2.04e-06, RL2:6.68e-03
# Stage 3 Iter 14000 Time:2.8e+03 # Loss:7.03e-07, Loss_r:7.03e-07, Loss_b:1.58e-07 # Valid:2.48e-06, RL2:4.89e-03
# Adjusting learning rate of group 0 to 6.9834e-04.
# Adjusting learning rate of group 0 to 6.9834e-05.
# Stage 3 Iter 14100 Time:2.9e+03 # Loss:5.05e-07, Loss_r:3.21e-07, Loss_b:1.84e-07 # Valid:1.77e-06, RL2:5.65e-03
# Stage 3 Iter 14200 Time:2.9e+03 # Loss:5.49e-07, Loss_r:3.53e-07, Loss_b:1.96e-07 # Valid:2.85e-06, RL2:5.79e-03
# Stage 3 Iter 14300 Time:2.9e+03 # Loss:1.13e-06, Loss_r:1.13e-06, Loss_b:1.96e-07 # Valid:2.11e-06, RL2:7.86e-03
# Stage 3 Iter 14400 Time:2.9e+03 # Loss:6.90e-07, Loss_r:6.90e-07, Loss_b:1.96e-07 # Valid:2.53e-06, RL2:5.94e-03
# Stage 3 Iter 14500 Time:3.0e+03 # Loss:5.39e-07, Loss_r:3.36e-07, Loss_b:2.03e-07 # Valid:2.43e-06, RL2:5.23e-03
# Stage 3 Iter 14600 Time:3.0e+03 # Loss:5.11e-07, Loss_r:3.21e-07, Loss_b:1.91e-07 # Valid:2.32e-06, RL2:5.65e-03
# Stage 3 Iter 14700 Time:3.0e+03 # Loss:5.94e-07, Loss_r:5.94e-07, Loss_b:1.91e-07 # Valid:1.89e-06, RL2:6.65e-03
# Stage 3 Iter 14800 Time:3.0e+03 # Loss:6.43e-07, Loss_r:6.43e-07, Loss_b:1.91e-07 # Valid:2.08e-06, RL2:6.69e-03
# Stage 3 Iter 14900 Time:3.0e+03 # Loss:4.87e-07, Loss_r:3.34e-07, Loss_b:1.53e-07 # Valid:1.64e-06, RL2:5.40e-03
# Stage 3 Iter 15000 Time:3.1e+03 # Loss:4.28e-07, Loss_r:2.82e-07, Loss_b:1.46e-07 # Valid:1.64e-06, RL2:4.76e-03
# Stage 3 Iter 15100 Time:3.1e+03 # Loss:5.54e-07, Loss_r:5.54e-07, Loss_b:1.46e-07 # Valid:1.40e-06, RL2:5.10e-03
# Stage 3 Iter 15200 Time:3.1e+03 # Loss:5.62e-07, Loss_r:5.62e-07, Loss_b:1.46e-07 # Valid:1.38e-06, RL2:6.42e-03
# Stage 3 Iter 15300 Time:3.1e+03 # Loss:5.00e-07, Loss_r:3.38e-07, Loss_b:1.61e-07 # Valid:1.95e-06, RL2:6.54e-03
# Stage 3 Iter 15400 Time:3.1e+03 # Loss:4.05e-07, Loss_r:2.51e-07, Loss_b:1.54e-07 # Valid:1.94e-06, RL2:4.88e-03
# Stage 3 Iter 15500 Time:3.2e+03 # Loss:7.02e-07, Loss_r:7.02e-07, Loss_b:1.54e-07 # Valid:1.97e-06, RL2:4.64e-03
# Stage 3 Iter 15600 Time:3.2e+03 # Loss:8.02e-07, Loss_r:8.02e-07, Loss_b:1.54e-07 # Valid:1.71e-06, RL2:6.38e-03
# Stage 3 Iter 15700 Time:3.2e+03 # Loss:4.05e-07, Loss_r:2.72e-07, Loss_b:1.33e-07 # Valid:2.06e-06, RL2:6.39e-03
# Stage 3 Iter 15800 Time:3.2e+03 # Loss:3.65e-07, Loss_r:2.44e-07, Loss_b:1.21e-07 # Valid:2.59e-06, RL2:5.73e-03
# Stage 3 Iter 15900 Time:3.2e+03 # Loss:7.12e-07, Loss_r:7.12e-07, Loss_b:1.21e-07 # Valid:2.12e-06, RL2:5.29e-03
# Stage 3 Iter 16000 Time:3.3e+03 # Loss:7.12e-07, Loss_r:7.12e-07, Loss_b:1.21e-07 # Valid:2.26e-06, RL2:5.40e-03
# Adjusting learning rate of group 0 to 6.6342e-04.
# Adjusting learning rate of group 0 to 6.6342e-05.
# Stage 3 Iter 16100 Time:3.3e+03 # Loss:3.87e-07, Loss_r:2.47e-07, Loss_b:1.39e-07 # Valid:2.05e-06, RL2:5.68e-03
# Stage 3 Iter 16200 Time:3.3e+03 # Loss:4.06e-07, Loss_r:2.51e-07, Loss_b:1.55e-07 # Valid:1.33e-06, RL2:5.00e-03
# Stage 3 Iter 16300 Time:3.3e+03 # Loss:3.74e-07, Loss_r:3.74e-07, Loss_b:1.55e-07 # Valid:1.32e-06, RL2:5.10e-03
# Stage 3 Iter 16400 Time:3.3e+03 # Loss:6.39e-07, Loss_r:6.39e-07, Loss_b:1.55e-07 # Valid:1.30e-06, RL2:4.57e-03
# Stage 3 Iter 16500 Time:3.4e+03 # Loss:3.09e-07, Loss_r:1.98e-07, Loss_b:1.11e-07 # Valid:1.15e-06, RL2:6.43e-03
# Stage 3 Iter 16600 Time:3.4e+03 # Loss:1.12e-06, Loss_r:4.17e-07, Loss_b:7.05e-07 # Valid:1.88e-06, RL2:9.37e-03
# Stage 3 Iter 16700 Time:3.4e+03 # Loss:6.01e-07, Loss_r:6.01e-07, Loss_b:7.05e-07 # Valid:1.80e-06, RL2:9.07e-03
# Stage 3 Iter 16800 Time:3.4e+03 # Loss:6.22e-07, Loss_r:6.22e-07, Loss_b:7.05e-07 # Valid:2.16e-06, RL2:8.86e-03
# Stage 3 Iter 16900 Time:3.5e+03 # Loss:8.01e-07, Loss_r:2.55e-07, Loss_b:5.46e-07 # Valid:2.01e-06, RL2:6.67e-03
# Stage 3 Iter 17000 Time:3.5e+03 # Loss:2.83e-07, Loss_r:1.76e-07, Loss_b:1.07e-07 # Valid:1.16e-06, RL2:5.78e-03
# Stage 3 Iter 17100 Time:3.5e+03 # Loss:4.09e-07, Loss_r:4.09e-07, Loss_b:1.07e-07 # Valid:1.25e-06, RL2:5.18e-03
# Stage 3 Iter 17200 Time:3.5e+03 # Loss:4.65e-07, Loss_r:4.65e-07, Loss_b:1.07e-07 # Valid:1.10e-06, RL2:5.44e-03
# Stage 3 Iter 17300 Time:3.5e+03 # Loss:2.90e-07, Loss_r:1.95e-07, Loss_b:9.53e-08 # Valid:1.11e-06, RL2:5.44e-03
# Stage 3 Iter 17400 Time:3.6e+03 # Loss:5.71e-07, Loss_r:3.74e-07, Loss_b:1.97e-07 # Valid:1.50e-06, RL2:6.41e-03
# Stage 3 Iter 17500 Time:3.6e+03 # Loss:6.25e-07, Loss_r:6.25e-07, Loss_b:1.97e-07 # Valid:1.43e-06, RL2:5.20e-03
# Stage 3 Iter 17600 Time:3.6e+03 # Loss:9.90e-07, Loss_r:9.90e-07, Loss_b:1.97e-07 # Valid:1.58e-06, RL2:6.53e-03
# Stage 3 Iter 17700 Time:3.6e+03 # Loss:4.11e-07, Loss_r:2.61e-07, Loss_b:1.49e-07 # Valid:1.52e-06, RL2:4.79e-03
# Stage 3 Iter 17800 Time:3.6e+03 # Loss:3.62e-07, Loss_r:2.30e-07, Loss_b:1.32e-07 # Valid:1.97e-06, RL2:5.08e-03
# Stage 3 Iter 17900 Time:3.7e+03 # Loss:3.32e-07, Loss_r:3.32e-07, Loss_b:1.32e-07 # Valid:2.34e-06, RL2:4.68e-03
# Stage 3 Iter 18000 Time:3.7e+03 # Loss:6.32e-07, Loss_r:6.32e-07, Loss_b:1.32e-07 # Valid:2.22e-06, RL2:5.01e-03
# Adjusting learning rate of group 0 to 6.3025e-04.
# Adjusting learning rate of group 0 to 6.3025e-05.
# Stage 3 Iter 18100 Time:3.7e+03 # Loss:2.85e-07, Loss_r:1.82e-07, Loss_b:1.04e-07 # Valid:1.70e-06, RL2:4.96e-03
# Stage 3 Iter 18200 Time:3.7e+03 # Loss:2.59e-07, Loss_r:1.59e-07, Loss_b:1.00e-07 # Valid:1.41e-06, RL2:5.94e-03
# Stage 3 Iter 18300 Time:3.7e+03 # Loss:4.63e-07, Loss_r:4.63e-07, Loss_b:1.00e-07 # Valid:1.33e-06, RL2:4.29e-03
# Stage 3 Iter 18400 Time:3.8e+03 # Loss:4.50e-07, Loss_r:4.50e-07, Loss_b:1.00e-07 # Valid:1.28e-06, RL2:4.77e-03
# Stage 3 Iter 18500 Time:3.8e+03 # Loss:2.75e-07, Loss_r:1.80e-07, Loss_b:9.47e-08 # Valid:1.14e-06, RL2:5.25e-03
# Stage 3 Iter 18600 Time:3.8e+03 # Loss:2.56e-07, Loss_r:1.60e-07, Loss_b:9.57e-08 # Valid:1.19e-06, RL2:5.23e-03
# Stage 3 Iter 18700 Time:3.8e+03 # Loss:2.64e-07, Loss_r:2.64e-07, Loss_b:9.57e-08 # Valid:1.17e-06, RL2:4.54e-03
# Stage 3 Iter 18800 Time:3.8e+03 # Loss:3.60e-07, Loss_r:3.60e-07, Loss_b:9.57e-08 # Valid:1.21e-06, RL2:4.75e-03
# Stage 3 Iter 18900 Time:3.9e+03 # Loss:2.94e-07, Loss_r:1.75e-07, Loss_b:1.19e-07 # Valid:1.17e-06, RL2:4.67e-03
# Stage 3 Iter 19000 Time:3.9e+03 # Loss:2.54e-07, Loss_r:1.46e-07, Loss_b:1.08e-07 # Valid:1.14e-06, RL2:4.95e-03
# Stage 3 Iter 19100 Time:3.9e+03 # Loss:8.26e-07, Loss_r:8.26e-07, Loss_b:1.08e-07 # Valid:9.47e-07, RL2:4.42e-03
# Stage 3 Iter 19200 Time:3.9e+03 # Loss:6.17e-07, Loss_r:6.17e-07, Loss_b:1.08e-07 # Valid:1.22e-06, RL2:3.90e-03
# Stage 3 Iter 19300 Time:3.9e+03 # Loss:2.16e-07, Loss_r:1.39e-07, Loss_b:7.73e-08 # Valid:6.81e-07, RL2:3.95e-03
# Stage 3 Iter 19400 Time:4.0e+03 # Loss:2.26e-07, Loss_r:1.47e-07, Loss_b:7.87e-08 # Valid:7.86e-07, RL2:4.54e-03
# Stage 3 Iter 19500 Time:4.0e+03 # Loss:4.33e-07, Loss_r:4.33e-07, Loss_b:7.87e-08 # Valid:6.62e-07, RL2:4.91e-03
# Stage 3 Iter 19600 Time:4.0e+03 # Loss:2.56e-07, Loss_r:2.56e-07, Loss_b:7.87e-08 # Valid:8.14e-07, RL2:4.68e-03
# Stage 3 Iter 19700 Time:4.0e+03 # Loss:2.12e-07, Loss_r:1.36e-07, Loss_b:7.61e-08 # Valid:5.29e-07, RL2:4.29e-03
# Stage 3 Iter 19800 Time:4.0e+03 # Loss:2.03e-07, Loss_r:1.24e-07, Loss_b:7.93e-08 # Valid:8.65e-07, RL2:4.39e-03
# Stage 3 Iter 19900 Time:4.1e+03 # Loss:6.20e-07, Loss_r:6.20e-07, Loss_b:7.93e-08 # Valid:6.73e-07, RL2:3.97e-03
# Stage 3 Iter 20000 Time:4.1e+03 # Loss:9.19e-07, Loss_r:9.19e-07, Loss_b:7.93e-08 # Valid:6.56e-07, RL2:3.63e-03
# Adjusting learning rate of group 0 to 5.9874e-04.
# Adjusting learning rate of group 0 to 5.9874e-05.
# Stage 3 Iter 20100 Time:4.1e+03 # Loss:2.04e-07, Loss_r:1.19e-07, Loss_b:8.55e-08 # Valid:7.89e-07, RL2:4.20e-03
# Stage 3 Iter 20200 Time:4.1e+03 # Loss:1.50e-07, Loss_r:9.29e-08, Loss_b:5.75e-08 # Valid:5.86e-07, RL2:4.16e-03
# Stage 3 Iter 20300 Time:4.2e+03 # Loss:6.12e-07, Loss_r:6.12e-07, Loss_b:5.75e-08 # Valid:7.41e-07, RL2:4.72e-03
# Stage 3 Iter 20400 Time:4.2e+03 # Loss:3.09e-07, Loss_r:3.09e-07, Loss_b:5.75e-08 # Valid:4.87e-07, RL2:3.57e-03
# Stage 3 Iter 20500 Time:4.2e+03 # Loss:1.69e-07, Loss_r:1.08e-07, Loss_b:6.10e-08 # Valid:6.77e-07, RL2:3.92e-03
# Stage 3 Iter 20600 Time:4.2e+03 # Loss:1.38e-06, Loss_r:1.44e-07, Loss_b:1.24e-06 # Valid:1.98e-06, RL2:1.37e-02
# Stage 3 Iter 20700 Time:4.2e+03 # Loss:2.80e-07, Loss_r:2.80e-07, Loss_b:1.24e-06 # Valid:1.67e-06, RL2:1.40e-02
# Stage 3 Iter 20800 Time:4.3e+03 # Loss:5.97e-07, Loss_r:5.97e-07, Loss_b:1.24e-06 # Valid:1.71e-06, RL2:1.43e-02
# Stage 3 Iter 20900 Time:4.3e+03 # Loss:1.71e-07, Loss_r:1.03e-07, Loss_b:6.80e-08 # Valid:5.73e-07, RL2:4.40e-03
# Stage 3 Iter 21000 Time:4.3e+03 # Loss:5.05e-07, Loss_r:3.11e-07, Loss_b:1.94e-07 # Valid:1.27e-06, RL2:4.91e-03
# Stage 3 Iter 21100 Time:4.3e+03 # Loss:3.52e-06, Loss_r:3.52e-06, Loss_b:1.94e-07 # Valid:1.53e-06, RL2:5.01e-03
# Stage 3 Iter 21200 Time:4.3e+03 # Loss:3.81e-06, Loss_r:3.81e-06, Loss_b:1.94e-07 # Valid:1.50e-06, RL2:5.67e-03
# Stage 3 Iter 21300 Time:4.4e+03 # Loss:3.54e-07, Loss_r:2.30e-07, Loss_b:1.24e-07 # Valid:1.34e-06, RL2:5.64e-03
# Stage 3 Iter 21400 Time:4.4e+03 # Loss:2.61e-07, Loss_r:1.66e-07, Loss_b:9.56e-08 # Valid:9.90e-07, RL2:4.84e-03
# Stage 3 Iter 21500 Time:4.4e+03 # Loss:4.76e-07, Loss_r:4.76e-07, Loss_b:9.56e-08 # Valid:1.06e-06, RL2:4.78e-03
# Stage 3 Iter 21600 Time:4.4e+03 # Loss:4.40e-07, Loss_r:4.40e-07, Loss_b:9.56e-08 # Valid:8.95e-07, RL2:3.87e-03
# Stage 3 Iter 21700 Time:4.4e+03 # Loss:2.27e-07, Loss_r:1.46e-07, Loss_b:8.06e-08 # Valid:1.12e-06, RL2:4.26e-03
# Stage 3 Iter 21800 Time:4.5e+03 # Loss:1.94e-07, Loss_r:1.30e-07, Loss_b:6.31e-08 # Valid:7.96e-07, RL2:4.18e-03
# Stage 3 Iter 21900 Time:4.5e+03 # Loss:4.06e-07, Loss_r:4.06e-07, Loss_b:6.31e-08 # Valid:1.24e-06, RL2:4.92e-03
# Stage 3 Iter 22000 Time:4.5e+03 # Loss:4.09e-07, Loss_r:4.09e-07, Loss_b:6.31e-08 # Valid:9.60e-07, RL2:5.27e-03
# Adjusting learning rate of group 0 to 5.6880e-04.
# Adjusting learning rate of group 0 to 5.6880e-05.
# Stage 3 Iter 22100 Time:4.5e+03 # Loss:2.27e-07, Loss_r:1.28e-07, Loss_b:9.90e-08 # Valid:1.03e-06, RL2:5.06e-03
# Stage 3 Iter 22200 Time:4.5e+03 # Loss:3.13e-07, Loss_r:1.18e-07, Loss_b:1.95e-07 # Valid:7.70e-07, RL2:4.66e-03
# Stage 3 Iter 22300 Time:4.6e+03 # Loss:6.46e-07, Loss_r:6.46e-07, Loss_b:1.95e-07 # Valid:8.91e-07, RL2:4.73e-03
# Stage 3 Iter 22400 Time:4.6e+03 # Loss:3.74e-07, Loss_r:3.74e-07, Loss_b:1.95e-07 # Valid:1.09e-06, RL2:4.85e-03
# Stage 3 Iter 22500 Time:4.6e+03 # Loss:1.73e-07, Loss_r:1.07e-07, Loss_b:6.62e-08 # Valid:6.56e-07, RL2:4.14e-03
# Stage 3 Iter 22600 Time:4.6e+03 # Loss:2.88e-06, Loss_r:1.22e-07, Loss_b:2.76e-06 # Valid:4.51e-06, RL2:2.52e-02
# Stage 3 Iter 22700 Time:4.6e+03 # Loss:4.62e-07, Loss_r:4.62e-07, Loss_b:2.76e-06 # Valid:4.54e-06, RL2:2.43e-02
# Stage 3 Iter 22800 Time:4.7e+03 # Loss:2.66e-07, Loss_r:2.66e-07, Loss_b:2.76e-06 # Valid:4.50e-06, RL2:2.49e-02
# Stage 3 Iter 22900 Time:4.7e+03 # Loss:1.43e-07, Loss_r:9.86e-08, Loss_b:4.42e-08 # Valid:4.65e-07, RL2:4.16e-03
# Stage 3 Iter 23000 Time:4.7e+03 # Loss:1.63e-07, Loss_r:9.02e-08, Loss_b:7.29e-08 # Valid:5.61e-07, RL2:3.73e-03
# Stage 3 Iter 23100 Time:4.7e+03 # Loss:2.23e-07, Loss_r:2.23e-07, Loss_b:7.29e-08 # Valid:4.61e-07, RL2:4.12e-03
# Stage 3 Iter 23200 Time:4.7e+03 # Loss:2.78e-07, Loss_r:2.78e-07, Loss_b:7.29e-08 # Valid:5.28e-07, RL2:4.45e-03
# Stage 3 Iter 23300 Time:4.8e+03 # Loss:1.37e-07, Loss_r:8.05e-08, Loss_b:5.66e-08 # Valid:4.22e-07, RL2:3.82e-03
# Stage 3 Iter 23400 Time:4.8e+03 # Loss:1.34e-07, Loss_r:8.33e-08, Loss_b:5.07e-08 # Valid:5.34e-07, RL2:3.84e-03
# Stage 3 Iter 23500 Time:4.8e+03 # Loss:2.31e-07, Loss_r:2.31e-07, Loss_b:5.07e-08 # Valid:3.86e-07, RL2:3.95e-03
# Stage 3 Iter 23600 Time:4.8e+03 # Loss:3.98e-07, Loss_r:3.98e-07, Loss_b:5.07e-08 # Valid:4.11e-07, RL2:2.99e-03
# Stage 3 Iter 23700 Time:4.9e+03 # Loss:1.43e-07, Loss_r:7.83e-08, Loss_b:6.42e-08 # Valid:5.12e-07, RL2:4.75e-03
# Stage 3 Iter 23800 Time:4.9e+03 # Loss:1.92e-07, Loss_r:1.13e-07, Loss_b:7.90e-08 # Valid:3.69e-07, RL2:4.54e-03
# Stage 3 Iter 23900 Time:4.9e+03 # Loss:2.31e-07, Loss_r:2.31e-07, Loss_b:7.90e-08 # Valid:4.93e-07, RL2:4.01e-03
# Stage 3 Iter 24000 Time:4.9e+03 # Loss:2.42e-07, Loss_r:2.42e-07, Loss_b:7.90e-08 # Valid:4.50e-07, RL2:3.56e-03
# Adjusting learning rate of group 0 to 5.4036e-04.
# Adjusting learning rate of group 0 to 5.4036e-05.
# Stage 3 Iter 24100 Time:4.9e+03 # Loss:1.45e-07, Loss_r:9.23e-08, Loss_b:5.24e-08 # Valid:4.03e-07, RL2:3.65e-03
# Stage 3 Iter 24200 Time:5.0e+03 # Loss:1.32e-07, Loss_r:7.67e-08, Loss_b:5.54e-08 # Valid:4.33e-07, RL2:3.39e-03
# Stage 3 Iter 24300 Time:5.0e+03 # Loss:4.12e-07, Loss_r:4.12e-07, Loss_b:5.54e-08 # Valid:5.17e-07, RL2:2.95e-03
# Stage 3 Iter 24400 Time:5.0e+03 # Loss:4.64e-07, Loss_r:4.64e-07, Loss_b:5.54e-08 # Valid:4.13e-07, RL2:2.88e-03
# Stage 3 Iter 24500 Time:5.0e+03 # Loss:1.86e-07, Loss_r:9.30e-08, Loss_b:9.28e-08 # Valid:5.14e-07, RL2:3.92e-03
# Stage 3 Iter 24600 Time:5.0e+03 # Loss:1.08e-07, Loss_r:6.54e-08, Loss_b:4.30e-08 # Valid:4.22e-07, RL2:3.11e-03
# Stage 3 Iter 24700 Time:5.1e+03 # Loss:2.71e-07, Loss_r:2.71e-07, Loss_b:4.30e-08 # Valid:6.32e-07, RL2:4.72e-03
# Stage 3 Iter 24800 Time:5.1e+03 # Loss:2.06e-07, Loss_r:2.06e-07, Loss_b:4.30e-08 # Valid:4.54e-07, RL2:3.30e-03
# Stage 3 Iter 24900 Time:5.1e+03 # Loss:1.04e-07, Loss_r:5.81e-08, Loss_b:4.56e-08 # Valid:4.84e-07, RL2:3.32e-03
# Stage 3 Iter 25000 Time:5.1e+03 # Loss:1.54e-07, Loss_r:9.50e-08, Loss_b:5.94e-08 # Valid:4.18e-07, RL2:4.21e-03
# Stage 3 Iter 25100 Time:5.1e+03 # Loss:2.01e-07, Loss_r:2.01e-07, Loss_b:5.94e-08 # Valid:5.31e-07, RL2:3.30e-03
# Stage 3 Iter 25200 Time:5.2e+03 # Loss:2.62e-07, Loss_r:2.62e-07, Loss_b:5.94e-08 # Valid:4.23e-07, RL2:3.57e-03
# Stage 3 Iter 25300 Time:5.2e+03 # Loss:1.03e-07, Loss_r:6.76e-08, Loss_b:3.49e-08 # Valid:3.53e-07, RL2:3.43e-03
# Stage 3 Iter 25400 Time:5.2e+03 # Loss:1.19e-07, Loss_r:6.63e-08, Loss_b:5.29e-08 # Valid:3.62e-07, RL2:2.98e-03
# Stage 3 Iter 25500 Time:5.2e+03 # Loss:1.98e-07, Loss_r:1.98e-07, Loss_b:5.29e-08 # Valid:4.88e-07, RL2:2.71e-03
# Stage 3 Iter 25600 Time:5.2e+03 # Loss:2.01e-07, Loss_r:2.01e-07, Loss_b:5.29e-08 # Valid:4.79e-07, RL2:2.62e-03
# Stage 3 Iter 25700 Time:5.3e+03 # Loss:3.18e-06, Loss_r:1.94e-06, Loss_b:1.24e-06 # Valid:1.99e-06, RL2:1.26e-02
# Stage 3 Iter 25800 Time:5.3e+03 # Loss:7.15e-06, Loss_r:3.88e-06, Loss_b:3.27e-06 # Valid:5.93e-06, RL2:2.49e-02
# Stage 3 Iter 25900 Time:5.3e+03 # Loss:9.17e-07, Loss_r:9.17e-07, Loss_b:3.27e-06 # Valid:6.02e-06, RL2:2.24e-02
# Stage 3 Iter 26000 Time:5.3e+03 # Loss:8.82e-07, Loss_r:8.82e-07, Loss_b:3.27e-06 # Valid:5.71e-06, RL2:2.44e-02
# Adjusting learning rate of group 0 to 5.1334e-04.
# Adjusting learning rate of group 0 to 5.1334e-05.
# Stage 3 Iter 26100 Time:5.3e+03 # Loss:1.73e-06, Loss_r:9.26e-07, Loss_b:8.01e-07 # Valid:2.75e-06, RL2:1.32e-02
# Stage 3 Iter 26200 Time:5.4e+03 # Loss:1.41e-06, Loss_r:9.37e-07, Loss_b:4.76e-07 # Valid:1.62e-06, RL2:9.65e-03
# Stage 3 Iter 26300 Time:5.4e+03 # Loss:1.78e-06, Loss_r:1.78e-06, Loss_b:4.76e-07 # Valid:1.97e-06, RL2:1.11e-02
# Stage 3 Iter 26400 Time:5.4e+03 # Loss:1.11e-06, Loss_r:1.11e-06, Loss_b:4.76e-07 # Valid:2.15e-06, RL2:1.16e-02
# Stage 3 Iter 26500 Time:5.4e+03 # Loss:9.17e-07, Loss_r:5.99e-07, Loss_b:3.18e-07 # Valid:1.90e-06, RL2:8.15e-03
# Stage 3 Iter 26600 Time:5.4e+03 # Loss:1.67e-06, Loss_r:1.12e-06, Loss_b:5.50e-07 # Valid:1.72e-06, RL2:1.06e-02
# Stage 3 Iter 26700 Time:5.5e+03 # Loss:8.50e-07, Loss_r:8.50e-07, Loss_b:5.50e-07 # Valid:1.55e-06, RL2:9.43e-03
# Stage 3 Iter 26800 Time:5.5e+03 # Loss:1.67e-06, Loss_r:1.67e-06, Loss_b:5.50e-07 # Valid:1.71e-06, RL2:9.47e-03
# Stage 3 Iter 26900 Time:5.5e+03 # Loss:1.05e-06, Loss_r:7.26e-07, Loss_b:3.20e-07 # Valid:1.42e-06, RL2:7.15e-03
# Stage 3 Iter 27000 Time:5.5e+03 # Loss:8.80e-07, Loss_r:6.27e-07, Loss_b:2.53e-07 # Valid:1.54e-06, RL2:8.57e-03
# Stage 3 Iter 27100 Time:5.6e+03 # Loss:1.07e-06, Loss_r:1.07e-06, Loss_b:2.53e-07 # Valid:1.61e-06, RL2:7.10e-03
# Stage 3 Iter 27200 Time:5.6e+03 # Loss:8.67e-07, Loss_r:8.67e-07, Loss_b:2.53e-07 # Valid:1.48e-06, RL2:7.76e-03
# Stage 3 Iter 27300 Time:5.6e+03 # Loss:8.84e-07, Loss_r:5.15e-07, Loss_b:3.69e-07 # Valid:1.86e-06, RL2:5.99e-03
# Stage 3 Iter 27400 Time:5.6e+03 # Loss:6.70e-07, Loss_r:4.86e-07, Loss_b:1.84e-07 # Valid:1.63e-06, RL2:5.51e-03
# Stage 3 Iter 27500 Time:5.6e+03 # Loss:1.93e-06, Loss_r:1.93e-06, Loss_b:1.84e-07 # Valid:1.67e-06, RL2:5.78e-03
# Stage 3 Iter 27600 Time:5.7e+03 # Loss:2.03e-06, Loss_r:2.03e-06, Loss_b:1.84e-07 # Valid:1.49e-06, RL2:7.16e-03
# Stage 3 Iter 27700 Time:5.7e+03 # Loss:9.67e-07, Loss_r:6.73e-07, Loss_b:2.93e-07 # Valid:1.19e-06, RL2:8.61e-03
# Stage 3 Iter 27800 Time:5.7e+03 # Loss:5.95e-07, Loss_r:4.19e-07, Loss_b:1.76e-07 # Valid:1.21e-06, RL2:5.56e-03
# Stage 3 Iter 27900 Time:5.7e+03 # Loss:4.94e-07, Loss_r:4.94e-07, Loss_b:1.76e-07 # Valid:1.08e-06, RL2:6.73e-03
# Stage 3 Iter 28000 Time:5.7e+03 # Loss:7.63e-07, Loss_r:7.63e-07, Loss_b:1.76e-07 # Valid:1.15e-06, RL2:6.45e-03
# Adjusting learning rate of group 0 to 4.8767e-04.
# Adjusting learning rate of group 0 to 4.8767e-05.
# Stage 3 Iter 28100 Time:5.8e+03 # Loss:7.84e-07, Loss_r:4.75e-07, Loss_b:3.08e-07 # Valid:1.62e-06, RL2:9.72e-03
# Stage 3 Iter 28200 Time:5.8e+03 # Loss:4.50e-06, Loss_r:6.35e-07, Loss_b:3.86e-06 # Valid:7.36e-06, RL2:2.98e-02
# Stage 3 Iter 28300 Time:5.8e+03 # Loss:1.39e-06, Loss_r:1.39e-06, Loss_b:3.86e-06 # Valid:7.62e-06, RL2:2.96e-02
# Stage 3 Iter 28400 Time:5.8e+03 # Loss:1.36e-06, Loss_r:1.36e-06, Loss_b:3.86e-06 # Valid:7.41e-06, RL2:3.11e-02
# Stage 3 Iter 28500 Time:5.8e+03 # Loss:6.81e-07, Loss_r:4.78e-07, Loss_b:2.03e-07 # Valid:1.31e-06, RL2:6.33e-03
# Stage 3 Iter 28600 Time:5.9e+03 # Loss:4.99e-07, Loss_r:3.25e-07, Loss_b:1.75e-07 # Valid:1.34e-06, RL2:4.45e-03
# Stage 3 Iter 28700 Time:5.9e+03 # Loss:7.60e-07, Loss_r:7.60e-07, Loss_b:1.75e-07 # Valid:1.52e-06, RL2:5.76e-03
# Stage 3 Iter 28800 Time:5.9e+03 # Loss:2.05e-06, Loss_r:2.05e-06, Loss_b:1.75e-07 # Valid:1.40e-06, RL2:5.34e-03
# Stage 3 Iter 28900 Time:5.9e+03 # Loss:7.19e-07, Loss_r:5.04e-07, Loss_b:2.16e-07 # Valid:9.50e-07, RL2:5.51e-03
# Stage 3 Iter 29000 Time:5.9e+03 # Loss:6.17e-07, Loss_r:4.27e-07, Loss_b:1.90e-07 # Valid:1.09e-06, RL2:4.90e-03
# Stage 3 Iter 29100 Time:6.0e+03 # Loss:4.51e-07, Loss_r:4.51e-07, Loss_b:1.90e-07 # Valid:1.16e-06, RL2:5.36e-03
# Stage 3 Iter 29200 Time:6.0e+03 # Loss:5.58e-07, Loss_r:5.58e-07, Loss_b:1.90e-07 # Valid:1.10e-06, RL2:7.91e-03
# Stage 3 Iter 29300 Time:6.0e+03 # Loss:7.28e-07, Loss_r:4.58e-07, Loss_b:2.71e-07 # Valid:9.29e-07, RL2:5.53e-03
# Stage 3 Iter 29400 Time:6.0e+03 # Loss:4.45e-07, Loss_r:3.26e-07, Loss_b:1.20e-07 # Valid:1.15e-06, RL2:4.69e-03
# Stage 3 Iter 29500 Time:6.0e+03 # Loss:4.28e-07, Loss_r:4.28e-07, Loss_b:1.20e-07 # Valid:1.06e-06, RL2:5.22e-03
# Stage 3 Iter 29600 Time:6.1e+03 # Loss:5.29e-07, Loss_r:5.29e-07, Loss_b:1.20e-07 # Valid:1.17e-06, RL2:5.51e-03
# Stage 3 Iter 29700 Time:6.1e+03 # Loss:4.80e-07, Loss_r:3.47e-07, Loss_b:1.33e-07 # Valid:9.87e-07, RL2:4.82e-03
# Stage 3 Iter 29800 Time:6.1e+03 # Loss:3.42e-07, Loss_r:2.49e-07, Loss_b:9.26e-08 # Valid:1.19e-06, RL2:5.67e-03
# Stage 3 Iter 29900 Time:6.1e+03 # Loss:7.10e-07, Loss_r:7.10e-07, Loss_b:9.26e-08 # Valid:8.59e-07, RL2:5.01e-03
# Stage 3 Iter 30000 Time:6.2e+03 # Loss:4.80e-07, Loss_r:4.80e-07, Loss_b:9.26e-08 # Valid:1.04e-06, RL2:6.32e-03
# Adjusting learning rate of group 0 to 4.6329e-04.
# Adjusting learning rate of group 0 to 4.6329e-05.
# Stage 3 Iter 30100 Time:6.2e+03 # Loss:4.16e-07, Loss_r:2.65e-07, Loss_b:1.51e-07 # Valid:8.91e-07, RL2:4.80e-03
# Stage 3 Iter 30200 Time:6.2e+03 # Loss:7.98e-07, Loss_r:4.16e-07, Loss_b:3.82e-07 # Valid:1.40e-06, RL2:1.08e-02
# Stage 3 Iter 30300 Time:6.2e+03 # Loss:5.27e-07, Loss_r:5.27e-07, Loss_b:3.82e-07 # Valid:1.67e-06, RL2:1.11e-02
# Stage 3 Iter 30400 Time:6.2e+03 # Loss:6.66e-07, Loss_r:6.66e-07, Loss_b:3.82e-07 # Valid:1.36e-06, RL2:1.00e-02
# Stage 3 Iter 30500 Time:6.3e+03 # Loss:3.83e-07, Loss_r:2.65e-07, Loss_b:1.18e-07 # Valid:8.62e-07, RL2:4.65e-03
# Stage 3 Iter 30600 Time:6.3e+03 # Loss:4.22e-07, Loss_r:2.96e-07, Loss_b:1.26e-07 # Valid:9.22e-07, RL2:6.08e-03
# Stage 3 Iter 30700 Time:6.3e+03 # Loss:3.44e-07, Loss_r:3.44e-07, Loss_b:1.26e-07 # Valid:9.72e-07, RL2:5.84e-03
# Stage 3 Iter 30800 Time:6.3e+03 # Loss:3.79e-07, Loss_r:3.79e-07, Loss_b:1.26e-07 # Valid:8.40e-07, RL2:5.16e-03
# Stage 3 Iter 30900 Time:6.3e+03 # Loss:6.15e-07, Loss_r:3.14e-07, Loss_b:3.01e-07 # Valid:9.33e-07, RL2:7.44e-03
# Stage 3 Iter 31000 Time:6.4e+03 # Loss:3.60e-07, Loss_r:2.50e-07, Loss_b:1.10e-07 # Valid:8.27e-07, RL2:3.98e-03
# Stage 3 Iter 31100 Time:6.4e+03 # Loss:3.59e-07, Loss_r:3.59e-07, Loss_b:1.10e-07 # Valid:1.06e-06, RL2:4.51e-03
# Stage 3 Iter 31200 Time:6.4e+03 # Loss:6.95e-07, Loss_r:6.95e-07, Loss_b:1.10e-07 # Valid:9.16e-07, RL2:5.30e-03
# Stage 3 Iter 31300 Time:6.4e+03 # Loss:4.01e-07, Loss_r:2.71e-07, Loss_b:1.30e-07 # Valid:8.69e-07, RL2:4.95e-03
# Stage 3 Iter 31400 Time:6.4e+03 # Loss:3.94e-07, Loss_r:2.58e-07, Loss_b:1.35e-07 # Valid:1.32e-06, RL2:6.19e-03
# Stage 3 Iter 31500 Time:6.5e+03 # Loss:3.99e-07, Loss_r:3.99e-07, Loss_b:1.35e-07 # Valid:7.86e-07, RL2:4.88e-03
# Stage 3 Iter 31600 Time:6.5e+03 # Loss:2.75e-07, Loss_r:2.75e-07, Loss_b:1.35e-07 # Valid:8.88e-07, RL2:5.57e-03
# Stage 3 Iter 31700 Time:6.5e+03 # Loss:3.69e-07, Loss_r:2.40e-07, Loss_b:1.29e-07 # Valid:1.16e-06, RL2:4.59e-03
# Stage 3 Iter 31800 Time:6.5e+03 # Loss:3.67e-07, Loss_r:2.40e-07, Loss_b:1.27e-07 # Valid:1.46e-06, RL2:6.37e-03
# Stage 3 Iter 31900 Time:6.5e+03 # Loss:3.45e-07, Loss_r:3.45e-07, Loss_b:1.27e-07 # Valid:1.24e-06, RL2:5.78e-03
# Stage 3 Iter 32000 Time:6.6e+03 # Loss:3.52e-07, Loss_r:3.52e-07, Loss_b:1.27e-07 # Valid:1.34e-06, RL2:4.41e-03
# Adjusting learning rate of group 0 to 4.4013e-04.
# Adjusting learning rate of group 0 to 4.4013e-05.
# Stage 3 Iter 32100 Time:6.6e+03 # Loss:5.39e-07, Loss_r:2.43e-07, Loss_b:2.95e-07 # Valid:1.55e-06, RL2:8.22e-03
# Stage 3 Iter 32200 Time:6.6e+03 # Loss:3.80e-07, Loss_r:2.36e-07, Loss_b:1.44e-07 # Valid:1.08e-06, RL2:5.62e-03
# Stage 3 Iter 32300 Time:6.6e+03 # Loss:3.07e-07, Loss_r:3.07e-07, Loss_b:1.44e-07 # Valid:8.98e-07, RL2:4.88e-03
# Stage 3 Iter 32400 Time:6.6e+03 # Loss:2.53e-07, Loss_r:2.53e-07, Loss_b:1.44e-07 # Valid:1.01e-06, RL2:6.98e-03
# Stage 3 Iter 32500 Time:6.7e+03 # Loss:3.10e-07, Loss_r:1.98e-07, Loss_b:1.12e-07 # Valid:1.48e-06, RL2:5.93e-03
# Stage 3 Iter 32600 Time:6.7e+03 # Loss:2.63e-07, Loss_r:1.83e-07, Loss_b:7.99e-08 # Valid:1.22e-06, RL2:4.27e-03
# Stage 3 Iter 32700 Time:6.7e+03 # Loss:3.08e-07, Loss_r:3.08e-07, Loss_b:7.99e-08 # Valid:1.30e-06, RL2:4.21e-03
# Stage 3 Iter 32800 Time:6.7e+03 # Loss:4.31e-07, Loss_r:4.31e-07, Loss_b:7.99e-08 # Valid:1.49e-06, RL2:4.63e-03
# Stage 3 Iter 32900 Time:6.7e+03 # Loss:3.33e-07, Loss_r:2.14e-07, Loss_b:1.18e-07 # Valid:1.42e-06, RL2:4.80e-03
# Stage 3 Iter 33000 Time:6.8e+03 # Loss:3.32e-07, Loss_r:2.09e-07, Loss_b:1.23e-07 # Valid:1.76e-06, RL2:4.12e-03
# Stage 3 Iter 33100 Time:6.8e+03 # Loss:3.04e-07, Loss_r:3.04e-07, Loss_b:1.23e-07 # Valid:1.87e-06, RL2:4.76e-03
# Stage 3 Iter 33200 Time:6.8e+03 # Loss:2.64e-07, Loss_r:2.64e-07, Loss_b:1.23e-07 # Valid:1.70e-06, RL2:4.63e-03
# Stage 3 Iter 33300 Time:6.8e+03 # Loss:2.81e-07, Loss_r:1.99e-07, Loss_b:8.14e-08 # Valid:1.42e-06, RL2:4.93e-03
# Stage 3 Iter 33400 Time:6.9e+03 # Loss:3.09e-06, Loss_r:3.71e-07, Loss_b:2.71e-06 # Valid:3.64e-06, RL2:1.93e-02
# Stage 3 Iter 33500 Time:6.9e+03 # Loss:3.82e-07, Loss_r:3.82e-07, Loss_b:2.71e-06 # Valid:3.62e-06, RL2:1.89e-02
# Stage 3 Iter 33600 Time:6.9e+03 # Loss:4.29e-07, Loss_r:4.29e-07, Loss_b:2.71e-06 # Valid:3.87e-06, RL2:2.01e-02
# Stage 3 Iter 33700 Time:6.9e+03 # Loss:3.19e-07, Loss_r:2.10e-07, Loss_b:1.09e-07 # Valid:8.96e-07, RL2:6.18e-03
# Stage 3 Iter 33800 Time:6.9e+03 # Loss:3.12e-07, Loss_r:1.89e-07, Loss_b:1.23e-07 # Valid:1.20e-06, RL2:4.21e-03
# Stage 3 Iter 33900 Time:7.0e+03 # Loss:2.73e-07, Loss_r:2.73e-07, Loss_b:1.23e-07 # Valid:9.21e-07, RL2:4.19e-03
# Stage 3 Iter 34000 Time:7.0e+03 # Loss:2.66e-07, Loss_r:2.66e-07, Loss_b:1.23e-07 # Valid:8.58e-07, RL2:3.99e-03
# Adjusting learning rate of group 0 to 4.1812e-04.
# Adjusting learning rate of group 0 to 4.1812e-05.
# Stage 3 Iter 34100 Time:7.0e+03 # Loss:7.01e-07, Loss_r:2.50e-07, Loss_b:4.51e-07 # Valid:1.09e-06, RL2:8.06e-03
# Stage 3 Iter 34200 Time:7.0e+03 # Loss:2.82e-07, Loss_r:1.77e-07, Loss_b:1.05e-07 # Valid:1.09e-06, RL2:4.75e-03
# Stage 3 Iter 34300 Time:7.0e+03 # Loss:2.19e-07, Loss_r:2.19e-07, Loss_b:1.05e-07 # Valid:9.52e-07, RL2:4.80e-03
# Stage 3 Iter 34400 Time:7.1e+03 # Loss:2.49e-07, Loss_r:2.49e-07, Loss_b:1.05e-07 # Valid:1.23e-06, RL2:4.89e-03
# Stage 3 Iter 34500 Time:7.1e+03 # Loss:2.59e-07, Loss_r:1.67e-07, Loss_b:9.26e-08 # Valid:9.03e-07, RL2:6.10e-03
# Stage 3 Iter 34600 Time:7.1e+03 # Loss:2.29e-07, Loss_r:1.48e-07, Loss_b:8.11e-08 # Valid:8.22e-07, RL2:3.76e-03
# Stage 3 Iter 34700 Time:7.1e+03 # Loss:1.99e-07, Loss_r:1.99e-07, Loss_b:8.11e-08 # Valid:7.70e-07, RL2:5.15e-03
# Stage 3 Iter 34800 Time:7.1e+03 # Loss:2.05e-07, Loss_r:2.05e-07, Loss_b:8.11e-08 # Valid:8.30e-07, RL2:3.75e-03
# Stage 3 Iter 34900 Time:7.2e+03 # Loss:2.52e-07, Loss_r:1.66e-07, Loss_b:8.55e-08 # Valid:1.01e-06, RL2:4.46e-03
# Stage 3 Iter 35000 Time:7.2e+03 # Loss:3.67e-06, Loss_r:3.85e-07, Loss_b:3.28e-06 # Valid:2.36e-06, RL2:1.42e-02
# Stage 3 Iter 35100 Time:7.2e+03 # Loss:3.73e-07, Loss_r:3.73e-07, Loss_b:3.28e-06 # Valid:2.31e-06, RL2:1.37e-02
# Stage 3 Iter 35200 Time:7.2e+03 # Loss:2.87e-07, Loss_r:2.87e-07, Loss_b:3.28e-06 # Valid:2.12e-06, RL2:1.44e-02
# Stage 3 Iter 35300 Time:7.2e+03 # Loss:2.60e-07, Loss_r:1.62e-07, Loss_b:9.83e-08 # Valid:7.99e-07, RL2:3.60e-03
# Stage 3 Iter 35400 Time:7.3e+03 # Loss:1.85e-07, Loss_r:1.16e-07, Loss_b:6.95e-08 # Valid:7.63e-07, RL2:5.44e-03
# Stage 3 Iter 35500 Time:7.3e+03 # Loss:2.01e-07, Loss_r:2.01e-07, Loss_b:6.95e-08 # Valid:8.48e-07, RL2:4.21e-03
# Stage 3 Iter 35600 Time:7.3e+03 # Loss:2.21e-07, Loss_r:2.21e-07, Loss_b:6.95e-08 # Valid:6.80e-07, RL2:4.35e-03
# Stage 3 Iter 35700 Time:7.3e+03 # Loss:2.37e-07, Loss_r:1.37e-07, Loss_b:1.00e-07 # Valid:8.37e-07, RL2:4.19e-03
# Stage 3 Iter 35800 Time:7.3e+03 # Loss:1.76e-07, Loss_r:1.14e-07, Loss_b:6.18e-08 # Valid:7.77e-07, RL2:5.05e-03
# Stage 3 Iter 35900 Time:7.4e+03 # Loss:2.67e-07, Loss_r:2.67e-07, Loss_b:6.18e-08 # Valid:6.36e-07, RL2:3.21e-03
# Stage 3 Iter 36000 Time:7.4e+03 # Loss:1.67e-07, Loss_r:1.67e-07, Loss_b:6.18e-08 # Valid:7.03e-07, RL2:4.26e-03
# Adjusting learning rate of group 0 to 3.9721e-04.
# Adjusting learning rate of group 0 to 3.9721e-05.
# Stage 3 Iter 36100 Time:7.4e+03 # Loss:1.72e-07, Loss_r:1.10e-07, Loss_b:6.18e-08 # Valid:6.48e-07, RL2:3.41e-03
# Stage 3 Iter 36200 Time:7.4e+03 # Loss:2.29e-07, Loss_r:1.23e-07, Loss_b:1.06e-07 # Valid:8.59e-07, RL2:3.42e-03
# Stage 3 Iter 36300 Time:7.5e+03 # Loss:2.26e-07, Loss_r:2.26e-07, Loss_b:1.06e-07 # Valid:1.04e-06, RL2:4.99e-03
# Stage 3 Iter 36400 Time:7.5e+03 # Loss:1.87e-07, Loss_r:1.87e-07, Loss_b:1.06e-07 # Valid:8.77e-07, RL2:4.46e-03
# Stage 3 Iter 36500 Time:7.5e+03 # Loss:1.88e-07, Loss_r:1.19e-07, Loss_b:6.94e-08 # Valid:6.83e-07, RL2:5.41e-03
# Stage 3 Iter 36600 Time:7.5e+03 # Loss:1.78e-07, Loss_r:9.94e-08, Loss_b:7.82e-08 # Valid:9.44e-07, RL2:3.41e-03
# Stage 3 Iter 36700 Time:7.5e+03 # Loss:1.26e-07, Loss_r:1.26e-07, Loss_b:7.82e-08 # Valid:6.40e-07, RL2:3.67e-03
# Stage 3 Iter 36800 Time:7.6e+03 # Loss:1.98e-07, Loss_r:1.98e-07, Loss_b:7.82e-08 # Valid:5.47e-07, RL2:3.03e-03
# Stage 3 Iter 36900 Time:7.6e+03 # Loss:1.60e-07, Loss_r:9.56e-08, Loss_b:6.46e-08 # Valid:8.29e-07, RL2:3.27e-03
# Stage 3 Iter 37000 Time:7.6e+03 # Loss:3.24e-07, Loss_r:2.06e-07, Loss_b:1.18e-07 # Valid:1.27e-06, RL2:7.33e-03
# Stage 3 Iter 37100 Time:7.6e+03 # Loss:8.72e-07, Loss_r:8.72e-07, Loss_b:1.18e-07 # Valid:1.34e-06, RL2:7.56e-03
# Stage 3 Iter 37200 Time:7.6e+03 # Loss:1.03e-06, Loss_r:1.03e-06, Loss_b:1.18e-07 # Valid:1.46e-06, RL2:8.48e-03
# Stage 3 Iter 37300 Time:7.7e+03 # Loss:2.73e-07, Loss_r:1.67e-07, Loss_b:1.06e-07 # Valid:1.10e-06, RL2:5.46e-03
# Stage 3 Iter 37400 Time:7.7e+03 # Loss:2.04e-07, Loss_r:1.32e-07, Loss_b:7.27e-08 # Valid:8.08e-07, RL2:5.46e-03
# Stage 3 Iter 37500 Time:7.7e+03 # Loss:1.72e-07, Loss_r:1.72e-07, Loss_b:7.27e-08 # Valid:7.55e-07, RL2:4.95e-03
# Stage 3 Iter 37600 Time:7.7e+03 # Loss:2.45e-07, Loss_r:2.45e-07, Loss_b:7.27e-08 # Valid:7.96e-07, RL2:6.00e-03
# Stage 3 Iter 37700 Time:7.7e+03 # Loss:2.37e-07, Loss_r:1.34e-07, Loss_b:1.03e-07 # Valid:6.23e-07, RL2:4.12e-03
# Stage 3 Iter 37800 Time:7.8e+03 # Loss:3.18e-07, Loss_r:1.36e-07, Loss_b:1.82e-07 # Valid:7.24e-07, RL2:5.97e-03
# Stage 3 Iter 37900 Time:7.8e+03 # Loss:2.68e-07, Loss_r:2.68e-07, Loss_b:1.82e-07 # Valid:7.71e-07, RL2:4.62e-03
# Stage 3 Iter 38000 Time:7.8e+03 # Loss:2.88e-07, Loss_r:2.88e-07, Loss_b:1.82e-07 # Valid:7.49e-07, RL2:4.44e-03
# Adjusting learning rate of group 0 to 3.7735e-04.
# Adjusting learning rate of group 0 to 3.7735e-05.
# Stage 3 Iter 38100 Time:7.8e+03 # Loss:1.56e-07, Loss_r:1.04e-07, Loss_b:5.27e-08 # Valid:6.10e-07, RL2:3.47e-03
# Stage 3 Iter 38200 Time:7.8e+03 # Loss:5.67e-07, Loss_r:1.35e-07, Loss_b:4.32e-07 # Valid:8.62e-07, RL2:9.19e-03
# Stage 3 Iter 38300 Time:7.9e+03 # Loss:1.52e-07, Loss_r:1.52e-07, Loss_b:4.32e-07 # Valid:8.78e-07, RL2:8.70e-03
# Stage 3 Iter 38400 Time:7.9e+03 # Loss:1.57e-07, Loss_r:1.57e-07, Loss_b:4.32e-07 # Valid:8.87e-07, RL2:9.74e-03
# Stage 3 Iter 38500 Time:7.9e+03 # Loss:1.49e-07, Loss_r:9.24e-08, Loss_b:5.70e-08 # Valid:3.16e-07, RL2:3.66e-03
# Stage 3 Iter 38600 Time:7.9e+03 # Loss:1.37e-07, Loss_r:8.62e-08, Loss_b:5.12e-08 # Valid:3.34e-07, RL2:5.15e-03
# Stage 3 Iter 38700 Time:7.9e+03 # Loss:9.50e-08, Loss_r:9.50e-08, Loss_b:5.12e-08 # Valid:2.95e-07, RL2:5.66e-03
# Stage 3 Iter 38800 Time:8.0e+03 # Loss:2.00e-07, Loss_r:2.00e-07, Loss_b:5.12e-08 # Valid:3.08e-07, RL2:3.43e-03
# Stage 3 Iter 38900 Time:8.0e+03 # Loss:1.46e-07, Loss_r:8.60e-08, Loss_b:6.01e-08 # Valid:4.63e-07, RL2:3.88e-03
# Stage 3 Iter 39000 Time:8.0e+03 # Loss:1.16e-07, Loss_r:7.19e-08, Loss_b:4.46e-08 # Valid:4.07e-07, RL2:3.44e-03
# Stage 3 Iter 39100 Time:8.0e+03 # Loss:1.30e-07, Loss_r:1.30e-07, Loss_b:4.46e-08 # Valid:3.29e-07, RL2:3.00e-03
# Stage 3 Iter 39200 Time:8.0e+03 # Loss:1.30e-07, Loss_r:1.30e-07, Loss_b:4.46e-08 # Valid:3.79e-07, RL2:2.86e-03
# Stage 3 Iter 39300 Time:8.1e+03 # Loss:1.26e-07, Loss_r:8.00e-08, Loss_b:4.58e-08 # Valid:3.60e-07, RL2:3.16e-03
# Stage 3 Iter 39400 Time:8.1e+03 # Loss:1.12e-07, Loss_r:6.76e-08, Loss_b:4.46e-08 # Valid:3.69e-07, RL2:3.74e-03
# Stage 3 Iter 39500 Time:8.1e+03 # Loss:1.72e-07, Loss_r:1.72e-07, Loss_b:4.46e-08 # Valid:3.58e-07, RL2:3.08e-03
# Stage 3 Iter 39600 Time:8.1e+03 # Loss:1.01e-07, Loss_r:1.01e-07, Loss_b:4.46e-08 # Valid:3.61e-07, RL2:2.86e-03
# Stage 3 Iter 39700 Time:8.2e+03 # Loss:1.37e-07, Loss_r:7.33e-08, Loss_b:6.34e-08 # Valid:4.04e-07, RL2:2.99e-03
# Stage 3 Iter 39800 Time:8.2e+03 # Loss:4.56e-07, Loss_r:7.87e-08, Loss_b:3.77e-07 # Valid:6.99e-07, RL2:8.19e-03
# Stage 3 Iter 39900 Time:8.2e+03 # Loss:1.46e-07, Loss_r:1.46e-07, Loss_b:3.77e-07 # Valid:6.92e-07, RL2:7.78e-03
# Stage 3 Iter 40000 Time:8.2e+03 # Loss:1.19e-07, Loss_r:1.19e-07, Loss_b:3.77e-07 # Valid:6.91e-07, RL2:8.22e-03
# Adjusting learning rate of group 0 to 3.5849e-04.
# Adjusting learning rate of group 0 to 3.5849e-05.

# %%
np.save("./loss_logger_dict.npy", trainer.logger)
np.save("./loss_logger_valid_dict.npy", trainer.logger_valid)

# %% [markdown]
# ## 结果可视化

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size':18})

# %% [markdown]
# ### 训练的loss图

# %%
# loss图
loss_logger = np.load("./loss_logger_dict.npy", allow_pickle=True).item()
fig = plt.figure(figsize=(24, 5), dpi=64)
axes = fig.subplots(nrows=1, ncols=4)

for i, ax in enumerate(fig.axes):
    logger = loss_logger[f"stage{i + 1}"]
    
    ax.plot(logger["iter"], logger["loss"], label=r"$Loss$", linewidth=3)
    ax.plot(logger["iter"], logger["loss_res"], label=r"$Loss_{res}$", linewidth=2)
    ax.plot(logger["iter"], logger["loss_bcs"], label=r"$Loss_{bcs}$", linewidth=2)
    ax.set_yscale('log')
    ax.set_title(f"Stage {i + 1}")
    ax.grid()

lines, labels = fig.axes[-1].get_legend_handles_labels()
fig.legend(lines, labels, loc='upper center', bbox_to_anchor=(0.5, -0), ncol=3)

plt.tight_layout()
plt.savefig('Loss.png', dpi=100, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### 验证的loss图 (包括只经backbone和经过transformer和backbone的loss)

# %%
# valid的loss图 第一行只经过backbone 第二行经过transformer和backbone
# 因为只用backbone来valid 所以valid loss必须是对每个stage都是非增的 否则代码有误
# 由于随机采样 stage2的loss在小范围内波动属正常
# 第二行的stage2是经过transformer和backbone的 loss上升说明对抗网络是有效的
loss_logger_valid = np.load("./loss_logger_valid_dict.npy", allow_pickle=True).item()

fig = plt.figure(figsize=(24, 5), dpi=64)
axes = fig.subplots(nrows=1, ncols=4)

for i, ax in enumerate(fig.axes):
    logger = loss_logger_valid[f"stage{i + 1}"]
    
    ax.plot(logger["iter"], logger["loss"], label=r"$Loss$", linewidth=3)
    ax.plot(logger["iter"], logger["loss_res"], label=r"$Loss_{res}$", linewidth=2)
    ax.plot(logger["iter"], logger["loss_bcs"], label=r"$Loss_{bcs}$", linewidth=2)
    ax.set_yscale('log')
    ax.set_title(f"Stage {i + 1}")
    ax.grid()

lines, labels = fig.axes[-1].get_legend_handles_labels()
fig.legend(lines, labels, loc='upper center', bbox_to_anchor=(0.5, -0), ncol=3)

plt.tight_layout()
# plt.savefig('loss_valid.png', dpi=100, bbox_inches='tight')
plt.show()


fig = plt.figure(figsize=(24, 5), dpi=64)
axes = fig.subplots(nrows=1, ncols=4)

for i, ax in enumerate(fig.axes):
    logger = loss_logger_valid[f"stage{i + 1}"]
    
    ax.plot(logger["iter"], logger["loss_transformer"], label=r"$Loss$", linewidth=3)
    ax.plot(logger["iter"], logger["loss_res_transformer"], label=r"$Loss_{res}$", linewidth=2)
    ax.plot(logger["iter"], logger["loss_bcs_transformer"], label=r"$Loss_{bcs}$", linewidth=2)
    ax.set_yscale('log')
    ax.set_title(f"Stage {i + 1}")
    ax.grid()

lines, labels = fig.axes[-1].get_legend_handles_labels()
fig.legend(lines, labels, loc='upper center', bbox_to_anchor=(0.5, -0), ncol=3)

plt.tight_layout()
# plt.savefig('loss_valid_transformer.png', dpi=100, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### 验证的Relative L2 error图 (包括只经backbone和经过transformer和backbone的rl2)

# %%
# valid中记录的relative l2 error记录 第一行只经过backbone 第二行经过transformer和backbone
loss_logger_valid = np.load("./loss_logger_valid_dict.npy", allow_pickle=True).item()

fig = plt.figure(figsize=(24, 5), dpi=64)
axes = fig.subplots(nrows=1, ncols=4)

for i, ax in enumerate(fig.axes):
    logger = loss_logger_valid[f"stage{i + 1}"]
    
    ax.plot(logger["iter"], logger["error"], label=r"Backbone Relative error", color="blue", linewidth=3)
    ax.plot(logger["iter"], logger["error_transformer"], label=r"Transformer+Backbone Relative L2 error", color="red", linewidth=3)
    
    ax.set_yscale('log')
    ax.set_title(f"Stage {i + 1}")
    ax.grid()

lines, labels = fig.axes[-1].get_legend_handles_labels()
fig.legend(lines, labels, loc='upper center', bbox_to_anchor=(0.5, -0), ncol=3)

plt.tight_layout()
plt.savefig('Relative_L2_error.png', dpi=100, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### 验证的距离变化信息 d_mean d_var d_min d_max

# %%
# valid中记录的relative l2 error记录 第一行只经过backbone 第二行经过transformer和backbone
loss_logger_valid = np.load("./loss_logger_valid_dict.npy", allow_pickle=True).item()

fig = plt.figure(figsize=(24, 5), dpi=64)
axes = fig.subplots(nrows=1, ncols=4)

for i, ax in enumerate(fig.axes):
    logger = loss_logger_valid[f"stage{i + 1}"]
    
    ax.plot(logger["iter"], logger["distant"]["mean"], label=r"Mean distant", color="green", linewidth=3)
    ax.plot(logger["iter"], logger["distant"]["var"], label=r"Var distant", color="orange", linewidth=3)
    ax.plot(logger["iter"], logger["distant"]["min"], label=r"Min distant", color="cyan", linestyle=':', linewidth=3)
    ax.plot(logger["iter"], logger["distant"]["max"], label=r"Max distant", color="dodgerblue", linestyle='--', linewidth=3)
    
    ax.set_yscale('log')
    ax.set_title(f"Stage {i + 1}")
    ax.grid()

lines, labels = fig.axes[-1].get_legend_handles_labels()
fig.legend(lines, labels, loc='upper center', bbox_to_anchor=(0.5, -0), ncol=4)

plt.tight_layout()
# plt.savefig('Relative_L2_error.png', dpi=100, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Relative L2 error (仅考虑内部点）

# %%
# 使用最好的模型
backbone = ResNet(args.backbone_layers)
state_dict = torch.load(f'{trainer.model_path}/best_model.pth')
backbone.load_state_dict(state_dict['state_dict'])
backbone.eval()
print("Stage:\t", state_dict['stage'])
print("Iter:\t", state_dict['iter'] + 1)
print("Loss:\t", "{:.2e}".format(state_dict['best_loss']))
# Out:
# Stage:	 3
# Iter:	 38700
# Loss:	 2.95e-07

# %%
def exact_sol(X):
    # 解析解
    u_star = X.mean(axis=1, keepdims=True)
    u_star = u_star**2 + np.sin(u_star)
    return u_star

# 采样内部点
dataset = Dataset_PoissonHD(args.bot_top, args.dim, torch.device('cpu'))
X_res, _, _, _ = dataset.train_data(N_r=10000, N_b=0)
# 计算u_star u_pred
u_star = exact_sol(X_res)
u_pred = backbone(X_res)

u_star = u_star.detach().numpy()
u_pred = u_pred.detach().numpy()
#计算L2相对误差
error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)
with open("RL2.txt", 'w') as f:
    f.write(str(error_u))
print('Relative L2 error: {:.3e}'.format(error_u))
# Out:
# Relative L2 error: 4.350e-03

# %% [markdown]
# ### 可视化内部(x1, x2, 0, ..., 0)

# %%
n = 101
dim = args.dim
# 取前两维
x1 = np.linspace(-1, 1, n)
x2 = np.linspace(-1, 1, n)
x1, x2 = np.meshgrid(x1, x2)
# x3, ..., x50 = 0
x12 = np.zeros((n*n, dim))
x12[:, [0]] = x1.reshape(-1, 1)
x12[:, [1]] = x2.reshape(-1, 1)
x12 = torch.from_numpy(x12).float()
# 解析解和预测解
u12_star = exact_sol(x12)
u12_pred = backbone(x12)

u12_star = u12_star.detach().numpy()
u12_pred = u12_pred.detach().numpy()

u12_star = u12_star.reshape(x1.shape)
u12_pred = u12_pred.reshape(x1.shape)

# %%
fig = plt.figure(figsize=(20, 5))
axes = fig.subplots(1, 3)

cax1 = axes[0].pcolor(x1, x2, u12_star, cmap='jet')
fig.colorbar(cax1)
axes[0].set_xlabel('$x_1$')
axes[0].set_ylabel('$x_2$')
axes[0].set_title(r'Reference $u$')
axes[0].set_xlim([-1, 1])
axes[0].set_ylim([-1, 1])
axes[0].set_xticks(np.arange(-1, 1.1, 0.5))
axes[0].set_yticks(np.arange(-1, 1.1, 0.5))
axes[0].set_aspect(1./axes[0].get_data_ratio())

cax2 = axes[1].pcolor(x1, x2, u12_pred, cmap='jet')
fig.colorbar(cax2)
axes[1].set_xlabel('$x_1$')
axes[1].set_ylabel('$x_2$')
axes[1].set_title(r'Predicted $u$')
axes[1].set_xlim([-1, 1])
axes[1].set_ylim([-1, 1])
axes[1].set_xticks(np.arange(-1, 1.1, 0.5))
axes[1].set_yticks(np.arange(-1, 1.1, 0.5))
axes[1].set_aspect(1./axes[1].get_data_ratio())

cax3 = axes[2].pcolor(x1, x2, np.abs(u12_star - u12_pred), cmap='jet')
fig.colorbar(cax3)
axes[2].set_xlabel('$x_1$')
axes[2].set_ylabel('$x_2$')
axes[2].set_title('Absolute error')
axes[2].set_xlim([-1, 1])
axes[2].set_ylim([-1, 1])
axes[2].set_xticks(np.arange(-1, 1.1, 0.5))
axes[2].set_yticks(np.arange(-1, 1.1, 0.5))
axes[2].set_aspect(1./axes[2].get_data_ratio())

plt.tight_layout()
plt.savefig('HeatHD_result.png', dpi=100, bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6.5, 5), dpi=100)
plot = ax.contourf(x1, x2, np.abs(u12_star - u12_pred), levels=16, cmap='jet')

cbar = fig.colorbar(plot)
cbar.formatter.set_powerlimits((0, 0))
cbar.update_ticks()

ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')
ax.set_xticks([-1, -0.5, 0, 0.5, 1])
ax.set_yticks([-1, -0.5, 0, 0.5, 1])
ax.set_title('Absolute error')
ax.set_aspect(1./ax.get_data_ratio())

plt.tight_layout()
plt.savefig('./Absolute_error', dpi=100)
plt.show()

# %% [markdown]
# ## Transformer变换可视化

# %%
# loss_res
trainer.device = torch.device('cpu')
trainer.backbone = trainer.backbone.cpu()

f_res = trainer.dataset.func_res(x12)
f_res_pred = trainer.net_r(x12)
loss_res = (f_res - f_res_pred) ** 2

# %%
fig = plt.figure(figsize=(6.5, 5))
ax = fig.subplots()

cax = ax.scatter(x12.detach().numpy()[:, 0], x12.detach().numpy()[:, 1], 
                 c=loss_res.detach().cpu().numpy(), 
#                  vmin=0, vmax=5e-5,
                 cmap="jet", s=80)
fig.colorbar(cax)
ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')
ax.set_title(r'Residual')
ax.set_xlim([-1, 1])
ax.set_ylim([-1, 1])
ax.set_xticks(np.arange(-1, 1.1, 0.5))
ax.set_yticks(np.arange(-1, 1.1, 0.5))
ax.set_aspect(1./axes[0].get_data_ratio())

plt.tight_layout()
plt.show()

# %%
# 重新取点
n = 21
dim = args.dim
# 取前两维
xx1 = np.linspace(-1, 1, n)
xx2 = np.linspace(-1, 1, n)
xx1, xx2 = np.meshgrid(xx1, xx2)
# x3, ..., x50 = 0
xx12 = np.zeros((n*n, dim))
xx12[:, [0]] = xx1.reshape(-1, 1)
xx12[:, [1]] = xx2.reshape(-1, 1)
xx12 = torch.from_numpy(xx12).float()

# %%
# 变换后的点
# model = MLP(args.subnet_layers)  # 保存的loss最低时的transformer
# transformer = TransformerNet(model, args.bot_top)

# state_dict = torch.load(f'{trainer.model_path}/best_model.pth')
# transformer.load_state_dict(state_dict['state_dict_transformer'])
# transformer.eval()

# xx12_ = transformer(xx12)

trainer.transformer = trainer.transformer.cpu()  # 训练最后的transformer
f_xx12 = dataset.func_res(xx12)
k = trainer.update_k(xx12, f_xx12)
xx12_ = trainer.net_transformer(xx12, k)

# %%
plt.hist(k.detach().cpu().numpy().flatten())
# Out:
# (array([ 4.,  6.,  9., 14., 22., 37., 64., 92., 98., 95.]),
#  array([1.64116597, 1.84116602, 2.04116607, 2.24116611, 2.44116616,
#         2.64116621, 2.84116602, 3.04116607, 3.24116611, 3.44116616,
#         3.64116621]),
#  <BarContainer object of 10 artists>)

# %%
fig = plt.figure(figsize=(12, 5))
axes = fig.subplots(1, 2)

axes[0].scatter(xx12.detach().numpy()[:, 0], xx12.detach().numpy()[:, 1], s=30, color='b')
axes[0].set_xlabel('$x_1$')
axes[0].set_ylabel('$x_2$')
axes[0].set_title(r'Original distribution')
axes[0].set_xlim([-1, 1])
axes[0].set_ylim([-1, 1])
axes[0].set_xticks(np.arange(-1, 1.1, 0.5))
axes[0].set_yticks(np.arange(-1, 1.1, 0.5))
axes[0].set_aspect(1./axes[0].get_data_ratio())

axes[1].scatter(xx12_.detach().numpy()[:, 0], xx12_.detach().numpy()[:, 1], s=30, color='r')
axes[1].set_xlabel('$x_1$')
axes[1].set_ylabel('$x_2$')
axes[1].set_title('Transformed distribution')
axes[1].set_xlim([-1, 1])
axes[1].set_ylim([-1, 1])
axes[1].set_xticks(np.arange(-1, 1.1, 0.5))
axes[1].set_yticks(np.arange(-1, 1.1, 0.5))
axes[1].set_aspect(1./axes[1].get_data_ratio())

plt.tight_layout()
plt.show()
