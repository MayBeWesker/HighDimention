# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
# Out:
# /tmp/ipykernel_5596/82325636.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:80% !important; }</style>

# %%
import os
import shutil

import numpy as np
import time
from pyDOE import lhs
import matplotlib
import matplotlib.pyplot as plt
import scipy.io
import random

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import ExponentialLR

# %%
import argparse
class Options_PoissonHD:
    def __init__(self):
        parser = argparse.ArgumentParser()
        parser.add_argument('--cuda', default=True, help='if you use cuda')
        
        parser.add_argument('--bot_top', type=tuple, default=(-1, 1), help='a tuple of the form (bot, top)')
        parser.add_argument('--dim', default=20, help='dimension')
        parser.add_argument('--N_r', default=800, help='num of interior points')
        parser.add_argument('--N_b', default=400, help='num of boundary points')
        
        parser.add_argument('--backbone_layers', type=list, default=([60]*5), help='list of nn layers of backbone')
        parser.add_argument('--backbone_lr', type=float, default=1e-3, help='initial learning rate of backbone')
        
        parser.add_argument('--gamma', type=float, default=0.95, help='gamma in lr_scheduler for Adam optimizer')
        parser.add_argument('--step_size', type=int, default=1000, help='step_size of lr_scheduler for Adam optimizer')
        
        parser.add_argument('--iters_Adam', type=int, default=20000, help='iters for Adam')
        
        parser.add_argument('--lam_res', type=float, default=1, help='weight of loss_res')
        parser.add_argument('--lam_bcs', type=float, default=1, help='weight of loss_bcs')
        
        self.parser = parser

    def parse_default(self):
        args = self.parser.parse_args(args=[])
        args.device = torch.device('cuda' if args.cuda else 'cpu')
        
        # 增加网络输入输出层
        args.backbone_layers = [args.dim] + args.backbone_layers + [1]
        return args
    

args = Options_PoissonHD().parse_default()
print(args.cuda)
# Out:
# True

# %%
def save_model(state, is_best=None, save_dir=None):
    last_model = os.path.join(save_dir, 'last_model.pth')
    torch.save(state, last_model)
    if is_best:
        best_model = os.path.join(save_dir, 'best_model.pth')
        shutil.copyfile(last_model, best_model)

def seed_torch(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed) # 为了禁止hash随机化，使得实验可复现
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed) # if you are using multi-GPU.
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True
    random.seed(seed)

def grad(outputs, inputs):
    """ compute the derivative of outputs associated with inputs

    Params
    ======
    outputs: (N, 1) tensor
    inputs: (N, D) tensor
    """
    return torch.autograd.grad(outputs, inputs,
                               grad_outputs=torch.ones_like(outputs),
                               create_graph=True)

# %%
seed_torch(42)

# %% [markdown]
# ## 网络模型 (Modified ResNet / ResNet / Modified MLP / MLP)

# %%
class ModifiedResNet(nn.Module):
    def __init__(self, mlp_layers):
        super(ModifiedResNet, self).__init__()
        
        self.encoder_u = nn.Sequential()
        self.encoder_u.add_module('fc_u', nn.Linear(mlp_layers[0], mlp_layers[1], bias=True))
        self.encoder_u.add_module('act_u', nn.Tanh())
        
        self.encoder_v = nn.Sequential()
        self.encoder_v.add_module('fc_v', nn.Linear(mlp_layers[0], mlp_layers[1], bias=True))
        self.encoder_v.add_module('act_v', nn.Tanh())
        
        self.model = nn.Sequential()
        
        first_layer = nn.Sequential()
        first_layer.add_module(f'fc0', nn.Linear(mlp_layers[0], mlp_layers[1], bias=True))
        first_layer.add_module(f'act0', nn.Tanh())
        self.model.add_module(f'first', first_layer)
        
        for i in range(1, len(mlp_layers)-2):
            block = nn.Sequential()
            block.add_module(f'fc{i}_0', nn.Linear(mlp_layers[i], mlp_layers[i+1], bias=True))
            block.add_module(f'act{i}_0', nn.Tanh())
            block.add_module(f'fc{i}_1', nn.Linear(mlp_layers[i], mlp_layers[i+1], bias=True))
            block.add_module(f'act{i}_1', nn.Tanh())
            self.model.add_module(f'block{i}', block)

        last_layer = nn.Sequential()
        last_layer.add_module(f'fc{len(mlp_layers)-2}', nn.Linear(mlp_layers[-2], mlp_layers[-1], bias=False))
        self.model.add_module(f'last', last_layer)
        
#         for param in self.parameters():
#             if len(param.shape) > 1:
#                 nn.init.kaiming_normal_(param)
    
    def forward(self, X):
        u = self.encoder_u(X)
        v = self.encoder_v(X)
        
        X = self.model[0](X)
        for i_block in range(1, len(self.model) - 1):
            X_ = self.model[i_block](X)
            X = X + X_
            X = X / 2.
            X = (1 - X) * u + X * v
        return self.model[-1](X)

# %%
class ResNet(nn.Module):
    def __init__(self, mlp_layers):
        super(ResNet, self).__init__()
        
        self.model = nn.Sequential()
        
        first_layer = nn.Sequential()
        first_layer.add_module(f'fc0', nn.Linear(mlp_layers[0], mlp_layers[1], bias=True))
        first_layer.add_module(f'act0', nn.Tanh())
        self.model.add_module(f'first', first_layer)
        
        for i in range(1, len(mlp_layers)-2):
            block = nn.Sequential()
            block.add_module(f'fc{i}_0', nn.Linear(mlp_layers[i], mlp_layers[i+1], bias=True))
            block.add_module(f'act{i}_0', nn.Tanh())
            block.add_module(f'fc{i}_1', nn.Linear(mlp_layers[i], mlp_layers[i+1], bias=True))
            block.add_module(f'act{i}_1', nn.Tanh())
            self.model.add_module(f'block{i}', block)

        last_layer = nn.Sequential()
        last_layer.add_module(f'fc{len(mlp_layers)-2}', nn.Linear(mlp_layers[-2], mlp_layers[-1], bias=False))
        self.model.add_module(f'last', last_layer)
        
#         for param in self.parameters():
#             if len(param.shape) > 1:
#                 nn.init.kaiming_normal_(param)
    
    def forward(self, X):
        X = self.model[0](X)
        for i_block in range(1, len(self.model) - 1):
            X_ = self.model[i_block](X)
            X = X_ + X
        return self.model[-1](X)

# %%
class ModifiedMLP(nn.Module):
    def __init__(self, mlp_layers):
        super(ModifiedMLP, self).__init__()
        
        self.encoder_u = nn.Sequential()
        self.encoder_u.add_module('fc_u', nn.Linear(mlp_layers[0], mlp_layers[1], bias=True))
        self.encoder_u.add_module('act_u', nn.Tanh())
        
        self.encoder_v = nn.Sequential()
        self.encoder_v.add_module('fc_v', nn.Linear(mlp_layers[0], mlp_layers[1], bias=True))
        self.encoder_v.add_module('act_v', nn.Tanh())
        
        self.model = nn.Sequential()
        for i in range(len(mlp_layers)-2):
            layer = nn.Sequential()
            layer.add_module(f'fc{i}', nn.Linear(mlp_layers[i], mlp_layers[i+1], bias=True))
            layer.add_module(f'act{i}', nn.Tanh())
            self.model.add_module(f'layer{i}', layer)

        last_layer = nn.Sequential()
        last_layer.add_module(f'fc{len(mlp_layers)-2}', nn.Linear(mlp_layers[-2], mlp_layers[-1], bias=False))
        self.model.add_module(f'layer{len(mlp_layers)-2}', last_layer)
        
#         for param in self.parameters():
#             if len(param.shape) > 1:
#                 nn.init.kaiming_normal_(param)
    
    def forward(self, X):
        u = self.encoder_u(X)
        v = self.encoder_v(X)
        
        for i in range(len(self.model) - 1):
            X = self.model[i](X)
            X = X / 2.
            X = (1 - X) * u + X * v
        return self.model[-1](X)

# %%
class MLP(nn.Module):
    def __init__(self, mlp_layers):
        super(MLP, self).__init__()
        
        self.model = nn.Sequential()
        for i in range(len(mlp_layers)-2):
            layer = nn.Sequential()
            layer.add_module(f'fc{i}', nn.Linear(mlp_layers[i], mlp_layers[i+1], bias=True))
            layer.add_module(f'act{i}', nn.Tanh())
            self.model.add_module(f'layer{i}', layer)

        last_layer = nn.Sequential()
        last_layer.add_module(f'fc{len(mlp_layers)-2}', nn.Linear(mlp_layers[-2], mlp_layers[-1], bias=False))
        self.model.add_module(f'layer{len(mlp_layers)-2}', last_layer)
        
#         for param in self.parameters():
#             if len(param.shape) > 1:
#                 nn.init.kaiming_normal_(param)
    
    def forward(self, X):
        return self.model(X)

# %%
backbone = ResNet(args.backbone_layers)
backbone = backbone.to(args.device)
args.backbone = backbone
print(args.backbone)
# Out:
# ResNet(
#   (model): Sequential(
#     (first): Sequential(
#       (fc0): Linear(in_features=20, out_features=60, bias=True)
#       (act0): Tanh()
#     )
#     (block1): Sequential(
#       (fc1_0): Linear(in_features=60, out_features=60, bias=True)
#       (act1_0): Tanh()
#       (fc1_1): Linear(in_features=60, out_features=60, bias=True)
#       (act1_1): Tanh()
#     )
#     (block2): Sequential(
#       (fc2_0): Linear(in_features=60, out_features=60, bias=True)
#       (act2_0): Tanh()
#       (fc2_1): Linear(in_features=60, out_features=60, bias=True)
#       (act2_1): Tanh()
#     )
#     (block3): Sequential(
#       (fc3_0): Linear(in_features=60, out_features=60, bias=True)
#       (act3_0): Tanh()
#       (fc3_1): Linear(in_features=60, out_features=60, bias=True)
#       (act3_1): Tanh()
#     )
#     (block4): Sequential(
#       (fc4_0): Linear(in_features=60, out_features=60, bias=True)
#       (act4_0): Tanh()
#       (fc4_1): Linear(in_features=60, out_features=60, bias=True)
#       (act4_1): Tanh()
#     )
#     (last): Sequential(
#       (fc5): Linear(in_features=60, out_features=1, bias=False)
#     )
#   )
# )

# %% [markdown]
# ## 数据集生成

# %%
class Dataset_PoissonHD:
    def __init__(self, bot_top, dim, device, N_max=100000):
        """
        bot_top: 空间的上下界 默认是(-1,1)
        N_max: 原始的总样本点数 例如interior(N_r) 从N_max中随机采样N_r个点作为初始点
        """
        self.bot, self.top = bot_top
        self.dim = dim
        self.device = device
        self.N_max = N_max
    
    def train_data(self, N_r, N_b):
        """训练点采样"""
        X_res = self.interior(N_r).to(self.device)
        X_bcs = self.boundary(N_b).to(self.device)
        f_res = self.func_res(X_res).to(self.device)
        u_bcs = self.func_bcs(X_bcs).to(self.device)
        
        return X_res, X_bcs, f_res, u_bcs
    
    def interior(self, N_r):
        """内部点采样"""
        X_res = torch.Tensor(self.N_max, self.dim).uniform_(self.bot, self.top)
        idx = torch.randperm(self.N_max)
        idx = idx[:N_r]
        return X_res[idx]
    
    def boundary(self, N_b):
        """边界点采样"""
        X_bcs = torch.Tensor(self.N_max, self.dim).uniform_(self.bot, self.top)
        bots = self.bot * torch.ones(1, 1)
        tops = self.top * torch.ones(1, 1)
        
        n = int(self.N_max / self.dim / 2)
        num = [n * i for i in range(2 * self.dim)]
        num[0] = 0
        num.append(self.N_max)
        
        for i in range(self.dim):  # 逐个维度设为下界bot 以及上界top 得到边界点
            X_bcs[num[2 * i]:num[2 * i + 1], i] = bots.repeat(num[2 * i + 1] - num[2 * i], 1).squeeze()
            X_bcs[num[2 * i + 1]:num[2 * i + 2], i] = tops.repeat(num[2 * i + 2] - num[2 * i + 1], 1).squeeze()

        idx = torch.randperm(self.N_max)
        idx = idx[:N_b]
        return X_bcs[idx]
    
    def func_res(self, X_res):
        """控制方程右端项"""
        f = X_res.mean(axis=1, keepdims=True)
        f = (torch.sin(f) - 2) / self.dim
        return f
    
    def func_bcs(self, X_bcs):
        """边界条件右端项"""
        u_bcs = X_bcs.mean(axis=1, keepdims=True)
        u_bcs = u_bcs ** 2 + torch.sin(u_bcs)
        return u_bcs


dataset = Dataset_PoissonHD(args.bot_top, args.dim, args.device)
args.dataset = dataset
X_res, X_bcs, f_res, u_bcs = dataset.train_data(args.N_r, args.N_b)
print(X_res.shape, X_bcs.shape, f_res.shape, u_bcs.shape)
# Out:
# torch.Size([800, 20]) torch.Size([400, 20]) torch.Size([800, 1]) torch.Size([400, 1])

# %% [markdown]
# ## 训练

# %%
class Trainer_PoissonHD:
    def __init__(self, args):
        self.args = args
        self.dim = args.dim
        self.device = args.device
        
        self.N_r = args.N_r
        self.N_b = args.N_b
        self.dataset = args.dataset
        
        self.lam_res = args.lam_res
        self.lam_bcs = args.lam_bcs
        self.gamma = args.gamma
        self.backbone = args.backbone
        
        self.model_name = self.backbone.__class__.__name__
        self.model_path = self.get_model_path()
        
        self.iters_Adam = args.iters_Adam

        # eps = np.finfo(np.float32).eps
        self.optimizer_Adam = optim.Adam(self.backbone.parameters(), lr=args.backbone_lr, betas=(0.9, 0.999))
        
        self.step_size = args.step_size#int( self.iters_stage4 / (np.log(1e-3) / np.log(self.gamma)) )
        self.scheduler = ExponentialLR(self.optimizer_Adam, gamma=self.gamma, verbose=True)
        
        # data
        self.X_res, self.X_bcs, self.f_res, self.u_bcs = self.dataset.train_data(self.N_r, self.N_b)
        
        # Logger
        self.logger = {
            "loss": [],
            "loss_res": [],
            "loss_bcs": [],
            "iter": []
        }
        self.logger_valid = {
            "loss": [],
            "loss_res": [],
            "loss_bcs": [],
            "iter": [],
            "error": [],  # relative l2 error
        }
        
    def get_model_path(self):
        """生成保存模型的路径"""
        if not os.path.exists('models'):
            os.mkdir('models')
        
        path = os.path.join('models', self.model_name)
        if not os.path.exists(path):
            os.mkdir(path)
        
        return path
        
    def update_train_data(self):
        """更新采样点"""
        self.X_res, self.X_bcs, self.f_res, self.u_bcs = self.dataset.train_data(self.N_r, self.N_b)

    def net_u(self, X):
        return self.backbone(X)

    def net_r(self, x):
        x.requires_grad_(True)

        u = self.net_u(x)
        grad_u = grad(u, x)[0]
        u_xx = torch.zeros(u.shape).to(self.device)
        for i in range(self.dim):
            u_xx += grad(grad_u[:, [i]], x)[0][:, [i]]

        return - u_xx
    
    def compute_loss(self):
        """计算loss"""
        f_res_pred = self.net_r(self.X_res)
        self.loss_res = torch.mean((f_res_pred - self.f_res) ** 2)

        u_bcs_pred = self.net_u(self.X_bcs)
        self.loss_bcs = torch.mean((u_bcs_pred - self.u_bcs) ** 2)

        self.loss = self.lam_res * self.loss_res + self.lam_bcs * self.loss_bcs


    def log_loss(self):
        """记录当前loss至logger字典"""
        self.logger["loss"].append(self.loss.item())
        self.logger["loss_res"].append(self.loss_res.item())
        self.logger["loss_bcs"].append(self.loss_bcs.item())
        self.logger["iter"].append(self.iter + 1)

    def log_info(self):
        """保存并打印训练信息"""
        info = f'Iter {self.iter+1:5d} Time:{time.time()-self.start_time:.1e} # ' + \
               f'Loss:{self.loss.item():.2e}, Loss_r:{self.loss_res.item():.2e}, Loss_b:{self.loss_bcs.item():.2e} # ' + \
               f'Valid:{self.valid_loss_value:.2e}, RL2:{self.error_u:.2e}'
        with open("train_info.txt", 'a') as f:
            f.write(info + '\n')
        print(info)
        
    def compute_rl2(self, X_res):
        # 计算relative l2 error
        u_star = X_res.mean(axis=1, keepdims=True)
        u_star = u_star**2 + torch.sin(u_star)
        u_star = u_star.detach().cpu().numpy()
        
        u_pred = self.net_u(X_res)  # 计算预测解
        u_pred = u_pred.detach().cpu().numpy()
        
        error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)  # rl2 error
        return error_u

    def valid(self):
        """验证并保存最优模型"""
        # 计算loss
        X_res, X_bcs, f_res, u_bcs = self.dataset.train_data(1000, 1000)
        self.backbone.eval()
        # 不经过transformer的loss
        f_res_pred = self.net_r(X_res)
        u_bcs_pred = self.net_u(X_bcs)
        loss_res = torch.mean((f_res_pred - f_res) ** 2)
        loss_bcs = torch.mean((u_bcs_pred - u_bcs) ** 2)
        loss = self.lam_res * loss_res + self.lam_bcs * loss_bcs
        
        # 计算relative l2 error
        self.error_u = self.compute_rl2(X_res)
        
        self.backbone.train()
        
        # 记录valid的loss和rl2 error信息
        self.logger_valid["loss"].append(loss.item())
        self.logger_valid["loss_res"].append(loss_res.item())
        self.logger_valid["loss_bcs"].append(loss_bcs.item())
        self.logger_valid["iter"].append(self.iter + 1)
        self.logger_valid["error"].append(self.error_u)
        
        # 验证模型loss是否最优并选择保存
        self.valid_loss_value = loss.item()
        is_best = self.valid_loss_value < self.best_loss
        if is_best:
            self.best_loss = self.valid_loss_value
        state = {
            'iter': self.iter,
            'state_dict': self.backbone.state_dict(),
            'best_loss': self.best_loss
        }
        save_model(state, is_best, save_dir=self.model_path)
    
    def train(self):
        """训练"""
        self.start_time = time.time()
        self.best_loss = 1.e10
        
        self.iter = 0
        for _ in range(self.iters_Adam):
            self.optimizer_Adam.zero_grad()
            self.compute_loss()
            self.loss.backward()
            self.optimizer_Adam.step()
            self.log_loss()

            if (self.iter + 1) % 100 == 0:
                self.valid()
                self.log_info()
                self.update_train_data()

            if (self.iter + 1) % self.step_size == 0:
                self.scheduler.step()
            self.iter += 1
            
            
trainer = Trainer_PoissonHD(args)
# Out:
# Adjusting learning rate of group 0 to 1.0000e-03.

# %%
trainer.train()
# Out:
# Iter   100 Time:3.1e+00 # Loss:9.60e-04, Loss_r:4.31e-04, Loss_b:5.29e-04 # Valid:1.30e-03, RL2:1.84e-01
# Iter   200 Time:6.3e+00 # Loss:6.82e-04, Loss_r:2.61e-04, Loss_b:4.21e-04 # Valid:9.41e-04, RL2:1.75e-01
# Iter   300 Time:9.4e+00 # Loss:4.69e-04, Loss_r:1.66e-04, Loss_b:3.03e-04 # Valid:7.37e-04, RL2:1.66e-01
# Iter   400 Time:1.2e+01 # Loss:5.22e-04, Loss_r:1.47e-04, Loss_b:3.76e-04 # Valid:6.21e-04, RL2:1.53e-01
# Iter   500 Time:1.6e+01 # Loss:4.13e-04, Loss_r:1.33e-04, Loss_b:2.80e-04 # Valid:5.31e-04, RL2:1.40e-01
# Iter   600 Time:1.9e+01 # Loss:3.21e-04, Loss_r:1.11e-04, Loss_b:2.10e-04 # Valid:5.44e-04, RL2:1.31e-01
# Iter   700 Time:2.2e+01 # Loss:2.57e-04, Loss_r:8.72e-05, Loss_b:1.70e-04 # Valid:6.47e-04, RL2:1.22e-01
# Iter   800 Time:2.5e+01 # Loss:2.12e-04, Loss_r:6.92e-05, Loss_b:1.43e-04 # Valid:3.89e-04, RL2:1.11e-01
# Iter   900 Time:2.8e+01 # Loss:1.40e-04, Loss_r:6.24e-05, Loss_b:7.72e-05 # Valid:1.67e-04, RL2:7.63e-02
# Iter  1000 Time:3.1e+01 # Loss:6.69e-05, Loss_r:3.47e-05, Loss_b:3.23e-05 # Valid:1.34e-04, RL2:5.63e-02
# Adjusting learning rate of group 0 to 9.5000e-04.
# Iter  1100 Time:3.4e+01 # Loss:3.49e-05, Loss_r:2.08e-05, Loss_b:1.41e-05 # Valid:7.30e-05, RL2:3.88e-02
# Iter  1200 Time:3.7e+01 # Loss:2.96e-05, Loss_r:1.92e-05, Loss_b:1.04e-05 # Valid:3.71e-05, RL2:2.75e-02
# Iter  1300 Time:4.1e+01 # Loss:1.79e-05, Loss_r:1.18e-05, Loss_b:6.06e-06 # Valid:3.31e-05, RL2:2.18e-02
# Iter  1400 Time:4.5e+01 # Loss:1.24e-05, Loss_r:8.43e-06, Loss_b:3.93e-06 # Valid:5.39e-05, RL2:1.84e-02
# Iter  1500 Time:5.0e+01 # Loss:1.13e-05, Loss_r:7.33e-06, Loss_b:3.95e-06 # Valid:2.94e-05, RL2:1.75e-02
# Iter  1600 Time:5.6e+01 # Loss:9.76e-06, Loss_r:5.90e-06, Loss_b:3.86e-06 # Valid:2.14e-05, RL2:1.91e-02
# Iter  1700 Time:6.2e+01 # Loss:5.17e-05, Loss_r:1.13e-05, Loss_b:4.05e-05 # Valid:6.74e-05, RL2:5.44e-02
# Iter  1800 Time:6.7e+01 # Loss:7.61e-06, Loss_r:4.95e-06, Loss_b:2.66e-06 # Valid:1.26e-05, RL2:1.67e-02
# Iter  1900 Time:7.3e+01 # Loss:2.24e-05, Loss_r:5.70e-06, Loss_b:1.67e-05 # Valid:3.46e-05, RL2:3.79e-02
# Iter  2000 Time:7.8e+01 # Loss:6.80e-06, Loss_r:4.64e-06, Loss_b:2.17e-06 # Valid:1.06e-05, RL2:1.42e-02
# Adjusting learning rate of group 0 to 9.0250e-04.
# Iter  2100 Time:8.4e+01 # Loss:5.47e-06, Loss_r:3.67e-06, Loss_b:1.80e-06 # Valid:1.56e-05, RL2:1.31e-02
# Iter  2200 Time:9.2e+01 # Loss:5.41e-06, Loss_r:3.52e-06, Loss_b:1.89e-06 # Valid:7.71e-06, RL2:1.14e-02
# Iter  2300 Time:1.0e+02 # Loss:5.39e-06, Loss_r:3.52e-06, Loss_b:1.88e-06 # Valid:8.70e-06, RL2:1.15e-02
# Iter  2400 Time:1.1e+02 # Loss:4.33e-06, Loss_r:2.78e-06, Loss_b:1.55e-06 # Valid:1.46e-05, RL2:1.14e-02
# Iter  2500 Time:1.2e+02 # Loss:1.17e-05, Loss_r:2.64e-06, Loss_b:9.09e-06 # Valid:2.21e-05, RL2:1.19e-02
# Iter  2600 Time:1.2e+02 # Loss:3.96e-06, Loss_r:2.63e-06, Loss_b:1.33e-06 # Valid:2.60e-05, RL2:1.02e-02
# Iter  2700 Time:1.3e+02 # Loss:2.96e-06, Loss_r:1.84e-06, Loss_b:1.11e-06 # Valid:9.87e-06, RL2:9.26e-03
# Iter  2800 Time:1.4e+02 # Loss:3.31e-06, Loss_r:2.02e-06, Loss_b:1.28e-06 # Valid:4.54e-06, RL2:9.37e-03
# Iter  2900 Time:1.5e+02 # Loss:3.57e-06, Loss_r:2.25e-06, Loss_b:1.32e-06 # Valid:5.33e-06, RL2:9.33e-03
# Iter  3000 Time:1.6e+02 # Loss:2.70e-06, Loss_r:1.68e-06, Loss_b:1.01e-06 # Valid:5.57e-06, RL2:8.29e-03
# Adjusting learning rate of group 0 to 8.5737e-04.
# Iter  3100 Time:1.6e+02 # Loss:2.53e-06, Loss_r:1.66e-06, Loss_b:8.69e-07 # Valid:6.78e-06, RL2:8.62e-03
# Iter  3200 Time:1.7e+02 # Loss:3.26e-05, Loss_r:2.35e-06, Loss_b:3.02e-05 # Valid:1.82e-05, RL2:2.99e-02
# Iter  3300 Time:1.8e+02 # Loss:2.33e-06, Loss_r:1.51e-06, Loss_b:8.27e-07 # Valid:4.52e-06, RL2:8.44e-03
# Iter  3400 Time:1.9e+02 # Loss:3.33e-06, Loss_r:1.62e-06, Loss_b:1.71e-06 # Valid:5.21e-06, RL2:1.10e-02
# Iter  3500 Time:2.0e+02 # Loss:2.17e-06, Loss_r:1.44e-06, Loss_b:7.27e-07 # Valid:8.34e-06, RL2:7.61e-03
# Iter  3600 Time:2.0e+02 # Loss:2.19e-06, Loss_r:1.42e-06, Loss_b:7.65e-07 # Valid:2.99e-06, RL2:7.26e-03
# Iter  3700 Time:2.1e+02 # Loss:1.81e-06, Loss_r:1.15e-06, Loss_b:6.57e-07 # Valid:2.94e-06, RL2:7.64e-03
# Iter  3800 Time:2.2e+02 # Loss:2.80e-06, Loss_r:1.50e-06, Loss_b:1.30e-06 # Valid:1.60e-05, RL2:1.13e-02
# Iter  3900 Time:2.3e+02 # Loss:1.65e-06, Loss_r:1.11e-06, Loss_b:5.32e-07 # Valid:5.32e-06, RL2:6.55e-03
# Iter  4000 Time:2.4e+02 # Loss:1.90e-06, Loss_r:1.33e-06, Loss_b:5.69e-07 # Valid:3.09e-06, RL2:6.90e-03
# Adjusting learning rate of group 0 to 8.1451e-04.
# Iter  4100 Time:2.4e+02 # Loss:3.04e-06, Loss_r:1.74e-06, Loss_b:1.30e-06 # Valid:4.34e-06, RL2:9.44e-03
# Iter  4200 Time:2.5e+02 # Loss:1.55e-06, Loss_r:9.40e-07, Loss_b:6.05e-07 # Valid:2.92e-06, RL2:6.54e-03
# Iter  4300 Time:2.6e+02 # Loss:1.26e-06, Loss_r:8.18e-07, Loss_b:4.45e-07 # Valid:2.60e-06, RL2:5.80e-03
# Iter  4400 Time:2.7e+02 # Loss:1.41e-06, Loss_r:8.36e-07, Loss_b:5.78e-07 # Valid:2.74e-06, RL2:7.48e-03
# Iter  4500 Time:2.8e+02 # Loss:1.47e-06, Loss_r:9.41e-07, Loss_b:5.29e-07 # Valid:1.47e-05, RL2:6.30e-03
# Iter  4600 Time:2.9e+02 # Loss:9.83e-06, Loss_r:4.14e-06, Loss_b:5.69e-06 # Valid:1.41e-05, RL2:1.92e-02
# Iter  4700 Time:2.9e+02 # Loss:1.06e-06, Loss_r:6.51e-07, Loss_b:4.06e-07 # Valid:1.84e-06, RL2:5.77e-03
# Iter  4800 Time:3.0e+02 # Loss:1.31e-06, Loss_r:7.96e-07, Loss_b:5.12e-07 # Valid:1.89e-06, RL2:5.39e-03
# Iter  4900 Time:3.1e+02 # Loss:2.69e-06, Loss_r:6.06e-07, Loss_b:2.09e-06 # Valid:5.07e-06, RL2:1.39e-02
# Iter  5000 Time:3.2e+02 # Loss:1.11e-06, Loss_r:7.73e-07, Loss_b:3.37e-07 # Valid:1.97e-06, RL2:5.31e-03
# Adjusting learning rate of group 0 to 7.7378e-04.
# Iter  5100 Time:3.3e+02 # Loss:1.06e-06, Loss_r:6.92e-07, Loss_b:3.65e-07 # Valid:1.99e-06, RL2:5.32e-03
# Iter  5200 Time:3.3e+02 # Loss:9.64e-07, Loss_r:6.01e-07, Loss_b:3.63e-07 # Valid:1.76e-06, RL2:5.49e-03
# Iter  5300 Time:3.4e+02 # Loss:8.61e-07, Loss_r:5.67e-07, Loss_b:2.94e-07 # Valid:1.76e-06, RL2:4.72e-03
# Iter  5400 Time:3.5e+02 # Loss:1.33e-04, Loss_r:6.49e-06, Loss_b:1.27e-04 # Valid:9.26e-05, RL2:7.10e-02
# Iter  5500 Time:3.6e+02 # Loss:9.03e-07, Loss_r:6.09e-07, Loss_b:2.94e-07 # Valid:1.54e-06, RL2:5.54e-03
# Iter  5600 Time:3.7e+02 # Loss:9.56e-07, Loss_r:6.34e-07, Loss_b:3.23e-07 # Valid:1.56e-06, RL2:4.64e-03
# Iter  5700 Time:3.7e+02 # Loss:2.94e-06, Loss_r:1.34e-06, Loss_b:1.60e-06 # Valid:1.03e-05, RL2:2.01e-02
# Iter  5800 Time:3.8e+02 # Loss:8.79e-07, Loss_r:5.95e-07, Loss_b:2.84e-07 # Valid:2.08e-06, RL2:4.16e-03
# Iter  5900 Time:3.9e+02 # Loss:7.85e-07, Loss_r:5.61e-07, Loss_b:2.24e-07 # Valid:1.38e-06, RL2:4.47e-03
# Iter  6000 Time:4.0e+02 # Loss:8.36e-07, Loss_r:5.80e-07, Loss_b:2.56e-07 # Valid:2.21e-06, RL2:4.78e-03
# Adjusting learning rate of group 0 to 7.3509e-04.
# Iter  6100 Time:4.1e+02 # Loss:6.65e-07, Loss_r:4.35e-07, Loss_b:2.30e-07 # Valid:2.74e-06, RL2:4.08e-03
# Iter  6200 Time:4.1e+02 # Loss:8.54e-07, Loss_r:3.82e-07, Loss_b:4.72e-07 # Valid:2.15e-06, RL2:5.52e-03
# Iter  6300 Time:4.2e+02 # Loss:5.26e-07, Loss_r:3.33e-07, Loss_b:1.93e-07 # Valid:1.50e-06, RL2:3.42e-03
# Iter  6400 Time:4.3e+02 # Loss:8.43e-07, Loss_r:5.96e-07, Loss_b:2.47e-07 # Valid:4.48e-06, RL2:4.41e-03
# Iter  6500 Time:4.4e+02 # Loss:7.25e-07, Loss_r:4.96e-07, Loss_b:2.30e-07 # Valid:1.82e-06, RL2:4.56e-03
# Iter  6600 Time:4.5e+02 # Loss:5.75e-07, Loss_r:4.00e-07, Loss_b:1.75e-07 # Valid:1.54e-06, RL2:3.55e-03
# Iter  6700 Time:4.5e+02 # Loss:5.74e-07, Loss_r:3.98e-07, Loss_b:1.76e-07 # Valid:1.18e-06, RL2:3.94e-03
# Iter  6800 Time:4.6e+02 # Loss:5.22e-07, Loss_r:3.70e-07, Loss_b:1.53e-07 # Valid:1.04e-06, RL2:3.56e-03
# Iter  6900 Time:4.7e+02 # Loss:7.37e-07, Loss_r:5.17e-07, Loss_b:2.20e-07 # Valid:1.63e-06, RL2:4.23e-03
# Iter  7000 Time:4.8e+02 # Loss:4.87e-07, Loss_r:3.26e-07, Loss_b:1.61e-07 # Valid:9.73e-07, RL2:3.49e-03
# Adjusting learning rate of group 0 to 6.9834e-04.
# Iter  7100 Time:4.9e+02 # Loss:4.68e-07, Loss_r:3.02e-07, Loss_b:1.65e-07 # Valid:8.79e-07, RL2:3.39e-03
# Iter  7200 Time:4.9e+02 # Loss:2.37e-06, Loss_r:7.61e-07, Loss_b:1.61e-06 # Valid:1.73e-05, RL2:2.79e-02
# Iter  7300 Time:5.0e+02 # Loss:5.67e-07, Loss_r:4.20e-07, Loss_b:1.47e-07 # Valid:1.03e-06, RL2:3.64e-03
# Iter  7400 Time:5.1e+02 # Loss:3.98e-07, Loss_r:2.66e-07, Loss_b:1.32e-07 # Valid:8.47e-07, RL2:3.52e-03
# Iter  7500 Time:5.2e+02 # Loss:4.17e-07, Loss_r:2.83e-07, Loss_b:1.34e-07 # Valid:8.08e-07, RL2:3.53e-03
# Iter  7600 Time:5.3e+02 # Loss:1.79e-05, Loss_r:7.63e-07, Loss_b:1.71e-05 # Valid:6.88e-06, RL2:1.69e-02
# Iter  7700 Time:5.3e+02 # Loss:4.35e-07, Loss_r:2.96e-07, Loss_b:1.39e-07 # Valid:8.20e-07, RL2:3.54e-03
# Iter  7800 Time:5.4e+02 # Loss:1.76e-06, Loss_r:1.45e-06, Loss_b:3.18e-07 # Valid:3.03e-06, RL2:5.40e-03
# Iter  7900 Time:5.5e+02 # Loss:4.35e-07, Loss_r:3.05e-07, Loss_b:1.30e-07 # Valid:1.37e-06, RL2:3.41e-03
# Iter  8000 Time:5.6e+02 # Loss:3.60e-07, Loss_r:2.36e-07, Loss_b:1.24e-07 # Valid:8.53e-07, RL2:2.92e-03
# Adjusting learning rate of group 0 to 6.6342e-04.
# Iter  8100 Time:5.7e+02 # Loss:3.44e-07, Loss_r:2.40e-07, Loss_b:1.03e-07 # Valid:9.03e-07, RL2:2.98e-03
# Iter  8200 Time:5.7e+02 # Loss:1.76e-06, Loss_r:4.49e-07, Loss_b:1.31e-06 # Valid:2.94e-06, RL2:1.12e-02
# Iter  8300 Time:5.8e+02 # Loss:8.18e-07, Loss_r:6.46e-07, Loss_b:1.71e-07 # Valid:1.18e-06, RL2:3.60e-03
# Iter  8400 Time:5.9e+02 # Loss:3.45e-07, Loss_r:2.35e-07, Loss_b:1.10e-07 # Valid:7.64e-07, RL2:3.11e-03
# Iter  8500 Time:6.0e+02 # Loss:3.59e-07, Loss_r:2.30e-07, Loss_b:1.29e-07 # Valid:6.58e-07, RL2:2.91e-03
# Iter  8600 Time:6.1e+02 # Loss:2.94e-07, Loss_r:1.92e-07, Loss_b:1.02e-07 # Valid:1.22e-05, RL2:2.88e-03
# Iter  8700 Time:6.2e+02 # Loss:3.08e-07, Loss_r:2.23e-07, Loss_b:8.56e-08 # Valid:6.33e-07, RL2:2.59e-03
# Iter  8800 Time:6.2e+02 # Loss:2.91e-07, Loss_r:1.91e-07, Loss_b:9.95e-08 # Valid:1.12e-06, RL2:2.94e-03
# Iter  8900 Time:6.3e+02 # Loss:5.02e-07, Loss_r:3.21e-07, Loss_b:1.81e-07 # Valid:6.74e-07, RL2:3.20e-03
# Iter  9000 Time:6.4e+02 # Loss:5.40e-07, Loss_r:3.70e-07, Loss_b:1.70e-07 # Valid:8.00e-07, RL2:3.79e-03
# Adjusting learning rate of group 0 to 6.3025e-04.
# Iter  9100 Time:6.5e+02 # Loss:2.75e-07, Loss_r:1.66e-07, Loss_b:1.10e-07 # Valid:2.73e-05, RL2:3.33e-03
# Iter  9200 Time:6.6e+02 # Loss:2.60e-07, Loss_r:1.80e-07, Loss_b:8.05e-08 # Valid:8.89e-07, RL2:2.62e-03
# Iter  9300 Time:6.6e+02 # Loss:2.53e-07, Loss_r:1.71e-07, Loss_b:8.17e-08 # Valid:5.88e-07, RL2:2.57e-03
# Iter  9400 Time:6.7e+02 # Loss:2.52e-07, Loss_r:1.81e-07, Loss_b:7.11e-08 # Valid:5.70e-07, RL2:2.54e-03
# Iter  9500 Time:6.8e+02 # Loss:4.34e-06, Loss_r:3.55e-06, Loss_b:7.99e-07 # Valid:4.73e-06, RL2:5.89e-03
# Iter  9600 Time:6.9e+02 # Loss:2.30e-07, Loss_r:1.63e-07, Loss_b:6.63e-08 # Valid:2.14e-06, RL2:2.37e-03
# Iter  9700 Time:7.0e+02 # Loss:2.18e-07, Loss_r:1.43e-07, Loss_b:7.50e-08 # Valid:6.54e-07, RL2:2.30e-03
# Iter  9800 Time:7.0e+02 # Loss:1.96e-07, Loss_r:1.30e-07, Loss_b:6.66e-08 # Valid:3.43e-07, RL2:2.39e-03
# Iter  9900 Time:7.1e+02 # Loss:3.96e-07, Loss_r:2.77e-07, Loss_b:1.19e-07 # Valid:7.98e-07, RL2:3.11e-03
# Iter 10000 Time:7.2e+02 # Loss:2.56e-07, Loss_r:1.89e-07, Loss_b:6.65e-08 # Valid:6.46e-07, RL2:2.34e-03
# Adjusting learning rate of group 0 to 5.9874e-04.
# Iter 10100 Time:7.3e+02 # Loss:2.64e-07, Loss_r:2.01e-07, Loss_b:6.29e-08 # Valid:4.81e-07, RL2:2.62e-03
# Iter 10200 Time:7.4e+02 # Loss:2.43e-07, Loss_r:1.79e-07, Loss_b:6.47e-08 # Valid:2.84e-06, RL2:2.41e-03
# Iter 10300 Time:7.4e+02 # Loss:2.34e-07, Loss_r:1.73e-07, Loss_b:6.08e-08 # Valid:4.08e-07, RL2:2.11e-03
# Iter 10400 Time:7.5e+02 # Loss:1.73e-06, Loss_r:2.31e-07, Loss_b:1.50e-06 # Valid:1.25e-06, RL2:7.26e-03
# Iter 10500 Time:7.6e+02 # Loss:2.15e-07, Loss_r:1.52e-07, Loss_b:6.34e-08 # Valid:5.57e-07, RL2:2.16e-03
# Iter 10600 Time:7.7e+02 # Loss:2.21e-06, Loss_r:2.21e-07, Loss_b:1.99e-06 # Valid:3.07e-06, RL2:1.26e-02
# Iter 10700 Time:7.8e+02 # Loss:3.08e-07, Loss_r:2.41e-07, Loss_b:6.68e-08 # Valid:5.62e-07, RL2:2.49e-03
# Iter 10800 Time:7.8e+02 # Loss:3.16e-07, Loss_r:2.20e-07, Loss_b:9.60e-08 # Valid:8.86e-07, RL2:3.24e-03
# Iter 10900 Time:7.9e+02 # Loss:2.19e-07, Loss_r:1.46e-07, Loss_b:7.38e-08 # Valid:2.72e-06, RL2:2.42e-03
# Iter 11000 Time:8.0e+02 # Loss:1.88e-07, Loss_r:1.33e-07, Loss_b:5.47e-08 # Valid:6.78e-06, RL2:2.30e-03
# Adjusting learning rate of group 0 to 5.6880e-04.
# Iter 11100 Time:8.1e+02 # Loss:1.76e-07, Loss_r:1.25e-07, Loss_b:5.13e-08 # Valid:6.29e-07, RL2:1.98e-03
# Iter 11200 Time:8.2e+02 # Loss:1.70e-07, Loss_r:1.19e-07, Loss_b:5.07e-08 # Valid:3.03e-07, RL2:2.11e-03
# Iter 11300 Time:8.2e+02 # Loss:2.21e-07, Loss_r:1.68e-07, Loss_b:5.33e-08 # Valid:5.35e-07, RL2:2.25e-03
# Iter 11400 Time:8.3e+02 # Loss:2.18e-07, Loss_r:1.56e-07, Loss_b:6.24e-08 # Valid:4.73e-07, RL2:2.11e-03
# Iter 11500 Time:8.4e+02 # Loss:1.82e-07, Loss_r:1.39e-07, Loss_b:4.30e-08 # Valid:9.63e-07, RL2:1.88e-03
# Iter 11600 Time:8.5e+02 # Loss:1.91e-07, Loss_r:1.44e-07, Loss_b:4.75e-08 # Valid:4.84e-07, RL2:1.87e-03
# Iter 11700 Time:8.6e+02 # Loss:6.16e-07, Loss_r:1.32e-07, Loss_b:4.83e-07 # Valid:5.89e-07, RL2:3.89e-03
# Iter 11800 Time:8.6e+02 # Loss:2.02e-07, Loss_r:1.47e-07, Loss_b:5.46e-08 # Valid:3.22e-07, RL2:2.23e-03
# Iter 11900 Time:8.7e+02 # Loss:1.48e-07, Loss_r:1.02e-07, Loss_b:4.68e-08 # Valid:8.96e-07, RL2:1.91e-03
# Iter 12000 Time:8.8e+02 # Loss:1.22e-07, Loss_r:8.87e-08, Loss_b:3.36e-08 # Valid:2.93e-07, RL2:1.74e-03
# Adjusting learning rate of group 0 to 5.4036e-04.
# Iter 12100 Time:8.9e+02 # Loss:1.24e-07, Loss_r:8.61e-08, Loss_b:3.77e-08 # Valid:6.75e-07, RL2:2.00e-03
# Iter 12200 Time:9.0e+02 # Loss:2.63e-07, Loss_r:1.95e-07, Loss_b:6.84e-08 # Valid:9.67e-06, RL2:2.11e-03
# Iter 12300 Time:9.0e+02 # Loss:1.12e-07, Loss_r:8.04e-08, Loss_b:3.16e-08 # Valid:4.03e-06, RL2:1.74e-03
# Iter 12400 Time:9.1e+02 # Loss:1.45e-07, Loss_r:1.07e-07, Loss_b:3.86e-08 # Valid:2.32e-07, RL2:1.68e-03
# Iter 12500 Time:9.2e+02 # Loss:1.27e-07, Loss_r:8.99e-08, Loss_b:3.69e-08 # Valid:3.14e-07, RL2:1.61e-03
# Iter 12600 Time:9.3e+02 # Loss:1.39e-07, Loss_r:1.06e-07, Loss_b:3.29e-08 # Valid:3.22e-06, RL2:1.83e-03
# Iter 12700 Time:9.4e+02 # Loss:1.43e-06, Loss_r:8.40e-08, Loss_b:1.35e-06 # Valid:1.34e-05, RL2:9.17e-03
# Iter 12800 Time:9.4e+02 # Loss:9.77e-08, Loss_r:6.88e-08, Loss_b:2.89e-08 # Valid:2.48e-07, RL2:1.71e-03
# Iter 12900 Time:9.5e+02 # Loss:1.07e-07, Loss_r:7.05e-08, Loss_b:3.69e-08 # Valid:2.38e-07, RL2:1.87e-03
# Iter 13000 Time:9.6e+02 # Loss:1.30e-07, Loss_r:9.42e-08, Loss_b:3.54e-08 # Valid:3.85e-07, RL2:1.88e-03
# Adjusting learning rate of group 0 to 5.1334e-04.
# Iter 13100 Time:9.7e+02 # Loss:8.57e-08, Loss_r:5.78e-08, Loss_b:2.80e-08 # Valid:2.03e-07, RL2:1.55e-03
# Iter 13200 Time:9.8e+02 # Loss:9.57e-08, Loss_r:6.17e-08, Loss_b:3.40e-08 # Valid:9.85e-07, RL2:1.50e-03
# Iter 13300 Time:9.8e+02 # Loss:9.21e-08, Loss_r:6.58e-08, Loss_b:2.62e-08 # Valid:1.72e-06, RL2:1.79e-03
# Iter 13400 Time:9.9e+02 # Loss:8.78e-08, Loss_r:6.09e-08, Loss_b:2.68e-08 # Valid:3.40e-06, RL2:1.53e-03
# Iter 13500 Time:1.0e+03 # Loss:1.04e-07, Loss_r:7.42e-08, Loss_b:2.98e-08 # Valid:1.63e-06, RL2:1.61e-03
# Iter 13600 Time:1.0e+03 # Loss:7.34e-06, Loss_r:6.82e-06, Loss_b:5.24e-07 # Valid:5.70e-06, RL2:4.73e-03
# Iter 13700 Time:1.0e+03 # Loss:5.56e-07, Loss_r:1.83e-07, Loss_b:3.73e-07 # Valid:3.74e-07, RL2:2.18e-03
# Iter 13800 Time:1.0e+03 # Loss:1.05e-07, Loss_r:7.54e-08, Loss_b:3.00e-08 # Valid:1.77e-07, RL2:1.51e-03
# Iter 13900 Time:1.0e+03 # Loss:7.01e-08, Loss_r:5.15e-08, Loss_b:1.86e-08 # Valid:1.92e-07, RL2:1.52e-03
# Iter 14000 Time:1.0e+03 # Loss:1.27e-07, Loss_r:8.99e-08, Loss_b:3.75e-08 # Valid:1.27e-06, RL2:1.73e-03
# Adjusting learning rate of group 0 to 4.8767e-04.
# Iter 14100 Time:1.0e+03 # Loss:7.90e-08, Loss_r:6.01e-08, Loss_b:1.89e-08 # Valid:3.80e-07, RL2:1.43e-03
# Iter 14200 Time:1.1e+03 # Loss:9.52e-08, Loss_r:7.13e-08, Loss_b:2.40e-08 # Valid:5.60e-07, RL2:1.43e-03
# Iter 14300 Time:1.1e+03 # Loss:1.89e-07, Loss_r:1.41e-07, Loss_b:4.81e-08 # Valid:8.54e-07, RL2:2.11e-03
# Iter 14400 Time:1.1e+03 # Loss:9.89e-08, Loss_r:7.31e-08, Loss_b:2.58e-08 # Valid:2.86e-07, RL2:1.41e-03
# Iter 14500 Time:1.1e+03 # Loss:9.15e-08, Loss_r:6.68e-08, Loss_b:2.47e-08 # Valid:2.00e-07, RL2:1.37e-03
# Iter 14600 Time:1.1e+03 # Loss:1.72e-07, Loss_r:1.20e-07, Loss_b:5.21e-08 # Valid:1.86e-06, RL2:1.98e-03
# Iter 14700 Time:1.1e+03 # Loss:2.43e-07, Loss_r:1.97e-07, Loss_b:4.68e-08 # Valid:2.73e-07, RL2:1.66e-03
# Iter 14800 Time:1.1e+03 # Loss:8.68e-08, Loss_r:6.01e-08, Loss_b:2.68e-08 # Valid:3.11e-06, RL2:1.69e-03
# Iter 14900 Time:1.1e+03 # Loss:7.38e-08, Loss_r:5.56e-08, Loss_b:1.82e-08 # Valid:8.13e-07, RL2:1.32e-03
# Iter 15000 Time:1.1e+03 # Loss:7.77e-08, Loss_r:5.50e-08, Loss_b:2.27e-08 # Valid:2.99e-07, RL2:1.31e-03
# Adjusting learning rate of group 0 to 4.6329e-04.
# Iter 15100 Time:1.1e+03 # Loss:9.19e-08, Loss_r:7.32e-08, Loss_b:1.86e-08 # Valid:3.13e-07, RL2:1.27e-03
# Iter 15200 Time:1.1e+03 # Loss:9.60e-08, Loss_r:7.34e-08, Loss_b:2.25e-08 # Valid:1.90e-07, RL2:1.37e-03
# Iter 15300 Time:1.1e+03 # Loss:7.21e-08, Loss_r:5.38e-08, Loss_b:1.83e-08 # Valid:1.73e-06, RL2:1.37e-03
# Iter 15400 Time:1.2e+03 # Loss:6.39e-08, Loss_r:4.54e-08, Loss_b:1.85e-08 # Valid:3.52e-06, RL2:1.67e-03
# Iter 15500 Time:1.2e+03 # Loss:1.02e-07, Loss_r:7.45e-08, Loss_b:2.72e-08 # Valid:1.85e-07, RL2:1.34e-03
# Iter 15600 Time:1.2e+03 # Loss:7.78e-08, Loss_r:5.43e-08, Loss_b:2.36e-08 # Valid:1.42e-07, RL2:1.34e-03
# Iter 15700 Time:1.2e+03 # Loss:6.62e-06, Loss_r:1.53e-06, Loss_b:5.10e-06 # Valid:2.02e-06, RL2:1.02e-02
# Iter 15800 Time:1.2e+03 # Loss:1.07e-07, Loss_r:7.19e-08, Loss_b:3.52e-08 # Valid:3.91e-07, RL2:1.61e-03
# Iter 15900 Time:1.2e+03 # Loss:6.75e-08, Loss_r:5.10e-08, Loss_b:1.65e-08 # Valid:1.40e-07, RL2:1.19e-03
# Iter 16000 Time:1.2e+03 # Loss:5.79e-08, Loss_r:3.81e-08, Loss_b:1.98e-08 # Valid:3.51e-07, RL2:1.29e-03
# Adjusting learning rate of group 0 to 4.4013e-04.
# Iter 16100 Time:1.2e+03 # Loss:1.17e-07, Loss_r:8.46e-08, Loss_b:3.23e-08 # Valid:1.92e-07, RL2:1.63e-03
# Iter 16200 Time:1.2e+03 # Loss:7.11e-08, Loss_r:5.00e-08, Loss_b:2.10e-08 # Valid:5.80e-07, RL2:1.32e-03
# Iter 16300 Time:1.2e+03 # Loss:1.87e-07, Loss_r:6.47e-08, Loss_b:1.22e-07 # Valid:5.60e-07, RL2:2.58e-03
# Iter 16400 Time:1.3e+03 # Loss:5.85e-08, Loss_r:4.32e-08, Loss_b:1.53e-08 # Valid:1.56e-07, RL2:1.14e-03
# Iter 16500 Time:1.3e+03 # Loss:6.41e-08, Loss_r:4.50e-08, Loss_b:1.91e-08 # Valid:1.89e-07, RL2:1.26e-03
# Iter 16600 Time:1.3e+03 # Loss:6.45e-06, Loss_r:1.55e-07, Loss_b:6.30e-06 # Valid:2.99e-06, RL2:1.31e-02
# Iter 16700 Time:1.3e+03 # Loss:5.28e-08, Loss_r:3.63e-08, Loss_b:1.65e-08 # Valid:3.30e-06, RL2:1.11e-03
# Iter 16800 Time:1.3e+03 # Loss:4.78e-08, Loss_r:3.42e-08, Loss_b:1.36e-08 # Valid:1.37e-07, RL2:1.09e-03
# Iter 16900 Time:1.3e+03 # Loss:1.38e-07, Loss_r:9.55e-08, Loss_b:4.24e-08 # Valid:2.80e-07, RL2:1.80e-03
# Iter 17000 Time:1.3e+03 # Loss:8.12e-08, Loss_r:6.25e-08, Loss_b:1.87e-08 # Valid:7.77e-07, RL2:1.60e-03
# Adjusting learning rate of group 0 to 4.1812e-04.
# Iter 17100 Time:1.3e+03 # Loss:6.33e-08, Loss_r:4.68e-08, Loss_b:1.65e-08 # Valid:1.76e-07, RL2:1.13e-03
# Iter 17200 Time:1.3e+03 # Loss:6.08e-08, Loss_r:4.11e-08, Loss_b:1.97e-08 # Valid:1.28e-07, RL2:1.07e-03
# Iter 17300 Time:1.3e+03 # Loss:5.68e-08, Loss_r:3.93e-08, Loss_b:1.75e-08 # Valid:1.29e-07, RL2:1.14e-03
# Iter 17400 Time:1.4e+03 # Loss:5.09e-08, Loss_r:3.44e-08, Loss_b:1.64e-08 # Valid:1.05e-07, RL2:1.22e-03
# Iter 17500 Time:1.4e+03 # Loss:7.00e-08, Loss_r:5.33e-08, Loss_b:1.67e-08 # Valid:1.38e-07, RL2:1.14e-03
# Iter 17600 Time:1.4e+03 # Loss:5.11e-08, Loss_r:3.59e-08, Loss_b:1.52e-08 # Valid:1.25e-07, RL2:9.96e-04
# Iter 17700 Time:1.4e+03 # Loss:6.77e-08, Loss_r:5.27e-08, Loss_b:1.50e-08 # Valid:1.73e-07, RL2:1.04e-03
# Iter 17800 Time:1.4e+03 # Loss:4.85e-08, Loss_r:3.42e-08, Loss_b:1.44e-08 # Valid:1.48e-07, RL2:1.12e-03
# Iter 17900 Time:1.4e+03 # Loss:4.47e-08, Loss_r:3.19e-08, Loss_b:1.29e-08 # Valid:1.01e-07, RL2:1.04e-03
# Iter 18000 Time:1.4e+03 # Loss:3.93e-08, Loss_r:2.89e-08, Loss_b:1.04e-08 # Valid:1.40e-07, RL2:1.08e-03
# Adjusting learning rate of group 0 to 3.9721e-04.
# Iter 18100 Time:1.4e+03 # Loss:4.65e-08, Loss_r:3.52e-08, Loss_b:1.13e-08 # Valid:2.10e-07, RL2:1.06e-03
# Iter 18200 Time:1.4e+03 # Loss:4.14e-08, Loss_r:2.50e-08, Loss_b:1.65e-08 # Valid:1.12e-06, RL2:1.27e-03
# Iter 18300 Time:1.4e+03 # Loss:4.90e-08, Loss_r:3.37e-08, Loss_b:1.53e-08 # Valid:6.79e-07, RL2:1.05e-03
# Iter 18400 Time:1.4e+03 # Loss:1.37e-06, Loss_r:7.96e-08, Loss_b:1.29e-06 # Valid:1.96e-06, RL2:1.00e-02
# Iter 18500 Time:1.5e+03 # Loss:3.52e-06, Loss_r:3.54e-07, Loss_b:3.16e-06 # Valid:2.72e-06, RL2:1.14e-02
# Iter 18600 Time:1.5e+03 # Loss:1.27e-06, Loss_r:2.79e-07, Loss_b:9.93e-07 # Valid:5.06e-07, RL2:4.33e-03
# Iter 18700 Time:1.5e+03 # Loss:1.20e-07, Loss_r:8.10e-08, Loss_b:3.91e-08 # Valid:1.51e-06, RL2:2.25e-03
# Iter 18800 Time:1.5e+03 # Loss:1.11e-07, Loss_r:8.85e-08, Loss_b:2.20e-08 # Valid:2.36e-06, RL2:1.67e-03
# Iter 18900 Time:1.5e+03 # Loss:6.82e-08, Loss_r:4.85e-08, Loss_b:1.97e-08 # Valid:1.58e-07, RL2:1.29e-03
# Iter 19000 Time:1.5e+03 # Loss:4.56e-08, Loss_r:3.21e-08, Loss_b:1.35e-08 # Valid:1.07e-07, RL2:1.12e-03
# Adjusting learning rate of group 0 to 3.7735e-04.
# Iter 19100 Time:1.5e+03 # Loss:5.98e-08, Loss_r:4.39e-08, Loss_b:1.59e-08 # Valid:1.10e-07, RL2:1.09e-03
# Iter 19200 Time:1.5e+03 # Loss:4.39e-08, Loss_r:3.02e-08, Loss_b:1.37e-08 # Valid:1.11e-07, RL2:1.08e-03
# Iter 19300 Time:1.5e+03 # Loss:6.70e-06, Loss_r:1.35e-07, Loss_b:6.57e-06 # Valid:6.13e-06, RL2:1.84e-02
# Iter 19400 Time:1.5e+03 # Loss:4.02e-08, Loss_r:2.44e-08, Loss_b:1.58e-08 # Valid:8.01e-08, RL2:9.42e-04
# Iter 19500 Time:1.6e+03 # Loss:3.72e-08, Loss_r:2.61e-08, Loss_b:1.11e-08 # Valid:7.42e-08, RL2:9.30e-04
# Iter 19600 Time:1.6e+03 # Loss:5.01e-08, Loss_r:3.88e-08, Loss_b:1.14e-08 # Valid:1.86e-07, RL2:1.17e-03
# Iter 19700 Time:1.6e+03 # Loss:3.69e-08, Loss_r:2.46e-08, Loss_b:1.24e-08 # Valid:4.18e-07, RL2:9.76e-04
# Iter 19800 Time:1.6e+03 # Loss:3.73e-08, Loss_r:2.68e-08, Loss_b:1.04e-08 # Valid:8.15e-08, RL2:1.09e-03
# Iter 19900 Time:1.6e+03 # Loss:4.24e-08, Loss_r:2.94e-08, Loss_b:1.30e-08 # Valid:1.05e-07, RL2:9.44e-04
# Iter 20000 Time:1.6e+03 # Loss:1.08e-07, Loss_r:3.43e-08, Loss_b:7.33e-08 # Valid:2.04e-07, RL2:2.70e-03
# Adjusting learning rate of group 0 to 3.5849e-04.

# %%
np.save("./loss_logger_dict.npy", trainer.logger)
np.save("./loss_logger_valid_dict.npy", trainer.logger_valid)

# %% [markdown]
# ## 结果可视化

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size':18})

# %% [markdown]
# ### 训练的loss图

# %%
# loss图
loss_logger = np.load("./loss_logger_dict.npy", allow_pickle=True).item()

fig = plt.figure(figsize=(9, 7), dpi=64)
ax = fig.subplots()

k = 100
# ax.plot(loss_logger["iter"][::k], loss_logger["loss"][::k], label=r"$\mathcal{L}$", linewidth=3)
ax.plot(loss_logger["iter"][::k], loss_logger["loss_res"][::k], label=r"$\mathcal{L}_{r}$", linewidth=3)
ax.plot(loss_logger["iter"][::k], loss_logger["loss_bcs"][::k], label=r"$\mathcal{L}_{b}$", linewidth=3)
ax.set_yscale('log')
ax.set_xlabel("Iteration")
ax.set_ylabel("Loss")
ax.grid()

ax.legend(loc='upper right')

plt.tight_layout()
plt.savefig('Loss.png', dpi=100, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### 验证的loss图 (包括只经backbone和经过transformer和backbone的loss)

# %%
loss_logger_valid = np.load("./loss_logger_valid_dict.npy", allow_pickle=True).item()

fig = plt.figure(figsize=(9, 7), dpi=64)
ax = fig.subplots()

k = 1
# ax.plot(loss_logger_valid["iter"][::k], loss_logger_valid["loss"][::k], label=r"$\mathcal{L}$", linewidth=3)
ax.plot(loss_logger_valid["iter"][::k], loss_logger_valid["loss_res"][::k], label=r"$\mathcal{L}_{r}$", linewidth=3)
ax.plot(loss_logger_valid["iter"][::k], loss_logger_valid["loss_bcs"][::k], label=r"$\mathcal{L}_{b}$", linewidth=3)
ax.set_yscale('log')
ax.set_xlabel("Iteration")
ax.set_ylabel("Loss")
ax.grid()

ax.legend(loc='upper right')

plt.tight_layout()
# plt.savefig('loss_valid.png', dpi=100, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### 验证的Relative L2 error图 (包括只经backbone和经过transformer和backbone的rl2)

# %%
# valid中记录的relative l2 error记录 第一行只经过backbone 第二行经过transformer和backbone
loss_logger_valid = np.load("./loss_logger_valid_dict.npy", allow_pickle=True).item()

fig = plt.figure(figsize=(9, 7), dpi=64)
ax = fig.subplots()

k = 1
ax.plot(loss_logger_valid["iter"][::k], loss_logger_valid["error"][::k], label=r"PINN", color='k', linewidth=3)
ax.set_yscale('log')
ax.set_xlabel("Iteration")
ax.set_ylabel("Relative error")
ax.grid()

plt.tight_layout()
plt.savefig('Relative_L2_error.png', dpi=100, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Relative L2 error (仅考虑内部点）

# %%
# 使用最好的模型
backbone = ResNet(args.backbone_layers)
state_dict = torch.load(f'{trainer.model_path}/best_model.pth')
backbone.load_state_dict(state_dict['state_dict'])
backbone.eval()
print("Iter:\t", state_dict['iter'] + 1)
print("Loss:\t", "{:.2e}".format(state_dict['best_loss']))
# Out:
# Iter:	 19500
# Loss:	 7.42e-08

# %%
def exact_sol(X):
    # 解析解
    u_star = X.mean(axis=1, keepdims=True)
    u_star = u_star**2 + np.sin(u_star)
    return u_star

# 采样内部点
dataset = Dataset_PoissonHD(args.bot_top, args.dim, torch.device('cpu'))
X_res, _, _, _ = dataset.train_data(N_r=10000, N_b=0)
# 计算u_star u_pred
u_star = exact_sol(X_res)
u_pred = backbone(X_res)

u_star = u_star.detach().numpy()
u_pred = u_pred.detach().numpy()
#计算L2相对误差
error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)
with open("RL2.txt", 'w') as f:
    f.write(str(error_u))
print('Relative L2 error: {:.3e}'.format(error_u))
# Out:
# Relative L2 error: 1.008e-03

# %% [markdown]
# ### 可视化内部(x1, x2, 0, ..., 0)

# %%
n = 101
dim = args.dim
# 取前两维
x1 = np.linspace(-1, 1, n)
x2 = np.linspace(-1, 1, n)
x1, x2 = np.meshgrid(x1, x2)
# x3, ..., x50 = 0
x12 = np.zeros((n*n, dim))
x12[:, [0]] = x1.reshape(-1, 1)
x12[:, [1]] = x2.reshape(-1, 1)
x12 = torch.from_numpy(x12).float()
# 解析解和预测解
u12_star = exact_sol(x12)
u12_pred = backbone(x12)

u12_star = u12_star.detach().numpy()
u12_pred = u12_pred.detach().numpy()

u12_star = u12_star.reshape(x1.shape)
u12_pred = u12_pred.reshape(x1.shape)

# %%
fig = plt.figure(figsize=(20, 5))
axes = fig.subplots(1, 3)

cax1 = axes[0].pcolor(x1, x2, u12_star, cmap='jet')
fig.colorbar(cax1)
axes[0].set_xlabel('$x_1$')
axes[0].set_ylabel('$x_2$')
axes[0].set_title(r'Reference $u$')
axes[0].set_xlim([-1, 1])
axes[0].set_ylim([-1, 1])
axes[0].set_xticks(np.arange(-1, 1.1, 0.5))
axes[0].set_yticks(np.arange(-1, 1.1, 0.5))
axes[0].set_aspect(1./axes[0].get_data_ratio())

cax2 = axes[1].pcolor(x1, x2, u12_pred, cmap='jet')
fig.colorbar(cax2)
axes[1].set_xlabel('$x_1$')
axes[1].set_ylabel('$x_2$')
axes[1].set_title(r'Predicted $u$')
axes[1].set_xlim([-1, 1])
axes[1].set_ylim([-1, 1])
axes[1].set_xticks(np.arange(-1, 1.1, 0.5))
axes[1].set_yticks(np.arange(-1, 1.1, 0.5))
axes[1].set_aspect(1./axes[1].get_data_ratio())

cax3 = axes[2].pcolor(x1, x2, np.abs(u12_star - u12_pred), cmap='jet')
fig.colorbar(cax3)
axes[2].set_xlabel('$x_1$')
axes[2].set_ylabel('$x_2$')
axes[2].set_title('Absolute error')
axes[2].set_xlim([-1, 1])
axes[2].set_ylim([-1, 1])
axes[2].set_xticks(np.arange(-1, 1.1, 0.5))
axes[2].set_yticks(np.arange(-1, 1.1, 0.5))
axes[2].set_aspect(1./axes[2].get_data_ratio())

plt.tight_layout()
plt.savefig('Linear_Poisson_HD_result.png', dpi=100, bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6.5, 5), dpi=100)
plot = ax.contourf(x1, x2, np.abs(u12_star - u12_pred), levels=16, cmap='jet')

cbar = fig.colorbar(plot)
cbar.formatter.set_powerlimits((0, 0))
cbar.update_ticks()

ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')
ax.set_xticks([-1, -0.5, 0, 0.5, 1])
ax.set_yticks([-1, -0.5, 0, 0.5, 1])
ax.set_title('Absolute error')
ax.set_aspect(1./ax.get_data_ratio())
plt.tight_layout()
plt.savefig('./Absolute_error', dpi=100)
plt.show()
