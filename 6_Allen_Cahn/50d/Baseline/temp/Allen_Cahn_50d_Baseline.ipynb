# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# /tmp/ipykernel_2347278/3777615979.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:100% !important; }</style>

# %%
import os
import shutil

import numpy as np
import time
from pyDOE import lhs
import matplotlib
import matplotlib.pyplot as plt
import scipy.io
import random

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import ExponentialLR

# %%
import argparse
class Options_AllenCahnHD:
    def __init__(self):
        parser = argparse.ArgumentParser()
        parser.add_argument('--cuda', default=True, help='if you use cuda')
        
        parser.add_argument('--bot_top', type=tuple, default=(-1, 1), help='a tuple of the form (bot, top)')
        parser.add_argument('--T', type=float, default=1., help='a float T of time domain [0, T]')
        parser.add_argument('--dim', default=50, help='dimension')
        parser.add_argument('--N_r', default=2400, help='num of interior points')
        parser.add_argument('--N_b', default=1200, help='num of boundary points')
        parser.add_argument('--N_0', default=1200, help='num of initial points')
        
        parser.add_argument('--backbone_layers', type=list, default=([200]*3), help='list of nn layers of backbone')
        parser.add_argument('--backbone_lr', type=float, default=5e-3, help='initial learning rate of backbone')
        
        parser.add_argument('--backbone_gamma', type=float, default=0.85, help='gamma in lr_scheduler for backbone optimizer')
        parser.add_argument('--step_size', type=int, default=1000, help='step_size of lr_scheduler for Adam optimizer')
        
        parser.add_argument('--iters_Adam', type=int, default=20000, help='iters for stage 1 used Adam')
        
        parser.add_argument('--lam_res', type=float, default=1, help='weight of loss_res')
        parser.add_argument('--lam_bcs', type=float, default=100, help='weight of loss_bcs')
        parser.add_argument('--lam_ics', type=float, default=100, help='weight of loss_ics')
        
        self.parser = parser

    def parse_default(self):
        args = self.parser.parse_args(args=[])
        args.device = torch.device('cuda' if args.cuda else 'cpu')
        
        # 增加网络输入输出层
        args.backbone_layers = [args.dim + 1] + args.backbone_layers + [1]
        return args
    

args = Options_AllenCahnHD().parse_default()
print(args.cuda)
# Out:
# True

# %%
def save_model(state, is_best=None, save_dir=None):
    last_model = os.path.join(save_dir, 'last_model.pth')
    torch.save(state, last_model)
    if is_best:
        best_model = os.path.join(save_dir, 'best_model.pth')
        shutil.copyfile(last_model, best_model)

def seed_torch(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed) # 为了禁止hash随机化，使得实验可复现
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed) # if you are using multi-GPU.
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True
    random.seed(seed)

def grad(outputs, inputs):
    """ compute the derivative of outputs associated with inputs

    Params
    ======
    outputs: (N, 1) tensor
    inputs: (N, D) tensor
    """
    return torch.autograd.grad(outputs, inputs,
                               grad_outputs=torch.ones_like(outputs),
                               create_graph=True)

# %%
seed_torch(42)

# %% [markdown]
# ## 网络模型 (Modified ResNet / ResNet / Modified MLP / MLP)

# %%
class ModifiedResNet(nn.Module):
    def __init__(self, mlp_layers):
        super(ModifiedResNet, self).__init__()
        
        self.encoder_u = nn.Sequential()
        self.encoder_u.add_module('fc_u', nn.Linear(mlp_layers[0], mlp_layers[1], bias=True))
        self.encoder_u.add_module('act_u', nn.Tanh())
        
        self.encoder_v = nn.Sequential()
        self.encoder_v.add_module('fc_v', nn.Linear(mlp_layers[0], mlp_layers[1], bias=True))
        self.encoder_v.add_module('act_v', nn.Tanh())
        
        self.model = nn.Sequential()
        
        first_layer = nn.Sequential()
        first_layer.add_module(f'fc0', nn.Linear(mlp_layers[0], mlp_layers[1], bias=True))
        first_layer.add_module(f'act0', nn.Tanh())
        self.model.add_module(f'first', first_layer)
        
        for i in range(1, len(mlp_layers)-2):
            block = nn.Sequential()
            block.add_module(f'fc{i}_0', nn.Linear(mlp_layers[i], mlp_layers[i+1], bias=True))
            block.add_module(f'act{i}_0', nn.Tanh())
            block.add_module(f'fc{i}_1', nn.Linear(mlp_layers[i], mlp_layers[i+1], bias=True))
            block.add_module(f'act{i}_1', nn.Tanh())
            self.model.add_module(f'block{i}', block)

        last_layer = nn.Sequential()
        last_layer.add_module(f'fc{len(mlp_layers)-2}', nn.Linear(mlp_layers[-2], mlp_layers[-1], bias=False))
        self.model.add_module(f'last', last_layer)
        
#         for param in self.parameters():
#             if len(param.shape) > 1:
#                 nn.init.kaiming_normal_(param)
    
    def forward(self, X):
        u = self.encoder_u(X)
        v = self.encoder_v(X)
        
        X = self.model[0](X)
        for i_block in range(1, len(self.model) - 1):
            X_ = self.model[i_block](X)
            X = X + X_
            X = X / 2.
            X = (1 - X) * u + X * v
        return self.model[-1](X)

# %%
class ResNet(nn.Module):
    def __init__(self, mlp_layers):
        super(ResNet, self).__init__()
        
        self.model = nn.Sequential()
        
        first_layer = nn.Sequential()
        first_layer.add_module(f'fc0', nn.Linear(mlp_layers[0], mlp_layers[1], bias=True))
        first_layer.add_module(f'act0', nn.Tanh())
        self.model.add_module(f'first', first_layer)
        
        for i in range(1, len(mlp_layers)-2):
            block = nn.Sequential()
            block.add_module(f'fc{i}_0', nn.Linear(mlp_layers[i], mlp_layers[i+1], bias=True))
            block.add_module(f'act{i}_0', nn.Tanh())
            block.add_module(f'fc{i}_1', nn.Linear(mlp_layers[i], mlp_layers[i+1], bias=True))
            block.add_module(f'act{i}_1', nn.Tanh())
            self.model.add_module(f'block{i}', block)

        last_layer = nn.Sequential()
        last_layer.add_module(f'fc{len(mlp_layers)-2}', nn.Linear(mlp_layers[-2], mlp_layers[-1], bias=False))
        self.model.add_module(f'last', last_layer)
        
#         for param in self.parameters():
#             if len(param.shape) > 1:
#                 nn.init.kaiming_normal_(param)
    
    def forward(self, X):
        X = self.model[0](X)
        for i_block in range(1, len(self.model) - 1):
            X_ = self.model[i_block](X)
            X = X_ + X
        return self.model[-1](X)

# %%
class ModifiedMLP(nn.Module):
    def __init__(self, mlp_layers):
        super(ModifiedMLP, self).__init__()
        
        self.encoder_u = nn.Sequential()
        self.encoder_u.add_module('fc_u', nn.Linear(mlp_layers[0], mlp_layers[1], bias=True))
        self.encoder_u.add_module('act_u', nn.Tanh())
        
        self.encoder_v = nn.Sequential()
        self.encoder_v.add_module('fc_v', nn.Linear(mlp_layers[0], mlp_layers[1], bias=True))
        self.encoder_v.add_module('act_v', nn.Tanh())
        
        self.model = nn.Sequential()
        for i in range(len(mlp_layers)-2):
            layer = nn.Sequential()
            layer.add_module(f'fc{i}', nn.Linear(mlp_layers[i], mlp_layers[i+1], bias=True))
            layer.add_module(f'act{i}', nn.Tanh())
            self.model.add_module(f'layer{i}', layer)

        last_layer = nn.Sequential()
        last_layer.add_module(f'fc{len(mlp_layers)-2}', nn.Linear(mlp_layers[-2], mlp_layers[-1], bias=False))
        self.model.add_module(f'layer{len(mlp_layers)-2}', last_layer)
        
#         for param in self.parameters():
#             if len(param.shape) > 1:
#                 nn.init.kaiming_normal_(param)
    
    def forward(self, X):
        u = self.encoder_u(X)
        v = self.encoder_v(X)
        
        for i in range(len(self.model) - 1):
            X = self.model[i](X)
            X = X / 2.
            X = (1 - X) * u + X * v
        return self.model[-1](X)

# %%
class MLP(nn.Module):
    def __init__(self, mlp_layers):
        super(MLP, self).__init__()
        
        self.model = nn.Sequential()
        for i in range(len(mlp_layers)-2):
            layer = nn.Sequential()
            layer.add_module(f'fc{i}', nn.Linear(mlp_layers[i], mlp_layers[i+1], bias=True))
            layer.add_module(f'act{i}', nn.Tanh())
            self.model.add_module(f'layer{i}', layer)

        last_layer = nn.Sequential()
        last_layer.add_module(f'fc{len(mlp_layers)-2}', nn.Linear(mlp_layers[-2], mlp_layers[-1], bias=False))
        self.model.add_module(f'layer{len(mlp_layers)-2}', last_layer)
        
#         for param in self.parameters():
#             if len(param.shape) > 1:
#                 nn.init.kaiming_normal_(param)
    
    def forward(self, X):
        return self.model(X)

# %%
backbone = ResNet(args.backbone_layers)
backbone = backbone.to(args.device)
args.backbone = backbone
print(args.backbone)
# Out:
# ResNet(
#   (model): Sequential(
#     (first): Sequential(
#       (fc0): Linear(in_features=51, out_features=200, bias=True)
#       (act0): Tanh()
#     )
#     (block1): Sequential(
#       (fc1_0): Linear(in_features=200, out_features=200, bias=True)
#       (act1_0): Tanh()
#       (fc1_1): Linear(in_features=200, out_features=200, bias=True)
#       (act1_1): Tanh()
#     )
#     (block2): Sequential(
#       (fc2_0): Linear(in_features=200, out_features=200, bias=True)
#       (act2_0): Tanh()
#       (fc2_1): Linear(in_features=200, out_features=200, bias=True)
#       (act2_1): Tanh()
#     )
#     (last): Sequential(
#       (fc3): Linear(in_features=200, out_features=1, bias=False)
#     )
#   )
# )

# %% [markdown]
# ## 数据集生成

# %%
from torch import norm, exp, sin, cos, pi

def norm2(x):
    return norm(x, p=2, dim=1, keepdim=True)

def u(x, t):
    return exp(-t) * sin(pi/2 * (1 - norm2(x)).abs() ** 2.5)

def g(x, t):
    return torch.zeros_like(t)

def h(x):
    return sin(0.5 * pi * (1 - norm2(x)).abs() ** 2.5)

def l(x):
    return cos(0.5 * pi * (1 - norm2(x)).abs() ** 2.5)

def k(x):
    return -5/4 * pi * (x.shape[1] - 1) * norm2(x)**(-1) * l(x) * (1 - norm2(x)).abs() ** 1.5 \
        - 25/16 * pi**2 * h(x) * (1 - norm2(x)).abs() ** 3 \
        + 15/8 * pi * l(x) * (1 - norm2(x)).abs() ** 0.5

def f(x, t):
    return - exp(-t) * (h(x) + k(x)) - u(x, t) + u(x, t) ** 3

# %%
class Dataset_AllenCahnHD:
    def __init__(self, bot_top, T, dim, device, N_max=100000):
        self.bot, self.top = bot_top
        self.T = T
        self.dim = dim
        self.device = device
        self.N_max = N_max
    
    def train_data(self, N_r, N_b, N_0):
        """训练点采样"""
        X_res = self.interior(N_r).to(self.device)
        X_bcs = self.boundary(N_b).to(self.device)
        X_ics = self.initial(N_0).to(self.device)
        f_res = self.func_res(X_res).to(self.device)
        u_bcs = self.func_bcs(X_bcs).to(self.device)
        u_ics = self.func_ics(X_ics).to(self.device)
        
        return X_res, X_bcs, X_ics, f_res, u_bcs, u_ics
    
    def interior(self, N_r):
        """内部点采样"""
        X_res = torch.Tensor(self.N_max, self.dim).normal_(0, 1)
        X_res /= torch.norm(X_res, p=2, dim=1, keepdim=True)
        X_res *= torch.Tensor(self.N_max, self.dim).uniform_(-1, 1)
        
        idx = torch.randperm(self.N_max)
        idx = idx[:N_r]
        
        T = torch.Tensor(self.N_max, 1).uniform_(0, self.T)
        X_res = torch.cat([X_res[idx], T[idx]], dim=1)  # 拼接X和T
        return X_res
    
    def boundary(self, N_b):
        """边界点采样"""
        X_bcs = torch.Tensor(self.N_max, self.dim).normal_(0, 1)
        X_bcs /= torch.norm(X_bcs, p=2, dim=1, keepdim=True)

        idx = torch.randperm(self.N_max)
        idx = idx[:N_b]
        
        T = torch.Tensor(self.N_max, 1).uniform_(0, self.T)
        X_bcs = torch.cat([X_bcs[idx], T[idx]], dim=1)  # 拼接X和T
        return X_bcs
    
    def initial(self, N_0):
        """初始点采样"""
        X_ics = torch.Tensor(self.N_max, self.dim).normal_(0, 1)
        X_ics /= torch.norm(X_ics, p=2, dim=1, keepdim=True)
        X_ics *= torch.Tensor(self.N_max, self.dim).uniform_(-1, 1)
        idx = torch.randperm(self.N_max)
        idx = idx[:N_0]
        
        T = torch.Tensor(self.N_max, 1).fill_(0.)
        X_ics = torch.cat([X_ics[idx], T[idx]], dim=1)
        return X_ics
    
    def func_res(self, X_res):
        """控制方程右端项"""
        return f(x=X_res[:, :self.dim], t=X_res[:, [-1]])
    
    def func_bcs(self, X_bcs):
        """边界条件右端项"""
        return g(x=X_bcs[:, :self.dim], t=X_bcs[:, [-1]])
    
    def func_ics(self, X_ics):
        """初始条件右端项"""
        return h(x=X_ics[:, :self.dim])


dataset = Dataset_AllenCahnHD(args.bot_top, args.T, args.dim, args.device)
args.dataset = dataset
X_res, X_bcs, X_ics, f_res, u_bcs, u_ics = dataset.train_data(args.N_r, args.N_b, args.N_0)
print(X_res.shape, X_bcs.shape, X_ics.shape, f_res.shape, u_bcs.shape, u_ics.shape)
# Out:
# torch.Size([2400, 51]) torch.Size([1200, 51]) torch.Size([1200, 51]) torch.Size([2400, 1]) torch.Size([1200, 1]) torch.Size([1200, 1])

# %% [markdown]
# ## 训练

# %%
class Trainer_AllenCahnHD:
    def __init__(self, args):
        self.args = args
        self.dim = args.dim
        self.device = args.device
        
        self.N_r = args.N_r
        self.N_b = args.N_b
        self.N_0 = args.N_0
        self.dataset = args.dataset
        
        self.lam_res = args.lam_res
        self.lam_bcs = args.lam_bcs
        self.lam_ics = args.lam_ics
        self.backbone = args.backbone
        
        self.model_name = self.backbone.__class__.__name__
        self.model_path = self.get_model_path()
        
        self.iters_Adam = args.iters_Adam

        # eps = np.finfo(np.float32).eps
        self.optimizer_Adam = optim.Adam(self.backbone.parameters(), lr=args.backbone_lr, betas=(0.9, 0.999))
        
        self.step_size = args.step_size#int( self.iters_stage4 / (np.log(1e-3) / np.log(self.gamma)) )
        self.scheduler = ExponentialLR(self.optimizer_Adam, gamma=args.backbone_gamma, verbose=True)
        
        # data
        self.X_res, self.X_bcs, self.X_ics, self.f_res, self.u_bcs, self.u_ics = self.dataset.train_data(self.N_r, self.N_b, self.N_0)
        
        # Logger
        self.logger = {
            "loss": [],
            "loss_res": [],
            "loss_bcs": [],
            "loss_ics": [],
            "iter": []
        }
        
        self.logger_valid = {
            "loss": [],
            "loss_res": [],
            "loss_bcs": [],
            "loss_ics": [],
            "iter": [],
            "error": []
        }
        
    def get_model_path(self):
        """生成保存模型的路径"""
        if not os.path.exists('models'):
            os.mkdir('models')
        
        path = os.path.join('models', self.model_name)
        if not os.path.exists(path):
            os.mkdir(path)
        
        return path
        
    def update_train_data(self):
        """更新采样点"""
        self.X_res, self.X_bcs, self.X_ics, self.f_res, self.u_bcs, self.u_ics = self.dataset.train_data(self.N_r, self.N_b, self.N_0)

    def net_u(self, X):
        return self.backbone(X)

    def net_r(self, xt):
        xt.requires_grad_(True)
        
        u = self.net_u(xt)
        grad_u = grad(u, xt)[0]
        
        u_t = grad_u[:, [-1]]
        u_xx = torch.zeros(u.shape).to(xt.device)
        for i in range(self.dim):
            u_xx += grad(grad_u[:, [i]], xt)[0][:, [i]]
        return u_t - u_xx - u + u**3
    
    def net_transformer(self, X, k):
        X.requires_grad_(False)
        return self.transformer(X, k)
    
    def compute_loss(self, use_transformer=False):
        """计算loss 可选择是否使用transformer"""
        f_res_pred = self.net_r(self.X_res)
        self.loss_res = torch.mean((f_res_pred - self.f_res) ** 2)

        u_bcs_pred = self.net_u(self.X_bcs)
        self.loss_bcs = torch.mean((u_bcs_pred - self.u_bcs) ** 2)

        u_ics_pred = self.net_u(self.X_ics)
        self.loss_ics = torch.mean((u_ics_pred - self.u_ics) ** 2)

        self.loss = self.lam_res * self.loss_res + self.lam_bcs * self.loss_bcs + self.lam_ics * self.loss_ics

    def log_loss(self):
        """记录当前loss至logger字典"""
        self.logger["loss"].append(self.loss.item())
        self.logger["loss_res"].append(self.loss_res.item())
        self.logger["loss_bcs"].append(self.loss_bcs.item())
        self.logger["loss_ics"].append(self.loss_ics.item())
        self.logger["iter"].append(self.iter + 1)

    def log_info(self):
        """保存并打印训练信息"""
        info = f'Iter {self.iter+1:5d} Time:{time.time()-self.start_time:.1e} # ' + \
               f'Loss:{self.loss.item():.2e}, Loss_r:{self.loss_res.item():.2e}, Loss_b:{self.loss_bcs.item():.2e}, Loss_0:{self.loss_ics.item():.2e} # ' + \
               f'Valid:{self.valid_loss_value:.2e}, RL2:{self.error_u:.2e}'
        with open("train_info.txt", 'a') as f:
            f.write(info + '\n')
        print(info)
        
    def compute_rl2(self, X_res):
        """计算relative l2 error"""
        u_star = u(x=X_res[:, :-1], t=X_res[:, [-1]])  # 计算解析解
        u_star = u_star.detach().cpu().numpy()
        
        u_pred = self.net_u(X_res)  # 计算预测解
        u_pred = u_pred.detach().cpu().numpy()
        
        error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)  # rl2 error
        return error_u

    def valid(self):
        """验证并保存最优模型"""
        # 计算loss
        X_res, X_bcs, X_ics, f_res, u_bcs, u_ics = self.dataset.train_data(1000, 1000, 1000)
        self.backbone.eval()
        # 不经过transformer的loss
        f_res_pred = self.net_r(X_res)
        u_bcs_pred = self.net_u(X_bcs)
        u_ics_pred = self.net_u(X_ics)
        loss_res = torch.mean((f_res_pred - f_res) ** 2)
        loss_bcs = torch.mean((u_bcs_pred - u_bcs) ** 2)
        loss_ics = torch.mean((u_ics_pred - u_ics) ** 2)
        loss = self.lam_res * loss_res + self.lam_bcs * loss_bcs + self.lam_ics * loss_ics
        
        # 计算relative l2 error
        self.error_u = self.compute_rl2(X_res)
        
        self.backbone.train()
        
        # 记录valid的loss和rl2 error信息
        self.logger_valid["loss"].append(loss.item())
        self.logger_valid["loss_res"].append(loss_res.item())
        self.logger_valid["loss_bcs"].append(loss_bcs.item())
        self.logger_valid["loss_ics"].append(loss_ics.item())
        self.logger_valid["iter"].append(self.iter + 1)
        self.logger_valid["error"].append(self.error_u)
        
        # 验证模型loss是否最优并选择保存
        self.valid_loss_value = loss.item()
        is_best = self.valid_loss_value < self.best_loss
        if is_best:
            self.best_loss = self.valid_loss_value
        state = {
            'iter': self.iter,
            'state_dict': self.backbone.state_dict(),
            'best_loss': self.best_loss
        }
        save_model(state, is_best, save_dir=self.model_path)
    
    def train(self):
        self.start_time = time.time()
        self.best_loss = 1.e10
        
        self.iter = 0
        for _ in range(self.iters_Adam):
            self.optimizer_Adam.zero_grad()
            self.compute_loss()
            self.loss.backward()
            self.optimizer_Adam.step()
            self.log_loss()

            if (self.iter + 1) % 100 == 0:
                self.valid()
                self.log_info()
                self.update_train_data()

            if (self.iter + 1) % self.step_size == 0:
                self.scheduler.step()
            self.iter += 1
            
            
trainer = Trainer_AllenCahnHD(args)
# Out:
# Adjusting learning rate of group 0 to 5.0000e-03.

# %%
trainer.train()
# Out:
# Iter   100 Time:1.1e+01 # Loss:6.95e+02, Loss_r:4.75e+02, Loss_b:1.36e+00, Loss_0:8.40e-01 # Valid:2.08e+03, RL2:5.75e+00
# Iter   200 Time:2.2e+01 # Loss:5.42e+02, Loss_r:4.20e+02, Loss_b:7.39e-01, Loss_0:4.81e-01 # Valid:1.51e+03, RL2:4.68e+00
# Iter   300 Time:3.3e+01 # Loss:4.56e+02, Loss_r:3.80e+02, Loss_b:4.32e-01, Loss_0:3.26e-01 # Valid:2.89e+03, RL2:3.62e+00
# Iter   400 Time:4.4e+01 # Loss:3.79e+02, Loss_r:3.44e+02, Loss_b:2.50e-01, Loss_0:9.90e-02 # Valid:4.38e+02, RL2:2.39e+00
# Iter   500 Time:5.5e+01 # Loss:3.49e+02, Loss_r:3.29e+02, Loss_b:1.39e-01, Loss_0:6.02e-02 # Valid:3.82e+02, RL2:2.15e+00
# Iter   600 Time:6.6e+01 # Loss:3.20e+02, Loss_r:3.07e+02, Loss_b:8.92e-02, Loss_0:4.39e-02 # Valid:3.81e+02, RL2:1.78e+00
# Iter   700 Time:7.7e+01 # Loss:2.72e+02, Loss_r:2.62e+02, Loss_b:6.71e-02, Loss_0:3.13e-02 # Valid:3.70e+02, RL2:1.67e+00
# Iter   800 Time:8.7e+01 # Loss:2.51e+02, Loss_r:2.41e+02, Loss_b:6.22e-02, Loss_0:3.74e-02 # Valid:4.48e+02, RL2:1.81e+00
# Iter   900 Time:9.8e+01 # Loss:2.58e+02, Loss_r:2.50e+02, Loss_b:4.97e-02, Loss_0:2.83e-02 # Valid:3.38e+02, RL2:1.53e+00
# Iter  1000 Time:1.1e+02 # Loss:2.21e+02, Loss_r:2.14e+02, Loss_b:4.54e-02, Loss_0:2.21e-02 # Valid:3.73e+02, RL2:1.42e+00
# Adjusting learning rate of group 0 to 4.2500e-03.
# Iter  1100 Time:1.2e+02 # Loss:1.95e+02, Loss_r:1.89e+02, Loss_b:3.93e-02, Loss_0:2.25e-02 # Valid:3.72e+02, RL2:1.24e+00
# Iter  1200 Time:1.3e+02 # Loss:1.77e+02, Loss_r:1.72e+02, Loss_b:3.31e-02, Loss_0:2.22e-02 # Valid:3.93e+02, RL2:1.24e+00
# Iter  1300 Time:1.4e+02 # Loss:1.82e+02, Loss_r:1.74e+02, Loss_b:3.64e-02, Loss_0:4.62e-02 # Valid:3.86e+02, RL2:1.02e+00
# Iter  1400 Time:1.5e+02 # Loss:1.56e+02, Loss_r:1.51e+02, Loss_b:2.71e-02, Loss_0:2.01e-02 # Valid:3.64e+02, RL2:1.21e+00
# Iter  1500 Time:1.6e+02 # Loss:1.33e+02, Loss_r:1.28e+02, Loss_b:2.46e-02, Loss_0:2.13e-02 # Valid:3.66e+02, RL2:1.14e+00
# Iter  1600 Time:1.8e+02 # Loss:2.28e+02, Loss_r:2.14e+02, Loss_b:5.23e-02, Loss_0:7.97e-02 # Valid:4.36e+02, RL2:8.60e-01
# Iter  1700 Time:1.9e+02 # Loss:1.30e+02, Loss_r:1.27e+02, Loss_b:2.15e-02, Loss_0:1.52e-02 # Valid:3.41e+02, RL2:9.64e-01
# Iter  1800 Time:2.0e+02 # Loss:1.14e+02, Loss_r:1.10e+02, Loss_b:1.95e-02, Loss_0:2.64e-02 # Valid:3.58e+02, RL2:7.00e-01
# Iter  1900 Time:2.1e+02 # Loss:1.07e+02, Loss_r:1.04e+02, Loss_b:1.78e-02, Loss_0:1.21e-02 # Valid:3.43e+02, RL2:1.06e+00
# Iter  2000 Time:2.2e+02 # Loss:1.03e+02, Loss_r:9.94e+01, Loss_b:2.23e-02, Loss_0:1.35e-02 # Valid:3.62e+02, RL2:9.24e-01
# Adjusting learning rate of group 0 to 3.6125e-03.
# Iter  2100 Time:2.3e+02 # Loss:8.22e+01, Loss_r:7.92e+01, Loss_b:1.74e-02, Loss_0:1.32e-02 # Valid:3.28e+02, RL2:1.02e+00
# Iter  2200 Time:2.4e+02 # Loss:1.05e+02, Loss_r:1.02e+02, Loss_b:1.87e-02, Loss_0:1.22e-02 # Valid:3.75e+02, RL2:1.65e+00
# Iter  2300 Time:2.5e+02 # Loss:8.45e+01, Loss_r:8.18e+01, Loss_b:1.52e-02, Loss_0:1.16e-02 # Valid:3.61e+02, RL2:9.75e-01
# Iter  2400 Time:2.6e+02 # Loss:7.93e+01, Loss_r:7.67e+01, Loss_b:1.44e-02, Loss_0:1.09e-02 # Valid:2.94e+02, RL2:9.20e-01
# Iter  2500 Time:2.7e+02 # Loss:7.79e+01, Loss_r:7.48e+01, Loss_b:1.61e-02, Loss_0:1.51e-02 # Valid:2.64e+02, RL2:6.28e-01
# Iter  2600 Time:2.8e+02 # Loss:6.62e+01, Loss_r:6.37e+01, Loss_b:1.34e-02, Loss_0:1.09e-02 # Valid:3.48e+02, RL2:9.15e-01
# Iter  2700 Time:3.0e+02 # Loss:7.71e+01, Loss_r:7.41e+01, Loss_b:1.35e-02, Loss_0:1.73e-02 # Valid:3.16e+02, RL2:8.71e-01
# Iter  2800 Time:3.1e+02 # Loss:6.30e+01, Loss_r:6.07e+01, Loss_b:1.30e-02, Loss_0:1.02e-02 # Valid:3.53e+02, RL2:9.03e-01
# Iter  2900 Time:3.2e+02 # Loss:8.38e+01, Loss_r:8.11e+01, Loss_b:1.19e-02, Loss_0:1.58e-02 # Valid:3.27e+02, RL2:5.48e-01
# Iter  3000 Time:3.3e+02 # Loss:6.43e+01, Loss_r:6.18e+01, Loss_b:1.44e-02, Loss_0:1.10e-02 # Valid:3.05e+02, RL2:8.32e-01
# Adjusting learning rate of group 0 to 3.0706e-03.
# Iter  3100 Time:3.4e+02 # Loss:5.38e+01, Loss_r:5.17e+01, Loss_b:1.24e-02, Loss_0:8.54e-03 # Valid:3.21e+02, RL2:8.48e-01
# Iter  3200 Time:3.5e+02 # Loss:4.77e+01, Loss_r:4.59e+01, Loss_b:1.08e-02, Loss_0:7.41e-03 # Valid:2.99e+02, RL2:8.45e-01
# Iter  3300 Time:3.6e+02 # Loss:5.03e+01, Loss_r:4.82e+01, Loss_b:9.65e-03, Loss_0:1.10e-02 # Valid:2.79e+02, RL2:6.05e-01
# Iter  3400 Time:3.7e+02 # Loss:4.44e+01, Loss_r:4.23e+01, Loss_b:1.17e-02, Loss_0:8.37e-03 # Valid:3.07e+02, RL2:8.44e-01
# Iter  3500 Time:3.8e+02 # Loss:3.88e+01, Loss_r:3.70e+01, Loss_b:1.08e-02, Loss_0:7.02e-03 # Valid:3.09e+02, RL2:7.77e-01
# Iter  3600 Time:3.9e+02 # Loss:3.91e+01, Loss_r:3.73e+01, Loss_b:1.03e-02, Loss_0:7.34e-03 # Valid:2.70e+02, RL2:7.93e-01
# Iter  3700 Time:4.1e+02 # Loss:5.53e+01, Loss_r:5.36e+01, Loss_b:1.09e-02, Loss_0:6.69e-03 # Valid:2.48e+02, RL2:7.51e-01
# Iter  3800 Time:4.2e+02 # Loss:3.23e+01, Loss_r:3.08e+01, Loss_b:8.88e-03, Loss_0:5.74e-03 # Valid:2.47e+02, RL2:7.24e-01
# Iter  3900 Time:4.3e+02 # Loss:3.40e+01, Loss_r:3.24e+01, Loss_b:8.22e-03, Loss_0:7.36e-03 # Valid:2.58e+02, RL2:6.44e-01
# Iter  4000 Time:4.4e+02 # Loss:3.07e+01, Loss_r:2.93e+01, Loss_b:7.27e-03, Loss_0:6.67e-03 # Valid:2.59e+02, RL2:7.13e-01
# Adjusting learning rate of group 0 to 2.6100e-03.
# Iter  4100 Time:4.5e+02 # Loss:2.85e+01, Loss_r:2.72e+01, Loss_b:7.59e-03, Loss_0:5.85e-03 # Valid:2.45e+02, RL2:6.42e-01
# Iter  4200 Time:4.6e+02 # Loss:3.32e+01, Loss_r:3.21e+01, Loss_b:6.69e-03, Loss_0:4.57e-03 # Valid:2.43e+02, RL2:7.64e-01
# Iter  4300 Time:4.7e+02 # Loss:2.99e+01, Loss_r:2.87e+01, Loss_b:5.99e-03, Loss_0:5.28e-03 # Valid:2.49e+02, RL2:5.54e-01
# Iter  4400 Time:4.8e+02 # Loss:4.12e+01, Loss_r:3.96e+01, Loss_b:1.00e-02, Loss_0:6.07e-03 # Valid:2.56e+02, RL2:6.05e-01
# Iter  4500 Time:4.9e+02 # Loss:2.43e+01, Loss_r:2.32e+01, Loss_b:6.09e-03, Loss_0:4.88e-03 # Valid:2.15e+02, RL2:6.47e-01
# Iter  4600 Time:5.0e+02 # Loss:2.61e+01, Loss_r:2.50e+01, Loss_b:6.63e-03, Loss_0:4.35e-03 # Valid:1.87e+02, RL2:5.31e-01
# Iter  4700 Time:5.1e+02 # Loss:2.88e+01, Loss_r:2.74e+01, Loss_b:6.48e-03, Loss_0:7.60e-03 # Valid:2.17e+02, RL2:9.46e-01
# Iter  4800 Time:5.3e+02 # Loss:2.42e+01, Loss_r:2.32e+01, Loss_b:5.94e-03, Loss_0:4.39e-03 # Valid:1.88e+02, RL2:6.16e-01
# Iter  4900 Time:5.4e+02 # Loss:2.42e+01, Loss_r:2.31e+01, Loss_b:6.35e-03, Loss_0:4.30e-03 # Valid:2.07e+02, RL2:6.56e-01
# Iter  5000 Time:5.5e+02 # Loss:2.00e+01, Loss_r:1.90e+01, Loss_b:5.75e-03, Loss_0:4.80e-03 # Valid:1.99e+02, RL2:6.07e-01
# Adjusting learning rate of group 0 to 2.2185e-03.
# Iter  5100 Time:5.6e+02 # Loss:2.02e+01, Loss_r:1.91e+01, Loss_b:6.43e-03, Loss_0:4.39e-03 # Valid:1.89e+02, RL2:5.69e-01
# Iter  5200 Time:5.7e+02 # Loss:2.20e+01, Loss_r:2.10e+01, Loss_b:5.74e-03, Loss_0:4.59e-03 # Valid:1.97e+02, RL2:5.52e-01
# Iter  5300 Time:5.8e+02 # Loss:1.98e+01, Loss_r:1.89e+01, Loss_b:5.07e-03, Loss_0:3.73e-03 # Valid:1.81e+02, RL2:5.13e-01
# Iter  5400 Time:5.9e+02 # Loss:2.00e+01, Loss_r:1.90e+01, Loss_b:5.88e-03, Loss_0:4.35e-03 # Valid:1.68e+02, RL2:5.13e-01
# Iter  5500 Time:6.0e+02 # Loss:1.65e+01, Loss_r:1.56e+01, Loss_b:5.55e-03, Loss_0:3.56e-03 # Valid:1.70e+02, RL2:5.42e-01
# Iter  5600 Time:6.1e+02 # Loss:1.59e+01, Loss_r:1.50e+01, Loss_b:5.27e-03, Loss_0:3.33e-03 # Valid:1.65e+02, RL2:4.79e-01
# Iter  5700 Time:6.2e+02 # Loss:1.41e+01, Loss_r:1.34e+01, Loss_b:4.71e-03, Loss_0:2.72e-03 # Valid:1.63e+02, RL2:4.77e-01
# Iter  5800 Time:6.4e+02 # Loss:1.48e+01, Loss_r:1.41e+01, Loss_b:4.25e-03, Loss_0:2.65e-03 # Valid:1.42e+02, RL2:4.88e-01
# Iter  5900 Time:6.5e+02 # Loss:1.31e+01, Loss_r:1.24e+01, Loss_b:4.38e-03, Loss_0:2.91e-03 # Valid:1.32e+02, RL2:4.62e-01
# Iter  6000 Time:6.6e+02 # Loss:1.45e+01, Loss_r:1.37e+01, Loss_b:4.81e-03, Loss_0:2.94e-03 # Valid:1.51e+02, RL2:5.80e-01
# Adjusting learning rate of group 0 to 1.8857e-03.
# Iter  6100 Time:6.7e+02 # Loss:1.27e+01, Loss_r:1.21e+01, Loss_b:4.11e-03, Loss_0:2.73e-03 # Valid:1.46e+02, RL2:4.17e-01
# Iter  6200 Time:6.8e+02 # Loss:1.36e+01, Loss_r:1.29e+01, Loss_b:3.66e-03, Loss_0:2.65e-03 # Valid:1.18e+02, RL2:3.98e-01
# Iter  6300 Time:6.9e+02 # Loss:1.12e+01, Loss_r:1.06e+01, Loss_b:3.78e-03, Loss_0:2.41e-03 # Valid:1.06e+02, RL2:4.54e-01
# Iter  6400 Time:7.0e+02 # Loss:1.29e+01, Loss_r:1.23e+01, Loss_b:3.53e-03, Loss_0:2.00e-03 # Valid:1.05e+02, RL2:3.92e-01
# Iter  6500 Time:7.1e+02 # Loss:1.04e+01, Loss_r:9.84e+00, Loss_b:3.03e-03, Loss_0:2.10e-03 # Valid:8.54e+01, RL2:3.89e-01
# Iter  6600 Time:7.2e+02 # Loss:1.31e+01, Loss_r:1.26e+01, Loss_b:3.67e-03, Loss_0:1.62e-03 # Valid:8.93e+01, RL2:3.59e-01
# Iter  6700 Time:7.3e+02 # Loss:9.13e+00, Loss_r:8.69e+00, Loss_b:2.76e-03, Loss_0:1.63e-03 # Valid:8.64e+01, RL2:3.80e-01
# Iter  6800 Time:7.4e+02 # Loss:8.71e+00, Loss_r:8.25e+00, Loss_b:2.80e-03, Loss_0:1.76e-03 # Valid:8.55e+01, RL2:3.54e-01
# Iter  6900 Time:7.6e+02 # Loss:8.64e+00, Loss_r:8.19e+00, Loss_b:2.85e-03, Loss_0:1.63e-03 # Valid:8.33e+01, RL2:3.14e-01
# Iter  7000 Time:7.7e+02 # Loss:1.39e+01, Loss_r:1.33e+01, Loss_b:2.74e-03, Loss_0:2.97e-03 # Valid:7.43e+01, RL2:4.32e-01
# Adjusting learning rate of group 0 to 1.6029e-03.
# Iter  7100 Time:7.8e+02 # Loss:7.67e+00, Loss_r:7.28e+00, Loss_b:2.57e-03, Loss_0:1.28e-03 # Valid:6.05e+01, RL2:3.10e-01
# Iter  7200 Time:7.9e+02 # Loss:7.41e+00, Loss_r:7.00e+00, Loss_b:2.55e-03, Loss_0:1.47e-03 # Valid:7.41e+01, RL2:3.39e-01
# Iter  7300 Time:8.0e+02 # Loss:6.27e+00, Loss_r:5.96e+00, Loss_b:2.11e-03, Loss_0:1.06e-03 # Valid:5.58e+01, RL2:3.00e-01
# Iter  7400 Time:8.1e+02 # Loss:9.79e+00, Loss_r:9.45e+00, Loss_b:2.38e-03, Loss_0:1.05e-03 # Valid:5.95e+01, RL2:2.91e-01
# Iter  7500 Time:8.2e+02 # Loss:1.37e+01, Loss_r:1.33e+01, Loss_b:2.01e-03, Loss_0:1.56e-03 # Valid:6.60e+01, RL2:2.34e-01
# Iter  7600 Time:8.3e+02 # Loss:7.06e+00, Loss_r:6.73e+00, Loss_b:2.17e-03, Loss_0:1.11e-03 # Valid:5.84e+01, RL2:2.38e-01
# Iter  7700 Time:8.4e+02 # Loss:5.63e+00, Loss_r:5.29e+00, Loss_b:2.30e-03, Loss_0:1.05e-03 # Valid:5.06e+01, RL2:3.19e-01
# Iter  7800 Time:8.5e+02 # Loss:6.23e+00, Loss_r:5.92e+00, Loss_b:1.96e-03, Loss_0:1.10e-03 # Valid:4.56e+01, RL2:2.63e-01
# Iter  7900 Time:8.7e+02 # Loss:4.84e+00, Loss_r:4.54e+00, Loss_b:2.03e-03, Loss_0:9.39e-04 # Valid:4.22e+01, RL2:2.36e-01
# Iter  8000 Time:8.8e+02 # Loss:4.22e+00, Loss_r:3.96e+00, Loss_b:1.88e-03, Loss_0:7.61e-04 # Valid:4.35e+01, RL2:2.95e-01
# Adjusting learning rate of group 0 to 1.3625e-03.
# Iter  8100 Time:8.9e+02 # Loss:5.40e+00, Loss_r:5.13e+00, Loss_b:1.80e-03, Loss_0:8.66e-04 # Valid:3.80e+01, RL2:2.29e-01
# Iter  8200 Time:9.0e+02 # Loss:4.52e+00, Loss_r:4.26e+00, Loss_b:1.95e-03, Loss_0:6.61e-04 # Valid:3.53e+01, RL2:2.84e-01
# Iter  8300 Time:9.1e+02 # Loss:4.07e+00, Loss_r:3.83e+00, Loss_b:1.71e-03, Loss_0:6.84e-04 # Valid:3.40e+01, RL2:2.54e-01
# Iter  8400 Time:9.2e+02 # Loss:3.36e+00, Loss_r:3.13e+00, Loss_b:1.68e-03, Loss_0:6.13e-04 # Valid:3.29e+01, RL2:2.59e-01
# Iter  8500 Time:9.3e+02 # Loss:3.32e+00, Loss_r:3.10e+00, Loss_b:1.69e-03, Loss_0:4.89e-04 # Valid:2.86e+01, RL2:2.01e-01
# Iter  8600 Time:9.4e+02 # Loss:3.07e+00, Loss_r:2.86e+00, Loss_b:1.64e-03, Loss_0:5.48e-04 # Valid:2.84e+01, RL2:2.24e-01
# Iter  8700 Time:9.5e+02 # Loss:4.80e+00, Loss_r:4.58e+00, Loss_b:1.59e-03, Loss_0:6.08e-04 # Valid:2.33e+01, RL2:2.20e-01
# Iter  8800 Time:9.6e+02 # Loss:2.63e+00, Loss_r:2.43e+00, Loss_b:1.49e-03, Loss_0:4.53e-04 # Valid:2.54e+01, RL2:2.30e-01
# Iter  8900 Time:9.8e+02 # Loss:3.04e+00, Loss_r:2.84e+00, Loss_b:1.55e-03, Loss_0:4.74e-04 # Valid:2.23e+01, RL2:2.24e-01
# Iter  9000 Time:9.9e+02 # Loss:2.52e+00, Loss_r:2.34e+00, Loss_b:1.42e-03, Loss_0:4.07e-04 # Valid:2.29e+01, RL2:2.55e-01
# Adjusting learning rate of group 0 to 1.1581e-03.
# Iter  9100 Time:1.0e+03 # Loss:2.13e+00, Loss_r:1.95e+00, Loss_b:1.37e-03, Loss_0:3.95e-04 # Valid:1.84e+01, RL2:2.04e-01
# Iter  9200 Time:1.0e+03 # Loss:3.77e+00, Loss_r:3.60e+00, Loss_b:1.29e-03, Loss_0:4.00e-04 # Valid:1.80e+01, RL2:2.51e-01
# Iter  9300 Time:1.0e+03 # Loss:5.85e+00, Loss_r:5.67e+00, Loss_b:1.24e-03, Loss_0:5.10e-04 # Valid:2.11e+01, RL2:2.14e-01
# Iter  9400 Time:1.0e+03 # Loss:2.28e+00, Loss_r:2.11e+00, Loss_b:1.31e-03, Loss_0:3.80e-04 # Valid:1.83e+01, RL2:1.86e-01
# Iter  9500 Time:1.0e+03 # Loss:1.08e+01, Loss_r:1.06e+01, Loss_b:1.14e-03, Loss_0:8.33e-04 # Valid:2.22e+01, RL2:1.54e-01
# Iter  9600 Time:1.1e+03 # Loss:2.19e+00, Loss_r:2.03e+00, Loss_b:1.21e-03, Loss_0:3.86e-04 # Valid:1.68e+01, RL2:1.94e-01
# Iter  9700 Time:1.1e+03 # Loss:3.10e+00, Loss_r:2.94e+00, Loss_b:1.22e-03, Loss_0:4.42e-04 # Valid:1.84e+01, RL2:1.80e-01
# Iter  9800 Time:1.1e+03 # Loss:2.26e+00, Loss_r:2.10e+00, Loss_b:1.23e-03, Loss_0:3.37e-04 # Valid:1.73e+01, RL2:1.86e-01
# Iter  9900 Time:1.1e+03 # Loss:2.25e+00, Loss_r:2.10e+00, Loss_b:1.11e-03, Loss_0:3.44e-04 # Valid:1.66e+01, RL2:1.72e-01
# Iter 10000 Time:1.1e+03 # Loss:1.79e+00, Loss_r:1.64e+00, Loss_b:1.16e-03, Loss_0:3.43e-04 # Valid:1.60e+01, RL2:1.73e-01
# Adjusting learning rate of group 0 to 9.8437e-04.
# Iter 10100 Time:1.1e+03 # Loss:2.44e+00, Loss_r:2.28e+00, Loss_b:1.12e-03, Loss_0:4.50e-04 # Valid:1.54e+01, RL2:1.86e-01
# Iter 10200 Time:1.1e+03 # Loss:1.83e+00, Loss_r:1.69e+00, Loss_b:1.09e-03, Loss_0:3.03e-04 # Valid:1.59e+01, RL2:1.76e-01
# Iter 10300 Time:1.1e+03 # Loss:2.98e+00, Loss_r:2.85e+00, Loss_b:1.04e-03, Loss_0:2.88e-04 # Valid:1.73e+01, RL2:2.17e-01
# Iter 10400 Time:1.1e+03 # Loss:1.86e+00, Loss_r:1.73e+00, Loss_b:9.93e-04, Loss_0:2.81e-04 # Valid:1.30e+01, RL2:1.88e-01
# Iter 10500 Time:1.2e+03 # Loss:1.78e+00, Loss_r:1.65e+00, Loss_b:1.04e-03, Loss_0:3.08e-04 # Valid:1.27e+01, RL2:1.78e-01
# Iter 10600 Time:1.2e+03 # Loss:1.35e+01, Loss_r:1.33e+01, Loss_b:1.00e-03, Loss_0:1.05e-03 # Valid:1.93e+01, RL2:1.62e-01
# Iter 10700 Time:1.2e+03 # Loss:3.74e+00, Loss_r:3.59e+00, Loss_b:1.05e-03, Loss_0:3.91e-04 # Valid:1.50e+01, RL2:1.45e-01
# Iter 10800 Time:1.2e+03 # Loss:1.85e+00, Loss_r:1.73e+00, Loss_b:9.07e-04, Loss_0:2.66e-04 # Valid:1.36e+01, RL2:1.87e-01
# Iter 10900 Time:1.2e+03 # Loss:8.34e+00, Loss_r:8.21e+00, Loss_b:9.78e-04, Loss_0:2.80e-04 # Valid:2.18e+01, RL2:2.28e-01
# Iter 11000 Time:1.2e+03 # Loss:2.02e+00, Loss_r:1.89e+00, Loss_b:1.08e-03, Loss_0:2.76e-04 # Valid:1.38e+01, RL2:1.43e-01
# Adjusting learning rate of group 0 to 8.3672e-04.
# Iter 11100 Time:1.2e+03 # Loss:1.59e+00, Loss_r:1.48e+00, Loss_b:8.87e-04, Loss_0:2.46e-04 # Valid:1.19e+01, RL2:1.62e-01
# Iter 11200 Time:1.2e+03 # Loss:1.53e+00, Loss_r:1.41e+00, Loss_b:9.11e-04, Loss_0:2.37e-04 # Valid:1.19e+01, RL2:1.55e-01
# Iter 11300 Time:1.2e+03 # Loss:2.82e+00, Loss_r:2.68e+00, Loss_b:1.12e-03, Loss_0:3.31e-04 # Valid:1.22e+01, RL2:1.45e-01
# Iter 11400 Time:1.2e+03 # Loss:5.20e+00, Loss_r:5.07e+00, Loss_b:9.36e-04, Loss_0:3.87e-04 # Valid:1.31e+01, RL2:1.63e-01
# Iter 11500 Time:1.3e+03 # Loss:1.95e+00, Loss_r:1.83e+00, Loss_b:9.28e-04, Loss_0:2.32e-04 # Valid:1.21e+01, RL2:1.88e-01
# Iter 11600 Time:1.3e+03 # Loss:1.76e+00, Loss_r:1.64e+00, Loss_b:8.86e-04, Loss_0:2.59e-04 # Valid:1.15e+01, RL2:1.61e-01
# Iter 11700 Time:1.3e+03 # Loss:6.16e+00, Loss_r:6.05e+00, Loss_b:8.85e-04, Loss_0:2.58e-04 # Valid:1.45e+01, RL2:1.94e-01
# Iter 11800 Time:1.3e+03 # Loss:2.02e+00, Loss_r:1.91e+00, Loss_b:8.18e-04, Loss_0:2.21e-04 # Valid:1.28e+01, RL2:1.84e-01
# Iter 11900 Time:1.3e+03 # Loss:1.60e+00, Loss_r:1.49e+00, Loss_b:8.30e-04, Loss_0:2.31e-04 # Valid:1.12e+01, RL2:1.52e-01
# Iter 12000 Time:1.3e+03 # Loss:1.44e+00, Loss_r:1.33e+00, Loss_b:8.45e-04, Loss_0:2.31e-04 # Valid:1.18e+01, RL2:1.57e-01
# Adjusting learning rate of group 0 to 7.1121e-04.
# Iter 12100 Time:1.3e+03 # Loss:1.31e+00, Loss_r:1.20e+00, Loss_b:8.66e-04, Loss_0:2.28e-04 # Valid:1.03e+01, RL2:1.56e-01
# Iter 12200 Time:1.3e+03 # Loss:1.65e+00, Loss_r:1.54e+00, Loss_b:8.74e-04, Loss_0:2.08e-04 # Valid:9.87e+00, RL2:1.26e-01
# Iter 12300 Time:1.3e+03 # Loss:1.92e+00, Loss_r:1.81e+00, Loss_b:7.84e-04, Loss_0:2.88e-04 # Valid:1.03e+01, RL2:1.49e-01
# Iter 12400 Time:1.4e+03 # Loss:1.30e+00, Loss_r:1.20e+00, Loss_b:8.45e-04, Loss_0:2.27e-04 # Valid:9.36e+00, RL2:1.63e-01
# Iter 12500 Time:1.4e+03 # Loss:1.40e+00, Loss_r:1.30e+00, Loss_b:7.66e-04, Loss_0:2.25e-04 # Valid:9.80e+00, RL2:1.35e-01
# Iter 12600 Time:1.4e+03 # Loss:3.32e+00, Loss_r:3.22e+00, Loss_b:7.54e-04, Loss_0:2.00e-04 # Valid:1.19e+01, RL2:1.69e-01
# Iter 12700 Time:1.4e+03 # Loss:2.73e+00, Loss_r:2.62e+00, Loss_b:7.90e-04, Loss_0:2.95e-04 # Valid:1.16e+01, RL2:1.52e-01
# Iter 12800 Time:1.4e+03 # Loss:1.35e+00, Loss_r:1.25e+00, Loss_b:7.60e-04, Loss_0:2.14e-04 # Valid:9.99e+00, RL2:1.60e-01
# Iter 12900 Time:1.4e+03 # Loss:1.34e+00, Loss_r:1.25e+00, Loss_b:7.25e-04, Loss_0:1.99e-04 # Valid:1.11e+01, RL2:1.31e-01
# Iter 13000 Time:1.4e+03 # Loss:1.21e+00, Loss_r:1.11e+00, Loss_b:7.25e-04, Loss_0:2.17e-04 # Valid:1.05e+01, RL2:1.47e-01
# Adjusting learning rate of group 0 to 6.0453e-04.
# Iter 13100 Time:1.4e+03 # Loss:1.30e+00, Loss_r:1.20e+00, Loss_b:7.40e-04, Loss_0:2.32e-04 # Valid:9.60e+00, RL2:1.26e-01
# Iter 13200 Time:1.4e+03 # Loss:1.22e+00, Loss_r:1.13e+00, Loss_b:7.31e-04, Loss_0:1.95e-04 # Valid:8.83e+00, RL2:1.28e-01
# Iter 13300 Time:1.5e+03 # Loss:2.49e+00, Loss_r:2.39e+00, Loss_b:7.45e-04, Loss_0:2.76e-04 # Valid:9.14e+00, RL2:1.64e-01
# Iter 13400 Time:1.5e+03 # Loss:1.52e+00, Loss_r:1.43e+00, Loss_b:7.10e-04, Loss_0:1.94e-04 # Valid:9.10e+00, RL2:1.57e-01
# Iter 13500 Time:1.5e+03 # Loss:3.03e+00, Loss_r:2.94e+00, Loss_b:7.10e-04, Loss_0:1.89e-04 # Valid:1.19e+01, RL2:1.46e-01
# Iter 13600 Time:1.5e+03 # Loss:1.99e+00, Loss_r:1.89e+00, Loss_b:7.45e-04, Loss_0:2.15e-04 # Valid:1.09e+01, RL2:1.54e-01
# Iter 13700 Time:1.5e+03 # Loss:3.85e+00, Loss_r:3.76e+00, Loss_b:6.76e-04, Loss_0:1.94e-04 # Valid:1.34e+01, RL2:1.72e-01
# Iter 13800 Time:1.5e+03 # Loss:1.06e+00, Loss_r:9.80e-01, Loss_b:6.51e-04, Loss_0:1.68e-04 # Valid:8.27e+00, RL2:1.22e-01
# Iter 13900 Time:1.5e+03 # Loss:1.66e+00, Loss_r:1.57e+00, Loss_b:6.36e-04, Loss_0:1.76e-04 # Valid:9.41e+00, RL2:1.56e-01
# Iter 14000 Time:1.5e+03 # Loss:1.12e+00, Loss_r:1.05e+00, Loss_b:6.03e-04, Loss_0:1.65e-04 # Valid:9.15e+00, RL2:1.28e-01
# Adjusting learning rate of group 0 to 5.1385e-04.
# Iter 14100 Time:1.5e+03 # Loss:1.10e+00, Loss_r:1.03e+00, Loss_b:5.89e-04, Loss_0:1.64e-04 # Valid:8.99e+00, RL2:1.24e-01
# Iter 14200 Time:1.6e+03 # Loss:1.16e+00, Loss_r:1.08e+00, Loss_b:6.34e-04, Loss_0:1.70e-04 # Valid:8.17e+00, RL2:1.35e-01
# Iter 14300 Time:1.6e+03 # Loss:1.19e+00, Loss_r:1.12e+00, Loss_b:5.93e-04, Loss_0:1.60e-04 # Valid:7.57e+00, RL2:1.34e-01
# Iter 14400 Time:1.6e+03 # Loss:1.19e+00, Loss_r:1.12e+00, Loss_b:5.68e-04, Loss_0:1.68e-04 # Valid:8.18e+00, RL2:1.46e-01
# Iter 14500 Time:1.6e+03 # Loss:4.50e+00, Loss_r:4.42e+00, Loss_b:6.16e-04, Loss_0:1.74e-04 # Valid:1.29e+01, RL2:1.66e-01
# Iter 14600 Time:1.6e+03 # Loss:1.07e+00, Loss_r:9.95e-01, Loss_b:6.01e-04, Loss_0:1.67e-04 # Valid:7.29e+00, RL2:1.21e-01
# Iter 14700 Time:1.6e+03 # Loss:2.07e+00, Loss_r:1.99e+00, Loss_b:6.12e-04, Loss_0:1.76e-04 # Valid:8.32e+00, RL2:1.57e-01
# Iter 14800 Time:1.6e+03 # Loss:1.19e+00, Loss_r:1.11e+00, Loss_b:5.89e-04, Loss_0:1.62e-04 # Valid:8.54e+00, RL2:1.30e-01
# Iter 14900 Time:1.6e+03 # Loss:1.03e+00, Loss_r:9.54e-01, Loss_b:5.99e-04, Loss_0:1.55e-04 # Valid:8.09e+00, RL2:1.30e-01
# Iter 15000 Time:1.6e+03 # Loss:1.13e+00, Loss_r:1.05e+00, Loss_b:6.58e-04, Loss_0:1.60e-04 # Valid:7.27e+00, RL2:1.05e-01
# Adjusting learning rate of group 0 to 4.3677e-04.
# Iter 15100 Time:1.7e+03 # Loss:1.00e+00, Loss_r:9.32e-01, Loss_b:5.47e-04, Loss_0:1.63e-04 # Valid:7.88e+00, RL2:1.20e-01
# Iter 15200 Time:1.7e+03 # Loss:1.40e+00, Loss_r:1.32e+00, Loss_b:6.01e-04, Loss_0:1.81e-04 # Valid:7.07e+00, RL2:1.02e-01
# Iter 15300 Time:1.7e+03 # Loss:1.15e+00, Loss_r:1.08e+00, Loss_b:5.52e-04, Loss_0:1.50e-04 # Valid:6.75e+00, RL2:1.16e-01
# Iter 15400 Time:1.7e+03 # Loss:1.06e+00, Loss_r:9.87e-01, Loss_b:5.71e-04, Loss_0:1.65e-04 # Valid:6.86e+00, RL2:1.29e-01
# Iter 15500 Time:1.7e+03 # Loss:1.05e+00, Loss_r:9.71e-01, Loss_b:5.80e-04, Loss_0:1.69e-04 # Valid:7.04e+00, RL2:1.27e-01
# Iter 15600 Time:1.7e+03 # Loss:1.18e+00, Loss_r:1.11e+00, Loss_b:5.85e-04, Loss_0:1.62e-04 # Valid:6.89e+00, RL2:1.13e-01
# Iter 15700 Time:1.7e+03 # Loss:1.72e+00, Loss_r:1.65e+00, Loss_b:5.46e-04, Loss_0:1.67e-04 # Valid:7.46e+00, RL2:1.06e-01
# Iter 15800 Time:1.7e+03 # Loss:1.04e+00, Loss_r:9.76e-01, Loss_b:4.85e-04, Loss_0:1.48e-04 # Valid:6.32e+00, RL2:1.12e-01
# Iter 15900 Time:1.7e+03 # Loss:1.00e+00, Loss_r:9.39e-01, Loss_b:5.23e-04, Loss_0:1.40e-04 # Valid:6.60e+00, RL2:1.13e-01
# Iter 16000 Time:1.8e+03 # Loss:8.83e-01, Loss_r:8.15e-01, Loss_b:5.28e-04, Loss_0:1.51e-04 # Valid:6.75e+00, RL2:1.22e-01
# Adjusting learning rate of group 0 to 3.7126e-04.
# Iter 16100 Time:1.8e+03 # Loss:1.05e+00, Loss_r:9.78e-01, Loss_b:5.43e-04, Loss_0:1.35e-04 # Valid:6.79e+00, RL2:1.14e-01
# Iter 16200 Time:1.8e+03 # Loss:9.18e-01, Loss_r:8.48e-01, Loss_b:5.71e-04, Loss_0:1.31e-04 # Valid:5.65e+00, RL2:1.15e-01
# Iter 16300 Time:1.8e+03 # Loss:1.26e+00, Loss_r:1.19e+00, Loss_b:6.04e-04, Loss_0:1.35e-04 # Valid:6.45e+00, RL2:1.07e-01
# Iter 16400 Time:1.8e+03 # Loss:1.73e+00, Loss_r:1.66e+00, Loss_b:5.45e-04, Loss_0:1.64e-04 # Valid:5.72e+00, RL2:9.63e-02
# Iter 16500 Time:1.8e+03 # Loss:3.15e+00, Loss_r:3.09e+00, Loss_b:4.65e-04, Loss_0:1.37e-04 # Valid:9.57e+00, RL2:1.42e-01
# Iter 16600 Time:1.8e+03 # Loss:4.14e+00, Loss_r:4.08e+00, Loss_b:4.78e-04, Loss_0:1.47e-04 # Valid:7.82e+00, RL2:1.44e-01
# Iter 16700 Time:1.8e+03 # Loss:1.17e+00, Loss_r:1.10e+00, Loss_b:5.28e-04, Loss_0:1.37e-04 # Valid:6.27e+00, RL2:1.09e-01
# Iter 16800 Time:1.8e+03 # Loss:8.63e-01, Loss_r:7.99e-01, Loss_b:4.93e-04, Loss_0:1.43e-04 # Valid:7.07e+00, RL2:1.08e-01
# Iter 16900 Time:1.9e+03 # Loss:9.42e-01, Loss_r:8.80e-01, Loss_b:4.94e-04, Loss_0:1.21e-04 # Valid:6.13e+00, RL2:1.16e-01
# Iter 17000 Time:1.9e+03 # Loss:1.15e+00, Loss_r:1.08e+00, Loss_b:4.79e-04, Loss_0:1.44e-04 # Valid:5.93e+00, RL2:1.04e-01
# Adjusting learning rate of group 0 to 3.1557e-04.
# Iter 17100 Time:1.9e+03 # Loss:9.51e-01, Loss_r:8.91e-01, Loss_b:4.63e-04, Loss_0:1.29e-04 # Valid:6.07e+00, RL2:1.08e-01
# Iter 17200 Time:1.9e+03 # Loss:8.55e-01, Loss_r:7.99e-01, Loss_b:4.37e-04, Loss_0:1.25e-04 # Valid:6.21e+00, RL2:1.13e-01
# Iter 17300 Time:1.9e+03 # Loss:8.90e-01, Loss_r:8.34e-01, Loss_b:4.36e-04, Loss_0:1.26e-04 # Valid:6.25e+00, RL2:1.23e-01
# Iter 17400 Time:1.9e+03 # Loss:1.12e+00, Loss_r:1.06e+00, Loss_b:5.13e-04, Loss_0:1.29e-04 # Valid:5.28e+00, RL2:1.03e-01
# Iter 17500 Time:1.9e+03 # Loss:8.47e-01, Loss_r:7.87e-01, Loss_b:4.90e-04, Loss_0:1.11e-04 # Valid:4.63e+00, RL2:9.99e-02
# Iter 17600 Time:1.9e+03 # Loss:9.33e-01, Loss_r:8.75e-01, Loss_b:4.46e-04, Loss_0:1.25e-04 # Valid:5.32e+00, RL2:1.06e-01
# Iter 17700 Time:1.9e+03 # Loss:9.60e-01, Loss_r:9.06e-01, Loss_b:4.40e-04, Loss_0:1.05e-04 # Valid:5.06e+00, RL2:1.05e-01
# Iter 17800 Time:2.0e+03 # Loss:1.28e+00, Loss_r:1.23e+00, Loss_b:4.35e-04, Loss_0:1.60e-04 # Valid:5.34e+00, RL2:1.10e-01
# Iter 17900 Time:2.0e+03 # Loss:8.82e-01, Loss_r:8.24e-01, Loss_b:4.60e-04, Loss_0:1.12e-04 # Valid:5.16e+00, RL2:9.59e-02
# Iter 18000 Time:2.0e+03 # Loss:8.52e-01, Loss_r:7.98e-01, Loss_b:4.29e-04, Loss_0:1.13e-04 # Valid:5.63e+00, RL2:1.04e-01
# Adjusting learning rate of group 0 to 2.6823e-04.
# Iter 18100 Time:2.0e+03 # Loss:8.31e-01, Loss_r:7.78e-01, Loss_b:4.28e-04, Loss_0:1.03e-04 # Valid:4.68e+00, RL2:1.04e-01
# Iter 18200 Time:2.0e+03 # Loss:8.51e-01, Loss_r:7.95e-01, Loss_b:4.41e-04, Loss_0:1.11e-04 # Valid:4.49e+00, RL2:1.11e-01
# Iter 18300 Time:2.0e+03 # Loss:8.77e-01, Loss_r:8.21e-01, Loss_b:4.50e-04, Loss_0:1.07e-04 # Valid:4.79e+00, RL2:1.01e-01
# Iter 18400 Time:2.0e+03 # Loss:1.66e+00, Loss_r:1.61e+00, Loss_b:4.34e-04, Loss_0:1.27e-04 # Valid:5.80e+00, RL2:9.01e-02
# Iter 18500 Time:2.0e+03 # Loss:8.72e-01, Loss_r:8.22e-01, Loss_b:4.01e-04, Loss_0:9.22e-05 # Valid:4.76e+00, RL2:9.71e-02
# Iter 18600 Time:2.0e+03 # Loss:9.03e-01, Loss_r:8.53e-01, Loss_b:3.87e-04, Loss_0:1.12e-04 # Valid:4.71e+00, RL2:9.98e-02
# Iter 18700 Time:2.1e+03 # Loss:1.04e+00, Loss_r:9.88e-01, Loss_b:4.04e-04, Loss_0:1.07e-04 # Valid:5.13e+00, RL2:1.12e-01
# Iter 18800 Time:2.1e+03 # Loss:8.52e-01, Loss_r:8.02e-01, Loss_b:3.96e-04, Loss_0:1.02e-04 # Valid:5.13e+00, RL2:9.62e-02
# Iter 18900 Time:2.1e+03 # Loss:9.09e-01, Loss_r:8.54e-01, Loss_b:4.28e-04, Loss_0:1.15e-04 # Valid:4.74e+00, RL2:9.69e-02
# Iter 19000 Time:2.1e+03 # Loss:8.03e-01, Loss_r:7.50e-01, Loss_b:4.35e-04, Loss_0:9.92e-05 # Valid:4.11e+00, RL2:1.07e-01
# Adjusting learning rate of group 0 to 2.2800e-04.
# Iter 19100 Time:2.1e+03 # Loss:8.25e-01, Loss_r:7.74e-01, Loss_b:4.04e-04, Loss_0:1.07e-04 # Valid:4.49e+00, RL2:9.69e-02
# Iter 19200 Time:2.1e+03 # Loss:7.89e-01, Loss_r:7.45e-01, Loss_b:3.49e-04, Loss_0:9.03e-05 # Valid:4.73e+00, RL2:9.74e-02
# Iter 19300 Time:2.1e+03 # Loss:1.15e+00, Loss_r:1.10e+00, Loss_b:3.95e-04, Loss_0:1.11e-04 # Valid:5.57e+00, RL2:9.99e-02
# Iter 19400 Time:2.1e+03 # Loss:8.10e-01, Loss_r:7.63e-01, Loss_b:3.84e-04, Loss_0:9.35e-05 # Valid:4.05e+00, RL2:8.72e-02
# Iter 19500 Time:2.1e+03 # Loss:8.12e-01, Loss_r:7.63e-01, Loss_b:3.76e-04, Loss_0:1.06e-04 # Valid:4.00e+00, RL2:9.51e-02
# Iter 19600 Time:2.2e+03 # Loss:9.18e-01, Loss_r:8.70e-01, Loss_b:3.82e-04, Loss_0:9.91e-05 # Valid:4.34e+00, RL2:9.08e-02
# Iter 19700 Time:2.2e+03 # Loss:8.64e-01, Loss_r:8.12e-01, Loss_b:4.21e-04, Loss_0:9.67e-05 # Valid:4.61e+00, RL2:9.35e-02
# Iter 19800 Time:2.2e+03 # Loss:7.36e-01, Loss_r:6.89e-01, Loss_b:3.55e-04, Loss_0:1.11e-04 # Valid:3.97e+00, RL2:9.07e-02
# Iter 19900 Time:2.2e+03 # Loss:8.20e-01, Loss_r:7.73e-01, Loss_b:3.73e-04, Loss_0:9.79e-05 # Valid:3.95e+00, RL2:8.53e-02
# Iter 20000 Time:2.2e+03 # Loss:8.09e-01, Loss_r:7.63e-01, Loss_b:3.60e-04, Loss_0:1.04e-04 # Valid:5.01e+00, RL2:9.14e-02
# Adjusting learning rate of group 0 to 1.9380e-04.

# %%
np.save("./loss_logger_dict.npy", trainer.logger)
np.save("./loss_logger_valid_dict.npy", trainer.logger_valid)

# %% [markdown]
# ## 结果可视化

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size':18})

# %% [markdown]
# ### 训练的loss图

# %%
# loss图
loss_logger = np.load("./loss_logger_dict.npy", allow_pickle=True).item()

fig = plt.figure(figsize=(9, 7), dpi=64)
ax = fig.subplots()

_k = 100
# ax.plot(loss_logger["iter"][::k], loss_logger["loss"][::k], label=r"$\mathcal{L}$", linewidth=3)
ax.plot(loss_logger["iter"][::_k], loss_logger["loss_res"][::_k], label=r"$\mathcal{L}_{r}$", linewidth=3)
ax.plot(loss_logger["iter"][::_k], loss_logger["loss_bcs"][::_k], label=r"$\mathcal{L}_{b}$", linewidth=3)
ax.plot(loss_logger["iter"][::_k], loss_logger["loss_ics"][::_k], label=r"$\mathcal{L}_{0}$", linewidth=3)
ax.set_yscale('log')
ax.set_xlabel("Iteration")
ax.set_ylabel("Loss")
ax.grid()

ax.legend(loc='upper right')

plt.tight_layout()
plt.savefig('Loss.png', dpi=100, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### 验证的loss图 (包括只经backbone和经过transformer和backbone的loss)

# %%
loss_logger_valid = np.load("./loss_logger_valid_dict.npy", allow_pickle=True).item()

fig = plt.figure(figsize=(9, 7), dpi=64)
ax = fig.subplots()

_k = 1
# ax.plot(loss_logger_valid["iter"][::k], loss_logger_valid["loss"][::k], label=r"$\mathcal{L}$", linewidth=3)
ax.plot(loss_logger_valid["iter"][::_k], loss_logger_valid["loss_res"][::_k], label=r"$\mathcal{L}_{r}$", linewidth=3)
ax.plot(loss_logger_valid["iter"][::_k], loss_logger_valid["loss_bcs"][::_k], label=r"$\mathcal{L}_{b}$", linewidth=3)
ax.plot(loss_logger_valid["iter"][::_k], loss_logger_valid["loss_ics"][::_k], label=r"$\mathcal{L}_{0}$", linewidth=3)
ax.set_yscale('log')
ax.set_xlabel("Iteration")
ax.set_ylabel("Loss")
ax.grid()

ax.legend(loc='upper right')

plt.tight_layout()
# plt.savefig('loss_valid.png', dpi=100, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### 验证的Relative L2 error图 (包括只经backbone和经过transformer和backbone的rl2)

# %%
# valid中记录的relative l2 error记录 第一行只经过backbone 第二行经过transformer和backbone
loss_logger_valid = np.load("./loss_logger_valid_dict.npy", allow_pickle=True).item()

fig = plt.figure(figsize=(9, 7), dpi=64)
ax = fig.subplots()

_k = 1
ax.plot(loss_logger_valid["iter"][::_k], loss_logger_valid["error"][::_k], label=r"PINN", color='k', linewidth=3)
ax.set_yscale('log')
ax.set_xlabel("Iteration")
ax.set_ylabel("Relative error")
ax.grid()

plt.tight_layout()
plt.savefig('Relative_L2_error.png', dpi=100, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Relative L2 error (仅考虑内部点）

# %%
# 使用最好的模型
backbone = ResNet(args.backbone_layers)
state_dict = torch.load(f'{trainer.model_path}/best_model.pth')
backbone.load_state_dict(state_dict['state_dict'])
backbone.eval()
print("Iter:\t", state_dict['iter'] + 1)
print("Loss:\t", "{:.2e}".format(state_dict['best_loss']))
# Out:
# Iter:	 19900
# Loss:	 3.95e+00

# %%
def exact_sol(xt):
    # 解析解
    return u(x=xt[:, :-1], t=xt[:, [-1]])

# 采样内部点
dataset = Dataset_AllenCahnHD(args.bot_top, args.T, args.dim, torch.device('cpu'))
X_res, _, _, _, _, _ = dataset.train_data(N_r=10000, N_b=0, N_0=0)
# 计算u_star u_pred
u_star = exact_sol(X_res)
u_pred = backbone(X_res)

u_star = u_star.detach().numpy()
u_pred = u_pred.detach().numpy()
#计算L2相对误差
error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)
with open("RL2.txt", 'w') as f_:
    f_.write(str(error_u))
print('Relative L2 error: {:.3e}'.format(error_u))
# Out:
# Relative L2 error: 8.626e-02

# %% [markdown]
# ### 可视化内部(x1, x2, 0, ..., 0)

# %%
n = 101
dim = args.dim
# 取前两维
x1 = np.linspace(-1, 1, n)
x2 = np.linspace(-1, 1, n)
x1, x2 = np.meshgrid(x1, x2)
# x3, ..., x50 = 0
x12 = np.zeros((n*n, dim))
x12[:, [0]] = x1.reshape(-1, 1)
x12[:, [1]] = x2.reshape(-1, 1)
t = np.ones((x12.shape[0], 1)) * args.T
x12 = np.concatenate([x12, t], axis=1)
x12 = torch.from_numpy(x12).float()
# 解析解和预测解
u12_star = exact_sol(x12)
u12_pred = backbone(x12)

u12_star = u12_star.detach().numpy()
u12_pred = u12_pred.detach().numpy()

u12_star = u12_star.reshape(x1.shape)
u12_pred = u12_pred.reshape(x1.shape)

for i in range(u12_star.shape[0]):
    for j in range(u12_star.shape[1]):
        if x1[i, j]**2 + x2[i, j]**2 > 1.:
            u12_star[i, j] = np.nan
            u12_pred[i, j] = np.nan

# %%
fig = plt.figure(figsize=(20, 5))
axes = fig.subplots(1, 3)

cax1 = axes[0].pcolor(x1, x2, u12_star, cmap='jet')
fig.colorbar(cax1)
axes[0].set_xlabel('$x_1$')
axes[0].set_ylabel('$x_2$')
axes[0].set_title(r'Reference $u$')
axes[0].set_xlim([-1, 1])
axes[0].set_ylim([-1, 1])
axes[0].set_xticks(np.arange(-1, 1.1, 0.5))
axes[0].set_yticks(np.arange(-1, 1.1, 0.5))
axes[0].set_aspect(1./axes[0].get_data_ratio())

cax2 = axes[1].pcolor(x1, x2, u12_pred, cmap='jet')
fig.colorbar(cax2)
axes[1].set_xlabel('$x_1$')
axes[1].set_ylabel('$x_2$')
axes[1].set_title(r'Predicted $u$')
axes[1].set_xlim([-1, 1])
axes[1].set_ylim([-1, 1])
axes[1].set_xticks(np.arange(-1, 1.1, 0.5))
axes[1].set_yticks(np.arange(-1, 1.1, 0.5))
axes[1].set_aspect(1./axes[1].get_data_ratio())

cax3 = axes[2].pcolor(x1, x2, np.abs(u12_star - u12_pred), cmap='jet')
fig.colorbar(cax3)
axes[2].set_xlabel('$x_1$')
axes[2].set_ylabel('$x_2$')
axes[2].set_title('Absolute error')
axes[2].set_xlim([-1, 1])
axes[2].set_ylim([-1, 1])
axes[2].set_xticks(np.arange(-1, 1.1, 0.5))
axes[2].set_yticks(np.arange(-1, 1.1, 0.5))
axes[2].set_aspect(1./axes[2].get_data_ratio())

plt.tight_layout()
plt.savefig(f'Allen_Cahn_{args.dim}d_result.png', dpi=100, bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6.5, 5), dpi=100)
plot = ax.contourf(x1, x2, np.abs(u12_star - u12_pred), levels=16, cmap='jet')

cbar = fig.colorbar(plot)
cbar.formatter.set_powerlimits((0, 0))
cbar.update_ticks()

ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')
ax.set_xticks([-1, -0.5, 0, 0.5, 1])
ax.set_yticks([-1, -0.5, 0, 0.5, 1])
ax.set_title('Absolute error')
ax.set_aspect(1./ax.get_data_ratio())

plt.tight_layout()
plt.savefig('./Absolute_error', dpi=100)
plt.show()

# %% [markdown]
# ## Transformer变换可视化

# %%
# # loss_res
# trainer.device = torch.device('cpu')
# trainer.backbone = trainer.backbone.cpu()

# f_res = trainer.dataset.func_res(x12)
# f_res_pred = trainer.net_r(x12)
# loss_res = (f_res - f_res_pred) ** 2

# %%
# fig = plt.figure(figsize=(6.5, 5))
# ax = fig.subplots()

# cax = ax.scatter(x12.detach().numpy()[:, 0], x12.detach().numpy()[:, 1], 
#                  c=loss_res.detach().cpu().numpy(), 
# #                  vmin=0, vmax=5e-5,
#                  cmap="jet", s=80)
# fig.colorbar(cax)
# ax.set_xlabel('$x_1$')
# ax.set_ylabel('$x_2$')
# ax.set_title(r'Residual')
# ax.set_xlim([-1, 1])
# ax.set_ylim([-1, 1])
# ax.set_xticks(np.arange(-1, 1.1, 0.5))
# ax.set_yticks(np.arange(-1, 1.1, 0.5))
# ax.set_aspect(1./axes[0].get_data_ratio())

# plt.tight_layout()
# plt.show()

# %%
# # 重新取点
# n = 21
# dim = args.dim
# # 取前两维
# xx1 = np.linspace(-1, 1, n)
# xx2 = np.linspace(-1, 1, n)
# xx1, xx2 = np.meshgrid(xx1, xx2)
# # x3, ..., x50 = 0
# xx12 = np.zeros((n*n, dim))
# xx12[:, [0]] = xx1.reshape(-1, 1)
# xx12[:, [1]] = xx2.reshape(-1, 1)
# t = np.ones((xx12.shape[0], 1)) * args.T
# xx12 = np.concatenate([xx12, t], axis=1)
# xx12 = torch.from_numpy(xx12).float()

# %%
# # 变换后的点
# # model = MLP(args.subnet_layers)  # 保存的loss最低时的transformer
# # transformer = TransformerNet(model, args.bot_top)

# # state_dict = torch.load(f'{trainer.model_path}/best_model.pth')
# # transformer.load_state_dict(state_dict['state_dict_transformer'])
# # transformer.eval()

# # xx12_ = transformer(xx12)

# trainer.transformer = trainer.transformer.cpu()  # 训练最后的transformer
# f_xx12 = dataset.func_res(xx12)
# k = trainer.update_k(xx12, f_xx12)
# xx12_ = trainer.net_transformer(xx12, k)

# %%
# plt.hist(k.detach().cpu().numpy().flatten())

# %%
# fig = plt.figure(figsize=(12, 5))
# axes = fig.subplots(1, 2)

# axes[0].scatter(xx12.detach().numpy()[:, 0], xx12.detach().numpy()[:, 1], s=30, color='b')
# axes[0].set_xlabel('$x_1$')
# axes[0].set_ylabel('$x_2$')
# axes[0].set_title(r'Original distribution')
# axes[0].set_xlim([-1, 1])
# axes[0].set_ylim([-1, 1])
# axes[0].set_xticks(np.arange(-1, 1.1, 0.5))
# axes[0].set_yticks(np.arange(-1, 1.1, 0.5))
# axes[0].set_aspect(1./axes[0].get_data_ratio())

# axes[1].scatter(xx12_.detach().numpy()[:, 0], xx12_.detach().numpy()[:, 1], s=30, color='r')
# axes[1].set_xlabel('$x_1$')
# axes[1].set_ylabel('$x_2$')
# axes[1].set_title('Transformed distribution')
# axes[1].set_xlim([-1, 1])
# axes[1].set_ylim([-1, 1])
# axes[1].set_xticks(np.arange(-1, 1.1, 0.5))
# axes[1].set_yticks(np.arange(-1, 1.1, 0.5))
# axes[1].set_aspect(1./axes[1].get_data_ratio())

# plt.tight_layout()
# plt.show()
