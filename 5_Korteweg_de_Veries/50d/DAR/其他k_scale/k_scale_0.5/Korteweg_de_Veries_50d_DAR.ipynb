# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# /tmp/ipykernel_892183/3777615979.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:100% !important; }</style>

# %%
import os
import shutil

import numpy as np
import time
from pyDOE import lhs
import matplotlib
import matplotlib.pyplot as plt
import scipy.io
import random

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import ExponentialLR

# %%
import argparse
class Options_KortewegdeVeriesHD:
    def __init__(self):
        parser = argparse.ArgumentParser()
        parser.add_argument('--cuda', default=True, help='if you use cuda')
        
        parser.add_argument('--bot_top', type=tuple, default=(-1, 1), help='a tuple of the form (bot, top)')
        parser.add_argument('--T', type=float, default=1., help='a float T of time domain [0, T]')
        parser.add_argument('--dim', default=50, help='dimension')
        parser.add_argument('--N_r', default=2400, help='num of interior points')
        parser.add_argument('--N_b', default=1200, help='num of boundary points')
        parser.add_argument('--N_0', default=1200, help='num of initial points')
        
        parser.add_argument('--backbone_layers', type=list, default=([80]*3), help='list of nn layers of backbone')
        parser.add_argument('--subnet_layers', type=list, default=([200]*1), help='list of nn layers of subnet')
        
        parser.add_argument('--backbone_lr', type=float, default=5e-3, help='initial learning rate of backbone')
        parser.add_argument('--subnet_lr', type=float, default=5e-3, help='initial learning rate of subnet')
        
        parser.add_argument('--backbone_gamma', type=float, default=0.85, help='gamma in lr_scheduler for backbone optimizer')
        parser.add_argument('--subnet_gamma', type=float, default=0.95, help='gamma in lr_scheduler for subnet optimizer')
        parser.add_argument('--step_size', type=int, default=1200, help='step_size of lr_scheduler for Adam optimizer')
        
        parser.add_argument('--iters_stage1', type=int, default=0, help='iters for stage 1 used Adam')
        parser.add_argument('--iters_stage2', type=int, default=0, help='iters for stage 2 used Adam')
        parser.add_argument('--iters_stage3', type=int, default=24000, help='iters for stage 3 used Adam')
        parser.add_argument('--iters_stage4', type=int, default=0, help='iters for stage 4 used Adam')
        
        parser.add_argument('--lam_res', type=float, default=1, help='weight of loss_res')
        parser.add_argument('--lam_bcs', type=float, default=1, help='weight of loss_bcs')
        parser.add_argument('--lam_ics', type=float, default=1, help='weight of loss_ics')
        parser.add_argument('--K1', type=int, default=500, help='for stage3, optimize the backbone K1 times every (K1+K2) iters')
        parser.add_argument('--K2', type=int, default=100, help='for stage3, optimize the transformer K2 times every (K1+K2) iters')
        parser.add_argument('--k_scale', type=float, default=0.5, help='the scale of transformer limited residue')
        
        self.parser = parser

    def parse_default(self):
        args = self.parser.parse_args(args=[])
        args.device = torch.device('cuda' if args.cuda else 'cpu')
        
        # 增加网络输入输出层
        args.backbone_layers = [args.dim + 1] + args.backbone_layers + [1]
        args.subnet_layers = [args.dim + 1] + args.subnet_layers + [args.dim + 1]
        return args
    

args = Options_KortewegdeVeriesHD().parse_default()
print(args.cuda)
# Out:
# True

# %%
def save_model(state, is_best=None, save_dir=None):
    last_model = os.path.join(save_dir, 'last_model.pth')
    torch.save(state, last_model)
    if is_best:
        best_model = os.path.join(save_dir, 'best_model.pth')
        shutil.copyfile(last_model, best_model)

def seed_torch(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed) # 为了禁止hash随机化，使得实验可复现
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed) # if you are using multi-GPU.
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True
    random.seed(seed)

def grad(outputs, inputs):
    """ compute the derivative of outputs associated with inputs

    Params
    ======
    outputs: (N, 1) tensor
    inputs: (N, D) tensor
    """
    return torch.autograd.grad(outputs, inputs,
                               grad_outputs=torch.ones_like(outputs),
                               create_graph=True)

# %%
seed_torch(42)

# %% [markdown]
# ## 网络模型 (Modified ResNet / ResNet / Modified MLP / MLP)

# %%
class ModifiedResNet(nn.Module):
    def __init__(self, mlp_layers):
        super(ModifiedResNet, self).__init__()
        
        self.encoder_u = nn.Sequential()
        self.encoder_u.add_module('fc_u', nn.Linear(mlp_layers[0], mlp_layers[1], bias=True))
        self.encoder_u.add_module('act_u', nn.Tanh())
        
        self.encoder_v = nn.Sequential()
        self.encoder_v.add_module('fc_v', nn.Linear(mlp_layers[0], mlp_layers[1], bias=True))
        self.encoder_v.add_module('act_v', nn.Tanh())
        
        self.model = nn.Sequential()
        
        first_layer = nn.Sequential()
        first_layer.add_module(f'fc0', nn.Linear(mlp_layers[0], mlp_layers[1], bias=True))
        first_layer.add_module(f'act0', nn.Tanh())
        self.model.add_module(f'first', first_layer)
        
        for i in range(1, len(mlp_layers)-2):
            block = nn.Sequential()
            block.add_module(f'fc{i}_0', nn.Linear(mlp_layers[i], mlp_layers[i+1], bias=True))
            block.add_module(f'act{i}_0', nn.Tanh())
            block.add_module(f'fc{i}_1', nn.Linear(mlp_layers[i], mlp_layers[i+1], bias=True))
            block.add_module(f'act{i}_1', nn.Tanh())
            self.model.add_module(f'block{i}', block)

        last_layer = nn.Sequential()
        last_layer.add_module(f'fc{len(mlp_layers)-2}', nn.Linear(mlp_layers[-2], mlp_layers[-1], bias=False))
        self.model.add_module(f'last', last_layer)
        
#         for param in self.parameters():
#             if len(param.shape) > 1:
#                 nn.init.kaiming_normal_(param)
    
    def forward(self, X):
        u = self.encoder_u(X)
        v = self.encoder_v(X)
        
        X = self.model[0](X)
        for i_block in range(1, len(self.model) - 1):
            X_ = self.model[i_block](X)
            X = X + X_
            X = X / 2.
            X = (1 - X) * u + X * v
        return self.model[-1](X)

# %%
class ResNet(nn.Module):
    def __init__(self, mlp_layers):
        super(ResNet, self).__init__()
        
        self.model = nn.Sequential()
        
        first_layer = nn.Sequential()
        first_layer.add_module(f'fc0', nn.Linear(mlp_layers[0], mlp_layers[1], bias=True))
        first_layer.add_module(f'act0', nn.Tanh())
        self.model.add_module(f'first', first_layer)
        
        for i in range(1, len(mlp_layers)-2):
            block = nn.Sequential()
            block.add_module(f'fc{i}_0', nn.Linear(mlp_layers[i], mlp_layers[i+1], bias=True))
            block.add_module(f'act{i}_0', nn.Tanh())
            block.add_module(f'fc{i}_1', nn.Linear(mlp_layers[i], mlp_layers[i+1], bias=True))
            block.add_module(f'act{i}_1', nn.Tanh())
            self.model.add_module(f'block{i}', block)

        last_layer = nn.Sequential()
        last_layer.add_module(f'fc{len(mlp_layers)-2}', nn.Linear(mlp_layers[-2], mlp_layers[-1], bias=False))
        self.model.add_module(f'last', last_layer)
        
#         for param in self.parameters():
#             if len(param.shape) > 1:
#                 nn.init.kaiming_normal_(param)
    
    def forward(self, X):
        X = self.model[0](X)
        for i_block in range(1, len(self.model) - 1):
            X_ = self.model[i_block](X)
            X = X_ + X
        return self.model[-1](X)

# %%
class ModifiedMLP(nn.Module):
    def __init__(self, mlp_layers):
        super(ModifiedMLP, self).__init__()
        
        self.encoder_u = nn.Sequential()
        self.encoder_u.add_module('fc_u', nn.Linear(mlp_layers[0], mlp_layers[1], bias=True))
        self.encoder_u.add_module('act_u', nn.Tanh())
        
        self.encoder_v = nn.Sequential()
        self.encoder_v.add_module('fc_v', nn.Linear(mlp_layers[0], mlp_layers[1], bias=True))
        self.encoder_v.add_module('act_v', nn.Tanh())
        
        self.model = nn.Sequential()
        for i in range(len(mlp_layers)-2):
            layer = nn.Sequential()
            layer.add_module(f'fc{i}', nn.Linear(mlp_layers[i], mlp_layers[i+1], bias=True))
            layer.add_module(f'act{i}', nn.Tanh())
            self.model.add_module(f'layer{i}', layer)

        last_layer = nn.Sequential()
        last_layer.add_module(f'fc{len(mlp_layers)-2}', nn.Linear(mlp_layers[-2], mlp_layers[-1], bias=False))
        self.model.add_module(f'layer{len(mlp_layers)-2}', last_layer)
        
#         for param in self.parameters():
#             if len(param.shape) > 1:
#                 nn.init.kaiming_normal_(param)
    
    def forward(self, X):
        u = self.encoder_u(X)
        v = self.encoder_v(X)
        
        for i in range(len(self.model) - 1):
            X = self.model[i](X)
            X = X / 2.
            X = (1 - X) * u + X * v
        return self.model[-1](X)

# %%
class MLP(nn.Module):
    def __init__(self, mlp_layers):
        super(MLP, self).__init__()
        
        self.model = nn.Sequential()
        for i in range(len(mlp_layers)-2):
            layer = nn.Sequential()
            layer.add_module(f'fc{i}', nn.Linear(mlp_layers[i], mlp_layers[i+1], bias=True))
            layer.add_module(f'act{i}', nn.Tanh())
            self.model.add_module(f'layer{i}', layer)

        last_layer = nn.Sequential()
        last_layer.add_module(f'fc{len(mlp_layers)-2}', nn.Linear(mlp_layers[-2], mlp_layers[-1], bias=False))
        self.model.add_module(f'layer{len(mlp_layers)-2}', last_layer)
        
#         for param in self.parameters():
#             if len(param.shape) > 1:
#                 nn.init.kaiming_normal_(param)
    
    def forward(self, X):
        return self.model(X)

# %%
backbone = ResNet(args.backbone_layers)
backbone = backbone.to(args.device)
args.backbone = backbone
print(args.backbone)
# Out:
# ResNet(
#   (model): Sequential(
#     (first): Sequential(
#       (fc0): Linear(in_features=51, out_features=80, bias=True)
#       (act0): Tanh()
#     )
#     (block1): Sequential(
#       (fc1_0): Linear(in_features=80, out_features=80, bias=True)
#       (act1_0): Tanh()
#       (fc1_1): Linear(in_features=80, out_features=80, bias=True)
#       (act1_1): Tanh()
#     )
#     (block2): Sequential(
#       (fc2_0): Linear(in_features=80, out_features=80, bias=True)
#       (act2_0): Tanh()
#       (fc2_1): Linear(in_features=80, out_features=80, bias=True)
#       (act2_1): Tanh()
#     )
#     (last): Sequential(
#       (fc3): Linear(in_features=80, out_features=1, bias=False)
#     )
#   )
# )

# %% [markdown]
# ## 对抗TransformerNet

# %%
class TransformerNet(nn.Module):
    def __init__(self, model, bot_top, T, dim):
        super(TransformerNet, self).__init__()
        self.model = model
        bot, top = bot_top
        
        x_len = torch.ones(dim) * (top - bot)
        t_len = torch.ones(1) * T
        self.len = torch.cat([x_len, t_len], dim=0)
        
        x_mid = torch.ones(dim) * (bot + top) / 2
        t_mid = torch.ones(1) * T / 2
        self.mid = torch.cat([x_mid, t_mid], dim=0)
        
    def input_transform(self, X):
        """输入变换 压缩到[-1,1]再传入arcsin"""
        return torch.arcsin((X - self.mid) / self.len * 2.) / torch.pi
    
    def output_transform(self, X):
        # to PDE's domain 非线性放缩
        return torch.sin(torch.pi * X) / 2. * self.len + self.mid
    
    def forward(self, X, residual_limit):
        X = self.input_transform(X)
        X_ = self.model(X)
        
        X_ = torch.tanh(X_) * residual_limit  # 限制变换残差的界
        
        X = self.output_transform(X + X_)
        return X
    

model = MLP(args.subnet_layers)
transformer = TransformerNet(model, args.bot_top, args.T, args.dim)
transformer = transformer.to(args.device)
args.transformer = transformer
args.transformer.len = args.transformer.len.to(args.device)
args.transformer.mid = args.transformer.mid.to(args.device)
print(args.transformer)
# Out:
# TransformerNet(
#   (model): MLP(
#     (model): Sequential(
#       (layer0): Sequential(
#         (fc0): Linear(in_features=51, out_features=200, bias=True)
#         (act0): Tanh()
#       )
#       (layer1): Sequential(
#         (fc1): Linear(in_features=200, out_features=51, bias=False)
#       )
#     )
#   )
# )

# %% [markdown]
# ## 数据集生成

# %%
class Dataset_KortewegdeVeriesHD:
    def __init__(self, bot_top, T, dim, device, N_max=100000):
        self.bot, self.top = bot_top
        self.T = T
        self.dim = dim
        self.device = device
        self.N_max = N_max
    
    def train_data(self, N_r, N_b, N_0):
        """训练点采样"""
        X_res = self.interior(N_r).to(self.device)
        X_bcs = self.boundary(N_b).to(self.device)
        X_ics = self.initial(N_0).to(self.device)
        f_res = self.func_res(X_res).to(self.device)
        u_bcs = self.func_bcs(X_bcs).to(self.device)
        u_ics = self.func_ics(X_ics).to(self.device)
        
        return X_res, X_bcs, X_ics, f_res, u_bcs, u_ics
    
    def interior(self, N_r):
        """内部点采样"""
        X_res = torch.Tensor(self.N_max, self.dim).uniform_(self.bot, self.top)
        idx = torch.randperm(self.N_max)
        idx = idx[:N_r]
        
        T = torch.Tensor(self.N_max, 1).uniform_(0, self.T)
        X_res = torch.cat([X_res[idx], T[idx]], dim=1)  # 拼接X和T
        return X_res
    
    def boundary(self, N_b):
        """边界点采样"""
        X_bcs = torch.Tensor(self.N_max, self.dim).uniform_(self.bot, self.top)
        bots = self.bot * torch.ones(1, 1)
        tops = self.top * torch.ones(1, 1)
        
        n = int(self.N_max / self.dim / 2)
        num = [n * i for i in range(2 * self.dim)]
        num[0] = 0
        num.append(self.N_max)
        
        for i in range(self.dim):  # 逐个维度设为下界bot 以及上界top 得到边界点
            X_bcs[num[2 * i]:num[2 * i + 1], i] = bots.repeat(num[2 * i + 1] - num[2 * i], 1).squeeze()
            X_bcs[num[2 * i + 1]:num[2 * i + 2], i] = tops.repeat(num[2 * i + 2] - num[2 * i + 1], 1).squeeze()

        idx = torch.randperm(self.N_max)
        idx = idx[:N_b]
        
        T = torch.Tensor(self.N_max, 1).uniform_(0, self.T)
        X_bcs = torch.cat([X_bcs[idx], T[idx]], dim=1)  # 拼接X和T
        return X_bcs
    
    def initial(self, N_0):
        """初始点采样"""
        X_ics = torch.Tensor(self.N_max, self.dim).uniform_(self.bot, self.top)
        idx = torch.randperm(self.N_max)
        idx = idx[:N_0]
        
        T = torch.Tensor(self.N_max, 1).fill_(0.)
        X_ics = torch.cat([X_ics[idx], T[idx]], dim=1)
        return X_ics
    
    def func_res(self, X_res):
        """控制方程右端项"""
        f = X_res[:, :self.dim].mean(axis=1, keepdims=True)
        f = (- 1 / self.dim**2) * (torch.sin(f) + torch.cos(f)) * torch.exp(- X_res[:, [-1]] / self.dim**2)
        return f
    
    def func_bcs(self, X_bcs):
        """边界条件右端项"""
        u_bcs = X_bcs[:, :self.dim].mean(axis=1, keepdims=True)
        u_bcs = torch.sin(u_bcs) * torch.exp(- X_bcs[:, [-1]] / self.dim**2)
        return u_bcs
    
    def func_ics(self, X_ics):
        """初始条件右端项"""
        u_ics = X_ics[:, :self.dim].mean(axis=1, keepdims=True)
        u_ics = torch.sin(u_ics)
        return u_ics


dataset = Dataset_KortewegdeVeriesHD(args.bot_top, args.T, args.dim, args.device)
args.dataset = dataset
X_res, X_bcs, X_ics, f_res, u_bcs, u_ics = dataset.train_data(args.N_r, args.N_b, args.N_0)
print(X_res.shape, X_bcs.shape, X_ics.shape, f_res.shape, u_bcs.shape, u_ics.shape)
# Out:
# torch.Size([2400, 51]) torch.Size([1200, 51]) torch.Size([1200, 51]) torch.Size([2400, 1]) torch.Size([1200, 1]) torch.Size([1200, 1])

# %% [markdown]
# ## 训练

# %%
class Trainer_KortewegdeVeriesHD:
    def __init__(self, args):
        self.args = args
        self.dim = args.dim
        self.device = args.device
        
        self.N_r = args.N_r
        self.N_b = args.N_b
        self.N_0 = args.N_0
        self.dataset = args.dataset
        
        self.lam_res = args.lam_res
        self.lam_bcs = args.lam_bcs
        self.lam_ics = args.lam_ics
        self.backbone = args.backbone
        
        self.model_name = self.backbone.__class__.__name__
        self.model_path = self.get_model_path()
        
        self.iters_stage1 = args.iters_stage1
        self.iters_stage2 = args.iters_stage2
        self.iters_stage3 = args.iters_stage3
        self.iters_stage4 = args.iters_stage4
        
        self.K1 = args.K1
        self.K2 = args.K2

        # eps = np.finfo(np.float32).eps
        self.optimizer_Adam = optim.Adam(self.backbone.parameters(), lr=args.backbone_lr, betas=(0.9, 0.999))
        
        self.step_size = args.step_size#int( self.iters_stage4 / (np.log(1e-3) / np.log(self.gamma)) )
        self.scheduler = ExponentialLR(self.optimizer_Adam, gamma=args.backbone_gamma, verbose=True)
        
        # subnet (transformer net)
        self.transformer = args.transformer
        self.optimizer_Adam_transformer = optim.Adam(self.transformer.parameters(), lr=args.subnet_lr)    
        self.scheduler_transformer = ExponentialLR(self.optimizer_Adam_transformer, gamma=args.subnet_gamma, verbose=True)
        
        # data
        self.X_res, self.X_bcs, self.X_ics, self.f_res, self.u_bcs, self.u_ics = self.dataset.train_data(self.N_r, self.N_b, self.N_0)
        
        # Logger
        self.logger = {
            f"stage{i + 1}": {
                "loss": [],
                "loss_res": [],
                "loss_bcs": [],
                "loss_ics": [],
                "iter": [],
            }
            for i in range(4)
        }
        self.logger_valid = {
            f"stage{i + 1}": {
                "loss": [],
                "loss_res": [],
                "loss_bcs": [],
                "loss_ics": [],
                "iter": [],
                "error": [],  # relative l2 error
                
                "loss_transformer": [],
                "loss_res_transformer": [],
                "loss_bcs_transformer": [],
                "loss_ics_transformer": [],
                "error_transformer": [],  # 同一批点 经过transformer变换的rl2
                
                "distant": {"mean":[], "var":[], "min":[], "max":[]},
            }
            for i in range(4)
        }
        
        self.backbone_requires_grad = None  # 用以判断是否要更新该网络
        self.transformer_requires_grad = None
        
        self.k = None
        self.k_scale = args.k_scale
        
    def get_model_path(self):
        """生成保存模型的路径"""
        if not os.path.exists('models'):
            os.mkdir('models')
        
        path = os.path.join('models', self.model_name)
        if not os.path.exists(path):
            os.mkdir(path)
        
        return path
        
    def update_train_data(self, update_k=False):
        """更新采样点"""
        self.X_res, self.X_bcs, self.X_ics, self.f_res, self.u_bcs, self.u_ics = self.dataset.train_data(self.N_r, self.N_b, self.N_0)

        if update_k:
            self.k = self.update_k(self.X_res, self.f_res)
        
    def update_k(self, X_res, f_res):
        """将X_res输入net_r 确定这批X_res的限制残差的系数k"""
        self.backbone.train(False)
        
        f_res_pred = self.net_r(X_res)
        k = (f_res_pred - f_res) ** 2
        k = k / (k.max() - k.min())  # 归一
#         k = torch.log(k + 1.)  # 取对数
#         k = k / (k.max() - k.min())  # 再次归一
        self.backbone.train()
        return k.detach_() * self.k_scale
    
    def compute_distant_mean_var(self, X1, X2):
        d = ((X1 - X2) ** 2).sum(axis=1) ** 0.5
        return d.mean().item(), d.var().item(), d.min().item(), d.max().item()
            
    def set_backbone_requires_grad(self, bl):
        """设置backbone是否记录梯度"""
        self.backbone_requires_grad = bl
        for param in self.backbone.parameters():
            param.requires_grad = bl

    def set_transformer_requires_grad(self, bl):
        """设置transformer是否记录梯度"""
        self.transformer_requires_grad = bl
        for param in self.transformer.parameters():
            param.requires_grad = bl

    def net_u(self, X):
        return self.backbone(X)

    def net_r(self, xt):
        xt.requires_grad_(True)
        
        u = self.net_u(xt)
        grad_u = grad(u, xt)[0]
        
        u_t = grad_u[:, [-1]]
        u_xxx = torch.zeros(u.shape).to(self.device)
        for i in range(self.dim):
            u_x_i = grad_u[:, [i]]
            u_xx_i = grad(u_x_i, xt)[0][:, [i]]
            u_xxx_i = grad(u_xx_i, xt)[0][:, [i]]
            u_xxx += u_xxx_i
        return u_t + u_xxx
    
    def net_transformer(self, X, k):
        X.requires_grad_(False)
        return self.transformer(X, k)
    
    def compute_loss(self, use_transformer=False):
        """计算loss 可选择是否使用transformer"""
        if use_transformer:
            if self.transformer_requires_grad and not self.backbone_requires_grad:
                # 只更新transformer 训练点只考虑变换后的X_res_ 用loss_res
                
                self.X_res_ = self.X_res.clone().detach()
                self.X_res_ = self.net_transformer(self.X_res_, self.k)
                # clone会新开辟一片内存 detach会从计算图剥离
                # 用X_res_.clone().detach()计算f_res
                # 可以避免X_res计算图混乱
                # 从而保证transformer的网络正常地梯度传播
                self.f_res_ = self.dataset.func_res(self.X_res_.clone().detach())  # 细节

                f_res_pred_ = self.net_r(self.X_res_)
                
                self.loss_res = torch.mean((f_res_pred_ - self.f_res_) ** 2)
                self.loss = self.lam_res * self.loss_res
                
            elif self.backbone_requires_grad and not self.transformer_requires_grad:
                # 只更新backbone 训练点考虑变换前后的X_res X_res_ X_bcs X_ics 用loss_res和loss_bcs loss_ics
                
                self.X_res_ = self.X_res.clone().detach()
                self.X_res_ = self.net_transformer(self.X_res_, self.k)
                self.f_res_ = self.dataset.func_res(self.X_res_.clone().detach())  # 细节
                
                f_res_pred_ = self.net_r(self.X_res_)
                
                self.loss_res = torch.mean((f_res_pred_ - self.f_res_) ** 2)

                u_bcs_pred = self.net_u(self.X_bcs)
                self.loss_bcs = torch.mean((u_bcs_pred - self.u_bcs) ** 2)
                
                u_ics_pred = self.net_u(self.X_ics)
                self.loss_ics = torch.mean((u_ics_pred - self.u_ics) ** 2)

                self.loss = self.lam_res * self.loss_res + self.lam_bcs * self.loss_bcs + self.lam_ics * self.loss_ics
            else:
                raise "error at compute_loss"
        else:
            f_res_pred = self.net_r(self.X_res)
            self.loss_res = torch.mean((f_res_pred - self.f_res) ** 2)

            u_bcs_pred = self.net_u(self.X_bcs)
            self.loss_bcs = torch.mean((u_bcs_pred - self.u_bcs) ** 2)
            
            u_ics_pred = self.net_u(self.X_ics)
            self.loss_ics = torch.mean((u_ics_pred - self.u_ics) ** 2)

            self.loss = self.lam_res * self.loss_res + self.lam_bcs * self.loss_bcs + self.lam_ics * self.loss_ics

    def log_loss(self):
        """记录当前loss至logger字典"""
        self.logger[f"stage{self.current_stage}"]["loss"].append(self.loss.item())
        self.logger[f"stage{self.current_stage}"]["loss_res"].append(self.loss_res.item())
        self.logger[f"stage{self.current_stage}"]["loss_bcs"].append(self.loss_bcs.item())
        self.logger[f"stage{self.current_stage}"]["loss_ics"].append(self.loss_ics.item())
        self.logger[f"stage{self.current_stage}"]["iter"].append(self.iter + 1)

    def log_info(self):
        """保存并打印训练信息"""
        info = f'Stage {self.current_stage} Iter {self.iter+1:5d} Time:{time.time()-self.start_time:.1e} # ' + \
               f'Loss:{self.loss.item():.2e}, Loss_r:{self.loss_res.item():.2e}, Loss_b:{self.loss_bcs.item():.2e}, Loss_0:{self.loss_ics.item():.2e} # ' + \
               f'Valid:{self.valid_loss_value:.2e}, RL2:{self.error_u:.2e}'
        with open("train_info.txt", 'a') as f:
            f.write(info + '\n')
        print(info)
        
    def compute_rl2(self, X_res):
        """计算relative L2 error"""
        u_star = X_res[:, :self.dim].mean(axis=1, keepdims=True)  # 计算解析解
        u_star = torch.sin(u_star) * torch.exp(- X_res[:, [-1]] / self.dim**2)
        u_star = u_star.detach().cpu().numpy()
        
        u_pred = self.net_u(X_res)  # 计算预测解
        u_pred = u_pred.detach().cpu().numpy()
        
        error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)  # rl2 error
        return error_u

    def valid(self):
        """验证并保存最优模型"""
        # 计算loss
        X_res, X_bcs, X_ics, f_res, u_bcs, u_ics = self.dataset.train_data(1000, 1000, 1000)
        k = self.update_k(X_res, f_res)
        
        self.backbone.eval()
        self.transformer.eval()
        # 不经过transformer的loss
        f_res_pred = self.net_r(X_res)
        u_bcs_pred = self.net_u(X_bcs)
        u_ics_pred = self.net_u(X_ics)
        loss_res = torch.mean((f_res_pred - f_res) ** 2)
        loss_bcs = torch.mean((u_bcs_pred - u_bcs) ** 2)
        loss_ics = torch.mean((u_ics_pred - u_ics) ** 2)
        loss = self.lam_res * loss_res + self.lam_bcs * loss_bcs + self.lam_ics * loss_ics
        
        # 经过transformer后的内部点的loss
        X_res_ = self.net_transformer(X_res, k)
        f_res_ = self.dataset.func_res(X_res_.clone().detach())  # 计算相应X_res_的新的f_res_
        f_res_pred_transformer = self.net_r(X_res_)
        u_bcs_pred_transformer = self.net_u(X_bcs)  # 边界点也计算 对比经过和不经过transformer的两次loss 确保两次loss是基于同一批训练点
        u_ics_pred_transformer = self.net_u(X_ics)
        loss_res_transformer = torch.mean((f_res_pred_transformer - f_res_) ** 2)
        loss_bcs_transformer = torch.mean((u_bcs_pred_transformer - u_bcs) ** 2)
        loss_ics_transformer = torch.mean((u_ics_pred_transformer - u_ics) ** 2)
        loss_transformer = self.lam_res * loss_res_transformer + self.lam_bcs * loss_bcs_transformer + self.lam_ics * loss_ics_transformer
        
        # 计算relative l2 error
        self.error_u = self.compute_rl2(X_res)
        self.error_u_transformer = self.compute_rl2(X_res_)  # 经过transformer变换的内部点 看看其rl2是否会更大 即更难学
        
        # 计算经过transformer后的变化距离信息
        d_mean, d_var, d_min, d_max = self.compute_distant_mean_var(X_res, X_res_)
        
        self.backbone.train()
        self.transformer.train()
        
        # 记录valid的loss和rl2 error信息
        self.logger_valid[f"stage{self.current_stage}"]["loss"].append(loss.item())
        self.logger_valid[f"stage{self.current_stage}"]["loss_res"].append(loss_res.item())
        self.logger_valid[f"stage{self.current_stage}"]["loss_bcs"].append(loss_bcs.item())
        self.logger_valid[f"stage{self.current_stage}"]["loss_ics"].append(loss_ics.item())
        self.logger_valid[f"stage{self.current_stage}"]["iter"].append(self.iter + 1)
        self.logger_valid[f"stage{self.current_stage}"]["error"].append(self.error_u)
        
        self.logger_valid[f"stage{self.current_stage}"]["loss_transformer"].append(loss_transformer.item())
        self.logger_valid[f"stage{self.current_stage}"]["loss_res_transformer"].append(loss_res_transformer.item())
        self.logger_valid[f"stage{self.current_stage}"]["loss_bcs_transformer"].append(loss_bcs_transformer.item())
        self.logger_valid[f"stage{self.current_stage}"]["loss_ics_transformer"].append(loss_ics_transformer.item())
        self.logger_valid[f"stage{self.current_stage}"]["error_transformer"].append(self.error_u_transformer)
        
        self.logger_valid[f"stage{self.current_stage}"]["distant"]["mean"].append(d_mean)
        self.logger_valid[f"stage{self.current_stage}"]["distant"]["var"].append(d_var)
        self.logger_valid[f"stage{self.current_stage}"]["distant"]["min"].append(d_min)
        self.logger_valid[f"stage{self.current_stage}"]["distant"]["max"].append(d_max)
        
        # 验证模型loss是否最优并选择保存
        self.valid_loss_value = loss.item()
        is_best = self.valid_loss_value < self.best_loss
        if is_best:
            self.best_loss = self.valid_loss_value
        state = {
            'stage': self.current_stage,
            'iter': self.iter,
            'state_dict': self.backbone.state_dict(),
            'state_dict_transformer': self.transformer.state_dict(),
            'best_loss': self.best_loss
        }
        save_model(state, is_best, save_dir=self.model_path)
    
    def train(self):
        """DAR 4个Stage 训练"""
        self.start_time = time.time()
        self.best_loss = 1.e10
        
        # stage1 只训练backbone
        self.iter = 0
        self.current_stage = 1  # 设置当前stage
        self.set_backbone_requires_grad(True)  # 记录backbone的梯度
        self.set_transformer_requires_grad(False)  # 不记录transformer的梯度
        for _ in range(self.iters_stage1):
            self.optimizer_Adam.zero_grad()
            self.compute_loss(use_transformer=False)
            self.loss.backward()
            self.optimizer_Adam.step()
            self.log_loss()        
            
            if (self.iter + 1) % 100 == 0:
                self.valid()
                self.log_info()
                self.update_train_data()
            if (self.iter + 1) % self.step_size == 0:
                self.scheduler.step()
            self.iter += 1
            
            
        self.k = self.update_k(self.X_res, self.f_res)
            
                
        # stage2 只训练transformer
        self.iter = 0
        self.current_stage = 2
        self.set_backbone_requires_grad(False)
        self.set_transformer_requires_grad(True)
        for _ in range(self.iters_stage2):       
            self.optimizer_Adam_transformer.zero_grad()
            self.compute_loss(use_transformer=True)
            self.loss.backward()

            for param in self.transformer.parameters():
                if param.requires_grad == True:
                    param.grad *= -1
            self.optimizer_Adam_transformer.step()

            self.log_loss()
            
            if (self.iter + 1) % 10 == 0:
                self.valid()
                self.log_info()
                self.update_train_data(update_k=True)
            if (self.iter + 1) % self.step_size == 0:
                self.scheduler_transformer.step()
            self.iter += 1

        # stage3 同时训练backbone和transformer
        self.iter = 0
        self.current_stage = 3
        self.set_backbone_requires_grad(True)
        self.set_transformer_requires_grad(True)
        for _ in range(self.iters_stage3):
            self.optimizer_Adam.zero_grad()
            self.optimizer_Adam_transformer.zero_grad()
            
            # 优化K1次backbone 再优化K2次transformer 如此往复
            if (self.iter % (self.K1 + self.K2)) < self.K1:
                # 使用transformer优化backbone
                self.set_backbone_requires_grad(True)
                self.set_transformer_requires_grad(False)
                self.compute_loss(use_transformer=True)
                self.loss.backward()
                self.optimizer_Adam.step()
            else:
                # 优化transformer
                self.set_backbone_requires_grad(False)
                self.set_transformer_requires_grad(True)
                self.compute_loss(use_transformer=True)
                self.loss.backward()

                for param in self.transformer.parameters():
                    if param.requires_grad == True:
                        param.grad *= -1
                self.optimizer_Adam_transformer.step()
            
            self.log_loss()

            if (self.iter + 1) % 100 == 0:
                self.valid()
                self.log_info()
                self.update_train_data(update_k=True)
                
            if (self.iter + 1) % self.step_size == 0:
                self.scheduler.step()
                self.scheduler_transformer.step()
            self.iter += 1
            
        # stage4 只训练backbone
        self.iter = 0
        self.current_stage = 4
        self.set_backbone_requires_grad(True)
        self.set_transformer_requires_grad(False)
        for _ in range(self.iters_stage4):
            self.optimizer_Adam.zero_grad()
            self.compute_loss(use_transformer=False)
            self.loss.backward()
            self.optimizer_Adam.step()
            self.log_loss()

            if (self.iter + 1) % 100 == 0:
                self.valid()
                self.log_info()
                self.update_train_data()

            if (self.iter + 1) % self.step_size == 0:
                self.scheduler.step()
            self.iter += 1
            
            
trainer = Trainer_KortewegdeVeriesHD(args)
# Out:
# Adjusting learning rate of group 0 to 5.0000e-03.
# Adjusting learning rate of group 0 to 5.0000e-03.

# %%
trainer.train()
# Out:
# Stage 3 Iter   100 Time:1.7e+01 # Loss:4.42e-05, Loss_r:1.15e-05, Loss_b:1.91e-05, Loss_0:1.37e-05 # Valid:4.88e-05, RL2:5.39e-02
# Stage 3 Iter   200 Time:3.3e+01 # Loss:2.67e-05, Loss_r:6.40e-06, Loss_b:1.09e-05, Loss_0:9.41e-06 # Valid:3.09e-05, RL2:3.91e-02
# Stage 3 Iter   300 Time:4.9e+01 # Loss:2.02e-05, Loss_r:4.55e-06, Loss_b:8.46e-06, Loss_0:7.18e-06 # Valid:2.31e-05, RL2:3.71e-02
# Stage 3 Iter   400 Time:6.6e+01 # Loss:1.62e-05, Loss_r:3.52e-06, Loss_b:7.13e-06, Loss_0:5.55e-06 # Valid:1.85e-05, RL2:3.37e-02
# Stage 3 Iter   500 Time:8.2e+01 # Loss:1.30e-05, Loss_r:2.75e-06, Loss_b:5.32e-06, Loss_0:4.89e-06 # Valid:1.46e-05, RL2:3.07e-02
# Stage 3 Iter   600 Time:9.6e+01 # Loss:1.42e-05, Loss_r:1.42e-05, Loss_b:5.32e-06, Loss_0:4.89e-06 # Valid:1.47e-05, RL2:2.95e-02
# Stage 3 Iter   700 Time:1.1e+02 # Loss:1.19e-05, Loss_r:3.12e-06, Loss_b:4.44e-06, Loss_0:4.35e-06 # Valid:1.25e-05, RL2:2.73e-02
# Stage 3 Iter   800 Time:1.3e+02 # Loss:9.76e-06, Loss_r:1.97e-06, Loss_b:3.93e-06, Loss_0:3.85e-06 # Valid:9.94e-06, RL2:2.55e-02
# Stage 3 Iter   900 Time:1.5e+02 # Loss:7.36e-06, Loss_r:1.23e-06, Loss_b:3.12e-06, Loss_0:3.00e-06 # Valid:9.53e-06, RL2:2.43e-02
# Stage 3 Iter  1000 Time:1.6e+02 # Loss:6.22e-06, Loss_r:9.70e-07, Loss_b:2.71e-06, Loss_0:2.54e-06 # Valid:7.82e-06, RL2:2.13e-02
# Stage 3 Iter  1100 Time:1.8e+02 # Loss:5.51e-06, Loss_r:8.88e-07, Loss_b:2.42e-06, Loss_0:2.21e-06 # Valid:6.47e-06, RL2:1.96e-02
# Stage 3 Iter  1200 Time:1.9e+02 # Loss:1.40e-06, Loss_r:1.40e-06, Loss_b:2.42e-06, Loss_0:2.21e-06 # Valid:6.79e-06, RL2:1.99e-02
# Adjusting learning rate of group 0 to 4.2500e-03.
# Adjusting learning rate of group 0 to 4.7500e-03.
# Stage 3 Iter  1300 Time:2.1e+02 # Loss:5.53e-06, Loss_r:8.54e-07, Loss_b:2.66e-06, Loss_0:2.01e-06 # Valid:5.97e-06, RL2:1.88e-02
# Stage 3 Iter  1400 Time:2.3e+02 # Loss:4.57e-06, Loss_r:8.76e-07, Loss_b:1.91e-06, Loss_0:1.78e-06 # Valid:5.42e-06, RL2:1.77e-02
# Stage 3 Iter  1500 Time:2.4e+02 # Loss:3.96e-06, Loss_r:6.40e-07, Loss_b:1.76e-06, Loss_0:1.55e-06 # Valid:5.12e-06, RL2:1.64e-02
# Stage 3 Iter  1600 Time:2.6e+02 # Loss:3.37e-06, Loss_r:5.30e-07, Loss_b:1.51e-06, Loss_0:1.33e-06 # Valid:4.57e-06, RL2:1.58e-02
# Stage 3 Iter  1700 Time:2.8e+02 # Loss:3.11e-06, Loss_r:5.08e-07, Loss_b:1.35e-06, Loss_0:1.26e-06 # Valid:3.72e-06, RL2:1.48e-02
# Stage 3 Iter  1800 Time:2.9e+02 # Loss:6.20e-07, Loss_r:6.20e-07, Loss_b:1.35e-06, Loss_0:1.26e-06 # Valid:4.20e-06, RL2:1.51e-02
# Stage 3 Iter  1900 Time:3.1e+02 # Loss:2.97e-06, Loss_r:5.62e-07, Loss_b:1.34e-06, Loss_0:1.07e-06 # Valid:3.48e-06, RL2:1.35e-02
# Stage 3 Iter  2000 Time:3.2e+02 # Loss:1.01e-05, Loss_r:6.16e-07, Loss_b:4.76e-06, Loss_0:4.75e-06 # Valid:3.35e-06, RL2:1.46e-02
# Stage 3 Iter  2100 Time:3.4e+02 # Loss:2.67e-06, Loss_r:4.98e-07, Loss_b:1.16e-06, Loss_0:1.02e-06 # Valid:3.08e-06, RL2:1.35e-02
# Stage 3 Iter  2200 Time:3.6e+02 # Loss:2.20e-06, Loss_r:3.84e-07, Loss_b:9.83e-07, Loss_0:8.33e-07 # Valid:2.62e-06, RL2:1.32e-02
# Stage 3 Iter  2300 Time:3.7e+02 # Loss:3.48e-06, Loss_r:2.81e-07, Loss_b:1.74e-06, Loss_0:1.45e-06 # Valid:3.53e-06, RL2:1.48e-02
# Stage 3 Iter  2400 Time:3.9e+02 # Loss:3.71e-07, Loss_r:3.71e-07, Loss_b:1.74e-06, Loss_0:1.45e-06 # Valid:3.38e-06, RL2:1.47e-02
# Adjusting learning rate of group 0 to 3.6125e-03.
# Adjusting learning rate of group 0 to 4.5125e-03.
# Stage 3 Iter  2500 Time:4.0e+02 # Loss:1.97e-06, Loss_r:3.34e-07, Loss_b:8.62e-07, Loss_0:7.75e-07 # Valid:2.41e-06, RL2:1.14e-02
# Stage 3 Iter  2600 Time:4.2e+02 # Loss:1.77e-06, Loss_r:3.25e-07, Loss_b:7.28e-07, Loss_0:7.17e-07 # Valid:2.15e-06, RL2:1.25e-02
# Stage 3 Iter  2700 Time:4.4e+02 # Loss:1.63e-06, Loss_r:2.85e-07, Loss_b:6.98e-07, Loss_0:6.44e-07 # Valid:1.88e-06, RL2:1.05e-02
# Stage 3 Iter  2800 Time:4.5e+02 # Loss:1.39e-06, Loss_r:2.26e-07, Loss_b:6.05e-07, Loss_0:5.58e-07 # Valid:1.78e-06, RL2:9.92e-03
# Stage 3 Iter  2900 Time:4.7e+02 # Loss:1.35e-06, Loss_r:2.09e-07, Loss_b:6.08e-07, Loss_0:5.29e-07 # Valid:1.67e-06, RL2:1.09e-02
# Stage 3 Iter  3000 Time:4.8e+02 # Loss:2.44e-07, Loss_r:2.44e-07, Loss_b:6.08e-07, Loss_0:5.29e-07 # Valid:1.78e-06, RL2:1.02e-02
# Stage 3 Iter  3100 Time:5.0e+02 # Loss:1.22e-06, Loss_r:2.09e-07, Loss_b:5.28e-07, Loss_0:4.85e-07 # Valid:1.56e-06, RL2:9.69e-03
# Stage 3 Iter  3200 Time:5.2e+02 # Loss:1.33e-06, Loss_r:1.76e-07, Loss_b:5.89e-07, Loss_0:5.70e-07 # Valid:1.62e-06, RL2:9.79e-03
# Stage 3 Iter  3300 Time:5.3e+02 # Loss:1.05e-06, Loss_r:1.66e-07, Loss_b:4.77e-07, Loss_0:4.07e-07 # Valid:1.31e-06, RL2:9.17e-03
# Stage 3 Iter  3400 Time:5.5e+02 # Loss:4.20e-06, Loss_r:1.83e-07, Loss_b:2.17e-06, Loss_0:1.84e-06 # Valid:3.78e-06, RL2:1.71e-02
# Stage 3 Iter  3500 Time:5.7e+02 # Loss:1.18e-06, Loss_r:2.31e-07, Loss_b:5.05e-07, Loss_0:4.43e-07 # Valid:1.24e-06, RL2:8.16e-03
# Stage 3 Iter  3600 Time:5.8e+02 # Loss:1.75e-07, Loss_r:1.75e-07, Loss_b:5.05e-07, Loss_0:4.43e-07 # Valid:1.26e-06, RL2:8.78e-03
# Adjusting learning rate of group 0 to 3.0706e-03.
# Adjusting learning rate of group 0 to 4.2869e-03.
# Stage 3 Iter  3700 Time:6.0e+02 # Loss:9.48e-07, Loss_r:1.64e-07, Loss_b:4.03e-07, Loss_0:3.81e-07 # Valid:1.02e-06, RL2:8.44e-03
# Stage 3 Iter  3800 Time:6.1e+02 # Loss:8.38e-07, Loss_r:1.36e-07, Loss_b:3.79e-07, Loss_0:3.23e-07 # Valid:1.07e-06, RL2:8.14e-03
# Stage 3 Iter  3900 Time:6.3e+02 # Loss:7.68e-07, Loss_r:1.24e-07, Loss_b:3.47e-07, Loss_0:2.97e-07 # Valid:8.91e-07, RL2:7.08e-03
# Stage 3 Iter  4000 Time:6.5e+02 # Loss:9.07e-07, Loss_r:1.18e-07, Loss_b:4.17e-07, Loss_0:3.72e-07 # Valid:1.24e-06, RL2:8.86e-03
# Stage 3 Iter  4100 Time:6.6e+02 # Loss:6.96e-07, Loss_r:1.05e-07, Loss_b:3.07e-07, Loss_0:2.84e-07 # Valid:8.23e-07, RL2:7.70e-03
# Stage 3 Iter  4200 Time:6.8e+02 # Loss:1.20e-07, Loss_r:1.20e-07, Loss_b:3.07e-07, Loss_0:2.84e-07 # Valid:9.32e-07, RL2:7.38e-03
# Stage 3 Iter  4300 Time:6.9e+02 # Loss:7.59e-07, Loss_r:1.23e-07, Loss_b:3.31e-07, Loss_0:3.05e-07 # Valid:9.33e-07, RL2:7.79e-03
# Stage 3 Iter  4400 Time:7.1e+02 # Loss:1.08e-05, Loss_r:1.78e-07, Loss_b:5.22e-06, Loss_0:5.40e-06 # Valid:1.52e-05, RL2:3.44e-02
# Stage 3 Iter  4500 Time:7.3e+02 # Loss:7.10e-07, Loss_r:1.44e-07, Loss_b:3.08e-07, Loss_0:2.59e-07 # Valid:8.34e-07, RL2:7.07e-03
# Stage 3 Iter  4600 Time:7.4e+02 # Loss:7.15e-07, Loss_r:1.19e-07, Loss_b:3.21e-07, Loss_0:2.75e-07 # Valid:8.35e-07, RL2:7.49e-03
# Stage 3 Iter  4700 Time:7.6e+02 # Loss:5.91e-07, Loss_r:1.09e-07, Loss_b:2.61e-07, Loss_0:2.20e-07 # Valid:6.88e-07, RL2:6.31e-03
# Stage 3 Iter  4800 Time:7.7e+02 # Loss:8.98e-08, Loss_r:8.98e-08, Loss_b:2.61e-07, Loss_0:2.20e-07 # Valid:7.07e-07, RL2:6.69e-03
# Adjusting learning rate of group 0 to 2.6100e-03.
# Adjusting learning rate of group 0 to 4.0725e-03.
# Stage 3 Iter  4900 Time:7.9e+02 # Loss:5.05e-07, Loss_r:7.73e-08, Loss_b:2.28e-07, Loss_0:1.99e-07 # Valid:6.34e-07, RL2:6.43e-03
# Stage 3 Iter  5000 Time:8.1e+02 # Loss:5.12e-07, Loss_r:8.61e-08, Loss_b:2.33e-07, Loss_0:1.92e-07 # Valid:6.10e-07, RL2:6.14e-03
# Stage 3 Iter  5100 Time:8.2e+02 # Loss:4.56e-07, Loss_r:7.37e-08, Loss_b:2.02e-07, Loss_0:1.80e-07 # Valid:5.85e-07, RL2:5.94e-03
# Stage 3 Iter  5200 Time:8.4e+02 # Loss:6.56e-07, Loss_r:7.64e-08, Loss_b:3.12e-07, Loss_0:2.68e-07 # Valid:6.53e-07, RL2:6.58e-03
# Stage 3 Iter  5300 Time:8.6e+02 # Loss:4.73e-07, Loss_r:8.50e-08, Loss_b:2.16e-07, Loss_0:1.72e-07 # Valid:5.71e-07, RL2:6.04e-03
# Stage 3 Iter  5400 Time:8.7e+02 # Loss:7.11e-08, Loss_r:7.11e-08, Loss_b:2.16e-07, Loss_0:1.72e-07 # Valid:5.65e-07, RL2:6.24e-03
# Stage 3 Iter  5500 Time:8.9e+02 # Loss:4.42e-07, Loss_r:8.15e-08, Loss_b:1.91e-07, Loss_0:1.69e-07 # Valid:5.05e-07, RL2:5.78e-03
# Stage 3 Iter  5600 Time:9.0e+02 # Loss:3.75e-07, Loss_r:6.98e-08, Loss_b:1.61e-07, Loss_0:1.45e-07 # Valid:4.43e-07, RL2:5.66e-03
# Stage 3 Iter  5700 Time:9.2e+02 # Loss:4.10e-07, Loss_r:7.42e-08, Loss_b:1.91e-07, Loss_0:1.45e-07 # Valid:5.34e-07, RL2:5.52e-03
# Stage 3 Iter  5800 Time:9.4e+02 # Loss:4.26e-07, Loss_r:7.52e-08, Loss_b:1.85e-07, Loss_0:1.66e-07 # Valid:4.80e-07, RL2:5.49e-03
# Stage 3 Iter  5900 Time:9.5e+02 # Loss:6.99e-07, Loss_r:7.86e-08, Loss_b:3.10e-07, Loss_0:3.10e-07 # Valid:1.04e-06, RL2:8.61e-03
# Stage 3 Iter  6000 Time:9.7e+02 # Loss:6.38e-08, Loss_r:6.38e-08, Loss_b:3.10e-07, Loss_0:3.10e-07 # Valid:1.02e-06, RL2:8.47e-03
# Adjusting learning rate of group 0 to 2.2185e-03.
# Adjusting learning rate of group 0 to 3.8689e-03.
# Stage 3 Iter  6100 Time:9.9e+02 # Loss:3.31e-07, Loss_r:5.96e-08, Loss_b:1.50e-07, Loss_0:1.21e-07 # Valid:4.22e-07, RL2:5.09e-03
# Stage 3 Iter  6200 Time:1.0e+03 # Loss:3.42e-07, Loss_r:5.76e-08, Loss_b:1.62e-07, Loss_0:1.22e-07 # Valid:4.44e-07, RL2:4.89e-03
# Stage 3 Iter  6300 Time:1.0e+03 # Loss:2.97e-07, Loss_r:5.16e-08, Loss_b:1.31e-07, Loss_0:1.15e-07 # Valid:3.50e-07, RL2:4.71e-03
# Stage 3 Iter  6400 Time:1.0e+03 # Loss:2.80e-07, Loss_r:4.77e-08, Loss_b:1.21e-07, Loss_0:1.11e-07 # Valid:3.27e-07, RL2:4.65e-03
# Stage 3 Iter  6500 Time:1.1e+03 # Loss:2.81e-07, Loss_r:5.63e-08, Loss_b:1.19e-07, Loss_0:1.06e-07 # Valid:3.63e-07, RL2:4.61e-03
# Stage 3 Iter  6600 Time:1.1e+03 # Loss:6.16e-08, Loss_r:6.16e-08, Loss_b:1.19e-07, Loss_0:1.06e-07 # Valid:3.20e-07, RL2:4.26e-03
# Stage 3 Iter  6700 Time:1.1e+03 # Loss:2.09e-06, Loss_r:6.99e-08, Loss_b:1.00e-06, Loss_0:1.02e-06 # Valid:1.20e-06, RL2:9.12e-03
# Stage 3 Iter  6800 Time:1.1e+03 # Loss:2.97e-07, Loss_r:5.54e-08, Loss_b:1.29e-07, Loss_0:1.12e-07 # Valid:3.33e-07, RL2:4.42e-03
# Stage 3 Iter  6900 Time:1.1e+03 # Loss:2.57e-07, Loss_r:4.44e-08, Loss_b:1.15e-07, Loss_0:9.79e-08 # Valid:3.30e-07, RL2:4.50e-03
# Stage 3 Iter  7000 Time:1.1e+03 # Loss:6.91e-07, Loss_r:6.15e-08, Loss_b:3.27e-07, Loss_0:3.03e-07 # Valid:5.41e-07, RL2:6.68e-03
# Stage 3 Iter  7100 Time:1.1e+03 # Loss:2.34e-07, Loss_r:4.40e-08, Loss_b:1.00e-07, Loss_0:8.98e-08 # Valid:2.57e-07, RL2:4.23e-03
# Stage 3 Iter  7200 Time:1.2e+03 # Loss:6.08e-08, Loss_r:6.08e-08, Loss_b:1.00e-07, Loss_0:8.98e-08 # Valid:2.94e-07, RL2:4.14e-03
# Adjusting learning rate of group 0 to 1.8857e-03.
# Adjusting learning rate of group 0 to 3.6755e-03.
# Stage 3 Iter  7300 Time:1.2e+03 # Loss:2.05e-07, Loss_r:4.29e-08, Loss_b:8.83e-08, Loss_0:7.41e-08 # Valid:2.40e-07, RL2:4.07e-03
# Stage 3 Iter  7400 Time:1.2e+03 # Loss:1.87e-07, Loss_r:3.71e-08, Loss_b:8.40e-08, Loss_0:6.59e-08 # Valid:2.24e-07, RL2:3.72e-03
# Stage 3 Iter  7500 Time:1.2e+03 # Loss:1.80e-07, Loss_r:3.48e-08, Loss_b:8.08e-08, Loss_0:6.45e-08 # Valid:2.41e-07, RL2:3.67e-03
# Stage 3 Iter  7600 Time:1.2e+03 # Loss:1.87e-07, Loss_r:3.64e-08, Loss_b:8.91e-08, Loss_0:6.15e-08 # Valid:2.34e-07, RL2:4.03e-03
# Stage 3 Iter  7700 Time:1.2e+03 # Loss:1.70e-06, Loss_r:7.01e-08, Loss_b:8.24e-07, Loss_0:8.05e-07 # Valid:9.82e-07, RL2:8.00e-03
# Stage 3 Iter  7800 Time:1.3e+03 # Loss:2.68e-08, Loss_r:2.68e-08, Loss_b:8.24e-07, Loss_0:8.05e-07 # Valid:1.02e-06, RL2:7.95e-03
# Stage 3 Iter  7900 Time:1.3e+03 # Loss:1.55e-07, Loss_r:2.99e-08, Loss_b:6.83e-08, Loss_0:5.70e-08 # Valid:2.08e-07, RL2:3.50e-03
# Stage 3 Iter  8000 Time:1.3e+03 # Loss:2.17e-07, Loss_r:4.19e-08, Loss_b:9.14e-08, Loss_0:8.34e-08 # Valid:2.34e-07, RL2:3.81e-03
# Stage 3 Iter  8100 Time:1.3e+03 # Loss:2.49e-07, Loss_r:6.93e-08, Loss_b:9.60e-08, Loss_0:8.38e-08 # Valid:2.83e-07, RL2:4.19e-03
# Stage 3 Iter  8200 Time:1.3e+03 # Loss:1.68e-07, Loss_r:3.96e-08, Loss_b:7.01e-08, Loss_0:5.88e-08 # Valid:1.90e-07, RL2:3.41e-03
# Stage 3 Iter  8300 Time:1.3e+03 # Loss:1.65e-07, Loss_r:3.26e-08, Loss_b:7.32e-08, Loss_0:5.89e-08 # Valid:2.07e-07, RL2:3.63e-03
# Stage 3 Iter  8400 Time:1.4e+03 # Loss:3.19e-08, Loss_r:3.19e-08, Loss_b:7.32e-08, Loss_0:5.89e-08 # Valid:2.16e-07, RL2:3.79e-03
# Adjusting learning rate of group 0 to 1.6029e-03.
# Adjusting learning rate of group 0 to 3.4917e-03.
# Stage 3 Iter  8500 Time:1.4e+03 # Loss:1.35e-07, Loss_r:2.72e-08, Loss_b:5.54e-08, Loss_0:5.21e-08 # Valid:1.62e-07, RL2:3.23e-03
# Stage 3 Iter  8600 Time:1.4e+03 # Loss:1.27e-07, Loss_r:2.55e-08, Loss_b:5.76e-08, Loss_0:4.44e-08 # Valid:1.35e-07, RL2:2.96e-03
# Stage 3 Iter  8700 Time:1.4e+03 # Loss:2.05e-07, Loss_r:2.76e-08, Loss_b:9.37e-08, Loss_0:8.41e-08 # Valid:1.68e-07, RL2:3.46e-03
# Stage 3 Iter  8800 Time:1.4e+03 # Loss:2.43e-07, Loss_r:2.43e-08, Loss_b:1.14e-07, Loss_0:1.05e-07 # Valid:3.23e-07, RL2:4.76e-03
# Stage 3 Iter  8900 Time:1.4e+03 # Loss:1.12e-07, Loss_r:2.54e-08, Loss_b:4.58e-08, Loss_0:4.11e-08 # Valid:1.33e-07, RL2:3.10e-03
# Stage 3 Iter  9000 Time:1.5e+03 # Loss:2.49e-08, Loss_r:2.49e-08, Loss_b:4.58e-08, Loss_0:4.11e-08 # Valid:1.36e-07, RL2:3.01e-03
# Stage 3 Iter  9100 Time:1.5e+03 # Loss:1.35e-06, Loss_r:2.74e-08, Loss_b:7.10e-07, Loss_0:6.12e-07 # Valid:2.71e-07, RL2:4.24e-03
# Stage 3 Iter  9200 Time:1.5e+03 # Loss:1.36e-07, Loss_r:2.61e-08, Loss_b:5.89e-08, Loss_0:5.15e-08 # Valid:1.82e-07, RL2:3.20e-03
# Stage 3 Iter  9300 Time:1.5e+03 # Loss:1.26e-07, Loss_r:2.33e-08, Loss_b:6.00e-08, Loss_0:4.30e-08 # Valid:1.52e-07, RL2:3.07e-03
# Stage 3 Iter  9400 Time:1.5e+03 # Loss:1.06e-07, Loss_r:2.29e-08, Loss_b:4.44e-08, Loss_0:3.88e-08 # Valid:1.16e-07, RL2:2.97e-03
# Stage 3 Iter  9500 Time:1.5e+03 # Loss:1.08e-07, Loss_r:2.17e-08, Loss_b:4.64e-08, Loss_0:3.96e-08 # Valid:1.11e-07, RL2:2.84e-03
# Stage 3 Iter  9600 Time:1.6e+03 # Loss:1.92e-08, Loss_r:1.92e-08, Loss_b:4.64e-08, Loss_0:3.96e-08 # Valid:1.09e-07, RL2:2.88e-03
# Adjusting learning rate of group 0 to 1.3625e-03.
# Adjusting learning rate of group 0 to 3.3171e-03.
# Stage 3 Iter  9700 Time:1.6e+03 # Loss:8.90e-08, Loss_r:1.95e-08, Loss_b:3.82e-08, Loss_0:3.13e-08 # Valid:1.03e-07, RL2:2.87e-03
# Stage 3 Iter  9800 Time:1.6e+03 # Loss:7.72e-08, Loss_r:1.70e-08, Loss_b:3.42e-08, Loss_0:2.60e-08 # Valid:1.12e-07, RL2:2.39e-03
# Stage 3 Iter  9900 Time:1.6e+03 # Loss:7.63e-08, Loss_r:1.67e-08, Loss_b:3.30e-08, Loss_0:2.66e-08 # Valid:9.46e-08, RL2:2.49e-03
# Stage 3 Iter 10000 Time:1.6e+03 # Loss:7.25e-08, Loss_r:1.73e-08, Loss_b:3.04e-08, Loss_0:2.48e-08 # Valid:8.75e-08, RL2:2.31e-03
# Stage 3 Iter 10100 Time:1.6e+03 # Loss:7.65e-08, Loss_r:1.64e-08, Loss_b:3.35e-08, Loss_0:2.67e-08 # Valid:9.51e-08, RL2:2.45e-03
# Stage 3 Iter 10200 Time:1.6e+03 # Loss:1.57e-08, Loss_r:1.57e-08, Loss_b:3.35e-08, Loss_0:2.67e-08 # Valid:9.70e-08, RL2:2.52e-03
# Stage 3 Iter 10300 Time:1.7e+03 # Loss:9.09e-08, Loss_r:2.01e-08, Loss_b:3.69e-08, Loss_0:3.39e-08 # Valid:1.14e-07, RL2:2.73e-03
# Stage 3 Iter 10400 Time:1.7e+03 # Loss:9.97e-08, Loss_r:1.42e-08, Loss_b:4.57e-08, Loss_0:3.97e-08 # Valid:1.28e-07, RL2:3.05e-03
# Stage 3 Iter 10500 Time:1.7e+03 # Loss:7.80e-08, Loss_r:1.41e-08, Loss_b:3.61e-08, Loss_0:2.78e-08 # Valid:8.32e-08, RL2:2.46e-03
# Stage 3 Iter 10600 Time:1.7e+03 # Loss:5.19e-06, Loss_r:2.89e-08, Loss_b:2.72e-06, Loss_0:2.44e-06 # Valid:6.09e-06, RL2:2.30e-02
# Stage 3 Iter 10700 Time:1.7e+03 # Loss:5.91e-08, Loss_r:1.16e-08, Loss_b:2.69e-08, Loss_0:2.07e-08 # Valid:8.44e-08, RL2:2.94e-03
# Stage 3 Iter 10800 Time:1.7e+03 # Loss:1.38e-08, Loss_r:1.38e-08, Loss_b:2.69e-08, Loss_0:2.07e-08 # Valid:8.60e-08, RL2:2.20e-03
# Adjusting learning rate of group 0 to 1.1581e-03.
# Adjusting learning rate of group 0 to 3.1512e-03.
# Stage 3 Iter 10900 Time:1.8e+03 # Loss:5.33e-08, Loss_r:1.18e-08, Loss_b:2.18e-08, Loss_0:1.96e-08 # Valid:7.99e-08, RL2:2.21e-03
# Stage 3 Iter 11000 Time:1.8e+03 # Loss:5.46e-08, Loss_r:1.12e-08, Loss_b:2.49e-08, Loss_0:1.85e-08 # Valid:6.36e-08, RL2:2.10e-03
# Stage 3 Iter 11100 Time:1.8e+03 # Loss:5.03e-08, Loss_r:1.15e-08, Loss_b:2.27e-08, Loss_0:1.60e-08 # Valid:6.23e-08, RL2:1.98e-03
# Stage 3 Iter 11200 Time:1.8e+03 # Loss:4.79e-08, Loss_r:9.85e-09, Loss_b:2.07e-08, Loss_0:1.74e-08 # Valid:6.35e-08, RL2:1.86e-03
# Stage 3 Iter 11300 Time:1.8e+03 # Loss:2.86e-07, Loss_r:9.49e-09, Loss_b:1.61e-07, Loss_0:1.15e-07 # Valid:3.19e-07, RL2:4.16e-03
# Stage 3 Iter 11400 Time:1.8e+03 # Loss:8.71e-08, Loss_r:8.71e-08, Loss_b:1.61e-07, Loss_0:1.15e-07 # Valid:2.88e-07, RL2:4.09e-03
# Stage 3 Iter 11500 Time:1.9e+03 # Loss:5.22e-08, Loss_r:1.33e-08, Loss_b:2.09e-08, Loss_0:1.80e-08 # Valid:6.36e-08, RL2:1.97e-03
# Stage 3 Iter 11600 Time:1.9e+03 # Loss:4.38e-08, Loss_r:9.95e-09, Loss_b:1.86e-08, Loss_0:1.52e-08 # Valid:1.39e-07, RL2:1.88e-03
# Stage 3 Iter 11700 Time:1.9e+03 # Loss:4.91e-08, Loss_r:1.22e-08, Loss_b:1.97e-08, Loss_0:1.73e-08 # Valid:6.11e-08, RL2:2.11e-03
# Stage 3 Iter 11800 Time:1.9e+03 # Loss:4.49e-08, Loss_r:9.70e-09, Loss_b:1.98e-08, Loss_0:1.55e-08 # Valid:6.59e-08, RL2:1.89e-03
# Stage 3 Iter 11900 Time:1.9e+03 # Loss:4.15e-08, Loss_r:9.70e-09, Loss_b:1.78e-08, Loss_0:1.41e-08 # Valid:5.02e-08, RL2:2.13e-03
# Stage 3 Iter 12000 Time:1.9e+03 # Loss:1.11e-08, Loss_r:1.11e-08, Loss_b:1.78e-08, Loss_0:1.41e-08 # Valid:5.59e-08, RL2:1.81e-03
# Adjusting learning rate of group 0 to 9.8437e-04.
# Adjusting learning rate of group 0 to 2.9937e-03.
# Stage 3 Iter 12100 Time:2.0e+03 # Loss:3.85e-08, Loss_r:9.77e-09, Loss_b:1.56e-08, Loss_0:1.31e-08 # Valid:5.14e-08, RL2:1.72e-03
# Stage 3 Iter 12200 Time:2.0e+03 # Loss:3.86e-08, Loss_r:8.72e-09, Loss_b:1.53e-08, Loss_0:1.46e-08 # Valid:4.80e-08, RL2:1.67e-03
# Stage 3 Iter 12300 Time:2.0e+03 # Loss:3.49e-08, Loss_r:8.76e-09, Loss_b:1.42e-08, Loss_0:1.19e-08 # Valid:4.13e-08, RL2:1.92e-03
# Stage 3 Iter 12400 Time:2.0e+03 # Loss:1.83e-07, Loss_r:7.36e-09, Loss_b:7.02e-08, Loss_0:1.06e-07 # Valid:3.10e-07, RL2:4.72e-03
# Stage 3 Iter 12500 Time:2.0e+03 # Loss:3.14e-08, Loss_r:8.46e-09, Loss_b:1.25e-08, Loss_0:1.04e-08 # Valid:4.38e-08, RL2:1.62e-03
# Stage 3 Iter 12600 Time:2.0e+03 # Loss:8.50e-09, Loss_r:8.50e-09, Loss_b:1.25e-08, Loss_0:1.04e-08 # Valid:3.96e-08, RL2:1.62e-03
# Stage 3 Iter 12700 Time:2.1e+03 # Loss:3.95e-08, Loss_r:8.88e-09, Loss_b:1.59e-08, Loss_0:1.47e-08 # Valid:4.90e-08, RL2:2.00e-03
# Stage 3 Iter 12800 Time:2.1e+03 # Loss:4.22e-07, Loss_r:8.08e-09, Loss_b:2.10e-07, Loss_0:2.03e-07 # Valid:4.02e-07, RL2:5.49e-03
# Stage 3 Iter 12900 Time:2.1e+03 # Loss:4.03e-08, Loss_r:9.79e-09, Loss_b:1.57e-08, Loss_0:1.49e-08 # Valid:4.58e-08, RL2:1.63e-03
# Stage 3 Iter 13000 Time:2.1e+03 # Loss:3.19e-08, Loss_r:7.71e-09, Loss_b:1.33e-08, Loss_0:1.09e-08 # Valid:3.92e-08, RL2:1.44e-03
# Stage 3 Iter 13100 Time:2.1e+03 # Loss:3.31e-08, Loss_r:8.76e-09, Loss_b:1.33e-08, Loss_0:1.11e-08 # Valid:3.35e-08, RL2:1.50e-03
# Stage 3 Iter 13200 Time:2.1e+03 # Loss:8.72e-09, Loss_r:8.72e-09, Loss_b:1.33e-08, Loss_0:1.11e-08 # Valid:4.57e-08, RL2:1.59e-03
# Adjusting learning rate of group 0 to 8.3672e-04.
# Adjusting learning rate of group 0 to 2.8440e-03.
# Stage 3 Iter 13300 Time:2.2e+03 # Loss:3.01e-08, Loss_r:7.79e-09, Loss_b:1.19e-08, Loss_0:1.04e-08 # Valid:3.37e-08, RL2:1.51e-03
# Stage 3 Iter 13400 Time:2.2e+03 # Loss:2.54e-08, Loss_r:6.53e-09, Loss_b:1.03e-08, Loss_0:8.53e-09 # Valid:3.85e-08, RL2:1.49e-03
# Stage 3 Iter 13500 Time:2.2e+03 # Loss:1.60e-06, Loss_r:1.19e-08, Loss_b:7.97e-07, Loss_0:7.89e-07 # Valid:6.58e-07, RL2:7.65e-03
# Stage 3 Iter 13600 Time:2.2e+03 # Loss:2.49e-08, Loss_r:6.02e-09, Loss_b:1.07e-08, Loss_0:8.18e-09 # Valid:3.15e-08, RL2:1.36e-03
# Stage 3 Iter 13700 Time:2.2e+03 # Loss:2.75e-08, Loss_r:6.80e-09, Loss_b:1.13e-08, Loss_0:9.32e-09 # Valid:3.28e-08, RL2:1.39e-03
# Stage 3 Iter 13800 Time:2.2e+03 # Loss:9.41e-09, Loss_r:9.41e-09, Loss_b:1.13e-08, Loss_0:9.32e-09 # Valid:3.38e-08, RL2:1.44e-03
# Stage 3 Iter 13900 Time:2.2e+03 # Loss:2.25e-08, Loss_r:6.04e-09, Loss_b:8.84e-09, Loss_0:7.62e-09 # Valid:2.88e-08, RL2:1.37e-03
# Stage 3 Iter 14000 Time:2.3e+03 # Loss:4.72e-08, Loss_r:5.91e-09, Loss_b:2.10e-08, Loss_0:2.02e-08 # Valid:4.97e-08, RL2:1.92e-03
# Stage 3 Iter 14100 Time:2.3e+03 # Loss:3.57e-08, Loss_r:7.57e-09, Loss_b:1.50e-08, Loss_0:1.31e-08 # Valid:4.03e-08, RL2:1.65e-03
# Stage 3 Iter 14200 Time:2.3e+03 # Loss:2.88e-08, Loss_r:6.95e-09, Loss_b:1.25e-08, Loss_0:9.37e-09 # Valid:3.17e-08, RL2:1.50e-03
# Stage 3 Iter 14300 Time:2.3e+03 # Loss:2.65e-08, Loss_r:6.36e-09, Loss_b:1.10e-08, Loss_0:9.05e-09 # Valid:3.21e-08, RL2:1.77e-03
# Stage 3 Iter 14400 Time:2.3e+03 # Loss:6.10e-09, Loss_r:6.10e-09, Loss_b:1.10e-08, Loss_0:9.05e-09 # Valid:3.09e-08, RL2:1.43e-03
# Adjusting learning rate of group 0 to 7.1121e-04.
# Adjusting learning rate of group 0 to 2.7018e-03.
# Stage 3 Iter 14500 Time:2.3e+03 # Loss:2.47e-08, Loss_r:6.49e-09, Loss_b:9.64e-09, Loss_0:8.58e-09 # Valid:2.95e-08, RL2:1.29e-03
# Stage 3 Iter 14600 Time:2.4e+03 # Loss:2.40e-08, Loss_r:6.92e-09, Loss_b:9.47e-09, Loss_0:7.61e-09 # Valid:2.99e-08, RL2:1.41e-03
# Stage 3 Iter 14700 Time:2.4e+03 # Loss:2.15e-08, Loss_r:5.36e-09, Loss_b:9.32e-09, Loss_0:6.78e-09 # Valid:2.92e-08, RL2:1.67e-03
# Stage 3 Iter 14800 Time:2.4e+03 # Loss:2.03e-08, Loss_r:5.30e-09, Loss_b:8.34e-09, Loss_0:6.63e-09 # Valid:2.82e-08, RL2:1.20e-03
# Stage 3 Iter 14900 Time:2.4e+03 # Loss:2.04e-08, Loss_r:4.69e-09, Loss_b:8.08e-09, Loss_0:7.63e-09 # Valid:3.93e-08, RL2:1.18e-03
# Stage 3 Iter 15000 Time:2.4e+03 # Loss:5.42e-09, Loss_r:5.42e-09, Loss_b:8.08e-09, Loss_0:7.63e-09 # Valid:2.52e-08, RL2:1.18e-03
# Stage 3 Iter 15100 Time:2.4e+03 # Loss:2.19e-08, Loss_r:6.51e-09, Loss_b:8.53e-09, Loss_0:6.89e-09 # Valid:2.41e-08, RL2:1.71e-03
# Stage 3 Iter 15200 Time:2.5e+03 # Loss:1.94e-08, Loss_r:4.88e-09, Loss_b:7.58e-09, Loss_0:6.97e-09 # Valid:2.43e-08, RL2:1.17e-03
# Stage 3 Iter 15300 Time:2.5e+03 # Loss:1.78e-08, Loss_r:4.74e-09, Loss_b:6.70e-09, Loss_0:6.39e-09 # Valid:2.13e-08, RL2:1.12e-03
# Stage 3 Iter 15400 Time:2.5e+03 # Loss:2.11e-08, Loss_r:6.20e-09, Loss_b:7.79e-09, Loss_0:7.09e-09 # Valid:2.99e-08, RL2:1.24e-03
# Stage 3 Iter 15500 Time:2.5e+03 # Loss:1.90e-08, Loss_r:4.84e-09, Loss_b:6.67e-09, Loss_0:7.50e-09 # Valid:2.06e-08, RL2:1.18e-03
# Stage 3 Iter 15600 Time:2.5e+03 # Loss:5.61e-09, Loss_r:5.61e-09, Loss_b:6.67e-09, Loss_0:7.50e-09 # Valid:2.98e-08, RL2:1.23e-03
# Adjusting learning rate of group 0 to 6.0453e-04.
# Adjusting learning rate of group 0 to 2.5667e-03.
# Stage 3 Iter 15700 Time:2.5e+03 # Loss:1.91e-08, Loss_r:6.64e-09, Loss_b:6.72e-09, Loss_0:5.75e-09 # Valid:2.17e-08, RL2:1.05e-03
# Stage 3 Iter 15800 Time:2.6e+03 # Loss:1.72e-08, Loss_r:4.67e-09, Loss_b:6.95e-09, Loss_0:5.53e-09 # Valid:2.36e-08, RL2:1.20e-03
# Stage 3 Iter 15900 Time:2.6e+03 # Loss:1.57e-08, Loss_r:4.43e-09, Loss_b:6.24e-09, Loss_0:4.98e-09 # Valid:1.91e-08, RL2:9.69e-04
# Stage 3 Iter 16000 Time:2.6e+03 # Loss:1.71e-08, Loss_r:3.90e-09, Loss_b:7.28e-09, Loss_0:5.91e-09 # Valid:2.87e-08, RL2:1.20e-03
# Stage 3 Iter 16100 Time:2.6e+03 # Loss:1.52e-08, Loss_r:3.93e-09, Loss_b:6.03e-09, Loss_0:5.21e-09 # Valid:2.31e-08, RL2:1.05e-03
# Stage 3 Iter 16200 Time:2.6e+03 # Loss:4.46e-09, Loss_r:4.46e-09, Loss_b:6.03e-09, Loss_0:5.21e-09 # Valid:3.13e-08, RL2:1.01e-03
# Stage 3 Iter 16300 Time:2.6e+03 # Loss:1.56e-08, Loss_r:4.72e-09, Loss_b:5.68e-09, Loss_0:5.21e-09 # Valid:2.15e-08, RL2:1.25e-03
# Stage 3 Iter 16400 Time:2.7e+03 # Loss:1.35e-08, Loss_r:4.21e-09, Loss_b:4.75e-09, Loss_0:4.58e-09 # Valid:2.40e-08, RL2:1.08e-03
# Stage 3 Iter 16500 Time:2.7e+03 # Loss:1.31e-08, Loss_r:4.15e-09, Loss_b:4.83e-09, Loss_0:4.16e-09 # Valid:1.66e-08, RL2:9.73e-04
# Stage 3 Iter 16600 Time:2.7e+03 # Loss:1.37e-08, Loss_r:3.40e-09, Loss_b:5.25e-09, Loss_0:5.04e-09 # Valid:2.38e-08, RL2:1.06e-03
# Stage 3 Iter 16700 Time:2.7e+03 # Loss:3.61e-08, Loss_r:5.20e-09, Loss_b:1.43e-08, Loss_0:1.67e-08 # Valid:4.56e-08, RL2:1.54e-03
# Stage 3 Iter 16800 Time:2.7e+03 # Loss:8.28e-09, Loss_r:8.28e-09, Loss_b:1.43e-08, Loss_0:1.67e-08 # Valid:4.63e-08, RL2:1.49e-03
# Adjusting learning rate of group 0 to 5.1385e-04.
# Adjusting learning rate of group 0 to 2.4384e-03.
# Stage 3 Iter 16900 Time:2.7e+03 # Loss:1.33e-08, Loss_r:3.65e-09, Loss_b:5.24e-09, Loss_0:4.46e-09 # Valid:1.74e-08, RL2:9.62e-04
# Stage 3 Iter 17000 Time:2.7e+03 # Loss:1.30e-08, Loss_r:3.49e-09, Loss_b:5.04e-09, Loss_0:4.44e-09 # Valid:1.95e-08, RL2:9.60e-04
# Stage 3 Iter 17100 Time:2.8e+03 # Loss:1.26e-08, Loss_r:3.10e-09, Loss_b:4.91e-09, Loss_0:4.58e-09 # Valid:1.67e-08, RL2:1.03e-03
# Stage 3 Iter 17200 Time:2.8e+03 # Loss:1.34e-08, Loss_r:3.78e-09, Loss_b:4.53e-09, Loss_0:5.09e-09 # Valid:1.64e-08, RL2:9.23e-04
# Stage 3 Iter 17300 Time:2.8e+03 # Loss:1.81e-08, Loss_r:4.05e-09, Loss_b:7.23e-09, Loss_0:6.79e-09 # Valid:1.99e-08, RL2:1.05e-03
# Stage 3 Iter 17400 Time:2.8e+03 # Loss:6.56e-09, Loss_r:6.56e-09, Loss_b:7.23e-09, Loss_0:6.79e-09 # Valid:2.00e-08, RL2:1.02e-03
# Stage 3 Iter 17500 Time:2.8e+03 # Loss:1.49e-08, Loss_r:3.46e-09, Loss_b:6.08e-09, Loss_0:5.34e-09 # Valid:1.90e-08, RL2:1.08e-03
# Stage 3 Iter 17600 Time:2.8e+03 # Loss:1.16e-08, Loss_r:2.95e-09, Loss_b:4.35e-09, Loss_0:4.29e-09 # Valid:1.73e-08, RL2:1.05e-03
# Stage 3 Iter 17700 Time:2.9e+03 # Loss:1.14e-08, Loss_r:3.04e-09, Loss_b:4.17e-09, Loss_0:4.18e-09 # Valid:1.67e-08, RL2:8.87e-04
# Stage 3 Iter 17800 Time:2.9e+03 # Loss:1.40e-08, Loss_r:3.90e-09, Loss_b:5.83e-09, Loss_0:4.25e-09 # Valid:1.80e-08, RL2:1.11e-03
# Stage 3 Iter 17900 Time:2.9e+03 # Loss:1.22e-08, Loss_r:3.49e-09, Loss_b:4.89e-09, Loss_0:3.84e-09 # Valid:1.37e-08, RL2:8.78e-04
# Stage 3 Iter 18000 Time:2.9e+03 # Loss:3.10e-09, Loss_r:3.10e-09, Loss_b:4.89e-09, Loss_0:3.84e-09 # Valid:1.46e-08, RL2:9.76e-04
# Adjusting learning rate of group 0 to 4.3677e-04.
# Adjusting learning rate of group 0 to 2.3165e-03.
# Stage 3 Iter 18100 Time:2.9e+03 # Loss:1.20e-08, Loss_r:3.41e-09, Loss_b:4.36e-09, Loss_0:4.18e-09 # Valid:1.49e-08, RL2:9.12e-04
# Stage 3 Iter 18200 Time:2.9e+03 # Loss:1.07e-08, Loss_r:3.90e-09, Loss_b:3.56e-09, Loss_0:3.28e-09 # Valid:1.36e-08, RL2:9.97e-04
# Stage 3 Iter 18300 Time:3.0e+03 # Loss:1.13e-08, Loss_r:2.80e-09, Loss_b:4.70e-09, Loss_0:3.76e-09 # Valid:1.40e-08, RL2:8.89e-04
# Stage 3 Iter 18400 Time:3.0e+03 # Loss:1.09e-08, Loss_r:3.31e-09, Loss_b:4.01e-09, Loss_0:3.55e-09 # Valid:1.59e-08, RL2:8.32e-04
# Stage 3 Iter 18500 Time:3.0e+03 # Loss:1.03e-08, Loss_r:2.77e-09, Loss_b:3.98e-09, Loss_0:3.51e-09 # Valid:1.23e-08, RL2:8.36e-04
# Stage 3 Iter 18600 Time:3.0e+03 # Loss:2.57e-09, Loss_r:2.57e-09, Loss_b:3.98e-09, Loss_0:3.51e-09 # Valid:1.20e-08, RL2:8.62e-04
# Stage 3 Iter 18700 Time:3.0e+03 # Loss:1.01e-08, Loss_r:2.72e-09, Loss_b:4.00e-09, Loss_0:3.39e-09 # Valid:1.43e-08, RL2:8.69e-04
# Stage 3 Iter 18800 Time:3.0e+03 # Loss:8.98e-09, Loss_r:2.76e-09, Loss_b:3.33e-09, Loss_0:2.89e-09 # Valid:1.45e-08, RL2:8.66e-04
# Stage 3 Iter 18900 Time:3.1e+03 # Loss:1.52e-08, Loss_r:2.85e-09, Loss_b:6.35e-09, Loss_0:5.96e-09 # Valid:3.01e-08, RL2:1.34e-03
# Stage 3 Iter 19000 Time:3.1e+03 # Loss:9.48e-09, Loss_r:2.43e-09, Loss_b:3.96e-09, Loss_0:3.10e-09 # Valid:1.16e-08, RL2:8.01e-04
# Stage 3 Iter 19100 Time:3.1e+03 # Loss:8.60e-09, Loss_r:2.00e-09, Loss_b:3.49e-09, Loss_0:3.12e-09 # Valid:1.12e-08, RL2:8.09e-04
# Stage 3 Iter 19200 Time:3.1e+03 # Loss:2.34e-09, Loss_r:2.34e-09, Loss_b:3.49e-09, Loss_0:3.12e-09 # Valid:1.38e-08, RL2:8.70e-04
# Adjusting learning rate of group 0 to 3.7126e-04.
# Adjusting learning rate of group 0 to 2.2006e-03.
# Stage 3 Iter 19300 Time:3.1e+03 # Loss:8.29e-09, Loss_r:1.91e-09, Loss_b:3.50e-09, Loss_0:2.87e-09 # Valid:1.51e-08, RL2:8.78e-04
# Stage 3 Iter 19400 Time:3.1e+03 # Loss:8.60e-09, Loss_r:2.26e-09, Loss_b:3.41e-09, Loss_0:2.93e-09 # Valid:9.90e-09, RL2:7.53e-04
# Stage 3 Iter 19500 Time:3.2e+03 # Loss:8.65e-09, Loss_r:2.74e-09, Loss_b:3.27e-09, Loss_0:2.64e-09 # Valid:9.75e-09, RL2:8.56e-04
# Stage 3 Iter 19600 Time:3.2e+03 # Loss:7.80e-09, Loss_r:1.89e-09, Loss_b:3.08e-09, Loss_0:2.83e-09 # Valid:1.03e-08, RL2:7.79e-04
# Stage 3 Iter 19700 Time:3.2e+03 # Loss:7.00e-09, Loss_r:1.65e-09, Loss_b:2.91e-09, Loss_0:2.44e-09 # Valid:1.24e-08, RL2:7.37e-04
# Stage 3 Iter 19800 Time:3.2e+03 # Loss:3.08e-09, Loss_r:3.08e-09, Loss_b:2.91e-09, Loss_0:2.44e-09 # Valid:1.04e-08, RL2:7.27e-04
# Stage 3 Iter 19900 Time:3.2e+03 # Loss:8.87e-09, Loss_r:2.04e-09, Loss_b:3.77e-09, Loss_0:3.07e-09 # Valid:1.18e-08, RL2:8.38e-04
# Stage 3 Iter 20000 Time:3.2e+03 # Loss:6.82e-09, Loss_r:1.70e-09, Loss_b:2.67e-09, Loss_0:2.45e-09 # Valid:8.57e-09, RL2:6.53e-04
# Stage 3 Iter 20100 Time:3.3e+03 # Loss:7.65e-09, Loss_r:1.93e-09, Loss_b:2.95e-09, Loss_0:2.77e-09 # Valid:1.27e-08, RL2:8.20e-04
# Stage 3 Iter 20200 Time:3.3e+03 # Loss:1.35e-07, Loss_r:2.95e-09, Loss_b:6.23e-08, Loss_0:6.94e-08 # Valid:1.96e-07, RL2:3.73e-03
# Stage 3 Iter 20300 Time:3.3e+03 # Loss:7.40e-09, Loss_r:1.92e-09, Loss_b:2.74e-09, Loss_0:2.75e-09 # Valid:1.11e-08, RL2:7.62e-04
# Stage 3 Iter 20400 Time:3.3e+03 # Loss:1.63e-09, Loss_r:1.63e-09, Loss_b:2.74e-09, Loss_0:2.75e-09 # Valid:1.16e-08, RL2:7.26e-04
# Adjusting learning rate of group 0 to 3.1557e-04.
# Adjusting learning rate of group 0 to 2.0906e-03.
# Stage 3 Iter 20500 Time:3.3e+03 # Loss:6.47e-09, Loss_r:1.78e-09, Loss_b:2.50e-09, Loss_0:2.19e-09 # Valid:9.68e-09, RL2:8.93e-04
# Stage 3 Iter 20600 Time:3.3e+03 # Loss:7.38e-09, Loss_r:2.16e-09, Loss_b:2.49e-09, Loss_0:2.72e-09 # Valid:8.95e-09, RL2:7.81e-04
# Stage 3 Iter 20700 Time:3.3e+03 # Loss:6.01e-09, Loss_r:1.88e-09, Loss_b:2.15e-09, Loss_0:1.98e-09 # Valid:8.76e-09, RL2:1.04e-03
# Stage 3 Iter 20800 Time:3.4e+03 # Loss:6.38e-09, Loss_r:1.52e-09, Loss_b:2.71e-09, Loss_0:2.15e-09 # Valid:9.30e-09, RL2:6.29e-04
# Stage 3 Iter 20900 Time:3.4e+03 # Loss:7.47e-09, Loss_r:1.97e-09, Loss_b:3.16e-09, Loss_0:2.33e-09 # Valid:1.06e-08, RL2:7.98e-04
# Stage 3 Iter 21000 Time:3.4e+03 # Loss:1.76e-09, Loss_r:1.76e-09, Loss_b:3.16e-09, Loss_0:2.33e-09 # Valid:8.36e-09, RL2:7.28e-04
# Stage 3 Iter 21100 Time:3.4e+03 # Loss:6.17e-09, Loss_r:1.47e-09, Loss_b:2.41e-09, Loss_0:2.29e-09 # Valid:7.14e-09, RL2:6.84e-04
# Stage 3 Iter 21200 Time:3.4e+03 # Loss:8.13e-09, Loss_r:1.85e-09, Loss_b:3.17e-09, Loss_0:3.12e-09 # Valid:9.50e-09, RL2:8.51e-04
# Stage 3 Iter 21300 Time:3.4e+03 # Loss:5.94e-09, Loss_r:1.41e-09, Loss_b:2.35e-09, Loss_0:2.19e-09 # Valid:8.14e-09, RL2:8.80e-04
# Stage 3 Iter 21400 Time:3.5e+03 # Loss:5.92e-09, Loss_r:1.54e-09, Loss_b:2.38e-09, Loss_0:2.00e-09 # Valid:7.65e-09, RL2:6.71e-04
# Stage 3 Iter 21500 Time:3.5e+03 # Loss:1.59e-08, Loss_r:1.44e-09, Loss_b:7.84e-09, Loss_0:6.58e-09 # Valid:2.11e-08, RL2:1.24e-03
# Stage 3 Iter 21600 Time:3.5e+03 # Loss:1.56e-09, Loss_r:1.56e-09, Loss_b:7.84e-09, Loss_0:6.58e-09 # Valid:2.28e-08, RL2:1.18e-03
# Adjusting learning rate of group 0 to 2.6823e-04.
# Adjusting learning rate of group 0 to 1.9861e-03.
# Stage 3 Iter 21700 Time:3.5e+03 # Loss:5.77e-09, Loss_r:1.48e-09, Loss_b:2.33e-09, Loss_0:1.96e-09 # Valid:6.12e-09, RL2:6.55e-04
# Stage 3 Iter 21800 Time:3.5e+03 # Loss:5.43e-09, Loss_r:1.56e-09, Loss_b:2.03e-09, Loss_0:1.84e-09 # Valid:8.16e-09, RL2:6.39e-04
# Stage 3 Iter 21900 Time:3.5e+03 # Loss:5.96e-09, Loss_r:1.48e-09, Loss_b:2.23e-09, Loss_0:2.26e-09 # Valid:7.98e-09, RL2:6.88e-04
# Stage 3 Iter 22000 Time:3.6e+03 # Loss:6.14e-09, Loss_r:1.45e-09, Loss_b:2.30e-09, Loss_0:2.38e-09 # Valid:9.76e-09, RL2:6.59e-04
# Stage 3 Iter 22100 Time:3.6e+03 # Loss:5.39e-09, Loss_r:1.32e-09, Loss_b:2.14e-09, Loss_0:1.93e-09 # Valid:8.07e-09, RL2:7.70e-04
# Stage 3 Iter 22200 Time:3.6e+03 # Loss:1.37e-09, Loss_r:1.37e-09, Loss_b:2.14e-09, Loss_0:1.93e-09 # Valid:8.31e-09, RL2:6.04e-04
# Stage 3 Iter 22300 Time:3.6e+03 # Loss:5.29e-09, Loss_r:1.41e-09, Loss_b:2.02e-09, Loss_0:1.86e-09 # Valid:1.13e-08, RL2:6.18e-04
# Stage 3 Iter 22400 Time:3.6e+03 # Loss:5.35e-09, Loss_r:1.45e-09, Loss_b:2.09e-09, Loss_0:1.81e-09 # Valid:6.39e-09, RL2:6.33e-04
# Stage 3 Iter 22500 Time:3.6e+03 # Loss:5.12e-09, Loss_r:1.24e-09, Loss_b:2.03e-09, Loss_0:1.85e-09 # Valid:7.11e-09, RL2:6.31e-04
# Stage 3 Iter 22600 Time:3.7e+03 # Loss:4.65e-09, Loss_r:1.12e-09, Loss_b:1.95e-09, Loss_0:1.57e-09 # Valid:6.81e-09, RL2:6.06e-04
# Stage 3 Iter 22700 Time:3.7e+03 # Loss:3.63e-08, Loss_r:1.54e-09, Loss_b:1.68e-08, Loss_0:1.80e-08 # Valid:4.26e-08, RL2:1.74e-03
# Stage 3 Iter 22800 Time:3.7e+03 # Loss:1.62e-09, Loss_r:1.62e-09, Loss_b:1.68e-08, Loss_0:1.80e-08 # Valid:4.36e-08, RL2:1.57e-03
# Adjusting learning rate of group 0 to 2.2800e-04.
# Adjusting learning rate of group 0 to 1.8868e-03.
# Stage 3 Iter 22900 Time:3.7e+03 # Loss:4.60e-09, Loss_r:1.32e-09, Loss_b:1.73e-09, Loss_0:1.55e-09 # Valid:6.51e-09, RL2:6.90e-04
# Stage 3 Iter 23000 Time:3.7e+03 # Loss:4.83e-09, Loss_r:1.35e-09, Loss_b:1.87e-09, Loss_0:1.61e-09 # Valid:5.96e-09, RL2:6.28e-04
# Stage 3 Iter 23100 Time:3.7e+03 # Loss:5.35e-09, Loss_r:1.85e-09, Loss_b:1.82e-09, Loss_0:1.68e-09 # Valid:6.75e-09, RL2:5.37e-04
# Stage 3 Iter 23200 Time:3.8e+03 # Loss:4.92e-09, Loss_r:1.26e-09, Loss_b:1.86e-09, Loss_0:1.79e-09 # Valid:6.53e-09, RL2:6.64e-04
# Stage 3 Iter 23300 Time:3.8e+03 # Loss:4.33e-09, Loss_r:1.26e-09, Loss_b:1.52e-09, Loss_0:1.55e-09 # Valid:1.18e-08, RL2:5.62e-04
# Stage 3 Iter 23400 Time:3.8e+03 # Loss:1.89e-09, Loss_r:1.89e-09, Loss_b:1.52e-09, Loss_0:1.55e-09 # Valid:7.15e-09, RL2:6.50e-04
# Stage 3 Iter 23500 Time:3.8e+03 # Loss:5.07e-09, Loss_r:1.41e-09, Loss_b:1.70e-09, Loss_0:1.95e-09 # Valid:7.19e-09, RL2:5.99e-04
# Stage 3 Iter 23600 Time:3.8e+03 # Loss:4.62e-09, Loss_r:1.21e-09, Loss_b:1.76e-09, Loss_0:1.65e-09 # Valid:5.97e-09, RL2:6.68e-04
# Stage 3 Iter 23700 Time:3.8e+03 # Loss:5.36e-09, Loss_r:1.35e-09, Loss_b:2.01e-09, Loss_0:2.00e-09 # Valid:6.24e-09, RL2:6.27e-04
# Stage 3 Iter 23800 Time:3.9e+03 # Loss:4.61e-09, Loss_r:1.37e-09, Loss_b:1.78e-09, Loss_0:1.46e-09 # Valid:5.30e-09, RL2:5.34e-04
# Stage 3 Iter 23900 Time:3.9e+03 # Loss:1.46e-08, Loss_r:1.12e-09, Loss_b:6.48e-09, Loss_0:6.96e-09 # Valid:1.40e-08, RL2:9.92e-04
# Stage 3 Iter 24000 Time:3.9e+03 # Loss:1.02e-09, Loss_r:1.02e-09, Loss_b:6.48e-09, Loss_0:6.96e-09 # Valid:1.57e-08, RL2:9.96e-04
# Adjusting learning rate of group 0 to 1.9380e-04.
# Adjusting learning rate of group 0 to 1.7924e-03.

# %%
np.save("./loss_logger_dict.npy", trainer.logger)
np.save("./loss_logger_valid_dict.npy", trainer.logger_valid)

# %% [markdown]
# ## 结果可视化

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size':18})

# %% [markdown]
# ### 训练的loss图

# %%
# loss图
loss_logger = np.load("./loss_logger_dict.npy", allow_pickle=True).item()
fig = plt.figure(figsize=(24, 5), dpi=64)
axes = fig.subplots(nrows=1, ncols=4)

for i, ax in enumerate(fig.axes):
    logger = loss_logger[f"stage{i + 1}"]
    
    ax.plot(logger["iter"], logger["loss"], label=r"$Loss$", linewidth=3)
    ax.plot(logger["iter"], logger["loss_res"], label=r"$Loss_{res}$", linewidth=2)
    ax.plot(logger["iter"], logger["loss_bcs"], label=r"$Loss_{bcs}$", linewidth=2)
    ax.set_yscale('log')
    ax.set_title(f"Stage {i + 1}")
    ax.grid()

lines, labels = fig.axes[-1].get_legend_handles_labels()
fig.legend(lines, labels, loc='upper center', bbox_to_anchor=(0.5, -0), ncol=3)

plt.tight_layout()
plt.savefig('Loss.png', dpi=100, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### 验证的loss图 (包括只经backbone和经过transformer和backbone的loss)

# %%
# valid的loss图 第一行只经过backbone 第二行经过transformer和backbone
# 因为只用backbone来valid 所以valid loss必须是对每个stage都是非增的 否则代码有误
# 由于随机采样 stage2的loss在小范围内波动属正常
# 第二行的stage2是经过transformer和backbone的 loss上升说明对抗网络是有效的
loss_logger_valid = np.load("./loss_logger_valid_dict.npy", allow_pickle=True).item()

fig = plt.figure(figsize=(24, 5), dpi=64)
axes = fig.subplots(nrows=1, ncols=4)

for i, ax in enumerate(fig.axes):
    logger = loss_logger_valid[f"stage{i + 1}"]
    
    ax.plot(logger["iter"], logger["loss"], label=r"$Loss$", linewidth=3)
    ax.plot(logger["iter"], logger["loss_res"], label=r"$Loss_{res}$", linewidth=2)
    ax.plot(logger["iter"], logger["loss_bcs"], label=r"$Loss_{bcs}$", linewidth=2)
    ax.set_yscale('log')
    ax.set_title(f"Stage {i + 1}")
    ax.grid()

lines, labels = fig.axes[-1].get_legend_handles_labels()
fig.legend(lines, labels, loc='upper center', bbox_to_anchor=(0.5, -0), ncol=3)

plt.tight_layout()
# plt.savefig('loss_valid.png', dpi=100, bbox_inches='tight')
plt.show()


fig = plt.figure(figsize=(24, 5), dpi=64)
axes = fig.subplots(nrows=1, ncols=4)

for i, ax in enumerate(fig.axes):
    logger = loss_logger_valid[f"stage{i + 1}"]
    
    ax.plot(logger["iter"], logger["loss_transformer"], label=r"$Loss$", linewidth=3)
    ax.plot(logger["iter"], logger["loss_res_transformer"], label=r"$Loss_{res}$", linewidth=2)
    ax.plot(logger["iter"], logger["loss_bcs_transformer"], label=r"$Loss_{bcs}$", linewidth=2)
    ax.set_yscale('log')
    ax.set_title(f"Stage {i + 1}")
    ax.grid()

lines, labels = fig.axes[-1].get_legend_handles_labels()
fig.legend(lines, labels, loc='upper center', bbox_to_anchor=(0.5, -0), ncol=3)

plt.tight_layout()
# plt.savefig('loss_valid_transformer.png', dpi=100, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### 验证的Relative L2 error图 (包括只经backbone和经过transformer和backbone的rl2)

# %%
# valid中记录的relative l2 error记录 第一行只经过backbone 第二行经过transformer和backbone
loss_logger_valid = np.load("./loss_logger_valid_dict.npy", allow_pickle=True).item()

fig = plt.figure(figsize=(24, 5), dpi=64)
axes = fig.subplots(nrows=1, ncols=4)

for i, ax in enumerate(fig.axes):
    logger = loss_logger_valid[f"stage{i + 1}"]
    
    ax.plot(logger["iter"], logger["error"], label=r"Backbone Relative error", color="blue", linewidth=3)
    ax.plot(logger["iter"], logger["error_transformer"], label=r"Transformer+Backbone Relative L2 error", color="red", linewidth=3)
    
    ax.set_yscale('log')
    ax.set_title(f"Stage {i + 1}")
    ax.grid()

lines, labels = fig.axes[-1].get_legend_handles_labels()
fig.legend(lines, labels, loc='upper center', bbox_to_anchor=(0.5, -0), ncol=3)

plt.tight_layout()
plt.savefig('Relative_L2_error.png', dpi=100, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### 验证的距离变化信息 d_mean d_var d_min d_max

# %%
# valid中记录的relative l2 error记录 第一行只经过backbone 第二行经过transformer和backbone
loss_logger_valid = np.load("./loss_logger_valid_dict.npy", allow_pickle=True).item()

fig = plt.figure(figsize=(24, 5), dpi=64)
axes = fig.subplots(nrows=1, ncols=4)

for i, ax in enumerate(fig.axes):
    logger = loss_logger_valid[f"stage{i + 1}"]
    
    ax.plot(logger["iter"], logger["distant"]["mean"], label=r"Mean distant", color="green", linewidth=3)
    ax.plot(logger["iter"], logger["distant"]["var"], label=r"Var distant", color="orange", linewidth=3)
    ax.plot(logger["iter"], logger["distant"]["min"], label=r"Min distant", color="cyan", linestyle=':', linewidth=3)
    ax.plot(logger["iter"], logger["distant"]["max"], label=r"Max distant", color="dodgerblue", linestyle='--', linewidth=3)
    
    ax.set_yscale('log')
    ax.set_title(f"Stage {i + 1}")
    ax.grid()

lines, labels = fig.axes[-1].get_legend_handles_labels()
fig.legend(lines, labels, loc='upper center', bbox_to_anchor=(0.5, -0), ncol=4)

plt.tight_layout()
# plt.savefig('Relative_L2_error.png', dpi=100, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Relative L2 error (仅考虑内部点）

# %%
# 使用最好的模型
backbone = ResNet(args.backbone_layers)
state_dict = torch.load(f'{trainer.model_path}/best_model.pth')
backbone.load_state_dict(state_dict['state_dict'])
backbone.eval()
print("Stage:\t", state_dict['stage'])
print("Iter:\t", state_dict['iter'] + 1)
print("Loss:\t", "{:.2e}".format(state_dict['best_loss']))
# Out:
# Stage:	 3
# Iter:	 23800
# Loss:	 5.30e-09

# %%
def exact_sol(X):
    # 解析解
    u_star = X[:, :args.dim].mean(axis=1, keepdims=True)
    u_star = np.sin(u_star) * np.exp(- X[:, [-1]] / args.dim**2)
    return u_star

# 采样内部点
dataset = Dataset_KortewegdeVeriesHD(args.bot_top, args.T, args.dim, torch.device('cpu'))
X_res, _, _, _, _, _ = dataset.train_data(N_r=10000, N_b=0, N_0=0)
# 计算u_star u_pred
u_star = exact_sol(X_res)
u_pred = backbone(X_res)

u_star = u_star.detach().numpy()
u_pred = u_pred.detach().numpy()
#计算L2相对误差
error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)
with open("RL2.txt", 'w') as f:
    f.write(str(error_u))
print('Relative L2 error: {:.3e}'.format(error_u))
# Out:
# Relative L2 error: 5.953e-04

# %% [markdown]
# ### 可视化内部(x1, x2, 0, ..., 0)

# %%
n = 101
dim = args.dim
# 取前两维
x1 = np.linspace(-1, 1, n)
x2 = np.linspace(-1, 1, n)
x1, x2 = np.meshgrid(x1, x2)
# x3, ..., x50 = 0
x12 = np.zeros((n*n, dim))
x12[:, [0]] = x1.reshape(-1, 1)
x12[:, [1]] = x2.reshape(-1, 1)
t = np.ones((x12.shape[0], 1)) * args.T
x12 = np.concatenate([x12, t], axis=1)
x12 = torch.from_numpy(x12).float()
# 解析解和预测解
u12_star = exact_sol(x12)
u12_pred = backbone(x12)

u12_star = u12_star.detach().numpy()
u12_pred = u12_pred.detach().numpy()

u12_star = u12_star.reshape(x1.shape)
u12_pred = u12_pred.reshape(x1.shape)

# %%
# fig = plt.figure(figsize=(20, 5))
axes = fig.subplots(1, 3)

cax1 = axes[0].pcolor(x1, x2, u12_star, cmap='jet')
fig.colorbar(cax1)
axes[0].set_xlabel('$x_1$')
axes[0].set_ylabel('$x_2$')
axes[0].set_title(r'Reference $u$')
axes[0].set_xlim([-1, 1])
axes[0].set_ylim([-1, 1])
axes[0].set_xticks(np.arange(-1, 1.1, 0.5))
axes[0].set_yticks(np.arange(-1, 1.1, 0.5))
axes[0].set_aspect(1./axes[0].get_data_ratio())

cax2 = axes[1].pcolor(x1, x2, u12_pred, cmap='jet')
fig.colorbar(cax2)
axes[1].set_xlabel('$x_1$')
axes[1].set_ylabel('$x_2$')
axes[1].set_title(r'Predicted $u$')
axes[1].set_xlim([-1, 1])
axes[1].set_ylim([-1, 1])
axes[1].set_xticks(np.arange(-1, 1.1, 0.5))
axes[1].set_yticks(np.arange(-1, 1.1, 0.5))
axes[1].set_aspect(1./axes[1].get_data_ratio())

cax3 = axes[2].pcolor(x1, x2, np.abs(u12_star - u12_pred), cmap='jet')
fig.colorbar(cax3)
axes[2].set_xlabel('$x_1$')
axes[2].set_ylabel('$x_2$')
axes[2].set_title('Absolute error')
axes[2].set_xlim([-1, 1])
axes[2].set_ylim([-1, 1])
axes[2].set_xticks(np.arange(-1, 1.1, 0.5))
axes[2].set_yticks(np.arange(-1, 1.1, 0.5))
axes[2].set_aspect(1./axes[2].get_data_ratio())

plt.tight_layout()
plt.savefig(f'Korteweg_de_Veries_{args.dim}d_result.png', dpi=100, bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6.5, 5), dpi=100)
plot = ax.contourf(x1, x2, np.abs(u12_star - u12_pred), levels=16, cmap='jet')

cbar = fig.colorbar(plot)
cbar.formatter.set_powerlimits((0, 0))
cbar.update_ticks()

ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')
ax.set_xticks([-1, -0.5, 0, 0.5, 1])
ax.set_yticks([-1, -0.5, 0, 0.5, 1])
ax.set_title('Absolute error')
ax.set_aspect(1./ax.get_data_ratio())

plt.tight_layout()
plt.savefig('./Absolute_error', dpi=100)
plt.show()

# %% [markdown]
# ## Transformer变换可视化

# %%
# # loss_res
# trainer.device = torch.device('cpu')
# trainer.backbone = trainer.backbone.cpu()

# f_res = trainer.dataset.func_res(x12)
# f_res_pred = trainer.net_r(x12)
# loss_res = (f_res - f_res_pred) ** 2

# %%
# fig = plt.figure(figsize=(6.5, 5))
# ax = fig.subplots()

# cax = ax.scatter(x12.detach().numpy()[:, 0], x12.detach().numpy()[:, 1], 
#                  c=loss_res.detach().cpu().numpy(), 
# #                  vmin=0, vmax=5e-5,
#                  cmap="jet", s=80)
# fig.colorbar(cax)
# ax.set_xlabel('$x_1$')
# ax.set_ylabel('$x_2$')
# ax.set_title(r'Residual')
# ax.set_xlim([-1, 1])
# ax.set_ylim([-1, 1])
# ax.set_xticks(np.arange(-1, 1.1, 0.5))
# ax.set_yticks(np.arange(-1, 1.1, 0.5))
# ax.set_aspect(1./axes[0].get_data_ratio())

# plt.tight_layout()
# plt.show()

# %%
# # 重新取点
# n = 21
# dim = args.dim
# # 取前两维
# xx1 = np.linspace(-1, 1, n)
# xx2 = np.linspace(-1, 1, n)
# xx1, xx2 = np.meshgrid(xx1, xx2)
# # x3, ..., x50 = 0
# xx12 = np.zeros((n*n, dim))
# xx12[:, [0]] = xx1.reshape(-1, 1)
# xx12[:, [1]] = xx2.reshape(-1, 1)
# t = np.ones((xx12.shape[0], 1)) * args.T
# xx12 = np.concatenate([xx12, t], axis=1)
# xx12 = torch.from_numpy(xx12).float()

# %%
# # 变换后的点
# # model = MLP(args.subnet_layers)  # 保存的loss最低时的transformer
# # transformer = TransformerNet(model, args.bot_top)

# # state_dict = torch.load(f'{trainer.model_path}/best_model.pth')
# # transformer.load_state_dict(state_dict['state_dict_transformer'])
# # transformer.eval()

# # xx12_ = transformer(xx12)

# trainer.transformer = trainer.transformer.cpu()  # 训练最后的transformer
# f_xx12 = dataset.func_res(xx12)
# k = trainer.update_k(xx12, f_xx12)
# xx12_ = trainer.net_transformer(xx12, k)

# %%
# plt.hist(k.detach().cpu().numpy().flatten())

# %%
# fig = plt.figure(figsize=(12, 5))
# axes = fig.subplots(1, 2)

# axes[0].scatter(xx12.detach().numpy()[:, 0], xx12.detach().numpy()[:, 1], s=30, color='b')
# axes[0].set_xlabel('$x_1$')
# axes[0].set_ylabel('$x_2$')
# axes[0].set_title(r'Original distribution')
# axes[0].set_xlim([-1, 1])
# axes[0].set_ylim([-1, 1])
# axes[0].set_xticks(np.arange(-1, 1.1, 0.5))
# axes[0].set_yticks(np.arange(-1, 1.1, 0.5))
# axes[0].set_aspect(1./axes[0].get_data_ratio())

# axes[1].scatter(xx12_.detach().numpy()[:, 0], xx12_.detach().numpy()[:, 1], s=30, color='r')
# axes[1].set_xlabel('$x_1$')
# axes[1].set_ylabel('$x_2$')
# axes[1].set_title('Transformed distribution')
# axes[1].set_xlim([-1, 1])
# axes[1].set_ylim([-1, 1])
# axes[1].set_xticks(np.arange(-1, 1.1, 0.5))
# axes[1].set_yticks(np.arange(-1, 1.1, 0.5))
# axes[1].set_aspect(1./axes[1].get_data_ratio())

# plt.tight_layout()
# plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
plt.rcParams.update({'font.size':18})


loss_logger = np.load("./loss_logger_dict.npy", allow_pickle=True).item()
logger = loss_logger[f"stage{3}"]

k = 100
with sns.axes_style("darkgrid"):
    plt.figure(figsize=(9, 7))
    plt.subplot(111)
    # plt.plot(logger["iter"][::k], logger["loss"][::k], label=r"$L$")
    plt.plot(logger["iter"][::k], logger["loss_res"][::k], label=r"$\mathcal{L}_{r}$", linewidth=3)
    plt.plot(logger["iter"][::k], logger["loss_bcs"][::k], label=r"$\mathcal{L}_{b}$", linewidth=3)
    plt.legend()
    plt.xticks([0, 6000, 12000, 18000, 24000])
    plt.xlabel('Iteration')
    plt.ylabel('Loss')
    plt.yscale('log')
    plt.savefig('Loss.png', dpi=100)
    plt.show()
    
    
loss_logger_valid = np.load("./loss_logger_valid_dict.npy", allow_pickle=True).item()
logger = loss_logger_valid[f"stage{3}"]

k = 2
with sns.axes_style("darkgrid"):
    plt.figure(figsize=(9, 7))
    plt.subplot(111)
    # plt.plot(logger["iter"][::k], logger["loss"][::k], label=r"$L$")
    plt.plot(logger["iter"][::k], logger["loss_res"][::k], color='b', label=r"Backbone", linewidth=3)
    plt.plot(logger["iter"][::k], logger["loss_res_transformer"][::k], color='r', label=r"Transformer + Backbone", linewidth=3)
    plt.legend()
    plt.xticks([0, 6000, 12000, 18000, 24000])
    plt.xlabel('Iteration')
    plt.ylabel('Residual loss')
    plt.yscale('log')
    plt.savefig('Loss_r_compared_transformer.png', dpi=100)
    plt.show()
    
    
loss_logger_valid = np.load("./loss_logger_valid_dict.npy", allow_pickle=True).item()
logger = loss_logger_valid[f"stage{3}"]

k = 2
with sns.axes_style("darkgrid"):
    plt.figure(figsize=(9, 7))
    plt.subplot(111)
    # plt.plot(logger["iter"][::k], logger["loss"][::k], label=r"$L$")
    plt.plot(logger["iter"][::k], logger["error"][::k], label=r"Backbone", color="blue", linewidth=3)
    plt.plot(logger["iter"][::k], logger["error_transformer"][::k], label=r"Transformer + Backbone", color="red", linewidth=3)
    plt.legend()
    plt.xticks([0, 6000, 12000, 18000, 24000])
    plt.xlabel('Iteration')
    plt.ylabel('Relative error')
    plt.yscale('log')
    plt.savefig('Relative_L2_error.png', dpi=100)
    plt.show()
