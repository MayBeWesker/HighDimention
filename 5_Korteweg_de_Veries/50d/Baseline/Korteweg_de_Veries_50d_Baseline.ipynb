# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# /tmp/ipykernel_10547/3777615979.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# - 输入数据为$(\mathbf{x}, t)$
# - 变量dim指空间维度，时间维度会自动加一维到后面

# %%
import os
import shutil

import numpy as np
import time
from pyDOE import lhs
import matplotlib
import matplotlib.pyplot as plt
import scipy.io
import random

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import ExponentialLR

# %%
import argparse
class Options_KortewegdeVeriesHD:
    def __init__(self):
        parser = argparse.ArgumentParser()
        parser.add_argument('--cuda', default=True, help='if you use cuda')
        
        parser.add_argument('--bot_top', type=tuple, default=(-1, 1), help='a tuple of the form (bot, top)')
        parser.add_argument('--T', type=float, default=1., help='a float T of time domain [0, T]')
        parser.add_argument('--dim', default=50, help='dimension')
        parser.add_argument('--N_r', default=2400, help='num of interior points')
        parser.add_argument('--N_b', default=1200, help='num of boundary points')
        parser.add_argument('--N_0', default=1200, help='num of initial points')
        
        parser.add_argument('--backbone_layers', type=list, default=([60]*5), help='list of nn layers of backbone')
        parser.add_argument('--backbone_lr', type=float, default=1e-3, help='initial learning rate of backbone')
        
        parser.add_argument('--gamma', type=float, default=0.95, help='gamma in lr_scheduler for Adam optimizer')
        parser.add_argument('--step_size', type=int, default=1000, help='step_size of lr_scheduler for Adam optimizer')
        parser.add_argument('--iters_Adam', type=int, default=20000, help='iters for Adam')
        parser.add_argument('--lam_res', type=float, default=1, help='weight of loss_res')
        parser.add_argument('--lam_bcs', type=float, default=1, help='weight of loss_bcs')
        parser.add_argument('--lam_ics', type=float, default=1, help='weight of loss_ics')
        
        self.parser = parser

    def parse_default(self):
        args = self.parser.parse_args(args=[])
        args.device = torch.device('cuda' if args.cuda else 'cpu')
        
        # 增加网络输入输出层
        args.backbone_layers = [args.dim + 1] + args.backbone_layers + [1]  # Time-dependent PDEs, inputs' dimension '+1' for t
        return args
    

args = Options_KortewegdeVeriesHD().parse_default()
print(args.cuda)
# Out:
# True

# %%
def save_model(state, is_best=None, save_dir=None):
    last_model = os.path.join(save_dir, 'last_model.pth')
    torch.save(state, last_model)
    if is_best:
        best_model = os.path.join(save_dir, 'best_model.pth')
        shutil.copyfile(last_model, best_model)

def seed_torch(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed) # 为了禁止hash随机化，使得实验可复现
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed) # if you are using multi-GPU.
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True
    random.seed(seed)

def grad(outputs, inputs):
    """ compute the derivative of outputs associated with inputs

    Params
    ======
    outputs: (N, 1) tensor
    inputs: (N, D) tensor
    """
    return torch.autograd.grad(outputs, inputs,
                               grad_outputs=torch.ones_like(outputs),
                               create_graph=True)

# %%
seed_torch(42)

# %% [markdown]
# ## 网络模型 (Modified ResNet / ResNet / Modified MLP / MLP)

# %%
class ModifiedResNet(nn.Module):
    def __init__(self, mlp_layers):
        super(ModifiedResNet, self).__init__()
        
        self.encoder_u = nn.Sequential()
        self.encoder_u.add_module('fc_u', nn.Linear(mlp_layers[0], mlp_layers[1], bias=True))
        self.encoder_u.add_module('act_u', nn.Tanh())
        
        self.encoder_v = nn.Sequential()
        self.encoder_v.add_module('fc_v', nn.Linear(mlp_layers[0], mlp_layers[1], bias=True))
        self.encoder_v.add_module('act_v', nn.Tanh())
        
        self.model = nn.Sequential()
        
        first_layer = nn.Sequential()
        first_layer.add_module(f'fc0', nn.Linear(mlp_layers[0], mlp_layers[1], bias=True))
        first_layer.add_module(f'act0', nn.Tanh())
        self.model.add_module(f'first', first_layer)
        
        for i in range(1, len(mlp_layers)-2):
            block = nn.Sequential()
            block.add_module(f'fc{i}_0', nn.Linear(mlp_layers[i], mlp_layers[i+1], bias=True))
            block.add_module(f'act{i}_0', nn.Tanh())
            block.add_module(f'fc{i}_1', nn.Linear(mlp_layers[i], mlp_layers[i+1], bias=True))
            block.add_module(f'act{i}_1', nn.Tanh())
            self.model.add_module(f'block{i}', block)

        last_layer = nn.Sequential()
        last_layer.add_module(f'fc{len(mlp_layers)-2}', nn.Linear(mlp_layers[-2], mlp_layers[-1], bias=False))
        self.model.add_module(f'last', last_layer)
        
#         for param in self.parameters():
#             if len(param.shape) > 1:
#                 nn.init.kaiming_normal_(param)
    
    def forward(self, X):
        u = self.encoder_u(X)
        v = self.encoder_v(X)
        
        X = self.model[0](X)
        for i_block in range(1, len(self.model) - 1):
            X_ = self.model[i_block](X)
            X = X + X_
            X = X / 2.
            X = (1 - X) * u + X * v
        return self.model[-1](X)

# %%
class ResNet(nn.Module):
    def __init__(self, mlp_layers):
        super(ResNet, self).__init__()
        
        self.model = nn.Sequential()
        
        first_layer = nn.Sequential()
        first_layer.add_module(f'fc0', nn.Linear(mlp_layers[0], mlp_layers[1], bias=True))
        first_layer.add_module(f'act0', nn.Tanh())
        self.model.add_module(f'first', first_layer)
        
        for i in range(1, len(mlp_layers)-2):
            block = nn.Sequential()
            block.add_module(f'fc{i}_0', nn.Linear(mlp_layers[i], mlp_layers[i+1], bias=True))
            block.add_module(f'act{i}_0', nn.Tanh())
            block.add_module(f'fc{i}_1', nn.Linear(mlp_layers[i], mlp_layers[i+1], bias=True))
            block.add_module(f'act{i}_1', nn.Tanh())
            self.model.add_module(f'block{i}', block)

        last_layer = nn.Sequential()
        last_layer.add_module(f'fc{len(mlp_layers)-2}', nn.Linear(mlp_layers[-2], mlp_layers[-1], bias=False))
        self.model.add_module(f'last', last_layer)
        
#         for param in self.parameters():
#             if len(param.shape) > 1:
#                 nn.init.kaiming_normal_(param)
    
    def forward(self, X):
        X = self.model[0](X)
        for i_block in range(1, len(self.model) - 1):
            X_ = self.model[i_block](X)
            X = X_ + X
        return self.model[-1](X)

# %%
class ModifiedMLP(nn.Module):
    def __init__(self, mlp_layers):
        super(ModifiedMLP, self).__init__()
        
        self.encoder_u = nn.Sequential()
        self.encoder_u.add_module('fc_u', nn.Linear(mlp_layers[0], mlp_layers[1], bias=True))
        self.encoder_u.add_module('act_u', nn.Tanh())
        
        self.encoder_v = nn.Sequential()
        self.encoder_v.add_module('fc_v', nn.Linear(mlp_layers[0], mlp_layers[1], bias=True))
        self.encoder_v.add_module('act_v', nn.Tanh())
        
        self.model = nn.Sequential()
        for i in range(len(mlp_layers)-2):
            layer = nn.Sequential()
            layer.add_module(f'fc{i}', nn.Linear(mlp_layers[i], mlp_layers[i+1], bias=True))
            layer.add_module(f'act{i}', nn.Tanh())
            self.model.add_module(f'layer{i}', layer)

        last_layer = nn.Sequential()
        last_layer.add_module(f'fc{len(mlp_layers)-2}', nn.Linear(mlp_layers[-2], mlp_layers[-1], bias=False))
        self.model.add_module(f'layer{len(mlp_layers)-2}', last_layer)
        
#         for param in self.parameters():
#             if len(param.shape) > 1:
#                 nn.init.kaiming_normal_(param)
    
    def forward(self, X):
        u = self.encoder_u(X)
        v = self.encoder_v(X)
        
        for i in range(len(self.model) - 1):
            X = self.model[i](X)
            X = X / 2.
            X = (1 - X) * u + X * v
        return self.model[-1](X)

# %%
class MLP(nn.Module):
    def __init__(self, mlp_layers):
        super(MLP, self).__init__()
        
        self.model = nn.Sequential()
        for i in range(len(mlp_layers)-2):
            layer = nn.Sequential()
            layer.add_module(f'fc{i}', nn.Linear(mlp_layers[i], mlp_layers[i+1], bias=True))
            layer.add_module(f'act{i}', nn.Tanh())
            self.model.add_module(f'layer{i}', layer)

        last_layer = nn.Sequential()
        last_layer.add_module(f'fc{len(mlp_layers)-2}', nn.Linear(mlp_layers[-2], mlp_layers[-1], bias=False))
        self.model.add_module(f'layer{len(mlp_layers)-2}', last_layer)
        
#         for param in self.parameters():
#             if len(param.shape) > 1:
#                 nn.init.kaiming_normal_(param)
    
    def forward(self, X):
        return self.model(X)

# %%
backbone = ResNet(args.backbone_layers)
backbone = backbone.to(args.device)
args.backbone = backbone
print(args.backbone)
# Out:
# ResNet(
#   (model): Sequential(
#     (first): Sequential(
#       (fc0): Linear(in_features=51, out_features=60, bias=True)
#       (act0): Tanh()
#     )
#     (block1): Sequential(
#       (fc1_0): Linear(in_features=60, out_features=60, bias=True)
#       (act1_0): Tanh()
#       (fc1_1): Linear(in_features=60, out_features=60, bias=True)
#       (act1_1): Tanh()
#     )
#     (block2): Sequential(
#       (fc2_0): Linear(in_features=60, out_features=60, bias=True)
#       (act2_0): Tanh()
#       (fc2_1): Linear(in_features=60, out_features=60, bias=True)
#       (act2_1): Tanh()
#     )
#     (block3): Sequential(
#       (fc3_0): Linear(in_features=60, out_features=60, bias=True)
#       (act3_0): Tanh()
#       (fc3_1): Linear(in_features=60, out_features=60, bias=True)
#       (act3_1): Tanh()
#     )
#     (block4): Sequential(
#       (fc4_0): Linear(in_features=60, out_features=60, bias=True)
#       (act4_0): Tanh()
#       (fc4_1): Linear(in_features=60, out_features=60, bias=True)
#       (act4_1): Tanh()
#     )
#     (last): Sequential(
#       (fc5): Linear(in_features=60, out_features=1, bias=False)
#     )
#   )
# )

# %% [markdown]
# ## 数据集生成

# %%
class Dataset_KortewegdeVeriesHD:
    def __init__(self, bot_top, T, dim, device, N_max=100000):
        self.bot, self.top = bot_top
        self.T = T
        self.dim = dim
        self.device = device
        self.N_max = N_max
    
    def train_data(self, N_r, N_b, N_0):
        """训练点采样"""
        X_res = self.interior(N_r).to(self.device)
        X_bcs = self.boundary(N_b).to(self.device)
        X_ics = self.initial(N_0).to(self.device)
        f_res = self.func_res(X_res).to(self.device)
        u_bcs = self.func_bcs(X_bcs).to(self.device)
        u_ics = self.func_ics(X_ics).to(self.device)
        
        return X_res, X_bcs, X_ics, f_res, u_bcs, u_ics
    
    def interior(self, N_r):
        """内部点采样"""
        X_res = torch.Tensor(self.N_max, self.dim).uniform_(self.bot, self.top)
        idx = torch.randperm(self.N_max)
        idx = idx[:N_r]
        
        T = torch.Tensor(self.N_max, 1).uniform_(0, self.T)
        X_res = torch.cat([X_res[idx], T[idx]], dim=1)  # 拼接X和T
        return X_res
    
    def boundary(self, N_b):
        """边界点采样"""
        X_bcs = torch.Tensor(self.N_max, self.dim).uniform_(self.bot, self.top)
        bots = self.bot * torch.ones(1, 1)
        tops = self.top * torch.ones(1, 1)
        
        n = int(self.N_max / self.dim / 2)
        num = [n * i for i in range(2 * self.dim)]
        num[0] = 0
        num.append(self.N_max)
        
        for i in range(self.dim):  # 逐个维度设为下界bot 以及上界top 得到边界点
            X_bcs[num[2 * i]:num[2 * i + 1], i] = bots.repeat(num[2 * i + 1] - num[2 * i], 1).squeeze()
            X_bcs[num[2 * i + 1]:num[2 * i + 2], i] = tops.repeat(num[2 * i + 2] - num[2 * i + 1], 1).squeeze()

        idx = torch.randperm(self.N_max)
        idx = idx[:N_b]
        
        T = torch.Tensor(self.N_max, 1).uniform_(0, self.T)
        X_bcs = torch.cat([X_bcs[idx], T[idx]], dim=1)  # 拼接X和T
        return X_bcs
    
    def initial(self, N_0):
        """初始点采样"""
        X_ics = torch.Tensor(self.N_max, self.dim).uniform_(self.bot, self.top)
        idx = torch.randperm(self.N_max)
        idx = idx[:N_0]
        
        T = torch.Tensor(self.N_max, 1).fill_(0.)
        X_ics = torch.cat([X_ics[idx], T[idx]], dim=1)
        return X_ics
    
    def func_res(self, X_res):
        """控制方程右端项"""
        f = X_res[:, :self.dim].mean(axis=1, keepdims=True)
        f = (- 1 / self.dim**2) * (torch.sin(f) + torch.cos(f)) * torch.exp(- X_res[:, [-1]] / self.dim**2)
        return f
    
    def func_bcs(self, X_bcs):
        """边界条件右端项"""
        u_bcs = X_bcs[:, :self.dim].mean(axis=1, keepdims=True)
        u_bcs = torch.sin(u_bcs) * torch.exp(- X_bcs[:, [-1]] / self.dim**2)
        return u_bcs
    
    def func_ics(self, X_ics):
        """初始条件右端项"""
        u_ics = X_ics[:, :self.dim].mean(axis=1, keepdims=True)
        u_ics = torch.sin(u_ics)
        return u_ics


dataset = Dataset_KortewegdeVeriesHD(args.bot_top, args.T, args.dim, args.device)
args.dataset = dataset
X_res, X_bcs, X_ics, f_res, u_bcs, u_ics = dataset.train_data(args.N_r, args.N_b, args.N_0)
print(X_res.shape, X_bcs.shape, X_ics.shape, f_res.shape, u_bcs.shape, u_ics.shape)
# Out:
# torch.Size([2400, 51]) torch.Size([1200, 51]) torch.Size([1200, 51]) torch.Size([2400, 1]) torch.Size([1200, 1]) torch.Size([1200, 1])

# %% [markdown]
# ## 训练

# %%
class Trainer_KortewegdeVeriesHD:
    def __init__(self, args):
        self.args = args
        self.dim = args.dim
        self.device = args.device
        
        self.N_r = args.N_r
        self.N_b = args.N_b
        self.N_0 = args.N_0
        self.dataset = args.dataset
        
        self.lam_res = args.lam_res
        self.lam_bcs = args.lam_bcs
        self.lam_ics = args.lam_ics
        self.gamma = args.gamma
        self.backbone = args.backbone
        
        self.model_name = self.backbone.__class__.__name__
        self.model_path = self.get_model_path()
        
        self.iters_Adam = args.iters_Adam

        # eps = np.finfo(np.float32).eps
        self.optimizer_Adam = optim.Adam(self.backbone.parameters(), lr=args.backbone_lr, betas=(0.9, 0.999))
        
        self.step_size = args.step_size#int( self.iters_stage4 / (np.log(1e-3) / np.log(self.gamma)) )
        self.scheduler = ExponentialLR(self.optimizer_Adam, gamma=self.gamma, verbose=True)
        
        # data
        self.X_res, self.X_bcs, self.X_ics, self.f_res, self.u_bcs, self.u_ics = self.dataset.train_data(self.N_r, self.N_b, self.N_0)
        
        # Logger
        self.logger = {
            "loss": [],
            "loss_res": [],
            "loss_bcs": [],
            "loss_ics": [],
            "iter": []
        }
        
        self.logger_valid = {
            "loss": [],
            "loss_res": [],
            "loss_bcs": [],
            "loss_ics": [],
            "iter": [],
            "error": []
        }
        
    def get_model_path(self):
        # 保存模型的路径
        if not os.path.exists('models'):
            os.mkdir('models')
        
        path = os.path.join('models', self.model_name)
        if not os.path.exists(path):
            os.mkdir(path)
        
        return path
        
    def update_train_data(self):
        # 更新采样点
        self.X_res, self.X_bcs, self.X_ics, self.f_res, self.u_bcs, self.u_ics = self.dataset.train_data(self.N_r, self.N_b, self.N_0)

    def net_u(self, X):
        return self.backbone(X)

    def net_r(self, xt):
        xt.requires_grad_(True)
        
        u = self.net_u(xt)
        grad_u = grad(u, xt)[0]
        
        u_t = grad_u[:, [-1]]
        u_xxx = torch.zeros(u.shape).to(self.device)
        for i in range(self.dim):
            u_x_i = grad_u[:, [i]]
            u_xx_i = grad(u_x_i, xt)[0][:, [i]]
            u_xxx_i = grad(u_xx_i, xt)[0][:, [i]]
            u_xxx += u_xxx_i
        return u_t + u_xxx
    
    def compute_loss(self):
        f_res_pred = self.net_r(self.X_res)
        self.loss_res = torch.mean((f_res_pred - self.f_res) ** 2)

        u_bcs_pred = self.net_u(self.X_bcs)
        self.loss_bcs = torch.mean((u_bcs_pred - self.u_bcs) ** 2)

        u_ics_pred = self.net_u(self.X_ics)
        self.loss_ics = torch.mean((u_ics_pred - self.u_ics) ** 2)

        self.loss = self.lam_res * self.loss_res + self.lam_bcs * self.loss_bcs + self.lam_ics * self.loss_ics

    def log_loss(self):
        # 记录当前loss至logger字典
        self.logger["loss"].append(self.loss.item())
        self.logger["loss_res"].append(self.loss_res.item())
        self.logger["loss_bcs"].append(self.loss_bcs.item())
        self.logger["loss_ics"].append(self.loss_ics.item())
        self.logger["iter"].append(self.iter + 1)

    def log_info(self):
        # 保存并打印训练信息
        info = f'Iter {self.iter+1:5d} Time:{time.time()-self.start_time:.1e} # ' + \
               f'Loss:{self.loss.item():.2e}, Loss_r:{self.loss_res.item():.2e}, Loss_b:{self.loss_bcs.item():.2e}, Loss_0:{self.loss_ics.item():.2e} # ' + \
               f'Valid:{self.valid_loss_value:.2e}, RL2:{self.error_u:.2e}'
        with open("train_info.txt", 'a') as f:
            f.write(info + '\n')
        print(info)
        
    def compute_rl2(self, X_res):
        """计算relative L2 error"""
        u_star = X_res[:, :self.dim].mean(axis=1, keepdims=True)  # 计算解析解
        u_star = torch.sin(u_star) * torch.exp(- X_res[:, [-1]] / self.dim**2)
        u_star = u_star.detach().cpu().numpy()
        
        u_pred = self.net_u(X_res)  # 计算预测解
        u_pred = u_pred.detach().cpu().numpy()
        
        error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)  # rl2 error
        return error_u

    def valid(self):
        """验证并保存最优模型"""
        # 计算loss
        X_res, X_bcs, X_ics, f_res, u_bcs, u_ics = self.dataset.train_data(1000, 1000, 1000)
        self.backbone.eval()
        # 不经过transformer的loss
        f_res_pred = self.net_r(X_res)
        u_bcs_pred = self.net_u(X_bcs)
        u_ics_pred = self.net_u(X_ics)
        loss_res = torch.mean((f_res_pred - f_res) ** 2)
        loss_bcs = torch.mean((u_bcs_pred - u_bcs) ** 2)
        loss_ics = torch.mean((u_ics_pred - u_ics) ** 2)
        loss = self.lam_res * loss_res + self.lam_bcs * loss_bcs + self.lam_ics * loss_ics
        
        # 计算relative l2 error
        self.error_u = self.compute_rl2(X_res)
        
        self.backbone.train()
        
        # 记录valid的loss和rl2 error信息
        self.logger_valid["loss"].append(loss.item())
        self.logger_valid["loss_res"].append(loss_res.item())
        self.logger_valid["loss_bcs"].append(loss_bcs.item())
        self.logger_valid["loss_ics"].append(loss_ics.item())
        self.logger_valid["iter"].append(self.iter + 1)
        self.logger_valid["error"].append(self.error_u)
        
        # 验证模型loss是否最优并选择保存
        self.valid_loss_value = loss.item()
        is_best = self.valid_loss_value < self.best_loss
        if is_best:
            self.best_loss = self.valid_loss_value
        state = {
            'iter': self.iter,
            'state_dict': self.backbone.state_dict(),
            'best_loss': self.best_loss
        }
        save_model(state, is_best, save_dir=self.model_path)
    
    def train(self):
        self.start_time = time.time()
        self.best_loss = 1.e10
        
        self.iter = 0
        for _ in range(self.iters_Adam):
            self.optimizer_Adam.zero_grad()
            self.compute_loss()
            self.loss.backward()
            self.optimizer_Adam.step()
            self.log_loss()

            if (self.iter + 1) % 100 == 0:
                self.valid()
                self.log_info()
                self.update_train_data()

            if (self.iter + 1) % self.step_size == 0:
                self.scheduler.step()
            self.iter += 1
            
            
trainer = Trainer_KortewegdeVeriesHD(args)
# Out:
# Adjusting learning rate of group 0 to 1.0000e-03.

# %%
trainer.train()
# Out:
# Iter   100 Time:2.8e+01 # Loss:1.84e-04, Loss_r:2.80e-05, Loss_b:9.47e-05, Loss_0:6.11e-05 # Valid:1.85e-04, RL2:1.19e-01
# Iter   200 Time:5.5e+01 # Loss:1.16e-04, Loss_r:1.59e-05, Loss_b:5.63e-05, Loss_0:4.42e-05 # Valid:1.23e-04, RL2:8.90e-02
# Iter   300 Time:8.1e+01 # Loss:8.36e-05, Loss_r:1.12e-05, Loss_b:3.70e-05, Loss_0:3.54e-05 # Valid:8.73e-05, RL2:7.67e-02
# Iter   400 Time:1.1e+02 # Loss:6.58e-05, Loss_r:9.70e-06, Loss_b:2.84e-05, Loss_0:2.77e-05 # Valid:7.59e-05, RL2:6.93e-02
# Iter   500 Time:1.3e+02 # Loss:5.96e-05, Loss_r:7.47e-06, Loss_b:2.67e-05, Loss_0:2.55e-05 # Valid:6.33e-05, RL2:6.31e-02
# Iter   600 Time:1.6e+02 # Loss:4.84e-05, Loss_r:6.20e-06, Loss_b:2.22e-05, Loss_0:2.00e-05 # Valid:5.47e-05, RL2:5.69e-02
# Iter   700 Time:1.9e+02 # Loss:4.16e-05, Loss_r:5.10e-06, Loss_b:1.89e-05, Loss_0:1.76e-05 # Valid:4.89e-05, RL2:5.40e-02
# Iter   800 Time:2.1e+02 # Loss:3.80e-05, Loss_r:4.55e-06, Loss_b:1.74e-05, Loss_0:1.61e-05 # Valid:4.11e-05, RL2:4.89e-02
# Iter   900 Time:2.4e+02 # Loss:3.52e-05, Loss_r:4.15e-06, Loss_b:1.68e-05, Loss_0:1.42e-05 # Valid:3.72e-05, RL2:4.73e-02
# Iter  1000 Time:2.6e+02 # Loss:2.99e-05, Loss_r:3.52e-06, Loss_b:1.42e-05, Loss_0:1.23e-05 # Valid:3.28e-05, RL2:4.55e-02
# Adjusting learning rate of group 0 to 9.5000e-04.
# Iter  1100 Time:2.9e+02 # Loss:2.73e-05, Loss_r:3.37e-06, Loss_b:1.24e-05, Loss_0:1.15e-05 # Valid:2.86e-05, RL2:4.50e-02
# Iter  1200 Time:3.1e+02 # Loss:2.42e-05, Loss_r:2.86e-06, Loss_b:1.12e-05, Loss_0:1.01e-05 # Valid:2.71e-05, RL2:4.03e-02
# Iter  1300 Time:3.4e+02 # Loss:2.20e-05, Loss_r:2.69e-06, Loss_b:9.91e-06, Loss_0:9.40e-06 # Valid:2.42e-05, RL2:4.00e-02
# Iter  1400 Time:3.7e+02 # Loss:1.96e-05, Loss_r:2.44e-06, Loss_b:8.73e-06, Loss_0:8.42e-06 # Valid:2.05e-05, RL2:3.82e-02
# Iter  1500 Time:3.9e+02 # Loss:1.79e-05, Loss_r:2.27e-06, Loss_b:8.45e-06, Loss_0:7.14e-06 # Valid:2.00e-05, RL2:3.78e-02
# Iter  1600 Time:4.2e+02 # Loss:1.73e-05, Loss_r:2.04e-06, Loss_b:8.21e-06, Loss_0:7.09e-06 # Valid:1.85e-05, RL2:3.79e-02
# Iter  1700 Time:4.5e+02 # Loss:1.55e-05, Loss_r:1.78e-06, Loss_b:7.34e-06, Loss_0:6.39e-06 # Valid:1.70e-05, RL2:3.32e-02
# Iter  1800 Time:4.8e+02 # Loss:1.43e-05, Loss_r:1.84e-06, Loss_b:6.48e-06, Loss_0:5.94e-06 # Valid:1.64e-05, RL2:3.12e-02
# Iter  1900 Time:5.0e+02 # Loss:1.26e-05, Loss_r:1.64e-06, Loss_b:5.61e-06, Loss_0:5.31e-06 # Valid:1.43e-05, RL2:3.03e-02
# Iter  2000 Time:5.3e+02 # Loss:1.21e-05, Loss_r:1.50e-06, Loss_b:5.44e-06, Loss_0:5.19e-06 # Valid:1.33e-05, RL2:2.83e-02
# Adjusting learning rate of group 0 to 9.0250e-04.
# Iter  2100 Time:5.6e+02 # Loss:1.09e-05, Loss_r:1.39e-06, Loss_b:5.08e-06, Loss_0:4.40e-06 # Valid:1.21e-05, RL2:2.88e-02
# Iter  2200 Time:5.8e+02 # Loss:1.06e-05, Loss_r:1.36e-06, Loss_b:4.83e-06, Loss_0:4.45e-06 # Valid:1.11e-05, RL2:2.74e-02
# Iter  2300 Time:6.1e+02 # Loss:9.39e-06, Loss_r:1.26e-06, Loss_b:4.09e-06, Loss_0:4.05e-06 # Valid:1.07e-05, RL2:2.43e-02
# Iter  2400 Time:6.4e+02 # Loss:8.01e-06, Loss_r:1.12e-06, Loss_b:3.38e-06, Loss_0:3.51e-06 # Valid:1.03e-05, RL2:2.46e-02
# Iter  2500 Time:6.6e+02 # Loss:9.64e-06, Loss_r:1.09e-06, Loss_b:4.61e-06, Loss_0:3.94e-06 # Valid:9.24e-06, RL2:2.34e-02
# Iter  2600 Time:6.9e+02 # Loss:8.02e-06, Loss_r:9.97e-07, Loss_b:3.53e-06, Loss_0:3.48e-06 # Valid:8.25e-06, RL2:2.26e-02
# Iter  2700 Time:7.2e+02 # Loss:7.24e-06, Loss_r:9.09e-07, Loss_b:3.29e-06, Loss_0:3.04e-06 # Valid:8.42e-06, RL2:2.22e-02
# Iter  2800 Time:7.5e+02 # Loss:6.69e-06, Loss_r:8.94e-07, Loss_b:3.03e-06, Loss_0:2.77e-06 # Valid:6.99e-06, RL2:2.12e-02
# Iter  2900 Time:7.7e+02 # Loss:1.05e-05, Loss_r:8.04e-07, Loss_b:4.69e-06, Loss_0:4.98e-06 # Valid:1.24e-05, RL2:3.02e-02
# Iter  3000 Time:8.0e+02 # Loss:5.35e-06, Loss_r:7.86e-07, Loss_b:2.49e-06, Loss_0:2.07e-06 # Valid:6.30e-06, RL2:1.89e-02
# Adjusting learning rate of group 0 to 8.5737e-04.
# Iter  3100 Time:8.3e+02 # Loss:5.25e-06, Loss_r:7.64e-07, Loss_b:2.34e-06, Loss_0:2.15e-06 # Valid:6.07e-06, RL2:2.01e-02
# Iter  3200 Time:8.5e+02 # Loss:4.73e-06, Loss_r:6.89e-07, Loss_b:2.23e-06, Loss_0:1.82e-06 # Valid:5.26e-06, RL2:1.97e-02
# Iter  3300 Time:8.8e+02 # Loss:4.59e-06, Loss_r:6.17e-07, Loss_b:2.19e-06, Loss_0:1.78e-06 # Valid:4.72e-06, RL2:1.84e-02
# Iter  3400 Time:9.1e+02 # Loss:4.27e-06, Loss_r:6.06e-07, Loss_b:1.99e-06, Loss_0:1.68e-06 # Valid:4.44e-06, RL2:1.75e-02
# Iter  3500 Time:9.4e+02 # Loss:3.95e-06, Loss_r:5.48e-07, Loss_b:1.76e-06, Loss_0:1.65e-06 # Valid:4.37e-06, RL2:1.69e-02
# Iter  3600 Time:9.6e+02 # Loss:3.71e-06, Loss_r:5.49e-07, Loss_b:1.67e-06, Loss_0:1.49e-06 # Valid:3.83e-06, RL2:1.56e-02
# Iter  3700 Time:9.9e+02 # Loss:3.44e-06, Loss_r:5.01e-07, Loss_b:1.50e-06, Loss_0:1.44e-06 # Valid:3.98e-06, RL2:1.55e-02
# Iter  3800 Time:1.0e+03 # Loss:7.86e-06, Loss_r:4.78e-07, Loss_b:4.03e-06, Loss_0:3.34e-06 # Valid:8.25e-06, RL2:2.36e-02
# Iter  3900 Time:1.0e+03 # Loss:3.11e-06, Loss_r:4.72e-07, Loss_b:1.39e-06, Loss_0:1.24e-06 # Valid:3.39e-06, RL2:1.52e-02
# Iter  4000 Time:1.1e+03 # Loss:6.42e-05, Loss_r:5.40e-07, Loss_b:3.34e-05, Loss_0:3.02e-05 # Valid:5.56e-05, RL2:6.42e-02
# Adjusting learning rate of group 0 to 8.1451e-04.
# Iter  4100 Time:1.1e+03 # Loss:2.73e-06, Loss_r:4.29e-07, Loss_b:1.29e-06, Loss_0:1.01e-06 # Valid:3.17e-06, RL2:1.38e-02
# Iter  4200 Time:1.1e+03 # Loss:2.57e-06, Loss_r:3.96e-07, Loss_b:1.12e-06, Loss_0:1.05e-06 # Valid:2.92e-06, RL2:1.38e-02
# Iter  4300 Time:1.2e+03 # Loss:2.36e-06, Loss_r:3.74e-07, Loss_b:1.06e-06, Loss_0:9.25e-07 # Valid:2.69e-06, RL2:1.26e-02
# Iter  4400 Time:1.2e+03 # Loss:2.43e-06, Loss_r:3.67e-07, Loss_b:1.02e-06, Loss_0:1.04e-06 # Valid:2.60e-06, RL2:1.25e-02
# Iter  4500 Time:1.2e+03 # Loss:2.14e-06, Loss_r:3.37e-07, Loss_b:9.55e-07, Loss_0:8.48e-07 # Valid:2.37e-06, RL2:1.27e-02
# Iter  4600 Time:1.2e+03 # Loss:2.08e-06, Loss_r:3.19e-07, Loss_b:8.77e-07, Loss_0:8.88e-07 # Valid:2.25e-06, RL2:1.20e-02
# Iter  4700 Time:1.3e+03 # Loss:1.91e-06, Loss_r:3.35e-07, Loss_b:8.42e-07, Loss_0:7.31e-07 # Valid:2.26e-06, RL2:1.11e-02
# Iter  4800 Time:1.3e+03 # Loss:2.01e-06, Loss_r:3.42e-07, Loss_b:8.37e-07, Loss_0:8.30e-07 # Valid:2.40e-06, RL2:1.08e-02
# Iter  4900 Time:1.3e+03 # Loss:1.63e-06, Loss_r:2.98e-07, Loss_b:6.95e-07, Loss_0:6.38e-07 # Valid:1.89e-06, RL2:1.09e-02
# Iter  5000 Time:1.3e+03 # Loss:2.66e-05, Loss_r:2.80e-07, Loss_b:1.35e-05, Loss_0:1.28e-05 # Valid:6.54e-06, RL2:2.18e-02
# Adjusting learning rate of group 0 to 7.7378e-04.
# Iter  5100 Time:1.4e+03 # Loss:1.53e-06, Loss_r:2.73e-07, Loss_b:6.52e-07, Loss_0:6.00e-07 # Valid:1.70e-06, RL2:1.02e-02
# Iter  5200 Time:1.4e+03 # Loss:1.44e-06, Loss_r:2.61e-07, Loss_b:6.29e-07, Loss_0:5.52e-07 # Valid:1.64e-06, RL2:1.02e-02
# Iter  5300 Time:1.4e+03 # Loss:1.54e-06, Loss_r:2.52e-07, Loss_b:6.48e-07, Loss_0:6.39e-07 # Valid:1.63e-06, RL2:9.96e-03
# Iter  5400 Time:1.5e+03 # Loss:1.34e-06, Loss_r:2.37e-07, Loss_b:5.87e-07, Loss_0:5.19e-07 # Valid:1.53e-06, RL2:9.34e-03
# Iter  5500 Time:1.5e+03 # Loss:1.34e-06, Loss_r:2.03e-07, Loss_b:6.08e-07, Loss_0:5.29e-07 # Valid:1.84e-06, RL2:1.21e-02
# Iter  5600 Time:1.5e+03 # Loss:1.15e-06, Loss_r:2.01e-07, Loss_b:4.90e-07, Loss_0:4.58e-07 # Valid:1.23e-06, RL2:9.19e-03
# Iter  5700 Time:1.5e+03 # Loss:1.11e-06, Loss_r:2.00e-07, Loss_b:4.75e-07, Loss_0:4.36e-07 # Valid:1.27e-06, RL2:8.45e-03
# Iter  5800 Time:1.6e+03 # Loss:1.13e-06, Loss_r:1.97e-07, Loss_b:4.89e-07, Loss_0:4.48e-07 # Valid:1.43e-06, RL2:9.76e-03
# Iter  5900 Time:1.6e+03 # Loss:9.39e-07, Loss_r:1.81e-07, Loss_b:4.15e-07, Loss_0:3.43e-07 # Valid:1.09e-06, RL2:7.98e-03
# Iter  6000 Time:1.6e+03 # Loss:9.50e-07, Loss_r:1.60e-07, Loss_b:4.18e-07, Loss_0:3.72e-07 # Valid:1.01e-06, RL2:8.52e-03
# Adjusting learning rate of group 0 to 7.3509e-04.
# Iter  6100 Time:1.6e+03 # Loss:8.59e-07, Loss_r:1.45e-07, Loss_b:3.69e-07, Loss_0:3.45e-07 # Valid:1.04e-06, RL2:8.35e-03
# Iter  6200 Time:1.7e+03 # Loss:8.76e-07, Loss_r:1.42e-07, Loss_b:3.86e-07, Loss_0:3.47e-07 # Valid:9.83e-07, RL2:8.01e-03
# Iter  6300 Time:1.7e+03 # Loss:7.83e-07, Loss_r:1.35e-07, Loss_b:3.41e-07, Loss_0:3.07e-07 # Valid:8.63e-07, RL2:7.66e-03
# Iter  6400 Time:1.7e+03 # Loss:7.74e-07, Loss_r:1.43e-07, Loss_b:3.31e-07, Loss_0:3.01e-07 # Valid:8.80e-07, RL2:7.60e-03
# Iter  6500 Time:1.8e+03 # Loss:3.47e-06, Loss_r:1.41e-07, Loss_b:1.55e-06, Loss_0:1.78e-06 # Valid:3.07e-06, RL2:1.60e-02
# Iter  6600 Time:1.8e+03 # Loss:6.59e-07, Loss_r:1.11e-07, Loss_b:2.89e-07, Loss_0:2.58e-07 # Valid:7.38e-07, RL2:7.02e-03
# Iter  6700 Time:1.8e+03 # Loss:6.62e-07, Loss_r:1.10e-07, Loss_b:2.76e-07, Loss_0:2.76e-07 # Valid:7.94e-07, RL2:7.11e-03
# Iter  6800 Time:1.8e+03 # Loss:6.36e-07, Loss_r:1.11e-07, Loss_b:2.68e-07, Loss_0:2.57e-07 # Valid:7.90e-07, RL2:6.54e-03
# Iter  6900 Time:1.9e+03 # Loss:7.34e-07, Loss_r:1.04e-07, Loss_b:3.24e-07, Loss_0:3.06e-07 # Valid:1.00e-06, RL2:7.44e-03
# Iter  7000 Time:1.9e+03 # Loss:6.58e-07, Loss_r:8.71e-08, Loss_b:2.88e-07, Loss_0:2.83e-07 # Valid:9.50e-07, RL2:8.01e-03
# Adjusting learning rate of group 0 to 6.9834e-04.
# Iter  7100 Time:1.9e+03 # Loss:5.60e-07, Loss_r:9.69e-08, Loss_b:2.36e-07, Loss_0:2.27e-07 # Valid:6.01e-07, RL2:6.07e-03
# Iter  7200 Time:1.9e+03 # Loss:5.61e-07, Loss_r:9.04e-08, Loss_b:2.50e-07, Loss_0:2.20e-07 # Valid:6.07e-07, RL2:5.91e-03
# Iter  7300 Time:2.0e+03 # Loss:4.54e-07, Loss_r:7.71e-08, Loss_b:2.08e-07, Loss_0:1.70e-07 # Valid:5.84e-07, RL2:5.75e-03
# Iter  7400 Time:2.0e+03 # Loss:4.62e-07, Loss_r:7.59e-08, Loss_b:2.05e-07, Loss_0:1.81e-07 # Valid:5.66e-07, RL2:5.92e-03
# Iter  7500 Time:2.0e+03 # Loss:4.95e-07, Loss_r:7.88e-08, Loss_b:2.17e-07, Loss_0:1.99e-07 # Valid:5.34e-07, RL2:5.64e-03
# Iter  7600 Time:2.0e+03 # Loss:4.19e-07, Loss_r:7.36e-08, Loss_b:1.88e-07, Loss_0:1.58e-07 # Valid:5.90e-07, RL2:6.31e-03
# Iter  7700 Time:2.1e+03 # Loss:4.34e-07, Loss_r:6.88e-08, Loss_b:2.04e-07, Loss_0:1.61e-07 # Valid:4.52e-07, RL2:5.33e-03
# Iter  7800 Time:2.1e+03 # Loss:1.81e-06, Loss_r:6.66e-08, Loss_b:9.65e-07, Loss_0:7.77e-07 # Valid:1.79e-06, RL2:1.07e-02
# Iter  7900 Time:2.1e+03 # Loss:3.89e-07, Loss_r:6.52e-08, Loss_b:1.76e-07, Loss_0:1.47e-07 # Valid:4.27e-07, RL2:5.06e-03
# Iter  8000 Time:2.2e+03 # Loss:4.37e-07, Loss_r:5.74e-08, Loss_b:2.12e-07, Loss_0:1.68e-07 # Valid:5.56e-07, RL2:6.19e-03
# Adjusting learning rate of group 0 to 6.6342e-04.
# Iter  8100 Time:2.2e+03 # Loss:3.79e-07, Loss_r:5.83e-08, Loss_b:1.74e-07, Loss_0:1.47e-07 # Valid:4.31e-07, RL2:5.56e-03
# Iter  8200 Time:2.2e+03 # Loss:3.64e-07, Loss_r:6.34e-08, Loss_b:1.55e-07, Loss_0:1.45e-07 # Valid:3.75e-07, RL2:4.74e-03
# Iter  8300 Time:2.2e+03 # Loss:3.20e-07, Loss_r:5.48e-08, Loss_b:1.43e-07, Loss_0:1.22e-07 # Valid:4.20e-07, RL2:5.02e-03
# Iter  8400 Time:2.3e+03 # Loss:3.80e-07, Loss_r:5.17e-08, Loss_b:1.74e-07, Loss_0:1.55e-07 # Valid:4.36e-07, RL2:5.08e-03
# Iter  8500 Time:2.3e+03 # Loss:6.26e-06, Loss_r:5.76e-08, Loss_b:3.28e-06, Loss_0:2.92e-06 # Valid:6.78e-06, RL2:2.31e-02
# Iter  8600 Time:2.3e+03 # Loss:2.87e-07, Loss_r:4.89e-08, Loss_b:1.25e-07, Loss_0:1.14e-07 # Valid:3.42e-07, RL2:4.90e-03
# Iter  8700 Time:2.3e+03 # Loss:3.02e-07, Loss_r:5.19e-08, Loss_b:1.37e-07, Loss_0:1.13e-07 # Valid:3.14e-07, RL2:4.52e-03
# Iter  8800 Time:2.4e+03 # Loss:2.84e-07, Loss_r:4.43e-08, Loss_b:1.25e-07, Loss_0:1.14e-07 # Valid:2.92e-07, RL2:4.49e-03
# Iter  8900 Time:2.4e+03 # Loss:9.07e-07, Loss_r:4.35e-08, Loss_b:4.47e-07, Loss_0:4.17e-07 # Valid:1.27e-06, RL2:9.77e-03
# Iter  9000 Time:2.4e+03 # Loss:2.60e-07, Loss_r:4.46e-08, Loss_b:1.23e-07, Loss_0:9.24e-08 # Valid:2.99e-07, RL2:4.52e-03
# Adjusting learning rate of group 0 to 6.3025e-04.
# Iter  9100 Time:2.5e+03 # Loss:2.38e-07, Loss_r:3.84e-08, Loss_b:1.11e-07, Loss_0:8.91e-08 # Valid:2.51e-07, RL2:4.39e-03
# Iter  9200 Time:2.5e+03 # Loss:2.24e-07, Loss_r:3.62e-08, Loss_b:1.10e-07, Loss_0:7.80e-08 # Valid:2.84e-07, RL2:4.03e-03
# Iter  9300 Time:2.5e+03 # Loss:2.30e-07, Loss_r:4.08e-08, Loss_b:1.03e-07, Loss_0:8.56e-08 # Valid:2.36e-07, RL2:4.15e-03
# Iter  9400 Time:2.5e+03 # Loss:2.02e-07, Loss_r:3.54e-08, Loss_b:9.30e-08, Loss_0:7.33e-08 # Valid:2.41e-07, RL2:3.71e-03
# Iter  9500 Time:2.6e+03 # Loss:2.10e-07, Loss_r:3.43e-08, Loss_b:1.01e-07, Loss_0:7.46e-08 # Valid:2.50e-07, RL2:4.01e-03
# Iter  9600 Time:2.6e+03 # Loss:1.83e-07, Loss_r:3.37e-08, Loss_b:8.27e-08, Loss_0:6.68e-08 # Valid:2.35e-07, RL2:3.84e-03
# Iter  9700 Time:2.6e+03 # Loss:1.90e-07, Loss_r:3.25e-08, Loss_b:8.95e-08, Loss_0:6.84e-08 # Valid:2.17e-07, RL2:3.78e-03
# Iter  9800 Time:2.7e+03 # Loss:4.54e-07, Loss_r:2.77e-08, Loss_b:2.28e-07, Loss_0:1.98e-07 # Valid:4.64e-07, RL2:5.19e-03
# Iter  9900 Time:2.7e+03 # Loss:1.91e-07, Loss_r:3.24e-08, Loss_b:9.19e-08, Loss_0:6.69e-08 # Valid:2.08e-07, RL2:3.68e-03
# Iter 10000 Time:2.7e+03 # Loss:1.65e-07, Loss_r:2.84e-08, Loss_b:7.37e-08, Loss_0:6.34e-08 # Valid:2.28e-07, RL2:3.48e-03
# Adjusting learning rate of group 0 to 5.9874e-04.
# Iter 10100 Time:2.7e+03 # Loss:1.61e-07, Loss_r:2.91e-08, Loss_b:7.02e-08, Loss_0:6.15e-08 # Valid:1.97e-07, RL2:3.66e-03
# Iter 10200 Time:2.8e+03 # Loss:1.56e-07, Loss_r:2.58e-08, Loss_b:7.08e-08, Loss_0:5.92e-08 # Valid:1.82e-07, RL2:3.77e-03
# Iter 10300 Time:2.8e+03 # Loss:1.51e-07, Loss_r:2.55e-08, Loss_b:6.81e-08, Loss_0:5.71e-08 # Valid:1.68e-07, RL2:3.36e-03
# Iter 10400 Time:2.8e+03 # Loss:1.51e-07, Loss_r:2.53e-08, Loss_b:6.84e-08, Loss_0:5.74e-08 # Valid:1.77e-07, RL2:3.48e-03
# Iter 10500 Time:2.8e+03 # Loss:7.13e-07, Loss_r:2.58e-08, Loss_b:3.28e-07, Loss_0:3.60e-07 # Valid:7.12e-07, RL2:6.99e-03
# Iter 10600 Time:2.9e+03 # Loss:1.21e-07, Loss_r:2.20e-08, Loss_b:5.35e-08, Loss_0:4.57e-08 # Valid:1.65e-07, RL2:3.27e-03
# Iter 10700 Time:2.9e+03 # Loss:1.32e-07, Loss_r:2.38e-08, Loss_b:6.20e-08, Loss_0:4.64e-08 # Valid:1.71e-07, RL2:3.08e-03
# Iter 10800 Time:2.9e+03 # Loss:1.20e-07, Loss_r:2.15e-08, Loss_b:5.47e-08, Loss_0:4.33e-08 # Valid:1.45e-07, RL2:3.26e-03
# Iter 10900 Time:3.0e+03 # Loss:4.40e-06, Loss_r:2.20e-08, Loss_b:2.19e-06, Loss_0:2.19e-06 # Valid:5.85e-06, RL2:2.10e-02
# Iter 11000 Time:3.0e+03 # Loss:1.15e-07, Loss_r:1.96e-08, Loss_b:4.88e-08, Loss_0:4.69e-08 # Valid:1.69e-07, RL2:3.16e-03
# Adjusting learning rate of group 0 to 5.6880e-04.
# Iter 11100 Time:3.0e+03 # Loss:1.13e-07, Loss_r:1.95e-08, Loss_b:4.98e-08, Loss_0:4.41e-08 # Valid:1.21e-07, RL2:3.05e-03
# Iter 11200 Time:3.0e+03 # Loss:1.08e-07, Loss_r:1.91e-08, Loss_b:4.41e-08, Loss_0:4.43e-08 # Valid:1.32e-07, RL2:2.94e-03
# Iter 11300 Time:3.1e+03 # Loss:1.90e-07, Loss_r:1.85e-08, Loss_b:8.85e-08, Loss_0:8.27e-08 # Valid:2.21e-07, RL2:3.80e-03
# Iter 11400 Time:3.1e+03 # Loss:1.53e-07, Loss_r:1.76e-08, Loss_b:7.48e-08, Loss_0:6.06e-08 # Valid:1.90e-07, RL2:4.00e-03
# Iter 11500 Time:3.1e+03 # Loss:1.32e-06, Loss_r:1.65e-08, Loss_b:6.72e-07, Loss_0:6.32e-07 # Valid:1.58e-06, RL2:1.07e-02
# Iter 11600 Time:3.1e+03 # Loss:9.46e-08, Loss_r:1.67e-08, Loss_b:4.23e-08, Loss_0:3.57e-08 # Valid:1.09e-07, RL2:2.69e-03
# Iter 11700 Time:3.2e+03 # Loss:5.66e-07, Loss_r:1.58e-08, Loss_b:2.70e-07, Loss_0:2.80e-07 # Valid:3.64e-07, RL2:5.19e-03
# Iter 11800 Time:3.2e+03 # Loss:2.32e-07, Loss_r:1.45e-08, Loss_b:1.09e-07, Loss_0:1.08e-07 # Valid:1.84e-07, RL2:3.59e-03
# Iter 11900 Time:3.2e+03 # Loss:7.84e-08, Loss_r:1.46e-08, Loss_b:3.49e-08, Loss_0:2.89e-08 # Valid:1.09e-07, RL2:2.68e-03
# Iter 12000 Time:3.3e+03 # Loss:8.50e-08, Loss_r:1.43e-08, Loss_b:3.75e-08, Loss_0:3.33e-08 # Valid:9.91e-08, RL2:2.50e-03
# Adjusting learning rate of group 0 to 5.4036e-04.
# Iter 12100 Time:3.3e+03 # Loss:7.93e-08, Loss_r:1.32e-08, Loss_b:3.53e-08, Loss_0:3.07e-08 # Valid:9.37e-08, RL2:2.31e-03
# Iter 12200 Time:3.3e+03 # Loss:7.46e-08, Loss_r:1.24e-08, Loss_b:3.41e-08, Loss_0:2.81e-08 # Valid:8.79e-08, RL2:2.43e-03
# Iter 12300 Time:3.4e+03 # Loss:7.63e-08, Loss_r:1.28e-08, Loss_b:3.68e-08, Loss_0:2.68e-08 # Valid:8.97e-08, RL2:2.37e-03
# Iter 12400 Time:3.4e+03 # Loss:7.30e-08, Loss_r:1.26e-08, Loss_b:3.29e-08, Loss_0:2.75e-08 # Valid:8.84e-08, RL2:2.28e-03
# Iter 12500 Time:3.4e+03 # Loss:7.11e-08, Loss_r:1.10e-08, Loss_b:3.40e-08, Loss_0:2.61e-08 # Valid:8.96e-08, RL2:2.41e-03
# Iter 12600 Time:3.4e+03 # Loss:1.26e-07, Loss_r:1.11e-08, Loss_b:6.03e-08, Loss_0:5.51e-08 # Valid:1.79e-07, RL2:3.53e-03
# Iter 12700 Time:3.5e+03 # Loss:7.22e-08, Loss_r:1.05e-08, Loss_b:3.27e-08, Loss_0:2.90e-08 # Valid:1.07e-07, RL2:2.61e-03
# Iter 12800 Time:3.5e+03 # Loss:6.76e-08, Loss_r:1.22e-08, Loss_b:2.99e-08, Loss_0:2.55e-08 # Valid:8.75e-08, RL2:2.30e-03
# Iter 12900 Time:3.5e+03 # Loss:6.11e-08, Loss_r:1.06e-08, Loss_b:2.77e-08, Loss_0:2.29e-08 # Valid:7.49e-08, RL2:2.08e-03
# Iter 13000 Time:3.6e+03 # Loss:4.94e-07, Loss_r:1.09e-08, Loss_b:2.51e-07, Loss_0:2.31e-07 # Valid:7.15e-07, RL2:7.43e-03
# Adjusting learning rate of group 0 to 5.1334e-04.
# Iter 13100 Time:3.6e+03 # Loss:5.13e-08, Loss_r:9.23e-09, Loss_b:2.30e-08, Loss_0:1.90e-08 # Valid:5.94e-08, RL2:2.12e-03
# Iter 13200 Time:3.6e+03 # Loss:1.32e-07, Loss_r:9.48e-09, Loss_b:6.32e-08, Loss_0:5.92e-08 # Valid:1.53e-07, RL2:3.42e-03
# Iter 13300 Time:3.7e+03 # Loss:1.80e-07, Loss_r:8.14e-09, Loss_b:8.87e-08, Loss_0:8.36e-08 # Valid:2.51e-07, RL2:4.37e-03
# Iter 13400 Time:3.7e+03 # Loss:5.03e-08, Loss_r:9.42e-09, Loss_b:2.22e-08, Loss_0:1.87e-08 # Valid:6.92e-08, RL2:2.14e-03
# Iter 13500 Time:3.7e+03 # Loss:4.77e-08, Loss_r:8.81e-09, Loss_b:2.05e-08, Loss_0:1.84e-08 # Valid:6.14e-08, RL2:1.87e-03
# Iter 13600 Time:3.8e+03 # Loss:4.26e-08, Loss_r:7.82e-09, Loss_b:1.91e-08, Loss_0:1.56e-08 # Valid:5.69e-08, RL2:1.93e-03
# Iter 13700 Time:3.8e+03 # Loss:4.33e-08, Loss_r:8.24e-09, Loss_b:1.94e-08, Loss_0:1.56e-08 # Valid:5.55e-08, RL2:1.97e-03
# Iter 13800 Time:3.8e+03 # Loss:3.89e-08, Loss_r:7.65e-09, Loss_b:1.69e-08, Loss_0:1.44e-08 # Valid:5.27e-08, RL2:1.68e-03
# Iter 13900 Time:3.8e+03 # Loss:3.89e-08, Loss_r:7.49e-09, Loss_b:1.69e-08, Loss_0:1.45e-08 # Valid:4.80e-08, RL2:1.81e-03
# Iter 14000 Time:3.9e+03 # Loss:5.21e-08, Loss_r:9.86e-09, Loss_b:2.22e-08, Loss_0:2.00e-08 # Valid:5.74e-08, RL2:1.71e-03
# Adjusting learning rate of group 0 to 4.8767e-04.
# Iter 14100 Time:3.9e+03 # Loss:4.47e-08, Loss_r:7.56e-09, Loss_b:1.89e-08, Loss_0:1.83e-08 # Valid:5.30e-08, RL2:1.86e-03
# Iter 14200 Time:3.9e+03 # Loss:3.60e-08, Loss_r:6.34e-09, Loss_b:1.61e-08, Loss_0:1.36e-08 # Valid:4.84e-08, RL2:1.67e-03
# Iter 14300 Time:4.0e+03 # Loss:3.43e-08, Loss_r:6.23e-09, Loss_b:1.48e-08, Loss_0:1.33e-08 # Valid:4.25e-08, RL2:1.71e-03
# Iter 14400 Time:4.0e+03 # Loss:3.73e-08, Loss_r:6.03e-09, Loss_b:1.66e-08, Loss_0:1.46e-08 # Valid:4.49e-08, RL2:1.57e-03
# Iter 14500 Time:4.0e+03 # Loss:3.32e-08, Loss_r:5.82e-09, Loss_b:1.41e-08, Loss_0:1.33e-08 # Valid:3.94e-08, RL2:1.55e-03
# Iter 14600 Time:4.1e+03 # Loss:3.28e-08, Loss_r:6.07e-09, Loss_b:1.45e-08, Loss_0:1.23e-08 # Valid:5.18e-08, RL2:1.65e-03
# Iter 14700 Time:4.1e+03 # Loss:3.17e-08, Loss_r:6.07e-09, Loss_b:1.42e-08, Loss_0:1.15e-08 # Valid:3.86e-08, RL2:1.53e-03
# Iter 14800 Time:4.1e+03 # Loss:2.74e-08, Loss_r:5.29e-09, Loss_b:1.15e-08, Loss_0:1.07e-08 # Valid:3.88e-08, RL2:1.67e-03
# Iter 14900 Time:4.1e+03 # Loss:2.02e-06, Loss_r:7.18e-09, Loss_b:1.01e-06, Loss_0:9.98e-07 # Valid:2.41e-06, RL2:1.40e-02
# Iter 15000 Time:4.2e+03 # Loss:2.72e-08, Loss_r:5.44e-09, Loss_b:1.21e-08, Loss_0:9.66e-09 # Valid:3.85e-08, RL2:1.49e-03
# Adjusting learning rate of group 0 to 4.6329e-04.
# Iter 15100 Time:4.2e+03 # Loss:2.58e-08, Loss_r:5.37e-09, Loss_b:1.12e-08, Loss_0:9.31e-09 # Valid:3.56e-08, RL2:1.50e-03
# Iter 15200 Time:4.2e+03 # Loss:2.64e-08, Loss_r:5.00e-09, Loss_b:1.22e-08, Loss_0:9.22e-09 # Valid:3.34e-08, RL2:1.46e-03
# Iter 15300 Time:4.3e+03 # Loss:2.73e-08, Loss_r:4.82e-09, Loss_b:1.21e-08, Loss_0:1.04e-08 # Valid:3.35e-08, RL2:1.42e-03
# Iter 15400 Time:4.3e+03 # Loss:2.98e-08, Loss_r:5.21e-09, Loss_b:1.37e-08, Loss_0:1.09e-08 # Valid:3.57e-08, RL2:1.40e-03
# Iter 15500 Time:4.3e+03 # Loss:2.45e-08, Loss_r:4.81e-09, Loss_b:1.04e-08, Loss_0:9.29e-09 # Valid:3.09e-08, RL2:1.34e-03
# Iter 15600 Time:4.3e+03 # Loss:2.71e-08, Loss_r:5.13e-09, Loss_b:1.10e-08, Loss_0:1.09e-08 # Valid:3.78e-08, RL2:1.45e-03
# Iter 15700 Time:4.4e+03 # Loss:2.27e-08, Loss_r:4.88e-09, Loss_b:9.38e-09, Loss_0:8.43e-09 # Valid:3.45e-08, RL2:1.25e-03
# Iter 15800 Time:4.4e+03 # Loss:1.33e-07, Loss_r:5.02e-09, Loss_b:6.91e-08, Loss_0:5.89e-08 # Valid:1.74e-07, RL2:3.33e-03
# Iter 15900 Time:4.4e+03 # Loss:2.25e-08, Loss_r:4.21e-09, Loss_b:9.33e-09, Loss_0:8.94e-09 # Valid:3.24e-08, RL2:1.35e-03
# Iter 16000 Time:4.4e+03 # Loss:2.33e-08, Loss_r:4.17e-09, Loss_b:9.47e-09, Loss_0:9.65e-09 # Valid:3.08e-08, RL2:1.32e-03
# Adjusting learning rate of group 0 to 4.4013e-04.
# Iter 16100 Time:4.5e+03 # Loss:2.00e-07, Loss_r:4.41e-09, Loss_b:1.02e-07, Loss_0:9.29e-08 # Valid:2.80e-07, RL2:4.68e-03
# Iter 16200 Time:4.5e+03 # Loss:2.28e-08, Loss_r:3.87e-09, Loss_b:9.46e-09, Loss_0:9.49e-09 # Valid:2.99e-08, RL2:1.43e-03
# Iter 16300 Time:4.5e+03 # Loss:2.19e-08, Loss_r:4.18e-09, Loss_b:9.82e-09, Loss_0:7.91e-09 # Valid:2.76e-08, RL2:1.33e-03
# Iter 16400 Time:4.5e+03 # Loss:1.95e-08, Loss_r:3.59e-09, Loss_b:8.14e-09, Loss_0:7.75e-09 # Valid:2.54e-08, RL2:1.28e-03
# Iter 16500 Time:4.6e+03 # Loss:2.25e-08, Loss_r:3.68e-09, Loss_b:9.91e-09, Loss_0:8.94e-09 # Valid:2.58e-08, RL2:1.26e-03
# Iter 16600 Time:4.6e+03 # Loss:1.61e-07, Loss_r:3.73e-09, Loss_b:8.16e-08, Loss_0:7.54e-08 # Valid:1.93e-07, RL2:3.84e-03
# Iter 16700 Time:4.6e+03 # Loss:1.75e-08, Loss_r:3.58e-09, Loss_b:7.58e-09, Loss_0:6.39e-09 # Valid:2.33e-08, RL2:1.21e-03
# Iter 16800 Time:4.7e+03 # Loss:1.74e-08, Loss_r:3.75e-09, Loss_b:7.49e-09, Loss_0:6.13e-09 # Valid:2.15e-08, RL2:1.16e-03
# Iter 16900 Time:4.7e+03 # Loss:1.60e-08, Loss_r:3.43e-09, Loss_b:7.08e-09, Loss_0:5.51e-09 # Valid:2.24e-08, RL2:1.15e-03
# Iter 17000 Time:4.7e+03 # Loss:1.56e-08, Loss_r:3.23e-09, Loss_b:6.80e-09, Loss_0:5.58e-09 # Valid:2.17e-08, RL2:1.16e-03
# Adjusting learning rate of group 0 to 4.1812e-04.
# Iter 17100 Time:4.7e+03 # Loss:3.19e-07, Loss_r:3.95e-09, Loss_b:1.66e-07, Loss_0:1.49e-07 # Valid:1.90e-07, RL2:3.70e-03
# Iter 17200 Time:4.8e+03 # Loss:1.56e-08, Loss_r:3.40e-09, Loss_b:6.16e-09, Loss_0:6.01e-09 # Valid:1.90e-08, RL2:1.05e-03
# Iter 17300 Time:4.8e+03 # Loss:1.68e-08, Loss_r:3.17e-09, Loss_b:7.37e-09, Loss_0:6.24e-09 # Valid:2.37e-08, RL2:1.43e-03
# Iter 17400 Time:4.8e+03 # Loss:2.08e-08, Loss_r:3.63e-09, Loss_b:8.35e-09, Loss_0:8.85e-09 # Valid:2.58e-08, RL2:1.22e-03
# Iter 17500 Time:4.8e+03 # Loss:1.55e-08, Loss_r:3.02e-09, Loss_b:6.40e-09, Loss_0:6.05e-09 # Valid:1.97e-08, RL2:1.27e-03
# Iter 17600 Time:4.9e+03 # Loss:8.07e-07, Loss_r:2.82e-09, Loss_b:4.04e-07, Loss_0:4.00e-07 # Valid:1.25e-06, RL2:9.78e-03
# Iter 17700 Time:4.9e+03 # Loss:1.49e-08, Loss_r:3.08e-09, Loss_b:6.30e-09, Loss_0:5.50e-09 # Valid:1.78e-08, RL2:1.06e-03
# Iter 17800 Time:4.9e+03 # Loss:1.34e-08, Loss_r:2.75e-09, Loss_b:5.44e-09, Loss_0:5.25e-09 # Valid:1.72e-08, RL2:1.01e-03
# Iter 17900 Time:4.9e+03 # Loss:1.30e-08, Loss_r:3.02e-09, Loss_b:5.29e-09, Loss_0:4.73e-09 # Valid:1.74e-08, RL2:1.00e-03
# Iter 18000 Time:5.0e+03 # Loss:1.40e-08, Loss_r:2.81e-09, Loss_b:5.96e-09, Loss_0:5.19e-09 # Valid:1.72e-08, RL2:1.06e-03
# Adjusting learning rate of group 0 to 3.9721e-04.
# Iter 18100 Time:5.0e+03 # Loss:1.27e-08, Loss_r:2.78e-09, Loss_b:5.37e-09, Loss_0:4.53e-09 # Valid:1.91e-08, RL2:1.25e-03
# Iter 18200 Time:5.0e+03 # Loss:2.23e-07, Loss_r:3.06e-09, Loss_b:1.15e-07, Loss_0:1.04e-07 # Valid:3.31e-07, RL2:4.96e-03
# Iter 18300 Time:5.1e+03 # Loss:1.16e-08, Loss_r:2.67e-09, Loss_b:4.67e-09, Loss_0:4.30e-09 # Valid:1.39e-08, RL2:9.20e-04
# Iter 18400 Time:5.1e+03 # Loss:9.21e-08, Loss_r:2.87e-09, Loss_b:4.58e-08, Loss_0:4.34e-08 # Valid:9.61e-08, RL2:2.66e-03
# Iter 18500 Time:5.1e+03 # Loss:5.41e-08, Loss_r:2.60e-09, Loss_b:2.57e-08, Loss_0:2.58e-08 # Valid:4.49e-08, RL2:1.93e-03
# Iter 18600 Time:5.1e+03 # Loss:1.46e-07, Loss_r:2.46e-09, Loss_b:6.87e-08, Loss_0:7.52e-08 # Valid:1.68e-07, RL2:3.57e-03
# Iter 18700 Time:5.2e+03 # Loss:1.06e-08, Loss_r:2.48e-09, Loss_b:4.36e-09, Loss_0:3.75e-09 # Valid:1.29e-08, RL2:9.43e-04
# Iter 18800 Time:5.2e+03 # Loss:1.12e-08, Loss_r:2.19e-09, Loss_b:4.93e-09, Loss_0:4.10e-09 # Valid:1.32e-08, RL2:9.24e-04
# Iter 18900 Time:5.3e+03 # Loss:1.03e-08, Loss_r:2.14e-09, Loss_b:4.42e-09, Loss_0:3.77e-09 # Valid:1.34e-08, RL2:8.87e-04
# Iter 19000 Time:5.3e+03 # Loss:1.04e-08, Loss_r:2.32e-09, Loss_b:4.29e-09, Loss_0:3.77e-09 # Valid:1.33e-08, RL2:9.08e-04
# Adjusting learning rate of group 0 to 3.7735e-04.
# Iter 19100 Time:5.3e+03 # Loss:9.77e-09, Loss_r:2.27e-09, Loss_b:4.03e-09, Loss_0:3.47e-09 # Valid:1.23e-08, RL2:8.75e-04
# Iter 19200 Time:5.4e+03 # Loss:6.50e-07, Loss_r:2.53e-09, Loss_b:3.35e-07, Loss_0:3.13e-07 # Valid:8.06e-07, RL2:7.90e-03
# Iter 19300 Time:5.4e+03 # Loss:9.41e-09, Loss_r:2.11e-09, Loss_b:3.73e-09, Loss_0:3.57e-09 # Valid:1.29e-08, RL2:8.46e-04
# Iter 19400 Time:5.4e+03 # Loss:8.80e-09, Loss_r:2.06e-09, Loss_b:3.74e-09, Loss_0:2.99e-09 # Valid:1.16e-08, RL2:8.18e-04
# Iter 19500 Time:5.4e+03 # Loss:1.09e-08, Loss_r:2.05e-09, Loss_b:4.77e-09, Loss_0:4.06e-09 # Valid:1.42e-08, RL2:8.69e-04
# Iter 19600 Time:5.5e+03 # Loss:1.05e-08, Loss_r:2.19e-09, Loss_b:4.80e-09, Loss_0:3.55e-09 # Valid:1.39e-08, RL2:9.56e-04
# Iter 19700 Time:5.5e+03 # Loss:4.47e-08, Loss_r:2.22e-09, Loss_b:2.20e-08, Loss_0:2.05e-08 # Valid:5.09e-08, RL2:1.91e-03
# Iter 19800 Time:5.5e+03 # Loss:1.16e-08, Loss_r:2.02e-09, Loss_b:5.03e-09, Loss_0:4.59e-09 # Valid:1.59e-08, RL2:1.03e-03
# Iter 19900 Time:5.5e+03 # Loss:8.66e-09, Loss_r:2.07e-09, Loss_b:3.47e-09, Loss_0:3.11e-09 # Valid:1.32e-08, RL2:7.89e-04
# Iter 20000 Time:5.6e+03 # Loss:8.26e-09, Loss_r:2.05e-09, Loss_b:3.29e-09, Loss_0:2.92e-09 # Valid:1.12e-08, RL2:7.37e-04
# Adjusting learning rate of group 0 to 3.5849e-04.

# %%
np.save("./loss_logger_dict.npy", trainer.logger)
np.save("./loss_logger_valid_dict.npy", trainer.logger_valid)

# %% [markdown]
# ## 结果可视化

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size':18})

# %% [markdown]
# ### 训练的loss图

# %%
# loss图
loss_logger = np.load("./loss_logger_dict.npy", allow_pickle=True).item()

fig = plt.figure(figsize=(9, 7), dpi=64)
ax = fig.subplots()

k = 100
# ax.plot(loss_logger["iter"][::k], loss_logger["loss"][::k], label=r"$\mathcal{L}$", linewidth=3)
ax.plot(loss_logger["iter"][::k], loss_logger["loss_res"][::k], label=r"$\mathcal{L}_{r}$", linewidth=3)
ax.plot(loss_logger["iter"][::k], loss_logger["loss_bcs"][::k], label=r"$\mathcal{L}_{b}$", linewidth=3)
ax.plot(loss_logger["iter"][::k], loss_logger["loss_ics"][::k], label=r"$\mathcal{L}_{0}$", linewidth=3)
ax.set_yscale('log')
ax.set_xlabel("Iteration")
ax.set_ylabel("Loss")
ax.grid()

ax.legend(loc='upper right')

plt.tight_layout()
plt.savefig('Loss.png', dpi=100, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### 验证的loss图

# %%
loss_logger_valid = np.load("./loss_logger_valid_dict.npy", allow_pickle=True).item()

fig = plt.figure(figsize=(9, 7), dpi=64)
ax = fig.subplots()

k = 1
# ax.plot(loss_logger_valid["iter"][::k], loss_logger_valid["loss"][::k], label=r"$\mathcal{L}$", linewidth=3)
ax.plot(loss_logger_valid["iter"][::k], loss_logger_valid["loss_res"][::k], label=r"$\mathcal{L}_{r}$", linewidth=3)
ax.plot(loss_logger_valid["iter"][::k], loss_logger_valid["loss_bcs"][::k], label=r"$\mathcal{L}_{b}$", linewidth=3)
ax.plot(loss_logger_valid["iter"][::k], loss_logger_valid["loss_ics"][::k], label=r"$\mathcal{L}_{0}$", linewidth=3)
ax.set_yscale('log')
ax.set_xlabel("Iteration")
ax.set_ylabel("Loss")
ax.grid()

ax.legend(loc='upper right')

plt.tight_layout()
# plt.savefig('loss_valid.png', dpi=100, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### 验证的Relative L2 error图

# %%
# valid中记录的relative l2 error记录 第一行只经过backbone 第二行经过transformer和backbone
loss_logger_valid = np.load("./loss_logger_valid_dict.npy", allow_pickle=True).item()

fig = plt.figure(figsize=(9, 7), dpi=64)
ax = fig.subplots()

k = 1
ax.plot(loss_logger_valid["iter"][::k], loss_logger_valid["error"][::k], label=r"PINN", color='k', linewidth=3)
ax.set_yscale('log')
ax.set_xlabel("Iteration")
ax.set_ylabel("Relative error")
ax.grid()

plt.tight_layout()
plt.savefig('Relative_L2_error.png', dpi=100, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Relative L2 error (仅考虑内部点）

# %%
# 使用最好的模型
backbone = ResNet(args.backbone_layers)
state_dict = torch.load(f'{trainer.model_path}/best_model.pth')
backbone.load_state_dict(state_dict['state_dict'])
backbone.eval()
print("Iter:\t", state_dict['iter'] + 1)
print("Loss:\t", "{:.2e}".format(state_dict['best_loss']))
# Out:
# Iter:	 20000
# Loss:	 1.12e-08

# %%
def exact_sol(X):
    # 解析解
    u_star = X[:, :args.dim].mean(axis=1, keepdims=True)
    u_star = np.sin(u_star) * np.exp(- X[:, [-1]] / args.dim**2)
    return u_star

# 采样内部点
dataset = Dataset_KortewegdeVeriesHD(args.bot_top, args.T, args.dim, torch.device('cpu'))
X_res, _, _, _, _, _ = dataset.train_data(N_r=10000, N_b=0, N_0=0)
# 计算u_star u_pred
u_star = exact_sol(X_res)
u_pred = backbone(X_res)

u_star = u_star.detach().numpy()
u_pred = u_pred.detach().numpy()
#计算L2相对误差
error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)
with open("RL2.txt", 'w') as f:
    f.write(str(error_u))
print('Relative L2 error: {:.3e}'.format(error_u))
# Out:
# Relative L2 error: 7.731e-04

# %% [markdown]
# ### 可视化内部(x1, x2, 0, ..., 0)

# %%
n = 101
dim = args.dim
# 取前两维
x1 = np.linspace(-1, 1, n)
x2 = np.linspace(-1, 1, n)
x1, x2 = np.meshgrid(x1, x2)
# x3, ..., x50 = 0
x12 = np.zeros((n*n, dim))
x12[:, [0]] = x1.reshape(-1, 1)
x12[:, [1]] = x2.reshape(-1, 1)
t = np.ones((x12.shape[0], 1)) * args.T
x12 = np.concatenate([x12, t], axis=1)
x12 = torch.from_numpy(x12).float()
# 解析解和预测解
u12_star = exact_sol(x12)
u12_pred = backbone(x12)

u12_star = u12_star.detach().numpy()
u12_pred = u12_pred.detach().numpy()

u12_star = u12_star.reshape(x1.shape)
u12_pred = u12_pred.reshape(x1.shape)

# %%
fig = plt.figure(figsize=(20, 5))
axes = fig.subplots(1, 3)

cax1 = axes[0].pcolor(x1, x2, u12_star, cmap='jet')
fig.colorbar(cax1)
axes[0].set_xlabel('$x_1$')
axes[0].set_ylabel('$x_2$')
axes[0].set_title(r'Reference $u$')
axes[0].set_xlim([-1, 1])
axes[0].set_ylim([-1, 1])
axes[0].set_xticks(np.arange(-1, 1.1, 0.5))
axes[0].set_yticks(np.arange(-1, 1.1, 0.5))
axes[0].set_aspect(1./axes[0].get_data_ratio())

cax2 = axes[1].pcolor(x1, x2, u12_pred, cmap='jet')
fig.colorbar(cax2)
axes[1].set_xlabel('$x_1$')
axes[1].set_ylabel('$x_2$')
axes[1].set_title(r'Predicted $u$')
axes[1].set_xlim([-1, 1])
axes[1].set_ylim([-1, 1])
axes[1].set_xticks(np.arange(-1, 1.1, 0.5))
axes[1].set_yticks(np.arange(-1, 1.1, 0.5))
axes[1].set_aspect(1./axes[1].get_data_ratio())

cax3 = axes[2].pcolor(x1, x2, np.abs(u12_star - u12_pred), cmap='jet')
fig.colorbar(cax3)
axes[2].set_xlabel('$x_1$')
axes[2].set_ylabel('$x_2$')
axes[2].set_title('Absolute error')
axes[2].set_xlim([-1, 1])
axes[2].set_ylim([-1, 1])
axes[2].set_xticks(np.arange(-1, 1.1, 0.5))
axes[2].set_yticks(np.arange(-1, 1.1, 0.5))
axes[2].set_aspect(1./axes[2].get_data_ratio())

plt.tight_layout()
plt.savefig('Korteweg_de_Veries_HD_result.png', dpi=100, bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6.5, 5), dpi=100)
plot = ax.contourf(x1, x2, np.abs(u12_star - u12_pred), levels=16, cmap='jet')

cbar = fig.colorbar(plot)
cbar.formatter.set_powerlimits((0, 0))
cbar.update_ticks()

ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')
ax.set_xticks([-1, -0.5, 0, 0.5, 1])
ax.set_yticks([-1, -0.5, 0, 0.5, 1])
ax.set_title('Absolute error')
ax.set_aspect(1./ax.get_data_ratio())
plt.tight_layout()
plt.savefig('./Absolute_error', dpi=100)
plt.show()
