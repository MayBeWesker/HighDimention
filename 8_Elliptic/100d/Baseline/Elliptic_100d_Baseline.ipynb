# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
# Out:
# /tmp/ipykernel_1136829/82325636.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:80% !important; }</style>

# %%
import os
import shutil

import numpy as np
import time
from pyDOE import lhs
import matplotlib
import matplotlib.pyplot as plt
import scipy.io
import random

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau

# %%
import argparse
class Options_PoissonHD:
    def __init__(self):
        parser = argparse.ArgumentParser()
        parser.add_argument('--cuda', default=True, help='if you use cuda')
        
        parser.add_argument('--bot_top', type=tuple, default=(-1, 1), help='a tuple of the form (bot, top)')
        parser.add_argument('--dim', default=20, help='dimension')
        parser.add_argument('--N_r', default=2000, help='num of interior points')
        parser.add_argument('--N_b', default=2000, help='num of boundary points')
        
        parser.add_argument('--backbone_layers', type=list, default=([128]*4), help='list of nn layers of backbone')
        parser.add_argument('--backbone_lr', type=float, default=1e-3, help='initial learning rate of backbone')
        
        parser.add_argument('--gamma', type=float, default=0.7, help='gamma in lr_scheduler for Adam optimizer')
        parser.add_argument('--step_size', type=int, default=100, help='step_size of lr_scheduler for Adam optimizer')
        
        parser.add_argument('--iters_Adam', type=int, default=40000, help='iters for Adam')
        
        parser.add_argument('--lam_res', type=float, default=1, help='weight of loss_res')
        parser.add_argument('--lam_bcs', type=float, default=100, help='weight of loss_bcs')
        
        self.parser = parser

    def parse_default(self):
        args = self.parser.parse_args(args=[])
        args.device = torch.device('cuda' if args.cuda else 'cpu')
        
        # 增加网络输入输出层
        args.backbone_layers = [args.dim] + args.backbone_layers + [1]
        return args
    

args = Options_PoissonHD().parse_default()
print(args.cuda)
# Out:
# True

# %%
def save_model(state, is_best=None, save_dir=None):
    last_model = os.path.join(save_dir, 'last_model.pth')
    torch.save(state, last_model)
    if is_best:
        best_model = os.path.join(save_dir, 'best_model.pth')
        shutil.copyfile(last_model, best_model)

def seed_torch(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed) # 为了禁止hash随机化，使得实验可复现
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed) # if you are using multi-GPU.
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True
    random.seed(seed)

def grad(outputs, inputs):
    """ compute the derivative of outputs associated with inputs

    Params
    ======
    outputs: (N, 1) tensor
    inputs: (N, D) tensor
    """
    return torch.autograd.grad(outputs, inputs,
                               grad_outputs=torch.ones_like(outputs),
                               create_graph=True)

# %%
seed_torch(42)

# %% [markdown]
# ## 网络模型 (Modified ResNet / ResNet / Modified MLP / MLP)

# %%
class ModifiedResNet(nn.Module):
    def __init__(self, mlp_layers):
        super(ModifiedResNet, self).__init__()
        
        self.encoder_u = nn.Sequential()
        self.encoder_u.add_module('fc_u', nn.Linear(mlp_layers[0], mlp_layers[1], bias=True))
        self.encoder_u.add_module('act_u', nn.Tanh())
        
        self.encoder_v = nn.Sequential()
        self.encoder_v.add_module('fc_v', nn.Linear(mlp_layers[0], mlp_layers[1], bias=True))
        self.encoder_v.add_module('act_v', nn.Tanh())
        
        self.model = nn.Sequential()
        
        first_layer = nn.Sequential()
        first_layer.add_module(f'fc0', nn.Linear(mlp_layers[0], mlp_layers[1], bias=True))
        first_layer.add_module(f'act0', nn.Tanh())
        self.model.add_module(f'first', first_layer)
        
        for i in range(1, len(mlp_layers)-2):
            block = nn.Sequential()
            block.add_module(f'fc{i}_0', nn.Linear(mlp_layers[i], mlp_layers[i+1], bias=True))
            block.add_module(f'act{i}_0', nn.Tanh())
            block.add_module(f'fc{i}_1', nn.Linear(mlp_layers[i], mlp_layers[i+1], bias=True))
            block.add_module(f'act{i}_1', nn.Tanh())
            self.model.add_module(f'block{i}', block)

        last_layer = nn.Sequential()
        last_layer.add_module(f'fc{len(mlp_layers)-2}', nn.Linear(mlp_layers[-2], mlp_layers[-1], bias=False))
        self.model.add_module(f'last', last_layer)
        
#         for param in self.parameters():
#             if len(param.shape) > 1:
#                 nn.init.kaiming_normal_(param)
    
    def forward(self, X):
        u = self.encoder_u(X)
        v = self.encoder_v(X)
        
        X = self.model[0](X)
        for i_block in range(1, len(self.model) - 1):
            X_ = self.model[i_block](X)
            X = X + X_
            X = X / 2.
            X = (1 - X) * u + X * v
        return self.model[-1](X)

# %%
class ResNet(nn.Module):
    def __init__(self, mlp_layers):
        super(ResNet, self).__init__()
        
        self.model = nn.Sequential()
        
        first_layer = nn.Sequential()
        first_layer.add_module(f'fc0', nn.Linear(mlp_layers[0], mlp_layers[1], bias=True))
        first_layer.add_module(f'act0', nn.Tanh())
        self.model.add_module(f'first', first_layer)
        
        for i in range(1, len(mlp_layers)-2):
            block = nn.Sequential()
            block.add_module(f'fc{i}_0', nn.Linear(mlp_layers[i], mlp_layers[i+1], bias=True))
            block.add_module(f'act{i}_0', nn.Tanh())
            block.add_module(f'fc{i}_1', nn.Linear(mlp_layers[i], mlp_layers[i+1], bias=True))
            block.add_module(f'act{i}_1', nn.Tanh())
            self.model.add_module(f'block{i}', block)

        last_layer = nn.Sequential()
        last_layer.add_module(f'fc{len(mlp_layers)-2}', nn.Linear(mlp_layers[-2], mlp_layers[-1], bias=False))
        self.model.add_module(f'last', last_layer)
        
#         for param in self.parameters():
#             if len(param.shape) > 1:
#                 nn.init.kaiming_normal_(param)
    
    def forward(self, X):
        X = self.model[0](X)
        for i_block in range(1, len(self.model) - 1):
            X_ = self.model[i_block](X)
            X = X_ + X
        return self.model[-1](X)

# %%
class ModifiedMLP(nn.Module):
    def __init__(self, mlp_layers):
        super(ModifiedMLP, self).__init__()
        
        self.encoder_u = nn.Sequential()
        self.encoder_u.add_module('fc_u', nn.Linear(mlp_layers[0], mlp_layers[1], bias=True))
        self.encoder_u.add_module('act_u', nn.Tanh())
        
        self.encoder_v = nn.Sequential()
        self.encoder_v.add_module('fc_v', nn.Linear(mlp_layers[0], mlp_layers[1], bias=True))
        self.encoder_v.add_module('act_v', nn.Tanh())
        
        self.model = nn.Sequential()
        for i in range(len(mlp_layers)-2):
            layer = nn.Sequential()
            layer.add_module(f'fc{i}', nn.Linear(mlp_layers[i], mlp_layers[i+1], bias=True))
            layer.add_module(f'act{i}', nn.Tanh())
            self.model.add_module(f'layer{i}', layer)

        last_layer = nn.Sequential()
        last_layer.add_module(f'fc{len(mlp_layers)-2}', nn.Linear(mlp_layers[-2], mlp_layers[-1], bias=False))
        self.model.add_module(f'layer{len(mlp_layers)-2}', last_layer)
        
#         for param in self.parameters():
#             if len(param.shape) > 1:
#                 nn.init.kaiming_normal_(param)
    
    def forward(self, X):
        u = self.encoder_u(X)
        v = self.encoder_v(X)
        
        for i in range(len(self.model) - 1):
            X = self.model[i](X)
            X = X / 2.
            X = (1 - X) * u + X * v
        return self.model[-1](X)

# %%
class MLP(nn.Module):
    def __init__(self, mlp_layers):
        super(MLP, self).__init__()
        
        self.model = nn.Sequential()
        for i in range(len(mlp_layers)-2):
            layer = nn.Sequential()
            layer.add_module(f'fc{i}', nn.Linear(mlp_layers[i], mlp_layers[i+1], bias=True))
            layer.add_module(f'act{i}', nn.Tanh())
            self.model.add_module(f'layer{i}', layer)

        last_layer = nn.Sequential()
        last_layer.add_module(f'fc{len(mlp_layers)-2}', nn.Linear(mlp_layers[-2], mlp_layers[-1], bias=False))
        self.model.add_module(f'layer{len(mlp_layers)-2}', last_layer)
        
#         for param in self.parameters():
#             if len(param.shape) > 1:
#                 nn.init.kaiming_normal_(param)
    
    def forward(self, X):
        return self.model(X)

# %%
backbone = ResNet(args.backbone_layers)
backbone = backbone.to(args.device)
args.backbone = backbone
print(args.backbone)
# Out:
# ResNet(
#   (model): Sequential(
#     (first): Sequential(
#       (fc0): Linear(in_features=20, out_features=128, bias=True)
#       (act0): Tanh()
#     )
#     (block1): Sequential(
#       (fc1_0): Linear(in_features=128, out_features=128, bias=True)
#       (act1_0): Tanh()
#       (fc1_1): Linear(in_features=128, out_features=128, bias=True)
#       (act1_1): Tanh()
#     )
#     (block2): Sequential(
#       (fc2_0): Linear(in_features=128, out_features=128, bias=True)
#       (act2_0): Tanh()
#       (fc2_1): Linear(in_features=128, out_features=128, bias=True)
#       (act2_1): Tanh()
#     )
#     (block3): Sequential(
#       (fc3_0): Linear(in_features=128, out_features=128, bias=True)
#       (act3_0): Tanh()
#       (fc3_1): Linear(in_features=128, out_features=128, bias=True)
#       (act3_1): Tanh()
#     )
#     (last): Sequential(
#       (fc4): Linear(in_features=128, out_features=1, bias=False)
#     )
#   )
# )

# %% [markdown]
# ## 数据集生成

# %%
class Dataset_PoissonHD:
    def __init__(self, bot_top, dim, device, N_max=100000):
        """
        bot_top: 空间的上下界 默认是(-1,1)
        N_max: 原始的总样本点数 例如interior(N_r) 从N_max中随机采样N_r个点作为初始点
        """
        self.bot, self.top = bot_top
        self.dim = dim
        self.device = device
        self.N_max = N_max
    
    def train_data(self, N_r, N_b):
        """训练点采样"""
        X_res = self.interior(N_r).to(self.device)
        X_bcs = self.boundary(N_b).to(self.device)
        f_res = self.func_res(X_res).to(self.device)
        u_bcs = self.func_bcs(X_bcs).to(self.device)
        
        return X_res, X_bcs, f_res, u_bcs
    
    def interior(self, N_r):
        """内部点采样"""
        X_res = torch.Tensor(self.N_max, self.dim).normal_(0, 1)
        X_res /= torch.norm(X_res, p=2, dim=1, keepdim=True)
        X_res *= torch.Tensor(self.N_max, self.dim).uniform_(-1, 1)
        
        idx = torch.randperm(self.N_max)
        idx = idx[:N_r]
        
        X_res = X_res[idx]
        return X_res
    
    def boundary(self, N_b):
        """边界点采样"""
        X_bcs = torch.Tensor(self.N_max, self.dim).normal_(0, 1)
        X_bcs /= torch.norm(X_bcs, p=2, dim=1, keepdim=True)

        idx = torch.randperm(self.N_max)
        idx = idx[:N_b]
        
        X_bcs = X_bcs[idx]
        return X_bcs
    
    def func_res(self, X_res):
        """控制方程右端项"""
        X_res.requires_grad_(True)
        u = torch.sin(torch.pi/2 * (1 - (X_res**2).sum(axis=1, keepdims=True)**0.5)**2.5)
        
        f = torch.zeros(X_res.shape[0], 1).to(self.device)
        grad_u = grad(u, X_res)[0]
        for i in range(self.dim):
            f += - grad( (1 + 1/2 * (X_res**2).sum(axis=1, keepdims=True)) * grad_u[:, [i]], X_res)[0][:, [i]]
        for i in range(self.dim):
            f += grad_u[:, [i]]**2
            
        X_res.requires_grad_(False)
        f = f.detach().cpu().numpy()
        f = torch.from_numpy(f).float().to(self.device)
        return f
    
    def func_bcs(self, X_bcs):
        """边界条件右端项"""
        u_bcs = torch.zeros(X_bcs.shape[0], 1)
        return u_bcs


dataset = Dataset_PoissonHD(args.bot_top, args.dim, args.device)
args.dataset = dataset
X_res, X_bcs, f_res, u_bcs = dataset.train_data(args.N_r, args.N_b)
print(X_res.shape, X_bcs.shape, f_res.shape, u_bcs.shape)
# Out:
# torch.Size([2000, 20]) torch.Size([2000, 20]) torch.Size([2000, 1]) torch.Size([2000, 1])

# %% [markdown]
# ## 训练

# %%
class Trainer_PoissonHD:
    def __init__(self, args):
        self.args = args
        self.dim = args.dim
        self.device = args.device
        
        self.N_r = args.N_r
        self.N_b = args.N_b
        self.dataset = args.dataset
        
        self.lam_res = args.lam_res
        self.lam_bcs = args.lam_bcs
        self.gamma = args.gamma
        self.backbone = args.backbone
        
        self.model_name = self.backbone.__class__.__name__
        self.model_path = self.get_model_path()
        
        self.iters_Adam = args.iters_Adam

        # eps = np.finfo(np.float32).eps
        self.optimizer_Adam = optim.Adam(self.backbone.parameters(), lr=args.backbone_lr, betas=(0.9, 0.999))
        
        self.step_size = args.step_size#int( self.iters_stage4 / (np.log(1e-3) / np.log(self.gamma)) )
#         self.scheduler = ExponentialLR(self.optimizer_Adam, gamma=self.gamma, verbose=True)
        self.scheduler = ReduceLROnPlateau(self.optimizer_Adam, mode='min', factor=self.gamma, verbose=True)
        
        # data
        self.X_res, self.X_bcs, self.f_res, self.u_bcs = self.dataset.train_data(self.N_r, self.N_b)
        
        # Logger
        self.logger = {
            "loss": [],
            "loss_res": [],
            "loss_bcs": [],
            "iter": []
        }
        self.logger_valid = {
            "loss": [],
            "loss_res": [],
            "loss_bcs": [],
            "iter": [],
            "error": [],  # relative l2 error
        }
        
    def get_model_path(self):
        """生成保存模型的路径"""
        if not os.path.exists('models'):
            os.mkdir('models')
        
        path = os.path.join('models', self.model_name)
        if not os.path.exists(path):
            os.mkdir(path)
        
        return path
        
    def update_train_data(self):
        """更新采样点"""
        self.X_res, self.X_bcs, self.f_res, self.u_bcs = self.dataset.train_data(self.N_r, self.N_b)

    def net_u(self, X):
        return self.backbone(X)

    def net_r(self, x):
        x.requires_grad_(True)

        u = self.net_u(x)
        grad_u = grad(u, x)[0]
        u_xx = torch.zeros(u.shape).to(self.device)
        for i in range(self.dim):
            u_xx += grad(grad_u[:, [i]], x)[0][:, [i]]
            
        x.requires_grad_(True)
        u = self.net_u(x)
        
        f = torch.zeros(x.shape[0], 1).to(self.device)
        grad_u = grad(u, x)[0]
        for i in range(self.dim):
            f += - grad( (1 + 1/2 * (x**2).sum(axis=1, keepdims=True)) * grad_u[:, [i]], x)[0][:, [i]]
        for i in range(self.dim):
            f += grad_u[:, [i]]**2
        return f
    
    def compute_loss(self):
        """计算loss"""
        f_res_pred = self.net_r(self.X_res)
        self.loss_res = torch.mean((f_res_pred - self.f_res) ** 2)

        u_bcs_pred = self.net_u(self.X_bcs)
        self.loss_bcs = torch.mean((u_bcs_pred - self.u_bcs) ** 2)

        self.loss = self.lam_res * self.loss_res + self.lam_bcs * self.loss_bcs


    def log_loss(self):
        """记录当前loss至logger字典"""
        self.logger["loss"].append(self.loss.item())
        self.logger["loss_res"].append(self.loss_res.item())
        self.logger["loss_bcs"].append(self.loss_bcs.item())
        self.logger["iter"].append(self.iter + 1)

    def log_info(self):
        """保存并打印训练信息"""
        info = f'Iter {self.iter+1:5d} Time:{time.time()-self.start_time:.1e} # ' + \
               f'Loss:{self.loss.item():.2e}, Loss_r:{self.loss_res.item():.2e}, Loss_b:{self.loss_bcs.item():.2e} # ' + \
               f'Valid:{self.valid_loss_value:.2e}, RL2:{self.error_u:.2e}'
        with open("train_info.txt", 'a') as f:
            f.write(info + '\n')
        print(info)
        
    def compute_rl2(self, X_res):
        # 计算relative l2 error
        u_star = (X_res**2).sum(axis=1, keepdims=True)**0.5
        u_star = torch.sin(torch.pi/2 * (1 - u_star)**2.5)
        u_star = u_star.detach().cpu().numpy()
        
        u_pred = self.net_u(X_res)  # 计算预测解
        u_pred = u_pred.detach().cpu().numpy()
        
        error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)  # rl2 error
        return error_u

    def valid(self):
        """验证并保存最优模型"""
        # 计算loss
        X_res, X_bcs, f_res, u_bcs = self.dataset.train_data(1000, 1000)
        self.backbone.eval()
        # 不经过transformer的loss
        f_res_pred = self.net_r(X_res)
        u_bcs_pred = self.net_u(X_bcs)
        loss_res = torch.mean((f_res_pred - f_res) ** 2)
        loss_bcs = torch.mean((u_bcs_pred - u_bcs) ** 2)
        loss = self.lam_res * loss_res + self.lam_bcs * loss_bcs
        
        # 计算relative l2 error
        self.error_u = self.compute_rl2(X_res)
        
        self.backbone.train()
        
        # 记录valid的loss和rl2 error信息
        self.logger_valid["loss"].append(loss.item())
        self.logger_valid["loss_res"].append(loss_res.item())
        self.logger_valid["loss_bcs"].append(loss_bcs.item())
        self.logger_valid["iter"].append(self.iter + 1)
        self.logger_valid["error"].append(self.error_u)
        
        # 验证模型loss是否最优并选择保存
        self.valid_loss_value = loss.item()
        is_best = self.valid_loss_value < self.best_loss
        if is_best:
            self.best_loss = self.valid_loss_value
        state = {
            'iter': self.iter,
            'state_dict': self.backbone.state_dict(),
            'best_loss': self.best_loss
        }
        save_model(state, is_best, save_dir=self.model_path)
    
    def train(self):
        """训练"""
        self.start_time = time.time()
        self.best_loss = 1.e10
        
        self.iter = 0
        for _ in range(self.iters_Adam):
            self.optimizer_Adam.zero_grad()
            self.compute_loss()
            self.loss.backward()
            self.optimizer_Adam.step()
            self.log_loss()

            if (self.iter + 1) % 100 == 0:
                self.valid()
                self.log_info()
                self.update_train_data()

            if (self.iter + 1) % self.step_size == 0:
                self.scheduler.step(self.valid_loss_value)
            self.iter += 1
            
            
trainer = Trainer_PoissonHD(args)

# %%
trainer.train()
# Out:
# Iter   100 Time:5.4e+00 # Loss:5.48e+02, Loss_r:4.12e+02, Loss_b:1.36e+00 # Valid:5.76e+02, RL2:3.46e+00
# Iter   200 Time:1.1e+01 # Loss:3.49e+02, Loss_r:3.27e+02, Loss_b:2.20e-01 # Valid:4.19e+02, RL2:1.58e+00
# Iter   300 Time:1.6e+01 # Loss:1.84e+02, Loss_r:1.81e+02, Loss_b:2.83e-02 # Valid:3.37e+02, RL2:6.71e-01
# Iter   400 Time:2.1e+01 # Loss:8.34e+01, Loss_r:8.15e+01, Loss_b:1.92e-02 # Valid:3.32e+02, RL2:7.18e-01
# Iter   500 Time:2.6e+01 # Loss:3.64e+01, Loss_r:3.47e+01, Loss_b:1.75e-02 # Valid:3.33e+02, RL2:6.50e-01
# Iter   600 Time:3.1e+01 # Loss:1.64e+01, Loss_r:1.50e+01, Loss_b:1.38e-02 # Valid:2.89e+02, RL2:5.98e-01
# Iter   700 Time:3.6e+01 # Loss:1.02e+01, Loss_r:9.07e+00, Loss_b:1.14e-02 # Valid:2.58e+02, RL2:5.87e-01
# Iter   800 Time:4.1e+01 # Loss:7.84e+00, Loss_r:6.81e+00, Loss_b:1.03e-02 # Valid:2.43e+02, RL2:5.60e-01
# Iter   900 Time:4.6e+01 # Loss:5.22e+00, Loss_r:4.38e+00, Loss_b:8.41e-03 # Valid:1.80e+02, RL2:4.77e-01
# Iter  1000 Time:5.1e+01 # Loss:4.58e+00, Loss_r:3.82e+00, Loss_b:7.63e-03 # Valid:1.63e+02, RL2:4.58e-01
# Iter  1100 Time:5.6e+01 # Loss:3.74e+00, Loss_r:3.15e+00, Loss_b:5.98e-03 # Valid:1.53e+02, RL2:3.93e-01
# Iter  1200 Time:6.2e+01 # Loss:4.10e+00, Loss_r:3.56e+00, Loss_b:5.34e-03 # Valid:1.34e+02, RL2:3.83e-01
# Iter  1300 Time:6.7e+01 # Loss:4.33e+00, Loss_r:3.87e+00, Loss_b:4.57e-03 # Valid:7.09e+01, RL2:3.75e-01
# Iter  1400 Time:7.2e+01 # Loss:4.32e+00, Loss_r:3.95e+00, Loss_b:3.78e-03 # Valid:5.12e+01, RL2:2.94e-01
# Iter  1500 Time:7.7e+01 # Loss:3.99e+00, Loss_r:3.64e+00, Loss_b:3.43e-03 # Valid:2.89e+01, RL2:2.38e-01
# Iter  1600 Time:8.2e+01 # Loss:3.04e+00, Loss_r:2.73e+00, Loss_b:3.13e-03 # Valid:2.07e+01, RL2:2.06e-01
# Iter  1700 Time:8.7e+01 # Loss:5.46e+00, Loss_r:5.17e+00, Loss_b:2.93e-03 # Valid:2.08e+01, RL2:2.75e-01
# Iter  1800 Time:9.2e+01 # Loss:2.79e+00, Loss_r:2.51e+00, Loss_b:2.82e-03 # Valid:1.37e+01, RL2:1.85e-01
# Iter  1900 Time:9.7e+01 # Loss:2.75e+00, Loss_r:2.50e+00, Loss_b:2.46e-03 # Valid:1.39e+01, RL2:1.72e-01
# Iter  2000 Time:1.0e+02 # Loss:2.63e+00, Loss_r:2.36e+00, Loss_b:2.61e-03 # Valid:1.08e+01, RL2:1.69e-01
# Iter  2100 Time:1.1e+02 # Loss:2.30e+00, Loss_r:2.06e+00, Loss_b:2.37e-03 # Valid:1.10e+01, RL2:1.51e-01
# Iter  2200 Time:1.1e+02 # Loss:2.44e+00, Loss_r:2.21e+00, Loss_b:2.27e-03 # Valid:1.10e+01, RL2:1.61e-01
# Iter  2300 Time:1.2e+02 # Loss:2.07e+00, Loss_r:1.84e+00, Loss_b:2.31e-03 # Valid:9.15e+00, RL2:1.51e-01
# Iter  2400 Time:1.2e+02 # Loss:2.16e+00, Loss_r:1.95e+00, Loss_b:2.16e-03 # Valid:7.49e+00, RL2:1.37e-01
# Iter  2500 Time:1.3e+02 # Loss:1.94e+00, Loss_r:1.72e+00, Loss_b:2.18e-03 # Valid:8.59e+00, RL2:1.38e-01
# Iter  2600 Time:1.3e+02 # Loss:1.87e+00, Loss_r:1.68e+00, Loss_b:1.93e-03 # Valid:7.61e+00, RL2:1.30e-01
# Iter  2700 Time:1.4e+02 # Loss:1.83e+00, Loss_r:1.63e+00, Loss_b:2.00e-03 # Valid:8.16e+00, RL2:1.22e-01
# Iter  2800 Time:1.4e+02 # Loss:1.78e+00, Loss_r:1.58e+00, Loss_b:1.98e-03 # Valid:7.32e+00, RL2:1.66e-01
# Iter  2900 Time:1.5e+02 # Loss:1.79e+00, Loss_r:1.60e+00, Loss_b:1.86e-03 # Valid:7.40e+00, RL2:1.57e-01
# Iter  3000 Time:1.5e+02 # Loss:1.56e+00, Loss_r:1.37e+00, Loss_b:1.89e-03 # Valid:6.13e+00, RL2:1.32e-01
# Iter  3100 Time:1.6e+02 # Loss:1.58e+00, Loss_r:1.40e+00, Loss_b:1.80e-03 # Valid:7.11e+00, RL2:1.45e-01
# Iter  3200 Time:1.6e+02 # Loss:1.38e+00, Loss_r:1.22e+00, Loss_b:1.66e-03 # Valid:7.57e+00, RL2:1.39e-01
# Iter  3300 Time:1.7e+02 # Loss:2.79e+00, Loss_r:2.63e+00, Loss_b:1.65e-03 # Valid:7.10e+00, RL2:1.32e-01
# Iter  3400 Time:1.7e+02 # Loss:1.25e+00, Loss_r:1.09e+00, Loss_b:1.54e-03 # Valid:5.71e+00, RL2:1.35e-01
# Iter  3500 Time:1.8e+02 # Loss:1.33e+00, Loss_r:1.18e+00, Loss_b:1.52e-03 # Valid:6.04e+00, RL2:1.41e-01
# Iter  3600 Time:1.8e+02 # Loss:1.26e+00, Loss_r:1.11e+00, Loss_b:1.52e-03 # Valid:5.33e+00, RL2:1.33e-01
# Iter  3700 Time:1.9e+02 # Loss:1.20e+00, Loss_r:1.05e+00, Loss_b:1.46e-03 # Valid:6.05e+00, RL2:1.20e-01
# Iter  3800 Time:1.9e+02 # Loss:1.57e+00, Loss_r:1.43e+00, Loss_b:1.39e-03 # Valid:5.97e+00, RL2:1.57e-01
# Iter  3900 Time:2.0e+02 # Loss:1.13e+00, Loss_r:9.87e-01, Loss_b:1.39e-03 # Valid:5.22e+00, RL2:1.24e-01
# Iter  4000 Time:2.1e+02 # Loss:1.22e+00, Loss_r:1.09e+00, Loss_b:1.32e-03 # Valid:6.29e+00, RL2:1.40e-01
# Iter  4100 Time:2.1e+02 # Loss:9.60e-01, Loss_r:8.39e-01, Loss_b:1.21e-03 # Valid:4.79e+00, RL2:1.28e-01
# Iter  4200 Time:2.2e+02 # Loss:1.13e+00, Loss_r:9.98e-01, Loss_b:1.33e-03 # Valid:6.01e+00, RL2:1.02e-01
# Iter  4300 Time:2.2e+02 # Loss:9.17e-01, Loss_r:7.90e-01, Loss_b:1.26e-03 # Valid:5.08e+00, RL2:1.30e-01
# Iter  4400 Time:2.3e+02 # Loss:9.21e-01, Loss_r:7.99e-01, Loss_b:1.22e-03 # Valid:5.35e+00, RL2:1.32e-01
# Iter  4500 Time:2.3e+02 # Loss:8.27e-01, Loss_r:7.13e-01, Loss_b:1.15e-03 # Valid:4.73e+00, RL2:1.09e-01
# Iter  4600 Time:2.4e+02 # Loss:9.77e-01, Loss_r:8.61e-01, Loss_b:1.16e-03 # Valid:5.30e+00, RL2:1.24e-01
# Iter  4700 Time:2.4e+02 # Loss:8.15e-01, Loss_r:7.04e-01, Loss_b:1.10e-03 # Valid:4.75e+00, RL2:1.15e-01
# Iter  4800 Time:2.5e+02 # Loss:8.57e-01, Loss_r:7.49e-01, Loss_b:1.08e-03 # Valid:5.01e+00, RL2:1.27e-01
# Iter  4900 Time:2.5e+02 # Loss:8.07e-01, Loss_r:6.98e-01, Loss_b:1.10e-03 # Valid:4.29e+00, RL2:1.17e-01
# Iter  5000 Time:2.6e+02 # Loss:7.51e-01, Loss_r:6.42e-01, Loss_b:1.09e-03 # Valid:4.66e+00, RL2:1.19e-01
# Iter  5100 Time:2.6e+02 # Loss:1.08e+00, Loss_r:9.69e-01, Loss_b:1.11e-03 # Valid:4.96e+00, RL2:1.14e-01
# Iter  5200 Time:2.7e+02 # Loss:7.48e-01, Loss_r:6.48e-01, Loss_b:1.00e-03 # Valid:4.62e+00, RL2:1.03e-01
# Iter  5300 Time:2.7e+02 # Loss:6.60e-01, Loss_r:5.53e-01, Loss_b:1.07e-03 # Valid:4.76e+00, RL2:1.14e-01
# Iter  5400 Time:2.8e+02 # Loss:7.24e-01, Loss_r:6.25e-01, Loss_b:9.91e-04 # Valid:4.10e+00, RL2:1.17e-01
# Iter  5500 Time:2.8e+02 # Loss:8.51e-01, Loss_r:7.44e-01, Loss_b:1.06e-03 # Valid:5.33e+00, RL2:1.48e-01
# Iter  5600 Time:2.9e+02 # Loss:5.55e-01, Loss_r:4.56e-01, Loss_b:9.92e-04 # Valid:4.67e+00, RL2:1.06e-01
# Iter  5700 Time:2.9e+02 # Loss:6.58e-01, Loss_r:5.72e-01, Loss_b:8.64e-04 # Valid:4.18e+00, RL2:1.16e-01
# Iter  5800 Time:3.0e+02 # Loss:5.92e-01, Loss_r:4.99e-01, Loss_b:9.26e-04 # Valid:3.87e+00, RL2:1.12e-01
# Iter  5900 Time:3.0e+02 # Loss:5.41e-01, Loss_r:4.53e-01, Loss_b:8.86e-04 # Valid:3.62e+00, RL2:1.10e-01
# Iter  6000 Time:3.1e+02 # Loss:5.45e-01, Loss_r:4.48e-01, Loss_b:9.67e-04 # Valid:4.51e+00, RL2:1.07e-01
# Iter  6100 Time:3.1e+02 # Loss:1.16e+00, Loss_r:1.07e+00, Loss_b:9.03e-04 # Valid:4.56e+00, RL2:1.25e-01
# Iter  6200 Time:3.2e+02 # Loss:1.27e+00, Loss_r:1.18e+00, Loss_b:8.65e-04 # Valid:5.12e+00, RL2:1.47e-01
# Iter  6300 Time:3.2e+02 # Loss:4.88e-01, Loss_r:4.00e-01, Loss_b:8.76e-04 # Valid:4.08e+00, RL2:1.11e-01
# Iter  6400 Time:3.3e+02 # Loss:7.53e-01, Loss_r:6.71e-01, Loss_b:8.21e-04 # Valid:4.38e+00, RL2:9.22e-02
# Iter  6500 Time:3.3e+02 # Loss:4.66e-01, Loss_r:3.79e-01, Loss_b:8.64e-04 # Valid:4.30e+00, RL2:1.15e-01
# Iter  6600 Time:3.4e+02 # Loss:7.21e-01, Loss_r:6.35e-01, Loss_b:8.63e-04 # Valid:5.22e+00, RL2:7.27e-02
# Iter  6700 Time:3.4e+02 # Loss:4.58e-01, Loss_r:3.79e-01, Loss_b:7.99e-04 # Valid:5.02e+00, RL2:9.55e-02
# Iter  6800 Time:3.5e+02 # Loss:5.40e-01, Loss_r:4.62e-01, Loss_b:7.87e-04 # Valid:4.03e+00, RL2:1.16e-01
# Iter  6900 Time:3.6e+02 # Loss:4.80e-01, Loss_r:3.98e-01, Loss_b:8.18e-04 # Valid:3.76e+00, RL2:1.02e-01
# Iter  7000 Time:3.6e+02 # Loss:4.00e-01, Loss_r:3.19e-01, Loss_b:8.05e-04 # Valid:3.54e+00, RL2:1.01e-01
# Iter  7100 Time:3.7e+02 # Loss:4.55e-01, Loss_r:3.78e-01, Loss_b:7.72e-04 # Valid:3.89e+00, RL2:9.21e-02
# Iter  7200 Time:3.7e+02 # Loss:5.25e-01, Loss_r:4.49e-01, Loss_b:7.57e-04 # Valid:3.94e+00, RL2:1.09e-01
# Iter  7300 Time:3.8e+02 # Loss:4.04e-01, Loss_r:3.26e-01, Loss_b:7.76e-04 # Valid:3.95e+00, RL2:1.04e-01
# Iter  7400 Time:3.8e+02 # Loss:3.91e-01, Loss_r:3.12e-01, Loss_b:7.86e-04 # Valid:3.42e+00, RL2:1.15e-01
# Iter  7500 Time:3.9e+02 # Loss:3.72e-01, Loss_r:3.00e-01, Loss_b:7.20e-04 # Valid:3.55e+00, RL2:1.01e-01
# Iter  7600 Time:3.9e+02 # Loss:3.53e-01, Loss_r:2.78e-01, Loss_b:7.53e-04 # Valid:3.63e+00, RL2:9.43e-02
# Iter  7700 Time:4.0e+02 # Loss:3.58e-01, Loss_r:2.82e-01, Loss_b:7.58e-04 # Valid:3.75e+00, RL2:1.05e-01
# Iter  7800 Time:4.0e+02 # Loss:3.73e-01, Loss_r:2.93e-01, Loss_b:8.07e-04 # Valid:3.86e+00, RL2:1.03e-01
# Iter  7900 Time:4.1e+02 # Loss:3.34e-01, Loss_r:2.65e-01, Loss_b:6.87e-04 # Valid:4.18e+00, RL2:9.96e-02
# Iter  8000 Time:4.1e+02 # Loss:3.40e-01, Loss_r:2.71e-01, Loss_b:6.89e-04 # Valid:3.25e+00, RL2:1.00e-01
# Iter  8100 Time:4.2e+02 # Loss:3.19e-01, Loss_r:2.50e-01, Loss_b:6.89e-04 # Valid:3.15e+00, RL2:9.47e-02
# Iter  8200 Time:4.2e+02 # Loss:2.89e-01, Loss_r:2.25e-01, Loss_b:6.48e-04 # Valid:4.41e+00, RL2:8.82e-02
# Iter  8300 Time:4.3e+02 # Loss:3.29e-01, Loss_r:2.60e-01, Loss_b:6.87e-04 # Valid:3.25e+00, RL2:9.40e-02
# Iter  8400 Time:4.3e+02 # Loss:4.87e-01, Loss_r:4.21e-01, Loss_b:6.57e-04 # Valid:3.47e+00, RL2:7.27e-02
# Iter  8500 Time:4.4e+02 # Loss:2.79e-01, Loss_r:2.13e-01, Loss_b:6.64e-04 # Valid:3.42e+00, RL2:9.02e-02
# Iter  8600 Time:4.4e+02 # Loss:2.77e-01, Loss_r:2.17e-01, Loss_b:6.05e-04 # Valid:3.32e+00, RL2:8.17e-02
# Iter  8700 Time:4.5e+02 # Loss:3.56e-01, Loss_r:2.87e-01, Loss_b:6.90e-04 # Valid:3.38e+00, RL2:9.39e-02
# Iter  8800 Time:4.5e+02 # Loss:2.62e-01, Loss_r:2.00e-01, Loss_b:6.25e-04 # Valid:3.06e+00, RL2:8.06e-02
# Iter  8900 Time:4.6e+02 # Loss:2.62e-01, Loss_r:1.96e-01, Loss_b:6.66e-04 # Valid:3.02e+00, RL2:9.05e-02
# Iter  9000 Time:4.6e+02 # Loss:3.10e-01, Loss_r:2.41e-01, Loss_b:6.93e-04 # Valid:3.92e+00, RL2:8.17e-02
# Iter  9100 Time:4.7e+02 # Loss:2.87e-01, Loss_r:2.23e-01, Loss_b:6.46e-04 # Valid:3.26e+00, RL2:8.25e-02
# Iter  9200 Time:4.7e+02 # Loss:2.55e-01, Loss_r:1.94e-01, Loss_b:6.08e-04 # Valid:3.28e+00, RL2:7.93e-02
# Iter  9300 Time:4.8e+02 # Loss:2.59e-01, Loss_r:1.92e-01, Loss_b:6.73e-04 # Valid:3.24e+00, RL2:7.98e-02
# Iter  9400 Time:4.8e+02 # Loss:2.86e-01, Loss_r:2.23e-01, Loss_b:6.32e-04 # Valid:3.35e+00, RL2:8.51e-02
# Iter  9500 Time:4.9e+02 # Loss:2.03e+00, Loss_r:1.96e+00, Loss_b:6.20e-04 # Valid:3.25e+00, RL2:7.03e-02
# Iter  9600 Time:4.9e+02 # Loss:2.37e+00, Loss_r:2.31e+00, Loss_b:6.17e-04 # Valid:3.98e+00, RL2:6.41e-02
# Iter  9700 Time:5.0e+02 # Loss:2.72e-01, Loss_r:2.14e-01, Loss_b:5.86e-04 # Valid:3.52e+00, RL2:8.90e-02
# Iter  9800 Time:5.0e+02 # Loss:2.14e-01, Loss_r:1.55e-01, Loss_b:5.87e-04 # Valid:3.04e+00, RL2:8.16e-02
# Iter  9900 Time:5.1e+02 # Loss:2.40e-01, Loss_r:1.85e-01, Loss_b:5.46e-04 # Valid:2.70e+00, RL2:7.88e-02
# Iter 10000 Time:5.1e+02 # Loss:2.11e-01, Loss_r:1.53e-01, Loss_b:5.79e-04 # Valid:3.19e+00, RL2:8.03e-02
# Iter 10100 Time:5.2e+02 # Loss:3.21e-01, Loss_r:2.57e-01, Loss_b:6.43e-04 # Valid:3.62e+00, RL2:9.02e-02
# Iter 10200 Time:5.2e+02 # Loss:2.02e-01, Loss_r:1.43e-01, Loss_b:5.88e-04 # Valid:3.05e+00, RL2:7.33e-02
# Iter 10300 Time:5.3e+02 # Loss:2.15e-01, Loss_r:1.59e-01, Loss_b:5.60e-04 # Valid:3.23e+00, RL2:7.22e-02
# Iter 10400 Time:5.3e+02 # Loss:2.26e-01, Loss_r:1.67e-01, Loss_b:5.94e-04 # Valid:3.06e+00, RL2:7.96e-02
# Iter 10500 Time:5.4e+02 # Loss:6.29e-01, Loss_r:5.70e-01, Loss_b:5.92e-04 # Valid:3.21e+00, RL2:8.84e-02
# Iter 10600 Time:5.4e+02 # Loss:2.31e-01, Loss_r:1.78e-01, Loss_b:5.35e-04 # Valid:2.71e+00, RL2:7.72e-02
# Iter 10700 Time:5.5e+02 # Loss:1.89e-01, Loss_r:1.33e-01, Loss_b:5.55e-04 # Valid:2.77e+00, RL2:7.48e-02
# Iter 10800 Time:5.5e+02 # Loss:2.03e-01, Loss_r:1.49e-01, Loss_b:5.42e-04 # Valid:2.91e+00, RL2:7.81e-02
# Iter 10900 Time:5.6e+02 # Loss:1.90e-01, Loss_r:1.39e-01, Loss_b:5.12e-04 # Valid:2.64e+00, RL2:6.96e-02
# Iter 11000 Time:5.6e+02 # Loss:2.05e-01, Loss_r:1.53e-01, Loss_b:5.19e-04 # Valid:2.91e+00, RL2:7.69e-02
# Iter 11100 Time:5.7e+02 # Loss:4.11e-01, Loss_r:3.59e-01, Loss_b:5.18e-04 # Valid:3.09e+00, RL2:8.09e-02
# Iter 11200 Time:5.8e+02 # Loss:1.88e-01, Loss_r:1.37e-01, Loss_b:5.09e-04 # Valid:2.83e+00, RL2:7.03e-02
# Iter 11300 Time:5.8e+02 # Loss:2.01e-01, Loss_r:1.50e-01, Loss_b:5.08e-04 # Valid:2.93e+00, RL2:6.62e-02
# Iter 11400 Time:5.9e+02 # Loss:2.39e-01, Loss_r:1.85e-01, Loss_b:5.45e-04 # Valid:3.04e+00, RL2:7.78e-02
# Iter 11500 Time:5.9e+02 # Loss:1.78e-01, Loss_r:1.24e-01, Loss_b:5.37e-04 # Valid:2.95e+00, RL2:6.32e-02
# Iter 11600 Time:6.0e+02 # Loss:1.82e-01, Loss_r:1.30e-01, Loss_b:5.23e-04 # Valid:2.96e+00, RL2:6.68e-02
# Iter 11700 Time:6.0e+02 # Loss:1.84e-01, Loss_r:1.36e-01, Loss_b:4.81e-04 # Valid:2.77e+00, RL2:6.98e-02
# Iter 11800 Time:6.1e+02 # Loss:1.97e-01, Loss_r:1.41e-01, Loss_b:5.62e-04 # Valid:2.85e+00, RL2:7.18e-02
# Iter 11900 Time:6.1e+02 # Loss:1.79e-01, Loss_r:1.27e-01, Loss_b:5.26e-04 # Valid:2.65e+00, RL2:5.57e-02
# Iter 12000 Time:6.2e+02 # Loss:1.73e-01, Loss_r:1.24e-01, Loss_b:4.95e-04 # Valid:2.82e+00, RL2:6.25e-02
# Epoch 00120: reducing learning rate of group 0 to 7.0000e-04.
# Iter 12100 Time:6.2e+02 # Loss:2.29e-01, Loss_r:1.78e-01, Loss_b:5.12e-04 # Valid:2.43e+00, RL2:6.07e-02
# Iter 12200 Time:6.3e+02 # Loss:2.35e-01, Loss_r:1.86e-01, Loss_b:4.82e-04 # Valid:2.23e+00, RL2:5.65e-02
# Iter 12300 Time:6.3e+02 # Loss:2.53e-01, Loss_r:2.04e-01, Loss_b:4.93e-04 # Valid:2.19e+00, RL2:5.77e-02
# Iter 12400 Time:6.4e+02 # Loss:2.22e-01, Loss_r:1.73e-01, Loss_b:4.91e-04 # Valid:2.16e+00, RL2:5.61e-02
# Iter 12500 Time:6.4e+02 # Loss:2.02e-01, Loss_r:1.52e-01, Loss_b:4.96e-04 # Valid:2.16e+00, RL2:5.71e-02
# Iter 12600 Time:6.5e+02 # Loss:2.02e-01, Loss_r:1.54e-01, Loss_b:4.77e-04 # Valid:2.06e+00, RL2:5.32e-02
# Iter 12700 Time:6.5e+02 # Loss:2.06e-01, Loss_r:1.58e-01, Loss_b:4.82e-04 # Valid:2.06e+00, RL2:5.45e-02
# Iter 12800 Time:6.6e+02 # Loss:2.19e-01, Loss_r:1.71e-01, Loss_b:4.76e-04 # Valid:2.12e+00, RL2:5.15e-02
# Iter 12900 Time:6.6e+02 # Loss:1.74e-01, Loss_r:1.31e-01, Loss_b:4.30e-04 # Valid:2.03e+00, RL2:4.80e-02
# Iter 13000 Time:6.7e+02 # Loss:1.88e-01, Loss_r:1.41e-01, Loss_b:4.74e-04 # Valid:1.99e+00, RL2:5.22e-02
# Iter 13100 Time:6.7e+02 # Loss:1.29e+00, Loss_r:1.24e+00, Loss_b:5.06e-04 # Valid:3.62e+00, RL2:8.46e-02
# Iter 13200 Time:6.8e+02 # Loss:5.14e-01, Loss_r:4.69e-01, Loss_b:4.56e-04 # Valid:2.73e+00, RL2:3.96e-02
# Iter 13300 Time:6.8e+02 # Loss:1.61e-01, Loss_r:1.15e-01, Loss_b:4.65e-04 # Valid:2.11e+00, RL2:5.08e-02
# Iter 13400 Time:6.9e+02 # Loss:1.62e-01, Loss_r:1.18e-01, Loss_b:4.38e-04 # Valid:2.04e+00, RL2:4.66e-02
# Iter 13500 Time:6.9e+02 # Loss:1.84e-01, Loss_r:1.42e-01, Loss_b:4.13e-04 # Valid:2.00e+00, RL2:5.00e-02
# Iter 13600 Time:7.0e+02 # Loss:1.70e-01, Loss_r:1.28e-01, Loss_b:4.14e-04 # Valid:2.13e+00, RL2:4.91e-02
# Iter 13700 Time:7.0e+02 # Loss:1.72e-01, Loss_r:1.31e-01, Loss_b:4.14e-04 # Valid:1.93e+00, RL2:4.43e-02
# Iter 13800 Time:7.1e+02 # Loss:1.66e-01, Loss_r:1.22e-01, Loss_b:4.48e-04 # Valid:1.88e+00, RL2:4.85e-02
# Iter 13900 Time:7.1e+02 # Loss:1.72e-01, Loss_r:1.31e-01, Loss_b:4.04e-04 # Valid:1.84e+00, RL2:4.84e-02
# Iter 14000 Time:7.2e+02 # Loss:1.62e-01, Loss_r:1.20e-01, Loss_b:4.17e-04 # Valid:1.85e+00, RL2:4.63e-02
# Iter 14100 Time:7.2e+02 # Loss:2.28e-01, Loss_r:1.84e-01, Loss_b:4.49e-04 # Valid:2.43e+00, RL2:4.57e-02
# Iter 14200 Time:7.3e+02 # Loss:2.34e-01, Loss_r:1.92e-01, Loss_b:4.21e-04 # Valid:1.87e+00, RL2:4.41e-02
# Iter 14300 Time:7.3e+02 # Loss:1.64e-01, Loss_r:1.22e-01, Loss_b:4.23e-04 # Valid:2.00e+00, RL2:4.69e-02
# Iter 14400 Time:7.4e+02 # Loss:1.58e-01, Loss_r:1.14e-01, Loss_b:4.38e-04 # Valid:1.93e+00, RL2:4.79e-02
# Iter 14500 Time:7.4e+02 # Loss:1.48e-01, Loss_r:1.06e-01, Loss_b:4.13e-04 # Valid:1.71e+00, RL2:4.34e-02
# Iter 14600 Time:7.5e+02 # Loss:1.53e-01, Loss_r:1.12e-01, Loss_b:4.11e-04 # Valid:1.69e+00, RL2:4.12e-02
# Iter 14700 Time:7.5e+02 # Loss:1.60e-01, Loss_r:1.19e-01, Loss_b:4.07e-04 # Valid:1.76e+00, RL2:5.02e-02
# Iter 14800 Time:7.6e+02 # Loss:1.44e-01, Loss_r:1.05e-01, Loss_b:3.88e-04 # Valid:1.89e+00, RL2:4.21e-02
# Iter 14900 Time:7.6e+02 # Loss:1.32e-01, Loss_r:9.39e-02, Loss_b:3.84e-04 # Valid:1.64e+00, RL2:3.80e-02
# Iter 15000 Time:7.7e+02 # Loss:1.43e+00, Loss_r:1.39e+00, Loss_b:3.75e-04 # Valid:3.61e+00, RL2:4.63e-02
# Iter 15100 Time:7.7e+02 # Loss:1.14e+00, Loss_r:1.09e+00, Loss_b:4.28e-04 # Valid:3.10e+00, RL2:4.62e-02
# Iter 15200 Time:7.8e+02 # Loss:1.86e-01, Loss_r:1.47e-01, Loss_b:3.88e-04 # Valid:1.87e+00, RL2:3.69e-02
# Iter 15300 Time:7.8e+02 # Loss:1.35e-01, Loss_r:9.58e-02, Loss_b:3.95e-04 # Valid:1.72e+00, RL2:4.37e-02
# Iter 15400 Time:7.9e+02 # Loss:1.43e-01, Loss_r:1.02e-01, Loss_b:4.01e-04 # Valid:1.77e+00, RL2:4.86e-02
# Iter 15500 Time:8.0e+02 # Loss:5.35e-01, Loss_r:4.96e-01, Loss_b:3.88e-04 # Valid:2.35e+00, RL2:3.68e-02
# Iter 15600 Time:8.0e+02 # Loss:1.44e-01, Loss_r:1.03e-01, Loss_b:4.07e-04 # Valid:1.76e+00, RL2:4.43e-02
# Iter 15700 Time:8.1e+02 # Loss:1.42e-01, Loss_r:1.01e-01, Loss_b:4.11e-04 # Valid:1.90e+00, RL2:3.93e-02
# Iter 15800 Time:8.1e+02 # Loss:1.22e-01, Loss_r:8.44e-02, Loss_b:3.79e-04 # Valid:1.48e+00, RL2:3.71e-02
# Iter 15900 Time:8.2e+02 # Loss:1.36e-01, Loss_r:9.64e-02, Loss_b:3.92e-04 # Valid:1.60e+00, RL2:4.45e-02
# Iter 16000 Time:8.2e+02 # Loss:1.65e+00, Loss_r:1.62e+00, Loss_b:3.89e-04 # Valid:3.63e+00, RL2:5.17e-02
# Iter 16100 Time:8.3e+02 # Loss:1.35e-01, Loss_r:9.74e-02, Loss_b:3.81e-04 # Valid:1.52e+00, RL2:3.73e-02
# Iter 16200 Time:8.3e+02 # Loss:1.39e-01, Loss_r:1.01e-01, Loss_b:3.85e-04 # Valid:1.79e+00, RL2:4.38e-02
# Iter 16300 Time:8.4e+02 # Loss:1.61e-01, Loss_r:1.25e-01, Loss_b:3.56e-04 # Valid:1.60e+00, RL2:4.03e-02
# Iter 16400 Time:8.4e+02 # Loss:2.92e+00, Loss_r:2.88e+00, Loss_b:3.87e-04 # Valid:4.84e+00, RL2:6.35e-02
# Iter 16500 Time:8.5e+02 # Loss:1.26e-01, Loss_r:8.90e-02, Loss_b:3.68e-04 # Valid:1.58e+00, RL2:4.30e-02
# Iter 16600 Time:8.5e+02 # Loss:1.44e-01, Loss_r:1.05e-01, Loss_b:3.87e-04 # Valid:1.50e+00, RL2:4.46e-02
# Iter 16700 Time:8.6e+02 # Loss:1.52e-01, Loss_r:1.12e-01, Loss_b:4.00e-04 # Valid:1.95e+00, RL2:4.39e-02
# Iter 16800 Time:8.6e+02 # Loss:2.75e-01, Loss_r:2.37e-01, Loss_b:3.72e-04 # Valid:1.78e+00, RL2:4.01e-02
# Iter 16900 Time:8.7e+02 # Loss:3.75e-01, Loss_r:3.38e-01, Loss_b:3.73e-04 # Valid:1.84e+00, RL2:4.81e-02
# Epoch 00169: reducing learning rate of group 0 to 4.9000e-04.
# Iter 17000 Time:8.7e+02 # Loss:1.59e-01, Loss_r:1.24e-01, Loss_b:3.46e-04 # Valid:1.43e+00, RL2:3.58e-02
# Iter 17100 Time:8.8e+02 # Loss:1.78e-01, Loss_r:1.41e-01, Loss_b:3.75e-04 # Valid:1.28e+00, RL2:3.57e-02
# Iter 17200 Time:8.8e+02 # Loss:1.52e-01, Loss_r:1.17e-01, Loss_b:3.42e-04 # Valid:1.44e+00, RL2:3.11e-02
# Iter 17300 Time:8.9e+02 # Loss:1.69e-01, Loss_r:1.34e-01, Loss_b:3.47e-04 # Valid:1.46e+00, RL2:3.78e-02
# Iter 17400 Time:8.9e+02 # Loss:1.60e-01, Loss_r:1.26e-01, Loss_b:3.42e-04 # Valid:1.48e+00, RL2:3.99e-02
# Iter 17500 Time:9.0e+02 # Loss:1.53e+00, Loss_r:1.50e+00, Loss_b:3.42e-04 # Valid:2.83e+00, RL2:6.58e-02
# Iter 17600 Time:9.0e+02 # Loss:1.53e-01, Loss_r:1.19e-01, Loss_b:3.44e-04 # Valid:1.33e+00, RL2:3.60e-02
# Iter 17700 Time:9.1e+02 # Loss:1.83e-01, Loss_r:1.43e-01, Loss_b:3.98e-04 # Valid:1.68e+00, RL2:4.14e-02
# Iter 17800 Time:9.1e+02 # Loss:1.77e-01, Loss_r:1.37e-01, Loss_b:4.01e-04 # Valid:1.61e+00, RL2:4.49e-02
# Iter 17900 Time:9.2e+02 # Loss:1.49e-01, Loss_r:1.11e-01, Loss_b:3.79e-04 # Valid:1.36e+00, RL2:4.11e-02
# Iter 18000 Time:9.2e+02 # Loss:1.56e-01, Loss_r:1.24e-01, Loss_b:3.21e-04 # Valid:1.43e+00, RL2:3.52e-02
# Iter 18100 Time:9.3e+02 # Loss:1.45e-01, Loss_r:1.11e-01, Loss_b:3.39e-04 # Valid:1.77e+00, RL2:3.50e-02
# Iter 18200 Time:9.3e+02 # Loss:1.60e+00, Loss_r:1.56e+00, Loss_b:3.50e-04 # Valid:2.61e+00, RL2:7.24e-02
# Epoch 00182: reducing learning rate of group 0 to 3.4300e-04.
# Iter 18300 Time:9.4e+02 # Loss:1.92e-01, Loss_r:1.60e-01, Loss_b:3.28e-04 # Valid:1.18e+00, RL2:3.35e-02
# Iter 18400 Time:9.4e+02 # Loss:1.95e-01, Loss_r:1.61e-01, Loss_b:3.41e-04 # Valid:1.31e+00, RL2:3.51e-02
# Iter 18500 Time:9.5e+02 # Loss:1.93e-01, Loss_r:1.57e-01, Loss_b:3.56e-04 # Valid:1.28e+00, RL2:3.37e-02
# Iter 18600 Time:9.5e+02 # Loss:1.66e-01, Loss_r:1.33e-01, Loss_b:3.32e-04 # Valid:1.39e+00, RL2:3.10e-02
# Iter 18700 Time:9.6e+02 # Loss:2.83e-01, Loss_r:2.47e-01, Loss_b:3.61e-04 # Valid:1.41e+00, RL2:3.90e-02
# Iter 18800 Time:9.6e+02 # Loss:6.08e-01, Loss_r:5.73e-01, Loss_b:3.49e-04 # Valid:1.42e+00, RL2:3.68e-02
# Iter 18900 Time:9.7e+02 # Loss:2.75e-01, Loss_r:2.41e-01, Loss_b:3.42e-04 # Valid:1.36e+00, RL2:4.20e-02
# Iter 19000 Time:9.7e+02 # Loss:1.57e-01, Loss_r:1.24e-01, Loss_b:3.26e-04 # Valid:1.06e+00, RL2:3.31e-02
# Iter 19100 Time:9.8e+02 # Loss:1.48e-01, Loss_r:1.16e-01, Loss_b:3.16e-04 # Valid:1.04e+00, RL2:3.30e-02
# Iter 19200 Time:9.8e+02 # Loss:1.77e-01, Loss_r:1.46e-01, Loss_b:3.04e-04 # Valid:1.01e+00, RL2:3.40e-02
# Iter 19300 Time:9.9e+02 # Loss:1.44e-01, Loss_r:1.14e-01, Loss_b:3.06e-04 # Valid:1.04e+00, RL2:2.79e-02
# Iter 19400 Time:1.0e+03 # Loss:1.48e-01, Loss_r:1.17e-01, Loss_b:3.06e-04 # Valid:1.23e+00, RL2:3.03e-02
# Iter 19500 Time:1.0e+03 # Loss:2.08e-01, Loss_r:1.78e-01, Loss_b:3.03e-04 # Valid:1.04e+00, RL2:2.87e-02
# Iter 19600 Time:1.0e+03 # Loss:1.54e-01, Loss_r:1.21e-01, Loss_b:3.30e-04 # Valid:1.11e+00, RL2:3.57e-02
# Iter 19700 Time:1.0e+03 # Loss:1.79e-01, Loss_r:1.47e-01, Loss_b:3.17e-04 # Valid:1.23e+00, RL2:3.35e-02
# Iter 19800 Time:1.0e+03 # Loss:1.46e-01, Loss_r:1.15e-01, Loss_b:3.13e-04 # Valid:1.12e+00, RL2:3.47e-02
# Iter 19900 Time:1.0e+03 # Loss:2.61e-01, Loss_r:2.31e-01, Loss_b:2.99e-04 # Valid:1.02e+00, RL2:3.27e-02
# Iter 20000 Time:1.0e+03 # Loss:1.92e-01, Loss_r:1.63e-01, Loss_b:2.96e-04 # Valid:1.11e+00, RL2:3.17e-02
# Iter 20100 Time:1.0e+03 # Loss:1.38e-01, Loss_r:1.07e-01, Loss_b:3.07e-04 # Valid:1.00e+00, RL2:3.18e-02
# Iter 20200 Time:1.0e+03 # Loss:1.32e-01, Loss_r:1.01e-01, Loss_b:3.07e-04 # Valid:9.42e-01, RL2:3.37e-02
# Iter 20300 Time:1.0e+03 # Loss:7.23e-01, Loss_r:6.94e-01, Loss_b:2.92e-04 # Valid:1.76e+00, RL2:3.56e-02
# Iter 20400 Time:1.0e+03 # Loss:1.49e-01, Loss_r:1.18e-01, Loss_b:3.10e-04 # Valid:1.08e+00, RL2:3.38e-02
# Iter 20500 Time:1.1e+03 # Loss:2.10e-01, Loss_r:1.81e-01, Loss_b:2.94e-04 # Valid:1.40e+00, RL2:3.70e-02
# Iter 20600 Time:1.1e+03 # Loss:1.31e-01, Loss_r:9.96e-02, Loss_b:3.13e-04 # Valid:8.69e-01, RL2:2.87e-02
# Iter 20700 Time:1.1e+03 # Loss:1.28e-01, Loss_r:9.93e-02, Loss_b:2.89e-04 # Valid:8.85e-01, RL2:3.02e-02
# Iter 20800 Time:1.1e+03 # Loss:1.06e+00, Loss_r:1.03e+00, Loss_b:2.92e-04 # Valid:1.48e+00, RL2:3.54e-02
# Iter 20900 Time:1.1e+03 # Loss:2.49e-01, Loss_r:2.20e-01, Loss_b:2.89e-04 # Valid:1.01e+00, RL2:2.55e-02
# Iter 21000 Time:1.1e+03 # Loss:1.38e-01, Loss_r:1.10e-01, Loss_b:2.82e-04 # Valid:8.42e-01, RL2:2.86e-02
# Iter 21100 Time:1.1e+03 # Loss:1.39e-01, Loss_r:1.11e-01, Loss_b:2.84e-04 # Valid:9.31e-01, RL2:3.23e-02
# Iter 21200 Time:1.1e+03 # Loss:1.23e-01, Loss_r:9.45e-02, Loss_b:2.82e-04 # Valid:8.98e-01, RL2:3.12e-02
# Iter 21300 Time:1.1e+03 # Loss:1.39e-01, Loss_r:1.07e-01, Loss_b:3.18e-04 # Valid:9.45e-01, RL2:3.03e-02
# Iter 21400 Time:1.1e+03 # Loss:8.34e-01, Loss_r:8.05e-01, Loss_b:2.92e-04 # Valid:1.48e+00, RL2:5.19e-02
# Iter 21500 Time:1.1e+03 # Loss:1.29e-01, Loss_r:9.92e-02, Loss_b:3.00e-04 # Valid:9.90e-01, RL2:2.77e-02
# Iter 21600 Time:1.1e+03 # Loss:1.31e-01, Loss_r:1.04e-01, Loss_b:2.74e-04 # Valid:1.05e+00, RL2:2.98e-02
# Iter 21700 Time:1.1e+03 # Loss:1.62e-01, Loss_r:1.36e-01, Loss_b:2.59e-04 # Valid:9.18e-01, RL2:2.63e-02
# Iter 21800 Time:1.1e+03 # Loss:1.31e-01, Loss_r:1.04e-01, Loss_b:2.71e-04 # Valid:8.47e-01, RL2:2.91e-02
# Iter 21900 Time:1.1e+03 # Loss:1.20e-01, Loss_r:9.39e-02, Loss_b:2.65e-04 # Valid:8.23e-01, RL2:2.78e-02
# Iter 22000 Time:1.1e+03 # Loss:1.25e-01, Loss_r:9.71e-02, Loss_b:2.79e-04 # Valid:8.46e-01, RL2:3.28e-02
# Iter 22100 Time:1.1e+03 # Loss:1.17e-01, Loss_r:8.95e-02, Loss_b:2.73e-04 # Valid:1.10e+00, RL2:2.99e-02
# Iter 22200 Time:1.1e+03 # Loss:1.26e-01, Loss_r:9.82e-02, Loss_b:2.75e-04 # Valid:8.45e-01, RL2:3.04e-02
# Iter 22300 Time:1.1e+03 # Loss:1.27e-01, Loss_r:9.95e-02, Loss_b:2.79e-04 # Valid:1.00e+00, RL2:3.08e-02
# Iter 22400 Time:1.1e+03 # Loss:1.25e-01, Loss_r:9.74e-02, Loss_b:2.76e-04 # Valid:8.46e-01, RL2:3.07e-02
# Iter 22500 Time:1.2e+03 # Loss:1.21e-01, Loss_r:9.43e-02, Loss_b:2.70e-04 # Valid:7.21e-01, RL2:3.04e-02
# Iter 22600 Time:1.2e+03 # Loss:1.29e-01, Loss_r:1.02e-01, Loss_b:2.68e-04 # Valid:9.27e-01, RL2:3.33e-02
# Iter 22700 Time:1.2e+03 # Loss:1.15e-01, Loss_r:8.84e-02, Loss_b:2.69e-04 # Valid:8.27e-01, RL2:2.93e-02
# Iter 22800 Time:1.2e+03 # Loss:1.23e-01, Loss_r:9.43e-02, Loss_b:2.84e-04 # Valid:8.03e-01, RL2:3.37e-02
# Iter 22900 Time:1.2e+03 # Loss:1.36e-01, Loss_r:1.07e-01, Loss_b:2.90e-04 # Valid:9.08e-01, RL2:3.50e-02
# Iter 23000 Time:1.2e+03 # Loss:1.19e-01, Loss_r:9.21e-02, Loss_b:2.66e-04 # Valid:7.75e-01, RL2:3.26e-02
# Iter 23100 Time:1.2e+03 # Loss:1.25e-01, Loss_r:9.81e-02, Loss_b:2.66e-04 # Valid:7.18e-01, RL2:3.20e-02
# Iter 23200 Time:1.2e+03 # Loss:1.22e-01, Loss_r:9.54e-02, Loss_b:2.70e-04 # Valid:7.93e-01, RL2:2.89e-02
# Iter 23300 Time:1.2e+03 # Loss:1.20e-01, Loss_r:9.51e-02, Loss_b:2.50e-04 # Valid:8.29e-01, RL2:2.94e-02
# Iter 23400 Time:1.2e+03 # Loss:1.48e-01, Loss_r:1.19e-01, Loss_b:2.97e-04 # Valid:9.99e-01, RL2:4.00e-02
# Iter 23500 Time:1.2e+03 # Loss:1.32e-01, Loss_r:1.05e-01, Loss_b:2.73e-04 # Valid:8.71e-01, RL2:3.46e-02
# Iter 23600 Time:1.2e+03 # Loss:1.16e-01, Loss_r:8.82e-02, Loss_b:2.81e-04 # Valid:8.25e-01, RL2:3.48e-02
# Iter 23700 Time:1.2e+03 # Loss:1.15e-01, Loss_r:8.81e-02, Loss_b:2.67e-04 # Valid:7.71e-01, RL2:3.45e-02
# Iter 23800 Time:1.2e+03 # Loss:2.03e-01, Loss_r:1.76e-01, Loss_b:2.64e-04 # Valid:7.83e-01, RL2:2.72e-02
# Iter 23900 Time:1.2e+03 # Loss:1.07e-01, Loss_r:8.17e-02, Loss_b:2.55e-04 # Valid:9.94e-01, RL2:2.91e-02
# Iter 24000 Time:1.2e+03 # Loss:1.29e-01, Loss_r:1.03e-01, Loss_b:2.55e-04 # Valid:7.63e-01, RL2:3.07e-02
# Iter 24100 Time:1.2e+03 # Loss:1.41e-01, Loss_r:1.14e-01, Loss_b:2.62e-04 # Valid:7.81e-01, RL2:3.69e-02
# Iter 24200 Time:1.2e+03 # Loss:1.05e-01, Loss_r:7.99e-02, Loss_b:2.48e-04 # Valid:7.62e-01, RL2:3.33e-02
# Epoch 00242: reducing learning rate of group 0 to 2.4010e-04.
# Iter 24300 Time:1.2e+03 # Loss:1.44e-01, Loss_r:1.19e-01, Loss_b:2.51e-04 # Valid:7.10e-01, RL2:3.07e-02
# Iter 24400 Time:1.3e+03 # Loss:1.37e-01, Loss_r:1.12e-01, Loss_b:2.51e-04 # Valid:8.06e-01, RL2:2.59e-02
# Iter 24500 Time:1.3e+03 # Loss:1.25e-01, Loss_r:9.99e-02, Loss_b:2.50e-04 # Valid:6.97e-01, RL2:2.86e-02
# Iter 24600 Time:1.3e+03 # Loss:1.20e-01, Loss_r:9.64e-02, Loss_b:2.34e-04 # Valid:6.23e-01, RL2:2.52e-02
# Iter 24700 Time:1.3e+03 # Loss:1.23e-01, Loss_r:9.78e-02, Loss_b:2.47e-04 # Valid:6.26e-01, RL2:2.81e-02
# Iter 24800 Time:1.3e+03 # Loss:1.16e-01, Loss_r:9.21e-02, Loss_b:2.37e-04 # Valid:7.60e-01, RL2:2.57e-02
# Iter 24900 Time:1.3e+03 # Loss:1.29e-01, Loss_r:1.04e-01, Loss_b:2.52e-04 # Valid:6.32e-01, RL2:2.92e-02
# Iter 25000 Time:1.3e+03 # Loss:1.27e-01, Loss_r:1.01e-01, Loss_b:2.51e-04 # Valid:7.53e-01, RL2:3.72e-02
# Iter 25100 Time:1.3e+03 # Loss:1.24e-01, Loss_r:9.91e-02, Loss_b:2.44e-04 # Valid:7.31e-01, RL2:2.74e-02
# Iter 25200 Time:1.3e+03 # Loss:1.25e-01, Loss_r:1.01e-01, Loss_b:2.39e-04 # Valid:7.40e-01, RL2:3.16e-02
# Iter 25300 Time:1.3e+03 # Loss:1.18e-01, Loss_r:9.42e-02, Loss_b:2.37e-04 # Valid:6.88e-01, RL2:2.79e-02
# Iter 25400 Time:1.3e+03 # Loss:2.28e-01, Loss_r:2.04e-01, Loss_b:2.40e-04 # Valid:6.61e-01, RL2:2.96e-02
# Iter 25500 Time:1.3e+03 # Loss:1.18e-01, Loss_r:9.60e-02, Loss_b:2.18e-04 # Valid:6.28e-01, RL2:2.83e-02
# Iter 25600 Time:1.3e+03 # Loss:1.24e-01, Loss_r:1.01e-01, Loss_b:2.26e-04 # Valid:6.08e-01, RL2:3.13e-02
# Iter 25700 Time:1.3e+03 # Loss:1.23e-01, Loss_r:9.90e-02, Loss_b:2.37e-04 # Valid:6.03e-01, RL2:3.31e-02
# Iter 25800 Time:1.3e+03 # Loss:9.09e-01, Loss_r:8.82e-01, Loss_b:2.73e-04 # Valid:1.70e+00, RL2:2.96e-02
# Iter 25900 Time:1.3e+03 # Loss:1.06e-01, Loss_r:8.37e-02, Loss_b:2.28e-04 # Valid:5.91e-01, RL2:3.12e-02
# Iter 26000 Time:1.3e+03 # Loss:1.09e-01, Loss_r:8.70e-02, Loss_b:2.21e-04 # Valid:7.21e-01, RL2:3.15e-02
# Iter 26100 Time:1.3e+03 # Loss:1.17e-01, Loss_r:9.42e-02, Loss_b:2.28e-04 # Valid:5.60e-01, RL2:3.20e-02
# Iter 26200 Time:1.3e+03 # Loss:1.25e-01, Loss_r:9.98e-02, Loss_b:2.50e-04 # Valid:6.47e-01, RL2:3.50e-02
# Iter 26300 Time:1.3e+03 # Loss:1.27e-01, Loss_r:1.05e-01, Loss_b:2.22e-04 # Valid:8.70e-01, RL2:3.06e-02
# Iter 26400 Time:1.4e+03 # Loss:1.24e-01, Loss_r:1.00e-01, Loss_b:2.40e-04 # Valid:6.25e-01, RL2:3.22e-02
# Iter 26500 Time:1.4e+03 # Loss:1.87e-01, Loss_r:1.63e-01, Loss_b:2.39e-04 # Valid:6.99e-01, RL2:3.31e-02
# Iter 26600 Time:1.4e+03 # Loss:9.79e-02, Loss_r:7.66e-02, Loss_b:2.13e-04 # Valid:6.32e-01, RL2:3.11e-02
# Iter 26700 Time:1.4e+03 # Loss:1.18e-01, Loss_r:9.60e-02, Loss_b:2.24e-04 # Valid:6.18e-01, RL2:3.39e-02
# Iter 26800 Time:1.4e+03 # Loss:1.08e-01, Loss_r:8.68e-02, Loss_b:2.17e-04 # Valid:5.33e-01, RL2:3.38e-02
# Iter 26900 Time:1.4e+03 # Loss:1.15e-01, Loss_r:9.31e-02, Loss_b:2.20e-04 # Valid:5.68e-01, RL2:2.80e-02
# Iter 27000 Time:1.4e+03 # Loss:1.11e-01, Loss_r:8.87e-02, Loss_b:2.28e-04 # Valid:5.81e-01, RL2:3.06e-02
# Iter 27100 Time:1.4e+03 # Loss:1.15e-01, Loss_r:9.21e-02, Loss_b:2.25e-04 # Valid:5.33e-01, RL2:3.08e-02
# Iter 27200 Time:1.4e+03 # Loss:1.31e-01, Loss_r:1.06e-01, Loss_b:2.54e-04 # Valid:6.27e-01, RL2:3.82e-02
# Iter 27300 Time:1.4e+03 # Loss:1.42e-01, Loss_r:1.19e-01, Loss_b:2.31e-04 # Valid:5.61e-01, RL2:2.70e-02
# Iter 27400 Time:1.4e+03 # Loss:1.13e-01, Loss_r:9.04e-02, Loss_b:2.27e-04 # Valid:6.05e-01, RL2:3.47e-02
# Iter 27500 Time:1.4e+03 # Loss:1.03e-01, Loss_r:8.07e-02, Loss_b:2.27e-04 # Valid:5.07e-01, RL2:2.84e-02
# Iter 27600 Time:1.4e+03 # Loss:3.90e-01, Loss_r:3.67e-01, Loss_b:2.28e-04 # Valid:9.65e-01, RL2:2.55e-02
# Iter 27700 Time:1.4e+03 # Loss:4.88e-01, Loss_r:4.66e-01, Loss_b:2.18e-04 # Valid:1.06e+00, RL2:2.29e-02
# Iter 27800 Time:1.4e+03 # Loss:1.08e-01, Loss_r:8.69e-02, Loss_b:2.10e-04 # Valid:5.48e-01, RL2:3.05e-02
# Iter 27900 Time:1.4e+03 # Loss:1.11e-01, Loss_r:8.83e-02, Loss_b:2.25e-04 # Valid:6.24e-01, RL2:3.44e-02
# Iter 28000 Time:1.4e+03 # Loss:1.11e-01, Loss_r:8.79e-02, Loss_b:2.32e-04 # Valid:5.73e-01, RL2:3.39e-02
# Iter 28100 Time:1.4e+03 # Loss:1.18e-01, Loss_r:9.45e-02, Loss_b:2.30e-04 # Valid:5.29e-01, RL2:2.76e-02
# Iter 28200 Time:1.4e+03 # Loss:1.00e-01, Loss_r:7.89e-02, Loss_b:2.15e-04 # Valid:5.87e-01, RL2:3.30e-02
# Iter 28300 Time:1.5e+03 # Loss:1.01e-01, Loss_r:8.02e-02, Loss_b:2.12e-04 # Valid:5.01e-01, RL2:2.95e-02
# Iter 28400 Time:1.5e+03 # Loss:1.10e-01, Loss_r:8.99e-02, Loss_b:2.05e-04 # Valid:5.82e-01, RL2:3.46e-02
# Iter 28500 Time:1.5e+03 # Loss:1.09e-01, Loss_r:8.73e-02, Loss_b:2.16e-04 # Valid:5.47e-01, RL2:3.60e-02
# Iter 28600 Time:1.5e+03 # Loss:1.16e-01, Loss_r:9.36e-02, Loss_b:2.28e-04 # Valid:5.64e-01, RL2:3.24e-02
# Iter 28700 Time:1.5e+03 # Loss:1.23e-01, Loss_r:1.01e-01, Loss_b:2.18e-04 # Valid:5.49e-01, RL2:3.08e-02
# Iter 28800 Time:1.5e+03 # Loss:1.03e-01, Loss_r:8.21e-02, Loss_b:2.10e-04 # Valid:4.53e-01, RL2:3.05e-02
# Iter 28900 Time:1.5e+03 # Loss:9.78e-02, Loss_r:7.68e-02, Loss_b:2.09e-04 # Valid:4.94e-01, RL2:2.79e-02
# Iter 29000 Time:1.5e+03 # Loss:1.08e-01, Loss_r:8.64e-02, Loss_b:2.13e-04 # Valid:5.72e-01, RL2:3.63e-02
# Iter 29100 Time:1.5e+03 # Loss:1.19e-01, Loss_r:9.61e-02, Loss_b:2.26e-04 # Valid:5.64e-01, RL2:4.22e-02
# Iter 29200 Time:1.5e+03 # Loss:9.88e-02, Loss_r:7.75e-02, Loss_b:2.13e-04 # Valid:5.30e-01, RL2:3.70e-02
# Iter 29300 Time:1.5e+03 # Loss:1.02e-01, Loss_r:8.14e-02, Loss_b:2.06e-04 # Valid:4.88e-01, RL2:3.19e-02
# Iter 29400 Time:1.5e+03 # Loss:1.13e-01, Loss_r:9.15e-02, Loss_b:2.16e-04 # Valid:4.68e-01, RL2:3.45e-02
# Iter 29500 Time:1.5e+03 # Loss:1.12e-01, Loss_r:9.10e-02, Loss_b:2.13e-04 # Valid:5.53e-01, RL2:3.41e-02
# Iter 29600 Time:1.5e+03 # Loss:9.91e-02, Loss_r:7.87e-02, Loss_b:2.04e-04 # Valid:4.87e-01, RL2:3.16e-02
# Iter 29700 Time:1.5e+03 # Loss:9.73e-02, Loss_r:7.75e-02, Loss_b:1.98e-04 # Valid:8.84e-01, RL2:2.65e-02
# Iter 29800 Time:1.5e+03 # Loss:1.04e-01, Loss_r:8.34e-02, Loss_b:2.07e-04 # Valid:5.62e-01, RL2:3.19e-02
# Iter 29900 Time:1.5e+03 # Loss:1.04e-01, Loss_r:8.38e-02, Loss_b:2.02e-04 # Valid:6.68e-01, RL2:3.35e-02
# Epoch 00299: reducing learning rate of group 0 to 1.6807e-04.
# Iter 30000 Time:1.5e+03 # Loss:1.33e-01, Loss_r:1.12e-01, Loss_b:2.10e-04 # Valid:1.11e+00, RL2:3.27e-02
# Iter 30100 Time:1.5e+03 # Loss:1.27e-01, Loss_r:1.07e-01, Loss_b:1.96e-04 # Valid:4.70e-01, RL2:2.57e-02
# Iter 30200 Time:1.5e+03 # Loss:1.16e-01, Loss_r:9.66e-02, Loss_b:1.96e-04 # Valid:5.39e-01, RL2:2.73e-02
# Iter 30300 Time:1.6e+03 # Loss:1.09e-01, Loss_r:9.04e-02, Loss_b:1.86e-04 # Valid:4.84e-01, RL2:2.75e-02
# Iter 30400 Time:1.6e+03 # Loss:1.03e-01, Loss_r:8.47e-02, Loss_b:1.80e-04 # Valid:5.44e-01, RL2:2.53e-02
# Iter 30500 Time:1.6e+03 # Loss:1.11e-01, Loss_r:9.20e-02, Loss_b:1.95e-04 # Valid:4.55e-01, RL2:3.15e-02
# Iter 30600 Time:1.6e+03 # Loss:1.20e-01, Loss_r:9.93e-02, Loss_b:2.03e-04 # Valid:5.04e-01, RL2:3.44e-02
# Iter 30700 Time:1.6e+03 # Loss:1.39e-01, Loss_r:1.16e-01, Loss_b:2.25e-04 # Valid:5.83e-01, RL2:4.51e-02
# Iter 30800 Time:1.6e+03 # Loss:1.15e-01, Loss_r:9.43e-02, Loss_b:2.04e-04 # Valid:6.21e-01, RL2:3.66e-02
# Iter 30900 Time:1.6e+03 # Loss:1.03e-01, Loss_r:8.31e-02, Loss_b:2.02e-04 # Valid:4.86e-01, RL2:3.18e-02
# Iter 31000 Time:1.6e+03 # Loss:1.05e-01, Loss_r:8.49e-02, Loss_b:2.02e-04 # Valid:5.89e-01, RL2:3.21e-02
# Epoch 00310: reducing learning rate of group 0 to 1.1765e-04.
# Iter 31100 Time:1.6e+03 # Loss:1.31e-01, Loss_r:1.12e-01, Loss_b:1.89e-04 # Valid:4.33e-01, RL2:3.12e-02
# Iter 31200 Time:1.6e+03 # Loss:1.43e-01, Loss_r:1.22e-01, Loss_b:2.10e-04 # Valid:5.83e-01, RL2:3.40e-02
# Iter 31300 Time:1.6e+03 # Loss:1.17e-01, Loss_r:9.85e-02, Loss_b:1.88e-04 # Valid:4.35e-01, RL2:3.31e-02
# Iter 31400 Time:1.6e+03 # Loss:1.57e-01, Loss_r:1.34e-01, Loss_b:2.29e-04 # Valid:5.32e-01, RL2:4.08e-02
# Iter 31500 Time:1.6e+03 # Loss:1.33e-01, Loss_r:1.12e-01, Loss_b:2.13e-04 # Valid:4.78e-01, RL2:3.91e-02
# Iter 31600 Time:1.6e+03 # Loss:1.04e-01, Loss_r:8.64e-02, Loss_b:1.80e-04 # Valid:4.39e-01, RL2:3.22e-02
# Iter 31700 Time:1.6e+03 # Loss:1.17e-01, Loss_r:9.57e-02, Loss_b:2.10e-04 # Valid:5.40e-01, RL2:3.47e-02
# Iter 31800 Time:1.6e+03 # Loss:1.18e-01, Loss_r:9.90e-02, Loss_b:1.94e-04 # Valid:4.26e-01, RL2:3.45e-02
# Iter 31900 Time:1.6e+03 # Loss:1.51e-01, Loss_r:1.27e-01, Loss_b:2.35e-04 # Valid:5.43e-01, RL2:4.77e-02
# Iter 32000 Time:1.6e+03 # Loss:2.71e-01, Loss_r:2.49e-01, Loss_b:2.18e-04 # Valid:6.68e-01, RL2:5.46e-02
# Iter 32100 Time:1.6e+03 # Loss:1.14e-01, Loss_r:9.52e-02, Loss_b:1.85e-04 # Valid:4.33e-01, RL2:3.74e-02
# Iter 32200 Time:1.7e+03 # Loss:1.06e-01, Loss_r:8.56e-02, Loss_b:2.04e-04 # Valid:6.13e-01, RL2:3.30e-02
# Iter 32300 Time:1.7e+03 # Loss:1.15e-01, Loss_r:9.68e-02, Loss_b:1.87e-04 # Valid:4.07e-01, RL2:3.64e-02
# Iter 32400 Time:1.7e+03 # Loss:1.21e-01, Loss_r:1.02e-01, Loss_b:1.95e-04 # Valid:4.03e-01, RL2:3.74e-02
# Iter 32500 Time:1.7e+03 # Loss:1.11e-01, Loss_r:9.10e-02, Loss_b:1.98e-04 # Valid:4.51e-01, RL2:3.56e-02
# Iter 32600 Time:1.7e+03 # Loss:1.10e-01, Loss_r:9.08e-02, Loss_b:1.89e-04 # Valid:3.92e-01, RL2:3.61e-02
# Iter 32700 Time:1.7e+03 # Loss:1.08e-01, Loss_r:8.83e-02, Loss_b:2.01e-04 # Valid:4.50e-01, RL2:3.60e-02
# Iter 32800 Time:1.7e+03 # Loss:1.11e-01, Loss_r:9.22e-02, Loss_b:1.89e-04 # Valid:3.68e-01, RL2:3.69e-02
# Iter 32900 Time:1.7e+03 # Loss:1.16e-01, Loss_r:9.70e-02, Loss_b:1.90e-04 # Valid:3.95e-01, RL2:3.42e-02
# Iter 33000 Time:1.7e+03 # Loss:1.07e-01, Loss_r:8.87e-02, Loss_b:1.85e-04 # Valid:4.06e-01, RL2:3.48e-02
# Iter 33100 Time:1.7e+03 # Loss:1.07e-01, Loss_r:8.78e-02, Loss_b:1.87e-04 # Valid:3.42e-01, RL2:2.84e-02
# Iter 33200 Time:1.7e+03 # Loss:1.04e-01, Loss_r:8.57e-02, Loss_b:1.86e-04 # Valid:3.89e-01, RL2:3.40e-02
# Iter 33300 Time:1.7e+03 # Loss:1.09e-01, Loss_r:9.08e-02, Loss_b:1.83e-04 # Valid:4.20e-01, RL2:2.93e-02
# Iter 33400 Time:1.7e+03 # Loss:2.13e-01, Loss_r:1.95e-01, Loss_b:1.83e-04 # Valid:6.83e-01, RL2:4.16e-02
# Iter 33500 Time:1.7e+03 # Loss:1.45e-01, Loss_r:1.25e-01, Loss_b:2.01e-04 # Valid:4.62e-01, RL2:4.28e-02
# Iter 33600 Time:1.7e+03 # Loss:1.09e-01, Loss_r:8.95e-02, Loss_b:2.00e-04 # Valid:3.67e-01, RL2:3.17e-02
# Iter 33700 Time:1.7e+03 # Loss:1.35e-01, Loss_r:1.16e-01, Loss_b:1.89e-04 # Valid:4.25e-01, RL2:3.96e-02
# Iter 33800 Time:1.7e+03 # Loss:1.17e-01, Loss_r:9.81e-02, Loss_b:1.91e-04 # Valid:4.08e-01, RL2:3.54e-02
# Iter 33900 Time:1.7e+03 # Loss:1.09e-01, Loss_r:9.00e-02, Loss_b:1.89e-04 # Valid:4.05e-01, RL2:3.66e-02
# Iter 34000 Time:1.7e+03 # Loss:1.11e-01, Loss_r:9.40e-02, Loss_b:1.74e-04 # Valid:4.46e-01, RL2:3.42e-02
# Iter 34100 Time:1.8e+03 # Loss:1.43e-01, Loss_r:1.22e-01, Loss_b:2.08e-04 # Valid:4.89e-01, RL2:3.85e-02
# Iter 34200 Time:1.8e+03 # Loss:1.75e-01, Loss_r:1.57e-01, Loss_b:1.78e-04 # Valid:4.82e-01, RL2:4.28e-02
# Epoch 00342: reducing learning rate of group 0 to 8.2354e-05.
# Iter 34300 Time:1.8e+03 # Loss:1.36e-01, Loss_r:1.18e-01, Loss_b:1.79e-04 # Valid:3.48e-01, RL2:3.54e-02
# Iter 34400 Time:1.8e+03 # Loss:1.25e-01, Loss_r:1.07e-01, Loss_b:1.82e-04 # Valid:3.77e-01, RL2:3.21e-02
# Iter 34500 Time:1.8e+03 # Loss:1.39e-01, Loss_r:1.20e-01, Loss_b:1.89e-04 # Valid:3.72e-01, RL2:3.47e-02
# Iter 34600 Time:1.8e+03 # Loss:1.61e-01, Loss_r:1.40e-01, Loss_b:2.15e-04 # Valid:4.24e-01, RL2:4.09e-02
# Iter 34700 Time:1.8e+03 # Loss:1.10e-01, Loss_r:9.20e-02, Loss_b:1.76e-04 # Valid:3.49e-01, RL2:3.58e-02
# Iter 34800 Time:1.8e+03 # Loss:1.18e-01, Loss_r:9.98e-02, Loss_b:1.84e-04 # Valid:4.30e-01, RL2:3.28e-02
# Iter 34900 Time:1.8e+03 # Loss:1.22e-01, Loss_r:1.04e-01, Loss_b:1.79e-04 # Valid:4.01e-01, RL2:3.38e-02
# Iter 35000 Time:1.8e+03 # Loss:1.20e-01, Loss_r:1.01e-01, Loss_b:1.90e-04 # Valid:3.74e-01, RL2:3.81e-02
# Iter 35100 Time:1.8e+03 # Loss:1.17e-01, Loss_r:9.86e-02, Loss_b:1.79e-04 # Valid:3.63e-01, RL2:3.22e-02
# Iter 35200 Time:1.8e+03 # Loss:1.30e-01, Loss_r:1.12e-01, Loss_b:1.78e-04 # Valid:4.07e-01, RL2:3.45e-02
# Iter 35300 Time:1.8e+03 # Loss:1.25e-01, Loss_r:1.06e-01, Loss_b:1.88e-04 # Valid:3.78e-01, RL2:3.60e-02
# Epoch 00353: reducing learning rate of group 0 to 5.7648e-05.
# Iter 35400 Time:1.8e+03 # Loss:1.41e-01, Loss_r:1.21e-01, Loss_b:1.94e-04 # Valid:3.58e-01, RL2:3.31e-02
# Iter 35500 Time:1.8e+03 # Loss:1.24e-01, Loss_r:1.05e-01, Loss_b:1.86e-04 # Valid:3.16e-01, RL2:3.10e-02
# Iter 35600 Time:1.8e+03 # Loss:1.53e-01, Loss_r:1.34e-01, Loss_b:1.90e-04 # Valid:6.13e-01, RL2:3.47e-02
# Iter 35700 Time:1.8e+03 # Loss:1.49e-01, Loss_r:1.30e-01, Loss_b:1.92e-04 # Valid:4.68e-01, RL2:3.56e-02
# Iter 35800 Time:1.8e+03 # Loss:1.17e-01, Loss_r:9.95e-02, Loss_b:1.79e-04 # Valid:3.14e-01, RL2:3.39e-02
# Iter 35900 Time:1.8e+03 # Loss:1.28e-01, Loss_r:1.10e-01, Loss_b:1.80e-04 # Valid:7.75e-01, RL2:3.20e-02
# Iter 36000 Time:1.8e+03 # Loss:1.52e-01, Loss_r:1.35e-01, Loss_b:1.72e-04 # Valid:4.06e-01, RL2:2.77e-02
# Iter 36100 Time:1.9e+03 # Loss:1.14e-01, Loss_r:9.67e-02, Loss_b:1.74e-04 # Valid:2.98e-01, RL2:3.05e-02
# Iter 36200 Time:1.9e+03 # Loss:1.23e-01, Loss_r:1.06e-01, Loss_b:1.75e-04 # Valid:3.57e-01, RL2:3.40e-02
# Iter 36300 Time:1.9e+03 # Loss:1.12e-01, Loss_r:9.46e-02, Loss_b:1.71e-04 # Valid:2.94e-01, RL2:3.07e-02
# Iter 36400 Time:1.9e+03 # Loss:1.23e-01, Loss_r:1.04e-01, Loss_b:1.82e-04 # Valid:3.19e-01, RL2:3.41e-02
# Iter 36500 Time:1.9e+03 # Loss:1.21e-01, Loss_r:1.03e-01, Loss_b:1.79e-04 # Valid:3.39e-01, RL2:3.76e-02
# Iter 36600 Time:1.9e+03 # Loss:1.12e-01, Loss_r:9.49e-02, Loss_b:1.69e-04 # Valid:2.79e-01, RL2:3.62e-02
# Iter 36700 Time:1.9e+03 # Loss:1.20e-01, Loss_r:1.02e-01, Loss_b:1.74e-04 # Valid:3.29e-01, RL2:3.65e-02
# Iter 36800 Time:1.9e+03 # Loss:1.14e-01, Loss_r:9.73e-02, Loss_b:1.64e-04 # Valid:3.71e-01, RL2:3.30e-02
# Iter 36900 Time:1.9e+03 # Loss:1.14e-01, Loss_r:9.65e-02, Loss_b:1.74e-04 # Valid:3.20e-01, RL2:3.63e-02
# Iter 37000 Time:1.9e+03 # Loss:1.06e-01, Loss_r:8.91e-02, Loss_b:1.70e-04 # Valid:4.75e-01, RL2:3.36e-02
# Iter 37100 Time:1.9e+03 # Loss:1.13e-01, Loss_r:9.62e-02, Loss_b:1.70e-04 # Valid:3.09e-01, RL2:2.71e-02
# Iter 37200 Time:1.9e+03 # Loss:1.19e-01, Loss_r:1.03e-01, Loss_b:1.63e-04 # Valid:3.03e-01, RL2:2.70e-02
# Iter 37300 Time:1.9e+03 # Loss:1.10e-01, Loss_r:9.30e-02, Loss_b:1.68e-04 # Valid:3.07e-01, RL2:3.28e-02
# Iter 37400 Time:1.9e+03 # Loss:1.12e-01, Loss_r:9.45e-02, Loss_b:1.71e-04 # Valid:2.94e-01, RL2:3.35e-02
# Iter 37500 Time:1.9e+03 # Loss:1.01e-01, Loss_r:8.53e-02, Loss_b:1.56e-04 # Valid:2.69e-01, RL2:2.50e-02
# Iter 37600 Time:1.9e+03 # Loss:1.17e-01, Loss_r:9.95e-02, Loss_b:1.77e-04 # Valid:3.23e-01, RL2:3.15e-02
# Iter 37700 Time:1.9e+03 # Loss:1.24e-01, Loss_r:1.07e-01, Loss_b:1.66e-04 # Valid:3.22e-01, RL2:3.32e-02
# Iter 37800 Time:1.9e+03 # Loss:1.32e-01, Loss_r:1.14e-01, Loss_b:1.85e-04 # Valid:4.37e-01, RL2:4.09e-02
# Iter 37900 Time:1.9e+03 # Loss:1.42e-01, Loss_r:1.25e-01, Loss_b:1.68e-04 # Valid:4.03e-01, RL2:3.56e-02
# Iter 38000 Time:2.0e+03 # Loss:1.27e-01, Loss_r:1.10e-01, Loss_b:1.75e-04 # Valid:3.24e-01, RL2:3.42e-02
# Iter 38100 Time:2.0e+03 # Loss:1.05e-01, Loss_r:8.74e-02, Loss_b:1.80e-04 # Valid:3.15e-01, RL2:3.60e-02
# Iter 38200 Time:2.0e+03 # Loss:1.77e-01, Loss_r:1.57e-01, Loss_b:2.00e-04 # Valid:3.71e-01, RL2:4.01e-02
# Iter 38300 Time:2.0e+03 # Loss:1.06e-01, Loss_r:8.96e-02, Loss_b:1.64e-04 # Valid:3.17e-01, RL2:3.71e-02
# Iter 38400 Time:2.0e+03 # Loss:1.16e-01, Loss_r:9.97e-02, Loss_b:1.66e-04 # Valid:3.16e-01, RL2:3.16e-02
# Iter 38500 Time:2.0e+03 # Loss:1.12e-01, Loss_r:9.56e-02, Loss_b:1.63e-04 # Valid:3.14e-01, RL2:2.85e-02
# Iter 38600 Time:2.0e+03 # Loss:1.31e-01, Loss_r:1.13e-01, Loss_b:1.81e-04 # Valid:3.77e-01, RL2:3.90e-02
# Epoch 00386: reducing learning rate of group 0 to 4.0354e-05.
# Iter 38700 Time:2.0e+03 # Loss:1.19e-01, Loss_r:1.03e-01, Loss_b:1.61e-04 # Valid:2.85e-01, RL2:3.51e-02
# Iter 38800 Time:2.0e+03 # Loss:1.11e-01, Loss_r:9.41e-02, Loss_b:1.66e-04 # Valid:2.56e-01, RL2:3.07e-02
# Iter 38900 Time:2.0e+03 # Loss:1.10e-01, Loss_r:9.40e-02, Loss_b:1.57e-04 # Valid:3.60e-01, RL2:2.92e-02
# Iter 39000 Time:2.0e+03 # Loss:1.21e-01, Loss_r:1.05e-01, Loss_b:1.64e-04 # Valid:3.21e-01, RL2:3.18e-02
# Iter 39100 Time:2.0e+03 # Loss:1.13e-01, Loss_r:9.64e-02, Loss_b:1.62e-04 # Valid:2.82e-01, RL2:3.04e-02
# Iter 39200 Time:2.0e+03 # Loss:1.03e-01, Loss_r:8.72e-02, Loss_b:1.55e-04 # Valid:2.76e-01, RL2:3.20e-02
# Iter 39300 Time:2.0e+03 # Loss:1.35e-01, Loss_r:1.20e-01, Loss_b:1.58e-04 # Valid:3.36e-01, RL2:3.42e-02
# Iter 39400 Time:2.0e+03 # Loss:1.20e-01, Loss_r:1.03e-01, Loss_b:1.69e-04 # Valid:2.69e-01, RL2:2.88e-02
# Iter 39500 Time:2.0e+03 # Loss:1.07e-01, Loss_r:9.18e-02, Loss_b:1.53e-04 # Valid:2.62e-01, RL2:2.59e-02
# Iter 39600 Time:2.0e+03 # Loss:1.23e-01, Loss_r:1.08e-01, Loss_b:1.57e-04 # Valid:2.87e-01, RL2:2.81e-02
# Iter 39700 Time:2.0e+03 # Loss:1.23e-01, Loss_r:1.07e-01, Loss_b:1.62e-04 # Valid:3.08e-01, RL2:2.85e-02
# Iter 39800 Time:2.0e+03 # Loss:1.29e-01, Loss_r:1.12e-01, Loss_b:1.71e-04 # Valid:3.03e-01, RL2:3.13e-02
# Iter 39900 Time:2.0e+03 # Loss:1.25e-01, Loss_r:1.08e-01, Loss_b:1.67e-04 # Valid:2.84e-01, RL2:3.07e-02
# Epoch 00399: reducing learning rate of group 0 to 2.8248e-05.
# Iter 40000 Time:2.1e+03 # Loss:1.36e-01, Loss_r:1.20e-01, Loss_b:1.68e-04 # Valid:2.51e-01, RL2:3.24e-02

# %%
np.save("./loss_logger_dict.npy", trainer.logger)
np.save("./loss_logger_valid_dict.npy", trainer.logger_valid)

# %% [markdown]
# ## 结果可视化

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size':18})

# %% [markdown]
# ### 训练的loss图

# %%
# loss图
loss_logger = np.load("./loss_logger_dict.npy", allow_pickle=True).item()

fig = plt.figure(figsize=(9, 7), dpi=64)
ax = fig.subplots()

k = 100
# ax.plot(loss_logger["iter"][::k], loss_logger["loss"][::k], label=r"$\mathcal{L}$", linewidth=3)
ax.plot(loss_logger["iter"][::k], loss_logger["loss_res"][::k], label=r"$\mathcal{L}_{r}$", linewidth=3)
ax.plot(loss_logger["iter"][::k], loss_logger["loss_bcs"][::k], label=r"$\mathcal{L}_{b}$", linewidth=3)
ax.set_yscale('log')
ax.set_xlabel("Iteration")
ax.set_ylabel("Loss")
ax.grid()

ax.legend(loc='upper right')

plt.tight_layout()
plt.savefig('Loss.png', dpi=100, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### 验证的loss图 (包括只经backbone和经过transformer和backbone的loss)

# %%
loss_logger_valid = np.load("./loss_logger_valid_dict.npy", allow_pickle=True).item()

fig = plt.figure(figsize=(9, 7), dpi=64)
ax = fig.subplots()

k = 1
# ax.plot(loss_logger_valid["iter"][::k], loss_logger_valid["loss"][::k], label=r"$\mathcal{L}$", linewidth=3)
ax.plot(loss_logger_valid["iter"][::k], loss_logger_valid["loss_res"][::k], label=r"$\mathcal{L}_{r}$", linewidth=3)
ax.plot(loss_logger_valid["iter"][::k], loss_logger_valid["loss_bcs"][::k], label=r"$\mathcal{L}_{b}$", linewidth=3)
ax.set_yscale('log')
ax.set_xlabel("Iteration")
ax.set_ylabel("Loss")
ax.grid()

ax.legend(loc='upper right')

plt.tight_layout()
# plt.savefig('loss_valid.png', dpi=100, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### 验证的Relative L2 error图 (包括只经backbone和经过transformer和backbone的rl2)

# %%
# valid中记录的relative l2 error记录 第一行只经过backbone 第二行经过transformer和backbone
loss_logger_valid = np.load("./loss_logger_valid_dict.npy", allow_pickle=True).item()

fig = plt.figure(figsize=(9, 7), dpi=64)
ax = fig.subplots()

k = 1
ax.plot(loss_logger_valid["iter"][::k], loss_logger_valid["error"][::k], label=r"PINN", color='k', linewidth=3)
ax.set_yscale('log')
ax.set_xlabel("Iteration")
ax.set_ylabel("Relative error")
ax.grid()

plt.tight_layout()
plt.savefig('Relative_L2_error.png', dpi=100, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Relative L2 error (仅考虑内部点）

# %%
# 使用最好的模型
backbone = ResNet(args.backbone_layers)
state_dict = torch.load(f'{trainer.model_path}/best_model.pth')
backbone.load_state_dict(state_dict['state_dict'])
backbone.eval()
print("Iter:\t", state_dict['iter'] + 1)
print("Loss:\t", "{:.2e}".format(state_dict['best_loss']))
# Out:
# Iter:	 40000
# Loss:	 2.51e-01

# %%
def exact_sol(X):
    # 解析解
    u_star = (X**2).sum(axis=1, keepdims=True)**0.5
    u_star = torch.sin(torch.pi/2 * (1 - u_star)**2.5)
    return u_star

# 采样内部点
dataset = Dataset_PoissonHD(args.bot_top, args.dim, torch.device('cpu'))
X_res, _, _, _ = dataset.train_data(N_r=10000, N_b=0)
# 计算u_star u_pred
u_star = exact_sol(X_res)
u_pred = backbone(X_res)

u_star = u_star.detach().numpy()
u_pred = u_pred.detach().numpy()
#计算L2相对误差
error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)
with open("RL2.txt", 'w') as f:
    f.write(str(error_u))
print('Relative L2 error: {:.3e}'.format(error_u))
# Out:
# Relative L2 error: 3.186e-02

# %% [markdown]
# ### 可视化内部(x1, x2, 0, ..., 0)

# %%
n = 101
dim = args.dim
# 取前两维
x1 = np.linspace(-1, 1, n)
x2 = np.linspace(-1, 1, n)
x1, x2 = np.meshgrid(x1, x2)
# x3, ..., x50 = 0
x12 = np.zeros((n*n, dim))
x12[:, [0]] = x1.reshape(-1, 1)
x12[:, [1]] = x2.reshape(-1, 1)
x12 = torch.from_numpy(x12).float()
# 解析解和预测解
u12_star = exact_sol(x12)
u12_pred = backbone(x12)

u12_star = u12_star.detach().numpy()
u12_pred = u12_pred.detach().numpy()

u12_star = u12_star.reshape(x1.shape)
u12_pred = u12_pred.reshape(x1.shape)

for i in range(u12_star.shape[0]):
    for j in range(u12_star.shape[1]):
        if x1[i, j]**2 + x2[i, j]**2 > 1.:
            u12_star[i, j] = np.nan
            u12_pred[i, j] = np.nan

# %%
fig = plt.figure(figsize=(20, 5))
axes = fig.subplots(1, 3)

cax1 = axes[0].pcolor(x1, x2, u12_star, cmap='jet')
fig.colorbar(cax1)
axes[0].set_xlabel('$x_1$')
axes[0].set_ylabel('$x_2$')
axes[0].set_title(r'Reference $u$')
axes[0].set_xlim([-1, 1])
axes[0].set_ylim([-1, 1])
axes[0].set_xticks(np.arange(-1, 1.1, 0.5))
axes[0].set_yticks(np.arange(-1, 1.1, 0.5))
axes[0].set_aspect(1./axes[0].get_data_ratio())

cax2 = axes[1].pcolor(x1, x2, u12_pred, cmap='jet')
fig.colorbar(cax2)
axes[1].set_xlabel('$x_1$')
axes[1].set_ylabel('$x_2$')
axes[1].set_title(r'Predicted $u$')
axes[1].set_xlim([-1, 1])
axes[1].set_ylim([-1, 1])
axes[1].set_xticks(np.arange(-1, 1.1, 0.5))
axes[1].set_yticks(np.arange(-1, 1.1, 0.5))
axes[1].set_aspect(1./axes[1].get_data_ratio())

cax3 = axes[2].pcolor(x1, x2, np.abs(u12_star - u12_pred), cmap='jet', vmax=0.07)
fig.colorbar(cax3)
axes[2].set_xlabel('$x_1$')
axes[2].set_ylabel('$x_2$')
axes[2].set_title('Absolute error')
axes[2].set_xlim([-1, 1])
axes[2].set_ylim([-1, 1])
axes[2].set_xticks(np.arange(-1, 1.1, 0.5))
axes[2].set_yticks(np.arange(-1, 1.1, 0.5))
axes[2].set_aspect(1./axes[2].get_data_ratio())

plt.tight_layout()
plt.savefig(f'Elliptic_{args.dim}d_result.png', dpi=100, bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6.5, 5), dpi=100)
plot = ax.contourf(x1, x2, np.abs(u12_star - u12_pred), levels=16, cmap='jet')

cbar = fig.colorbar(plot)
cbar.formatter.set_powerlimits((0, 0))
cbar.update_ticks()

ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')
ax.set_xticks([-1, -0.5, 0, 0.5, 1])
ax.set_yticks([-1, -0.5, 0, 0.5, 1])
ax.set_title('Absolute error')
ax.set_aspect(1./ax.get_data_ratio())
plt.tight_layout()
plt.savefig('./Absolute_error', dpi=100)
plt.show()
